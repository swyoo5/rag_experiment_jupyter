# %%
import os
import chromadb
from chromadb.utils import embedding_functions
import re
import pathlib

class ChromaVectorDB:
    """ChromaDB를 이용한 벡터 DB 관리 클래스"""
    
    # def __init__(self, embedding_model, persist_directory="./chroma_db", collection_name="Gray"):
    #     """
    #     ChromaDB 초기화
        
    #     Args:
    #         embedding_model: 임베딩 모델 (SentenceTransformer 또는 호환 래퍼)
    #         persist_directory (str): 벡터 DB가 저장될 디렉토리 경로
    #         collection_name (str): 컬렉션 이름
    #     """
    #     # 디렉토리 생성 확인
    #     os.makedirs(persist_directory, exist_ok=True)
        
    #     # 임베딩 모델 저장
    #     self.embedding_model = embedding_model
        
    #     # ChromaDB 클라이언트 설정
    #     self.client = chromadb.PersistentClient(path=persist_directory)
        
    #     # 사용자 정의 임베딩 함수 생성 - 기존 embedding_model을 활용
    #     self.embedding_function = CustomEmbeddingFunction(self.embedding_model)
        
    #     # 컬렉션 생성 또는 가져오기
    #     try:
    #         self.collection = self.client.get_collection(
    #             name=collection_name,
    #             embedding_function=self.embedding_function
    #         )
    #         print(f"기존 컬렉션 '{collection_name}'을 로드했습니다.")
    #     except Exception as e:
    #         print(f"컬렉션 로드 중 오류 발생: {e}")
    #         print(f"새 컬렉션 '{collection_name}'을 생성합니다.")
    #         self.collection = self.client.create_collection(
    #             name=collection_name,
    #             embedding_function=self.embedding_function
    #         )
    def __init__(self, embedding_model, persist_directory="./chroma_db", collection_name="Gray"):
        """
        ChromaDB 초기화
        
        Args:
            embedding_model: 임베딩 모델 (SentenceTransformer 또는 호환 래퍼)
            persist_directory (str): 벡터 DB가 저장될 디렉토리 경로
            collection_name (str): 컬렉션 이름
        """
        # 디렉토리 생성 확인
        os.makedirs(persist_directory, exist_ok=True)
        
        # 임베딩 모델 저장
        self.embedding_model = embedding_model
        
        # 기존 데이터베이스 디렉토리 확인 및 처리
        db_path = pathlib.Path(persist_directory)
        db_exists = db_path.exists() and any(db_path.iterdir())
        
        # 사용자 정의 임베딩 함수 생성 - 기존 embedding_model을 활용
        self.embedding_function = CustomEmbeddingFunction(self.embedding_model)
        
        # 만약 데이터베이스가 손상되었거나 호환성 문제가 있다면 다시 생성
        try:
            self.client = chromadb.PersistentClient(path=persist_directory)
            
            # 컬렉션 가져오기
            try:
                self.collection = self.client.get_collection(
                    name=collection_name,
                    embedding_function=self.embedding_function
                )
                print(f"기존 컬렉션 '{collection_name}'을 로드했습니다.")
            except Exception as e:
                print(f"컬렉션 로드 중 오류 발생: {e}")
                
                # 오류가 'max_seq_id' 관련 문제인지 확인
                if "max_seq_id" in str(e) or "PersistentData" in str(e):
                    print("데이터베이스 구조 호환성 문제가 발견되었습니다. 컬렉션을 재생성합니다.")
                    
                    # 기존 컬렉션 제거 시도
                    try:
                        self.client.delete_collection(name=collection_name)
                        print(f"기존 컬렉션 '{collection_name}'을 삭제했습니다.")
                    except:
                        pass
                    
                    # 새 컬렉션 생성
                    self.collection = self.client.create_collection(
                        name=collection_name,
                        embedding_function=self.embedding_function
                    )
                    print(f"새 컬렉션 '{collection_name}'을 생성했습니다.")
                else:
                    # 다른 종류의 오류면 새 컬렉션 생성
                    print(f"새 컬렉션 '{collection_name}'을 생성합니다.")
                    self.collection = self.client.create_collection(
                        name=collection_name,
                        embedding_function=self.embedding_function
                    )
                    
        except Exception as outer_e:
            print(f"치명적 오류: ChromaDB 클라이언트 초기화 실패: {outer_e}")
            print("백업 솔루션: 기존 데이터베이스를 재설정합니다.")
            
            # 데이터베이스 디렉토리가 존재하면 백업 후 재생성
            if db_exists:
                # 기존 폴더 백업 (이름 변경)
                import shutil
                import time
                
                backup_dir = f"{persist_directory}_backup_{int(time.time())}"
                try:
                    shutil.move(persist_directory, backup_dir)
                    print(f"기존 데이터베이스를 {backup_dir}로 백업했습니다.")
                except Exception as move_err:
                    print(f"백업 실패: {move_err}")
                    # 기존 폴더 삭제 시도
                    try:
                        shutil.rmtree(persist_directory)
                        print(f"기존 데이터베이스 폴더를 삭제했습니다.")
                    except Exception as rm_err:
                        print(f"폴더 삭제 실패: {rm_err}")
            
            # 폴더 재생성
            os.makedirs(persist_directory, exist_ok=True)
            
            # 클라이언트와 컬렉션 새로 생성
            self.client = chromadb.PersistentClient(path=persist_directory)
            self.collection = self.client.create_collection(
                name=collection_name,
                embedding_function=self.embedding_function
            )
            print(f"ChromaDB를 재설정하고 새 컬렉션 '{collection_name}'을 생성했습니다.")
    
    def add_documents(self, documents, metadatas=None, ids=None):
        """
        문서를 벡터 DB에 추가
        
        Args:
            documents (list): 문서 텍스트 리스트
            metadatas (list, optional): 각 문서에 대한 메타데이터 리스트
            ids (list, optional): 각 문서에 대한 고유 ID 리스트
        
        Returns:
            int: 추가된 문서 수
        """
        if ids is None:
            # 고유한 ID 생성 (timestamp + index)
            import time
            timestamp = int(time.time())
            ids = [f"doc_{timestamp}_{i}" for i in range(len(documents))]
        
        # 메타데이터가 제공되지 않은 경우 빈 딕셔너리 생성
        if metadatas is None:
            metadatas = [{} for _ in range(len(documents))]
        
        # 문서 임베딩 미리 계산 - 디버깅 용도
        # embeddings = self.embedding_model.encode(documents)
        
        # 문서 추가 (임베딩은 임베딩 함수가 자동 계산)
        self.collection.add(
            documents=documents,
            metadatas=metadatas,
            ids=ids
        )
        
        return len(documents)
    
    def load_document_file(self, file_path, chunk_size=None):
        """
        파일을 로드하여 벡터 DB에 저장
        
        Args:
            file_path (str): 로드할 파일 경로
            chunk_size (int, optional): 청크 분할 크기 (None이면 페이지 단위로 분할)
            
        Returns:
            int: 추가된 청크 수
        """
        # 파일 확장자 확인
        # _, ext = os.path.splitext(file_path)
        
        # 파일 읽기
        try:
            print(f"파일 로드 중: {file_path}")
            text_content = pathlib.Path(file_path).read_text(encoding="utf-8")
            print(f"파일 크기: {len(text_content)} 문자")
        except Exception as e:
            print(f"파일 로드 오류: {e}")
            return 0
        
        # 청크 분할 방식 결정
        chunks = []
        metadatas = []
        
        if chunk_size:
            # 지정된 청크 크기로 분할
            current_pos = 0
            while current_pos < len(text_content):
                chunk = text_content[current_pos:current_pos + chunk_size]
                chunks.append(chunk)
                metadatas.append({"source": file_path, "chunk_index": len(chunks)})
                current_pos += chunk_size
            
            print(f"크기 기반 분할: {len(chunks)}개 청크 생성")
        else:
            # 페이지 단위 분할 (#### Page X 패턴 사용)
            page_pattern = r'(####\s+Page\s+\d+\s*\n(?:[\s\S]*?)(?=####\s+Page\s+\d+\s*\n|$))'
            page_chunks = re.findall(page_pattern, text_content)
            
            if page_chunks:
                # 페이지 패턴 찾음
                for page_chunk in page_chunks:
                    # 페이지 번호 추출
                    page_match = re.match(r'####\s+Page\s+(\d+)', page_chunk)
                    page_num = page_match.group(1) if page_match else "unknown"
                    
                    chunks.append(page_chunk)
                    metadatas.append({"source": file_path, "page": f"Page {page_num}"})
                
                print(f"페이지 기반 분할: {len(chunks)}개 페이지 찾음")
            else:
                # 페이지 패턴 못찾음 - 문단 단위로 분할
                paragraphs = re.split(r'\n\s*\n', text_content)
                paragraphs = [p.strip() for p in paragraphs if p.strip()]
                
                for i, para in enumerate(paragraphs):
                    chunks.append(para)
                    metadatas.append({"source": file_path, "paragraph": i+1})
                
                print(f"문단 기반 분할: {len(chunks)}개 문단 생성")
        
        # 청크가 없으면 전체 텍스트를 하나의 청크로 처리
        if not chunks:
            chunks = [text_content]
            metadatas = [{"source": file_path, "full_document": True}]
            print("분할 실패: 전체 텍스트를 하나의 청크로 처리")
        
        # 벡터 DB에 추가
        added_count = self.add_documents(
            documents=chunks,
            metadatas=metadatas
        )
        
        print(f"벡터 DB에 {added_count}개 청크 추가 완료")
        return added_count
    
    def search(self, query, top_n=5, metadata_filter=None):
        """
        벡터 유사도 기반 검색 수행
        
        Args:
            query (str): 검색 쿼리
            top_n (int): 반환할 결과 수
            metadata_filter (dict, optional): 메타데이터 필터링 조건
        
        Returns:
            dict: 검색 결과
        """
        # 진단용 - 쿼리 임베딩 계산
        query_embedding = self.embedding_model.encode([query])[0]
        print(f"쿼리 임베딩 shape: {query_embedding.shape}")
        
        # ChromaDB를 통한 검색
        results = self.collection.query(
            query_texts=[query],
            n_results=top_n,
            where=metadata_filter,
            include=["documents", "metadatas", "distances", "embeddings"]
        )
        
        # 결과 포맷팅
        formatted_results = []
        for i in range(len(results["documents"][0])):
            formatted_results.append({
                "chunk": results["documents"][0][i],
                "id": results["ids"][0][i],
                "metadata": results["metadatas"][0][i],
                "distance": results["distances"][0][i] if "distances" in results else None,
                # "embedding": results["embeddings"][0][i] if "embeddings" in results else None
            })
        
        return formatted_results
    
    # def get_all_document_embeddings(self, ids=None):
    #     """
    #     저장된 모든 문서의 임베딩 조회 (디버깅 용도)
    #     """
    #     result = self.collection.get(ids=ids, include=["embeddings", "documents"])
    #     return result
    
    # def get_document_by_id(self, doc_id):
    #     """ID로 문서 조회"""
    #     result = self.collection.get(ids=[doc_id])
    #     if result["documents"]:
    #         return {
    #             "chunk": result["documents"][0],
    #             "metadata": result["metadatas"][0]
    #         }
    #     return None
    
    # def delete_document(self, doc_id):
    #     """ID로 문서 삭제"""
    #     self.collection.delete(ids=[doc_id])
    
    def delete_collection(self):
        """컬렉션 삭제"""
        self.client.delete_collection(self.collection.name)
    
    def get_collection_stats(self):
        """컬렉션 통계 조회"""
        count = self.collection.count()
        return {
            "document_count": count,
            "collection_name": self.collection.name
        }
    
class CustomEmbeddingFunction(embedding_functions.EmbeddingFunction):
    """기존 임베딩 모델을 ChromaDB에서 사용하기 위한 래퍼 클래스"""
    
    def __init__(self, embedding_model):
        """
        생성자
        
        Args:
            embedding_model: 임베딩 모델 (encode 메서드 제공)
        """
        self.embedding_model = embedding_model
    
    def __call__(self, texts):
        """
        텍스트를 임베딩 벡터로 변환
        
        Args:
            texts: 인코딩할 텍스트 리스트
        
        Returns:
            임베딩 벡터 리스트
        """
        return self.embedding_model.encode(texts).tolist()

# %%
import numpy as np
import re
import os
import json
from rank_bm25 import BM25Okapi
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from model_loader.config import embedding_loader, generation_loader

class HybridSearcher:
    def __init__(self, embedding_model, chunk_size=200, chunk_overlap=50, 
                 persist_directory="./chroma_db", collection_name="Gray"):
        """
        하이브리드 검색 클래스 초기화
        
        Args:
            embedding_model: 임베딩 모델
            chunk_size (int): 청크 크기
            chunk_overlap (int): 청크 간 중복 크기
            persist_directory (str): 벡터 DB 저장 경로
            collection_name (str): 벡터 DB 컬렉션 이름
        """
        self.embedding_model = embedding_model
        self.chunk_size = chunk_size
        self.chunk_overlap = chunk_overlap
        self.chunks = None
        self.chunk_metadata = None
        self.bm25_index = None
        self.vector_index = None
        
        # ChromaDB 벡터 DB 클래스 초기화 - 동일한 임베딩 모델 사용
        self.vector_db = ChromaVectorDB(
            embedding_model=self.embedding_model,
            persist_directory=persist_directory,
            collection_name=collection_name
        )
        
        # 검색 결과 비교용 플래그
        self.debug_mode = False
        
        # 프롬프트 로드
        self.complexity_prompt = self._load_prompt("prompts/en/complex/complex_prompt.txt")
        self.decompose_prompt = self._load_prompt("prompts/en/decompose/decompose_prompt.txt")

    def _load_prompt(self, file_path):
        """프롬프트 파일 로드"""
        try:
            with open(file_path, "r", encoding="utf-8") as f:
                return f.read()
        except Exception as e:
            print(f"프롬프트 파일 로드 중 오류 발생: {e}")
            # 기본 프롬프트 반환
            if "complex" in file_path:
                return "질문을 분석하여 복합적인 질문인지 판단하세요. 복합적인 질문은 여러 하위 질문으로 분해할 수 있습니다. '예' 또는 '아니오'로만 답변하세요."
            elif "decompose" in file_path:
                return "다음 복합적인 질문을 여러 개의 간단한 하위 질문으로 분해하세요. JSON 형식으로 하위 질문 목록을 반환하세요."

    def load_document(self, file_path):
        """문서 로드 및 청크 분할"""
        with open(file_path, "r", encoding="utf-8") as f:
            content = f.read()
        
        # 문서를 청크로 분할
        self.chunks, self.chunk_metadata = self._split_into_chunks_with_metadata(content)
        
        # BM25 인덱스 생성
        tokenized_chunks = [self._simple_tokenize(chunk) for chunk in self.chunks]
        self.bm25_index = BM25Okapi(tokenized_chunks)
        
        # 벡터 임베딩 생성 및 인메모리 인덱스 구축
        self.vector_index = self.embedding_model.encode(self.chunks)
        
        # ChromaDB에 문서 추가
        # 문서 ID 생성
        doc_name = os.path.basename(file_path)
        doc_ids = [f"{doc_name}_{i}" for i in range(len(self.chunks))]
        
        # 메타데이터에 페이지 정보 포함
        metadatas = [{"page": meta["page"], "source": doc_name, "chunk_index": i} 
                    for i, meta in enumerate(self.chunk_metadata)]
        
        # 벡터 DB에 문서 추가
        self.vector_db.add_documents(
            documents=self.chunks,
            metadatas=metadatas,
            ids=doc_ids
        )
        
        return len(self.chunks)
    
    # def search(self, query, top_n=5, alpha=0.5, use_vector_db=True):
    #     """
    #     하이브리드 검색 수행
        
    #     Args:
    #         query (str): 검색 쿼리
    #         top_n (int): 반환할 결과 수
    #         alpha (float): BM25와 벡터 검색 결과 결합 비율 (0에 가까울수록 벡터 검색 중시)
    #         use_vector_db (bool): ChromaDB 벡터 DB 사용 여부
        
    #     Returns:
    #         list: 검색 결과 리스트
    #     """
    #     if self.chunks is None or self.bm25_index is None:
    #         raise ValueError("문서가 로드되지 않았습니다. load_document()를 먼저 호출하세요.")
        
    #     if not isinstance(query, str) :
    #         query = str(query)
            
    #     # BM25 검색 수행
    #     bm25_scores = self.bm25_index.get_scores(self._simple_tokenize(query))
        
    #     # 두 검색 방식 모두 수행 (디버그 모드)
    #     query_embedding = self.embedding_model.encode([query])[0]
    #     memory_scores = cosine_similarity([query_embedding], self.vector_index)[0]
        
    #     if use_vector_db:
    #         # ChromaDB를 사용한 벡터 검색
    #         db_results = self.vector_db.search(query, top_n=len(self.chunks))
            
    #         # 결과를 벡터 점수로 변환
    #         vector_scores = np.zeros(len(self.chunks))
    #         for res in db_results:
    #             # 문서 ID에서 인덱스 추출
    #             chunk_id = res["id"]
    #             if "_" in chunk_id:
    #                 try:
    #                     chunk_index = int(chunk_id.split("_")[-1])
    #                     if chunk_index < len(self.chunks):
    #                         # 거리를 유사도로 변환 (코사인 거리는 1 - 코사인 유사도)
    #                         if res["distance"] is not None:
    #                             # ChromaDB가 코사인 거리를 사용하는 경우
    #                             similarity = 1.0 - res["distance"]
    #                             vector_scores[chunk_index] = similarity
    #                 except ValueError:
    #                     continue
            
    #         # 디버그 모드에서 점수 비교
    #         if self.debug_mode:
    #             print("\n벡터 검색 점수 비교:")
    #             for i in range(min(5, len(self.chunks))):
    #                 print(f"Chunk {i}: Memory={memory_scores[i]:.4f}, ChromaDB={vector_scores[i]:.4f}, 차이={memory_scores[i]-vector_scores[i]:.4f}")
    #     else:
    #         # 메모리 내 벡터 검색 수행 (기존 방식)
    #         vector_scores = memory_scores
        
    #     # 검색 결과 결합
    #     combined_scores = self._combine_scores(bm25_scores, vector_scores, alpha)
        
    #     # 상위 N개 결과 반환
    #     top_indices = np.argsort(combined_scores)[-top_n:][::-1]
    #     results = [
    #         {
    #             "chunk": self.chunks[i],
    #             "score": combined_scores[i],
    #             "bm25_score": bm25_scores[i],
    #             "vector_score": vector_scores[i],
    #             "memory_score": memory_scores[i],  # 디버깅용
    #             "index": i,
    #             "page": self.chunk_metadata[i]["page"]
    #         }
    #         for i in top_indices
    #     ]
        
    #     return results

    def search(self, query, top_n=5, alpha=0.5, use_vector_db=True):
        """
        하이브리드 검색 수행
        
        Args:
            query (str): 검색 쿼리
            top_n (int): 반환할 결과 수
            alpha (float): BM25와 벡터 검색 결과 결합 비율 (0에 가까울수록 벡터 검색 중시)
            use_vector_db (bool): ChromaDB 벡터 DB 사용 여부
        
        Returns:
            list: 검색 결과 리스트
        """
        if self.chunks is None or self.bm25_index is None:
            raise ValueError("문서가 로드되지 않았습니다. load_document()를 먼저 호출하세요.")
        
        if not isinstance(query, str):
            query = str(query)
        
        # 구두점으로 쿼리 분할
        import re
        query_parts = re.split(r'[.!?;]', query)
        query_parts = [part.strip() for part in query_parts if part.strip()]
        
        # 각 부분에 대한 임베딩 생성
        if query_parts:
            part_embeddings = self.embedding_model.encode(query_parts)
            # 임베딩의 평균 계산
            query_embedding = np.mean(part_embeddings, axis=0)
        else:
            # 분할 결과가 없으면 원래 쿼리 사용
            query_embedding = self.embedding_model.encode([query])[0]
            
        # BM25 검색 수행
        bm25_scores = self.bm25_index.get_scores(self._simple_tokenize(query))
        
        # 두 검색 방식 모두 수행 (디버그 모드)
        memory_scores = cosine_similarity([query_embedding], self.vector_index)[0]
        
        if use_vector_db:
            # ChromaDB를 사용한 벡터 검색 - 평균 임베딩 사용
            # query 대신 직접 임베딩 벡터 전달
            db_results = self.vector_db.search(
                query_texts=None,
                query_embeddings=[query_embedding.tolist()], 
                n_results=len(self.chunks)
            )
            
            # 결과를 벡터 점수로 변환
            vector_scores = np.zeros(len(self.chunks))
            for res in db_results:
                # 문서 ID에서 인덱스 추출
                chunk_id = res["id"]
                if "_" in chunk_id:
                    try:
                        chunk_index = int(chunk_id.split("_")[-1])
                        if chunk_index < len(self.chunks):
                            # 거리를 유사도로 변환 (코사인 거리는 1 - 코사인 유사도)
                            if res["distance"] is not None:
                                # ChromaDB가 코사인 거리를 사용하는 경우
                                similarity = 1.0 - res["distance"]
                                vector_scores[chunk_index] = similarity
                    except ValueError:
                        continue
            
            # 디버그 모드에서 점수 비교
            if self.debug_mode:
                print("\n벡터 검색 점수 비교:")
                for i in range(min(5, len(self.chunks))):
                    print(f"Chunk {i}: Memory={memory_scores[i]:.4f}, ChromaDB={vector_scores[i]:.4f}, 차이={memory_scores[i]-vector_scores[i]:.4f}")
        else:
            # 메모리 내 벡터 검색 수행 (기존 방식) - 평균 임베딩 사용
            vector_scores = memory_scores
        
        # 검색 결과 결합
        combined_scores = self._combine_scores(bm25_scores, vector_scores, alpha)
        
        # 상위 N개 결과 반환
        top_indices = np.argsort(combined_scores)[-top_n:][::-1]
        results = [
            {
                "chunk": self.chunks[i],
                "score": combined_scores[i],
                "bm25_score": bm25_scores[i],
                "vector_score": vector_scores[i],
                "memory_score": memory_scores[i],  # 디버깅용
                "index": i,
                "page": self.chunk_metadata[i]["page"]
            }
            for i in top_indices
        ]
        
        return results

    def _split_into_chunks_with_metadata(self, text):
        """텍스트를 청크로 분할하고 페이지 정보를 메타데이터로 유지하는 함수"""
        chunks = []
        chunk_metadata = []
        
        # 페이지 패턴 정규식 (####으로 시작하는 페이지 헤더)
        page_pattern = re.compile(r'####\s*Page (\d+)')
        
        # 텍스트를 줄 단위로 처리
        lines = text.split('\n')
        current_page = "unknown"
        current_chunk = ""
        
        for line in lines:
            # 페이지 헤더 확인
            page_match = page_pattern.match(line)
            
            if page_match:
                # 새 페이지 시작
                # 현재 청크가 있으면 저장
                if current_chunk.strip():
                    chunks.append(current_chunk.strip())
                    chunk_metadata.append({"page": current_page})
                    current_chunk = ""
                
                # 새 페이지 번호 설정
                current_page = page_match.group(1)
                continue
            
            # 현재 청크에 라인 추가
            current_chunk += line + "\n"
            
            # 청크 크기 확인
            if len(current_chunk) >= self.chunk_size:
                chunks.append(current_chunk.strip())
                chunk_metadata.append({"page": current_page})
                current_chunk = ""  # 새 청크 시작
        
        # 마지막 청크 처리
        if current_chunk.strip():
            chunks.append(current_chunk.strip())
            chunk_metadata.append({"page": current_page})
        
        # 너무 작은 청크 결합 (메타데이터 유지)
        i = 0
        while i < len(chunks) - 1:
            if len(chunks[i]) + len(chunks[i+1]) < self.chunk_size:
                # 같은 페이지인 경우에만 결합
                if chunk_metadata[i]["page"] == chunk_metadata[i+1]["page"]:
                    chunks[i] = chunks[i] + "\n\n" + chunks[i+1]
                    chunks.pop(i+1)
                    chunk_metadata.pop(i+1)
                else:
                    i += 1
            else:
                i += 1
        
        return chunks, chunk_metadata
    
    def _simple_tokenize(self, text):
        """텍스트를 간단히 토크나이징하는 함수"""
        if not isinstance(text, str):
            text = str(text)
        return re.findall(r'\w+', text.lower())
    
    def _combine_scores(self, bm25_scores, vector_scores, alpha=0.5):
        """BM25와 벡터 검색 점수를 결합"""
        # 점수 정규화
        if np.max(bm25_scores) > 0:
            bm25_scores = bm25_scores / np.max(bm25_scores)
        if np.max(vector_scores) > 0:
            vector_scores = vector_scores / np.max(vector_scores)
        
        # 가중 평균 계산
        combined = alpha * bm25_scores + (1 - alpha) * vector_scores
        return combined
    
    def get_chunks_with_page_info(self, indices=None):
        """청크와 페이지 정보 반환"""
        if indices is None:
            return [(chunk, self.chunk_metadata[i]["page"]) for i, chunk in enumerate(self.chunks)]
        else:
            return [(self.chunks[i], self.chunk_metadata[i]["page"]) for i in indices if i < len(self.chunks)]
    
    # 1. 질문이 복합적인지 확인하는 메서드
    def is_complex_question(self, question):
        """
        LLM을 사용하여 질문이 복합적인지 판단하는 메서드
        
        Args:
            question (str): 사용자 질문
            
        Returns:
            bool: 복합적인 질문이면 True, 아니면 False
        """
        prompt = self.complexity_prompt.format(question=question)
        response = generation_loader.generate(prompt)
        
        # '예' 또는 'Yes'가 응답에 포함되어 있으면 복합적인 질문으로 간주
        response = response.lower().strip()
        print(f"###############질문이 복잡한가요? : {response}")
        return '예' in response or 'yes' in response
    
    # 2. 복합적인 질문을 하위 질문으로 분해하는 메서드
    def decompose_question(self, complex_question):
        """
        LLM을 사용하여 복합적인 질문을 여러 개의 하위 질문으로 분해하는 메서드
        
        Args:
            complex_question (str): 복합적인 사용자 질문
            
        Returns:
            list: 하위 질문 목록
        """
        prompt = self.decompose_prompt.format(question=complex_question)
        response = generation_loader.generate(prompt)

        try:
            # JSON 형식으로 반환된 하위 질문 파싱
            # JSON 블록 추출 (```json과 ```로 감싸져 있을 수 있음)
            json_match = re.search(r'```json\s*(.+?)\s*```', response, re.DOTALL)
            if json_match:
                response = json_match.group(1)
            
            # 중괄호 블록 추출
            json_match = re.search(r'(\{.+?\})', response, re.DOTALL)
            if json_match:
                response = json_match.group(1)
                
            sub_questions_data = json.loads(response)
            # 다양한 JSON 형식 처리
            if isinstance(sub_questions_data, list):
                return sub_questions_data
            elif isinstance(sub_questions_data, dict):
                if "questions" in sub_questions_data:
                    return sub_questions_data["questions"]
                elif "subQuestions" in sub_questions_data:
                    return sub_questions_data["subQuestions"]
                else:
                    # 딕셔너리의 값들을 리스트로 반환
                    return list(sub_questions_data.values())
                
        except (json.JSONDecodeError, AttributeError) as e:
            print(f"하위 질문 파싱 오류: {e}")
            print(f"LLM 응답: {response}")
            
            # 파싱 실패 시 줄바꿈을 기준으로 질문 추출 시도
            questions = []
            for line in response.split('\n'):
                line = line.strip()
                if line and ('?' in line or '질문' in line):
                    # 숫자, 점, 괄호 등의 접두어 제거
                    cleaned_line = re.sub(r'^[\d\.\)\-\s]+', '', line).strip()
                    if cleaned_line:
                        questions.append(cleaned_line)
            
            if questions:
                return questions
            # 단일 질문으로 처리
            return [complex_question]

# %% [markdown]
# # decompose & complex 적용

# %%
from model_loader.config import *
from save_utils import *
from translate import *

class CarManualQA:
    def __init__(self, generation_loader, data_folder="./data/split_file", 
                 prompt_path_ko="./prompts/ko/generation/gemma3/generation_prompt2.txt", 
                 prompt_path_en="./prompts/en/generation/gemma3/generation_prompt2.txt", 
                 result_path="./result/5월12일/gemma3",
                 use_vector_db=True, 
                 persist_directory="./chroma_db",
                 collection_name="Gray",
                 language="en"):
        """
        자동차 매뉴얼 Q&A 시스템 초기화
        
        Args:
            generation_loader: 텍스트 생성 모델 로더
            data_folder (str): 분할된 데이터 파일들이 있는 폴더 경로
            prompt_path (str): 프롬프트 템플릿 파일 경로
            result_path (str): 결과를 저장할 경로
            use_vector_db (bool): ChromaDB 벡터 DB 사용 여부
            persist_directory (str): 벡터 DB 저장 경로
            collection_name (str): 벡터 DB 컬렉션 이름
        """
        self.data_folder = data_folder
        self.result_path = result_path
        self.use_vector_db = use_vector_db
        self.language = language

        if collection_name == "Gray" :
            collection_name = f"Gray_{language}"
        
        # 하이브리드 검색기 초기화 - ChromaDB 지원 버전
        self.searcher = HybridSearcher(
            embedding_model=embedding_loader,
            chunk_size=200, 
            chunk_overlap=50,
            persist_directory=persist_directory,
            collection_name=collection_name
        )
        
        self.loader = generation_loader
        self.prompt_path_ko = prompt_path_ko
        self.prompt_path_en = prompt_path_en

        if language=="ko" :
            self.prompt_template = self._load_prompt(prompt_path_ko)
        else :
            self.prompt_template = self._load_prompt(prompt_path_en)
        
        # 카테고리별 파일 매핑
        if language == "en" :
            self.category_to_file = {
                "16": "GrayAnatomy_Formatted.md"
            }
        else :
            self.category_to_file = {
                "16": "full.txt"
            }
        
        try :
            self.translate_en_to_ko = en_to_ko
        except ImportError :
            print("translate.py 모듈을 임포트할 수 없습니다.")
            self.translate_en_to_ko = en_to_ko

        # 이미 처리된 파일 추적
        self.loaded_files = set()
        
        # 전체 파일을 벡터 DB에 미리 로드할지 여부
        self.preload_all = False
        
        # 디버그 모드
        self.debug_mode = True
        
    def preload_documents(self):
        """
        모든 카테고리의 파일을 미리 벡터 DB에 로드
        """
        print("모든 문서를 벡터 DB에 로드 중...")
        for category, filename in self.category_to_file.items():
            file_path = os.path.join(self.data_folder, filename)
            if os.path.exists(file_path):
                print(f"카테고리 {category}: {filename} 로드 중...")
                self._load_document(file_path)
                self.loaded_files.add(file_path)
            else:
                print(f"[경고] 파일을 찾을 수 없습니다: {file_path}")
        
        print(f"총 {len(self.loaded_files)}개 파일이 벡터 DB에 로드되었습니다.")
        self.preload_all = True

    # def _load_document(self, file_path):
    #     """
    #     문서를 로드하여 검색기에 추가
        
    #     Args:
    #         file_path (str): 로드할 파일 경로
            
    #     Returns:
    #         int: 로드된 청크 수
    #     """
    #     # 이미 로드된 파일이면 건너뛰기
    #     if file_path in self.loaded_files and self.preload_all:
    #         if self.debug_mode:
    #             print(f"이미 로드된 파일입니다: {file_path}")
    #         return 0
        
    #     # 파일 로드 및 벡터 DB에 추가
    #     num_chunks = self.searcher.load_document(file_path)
        
    #     # 파일 추적 목록에 추가
    #     self.loaded_files.add(file_path)
        
    #     if self.debug_mode:
    #         print(f"파일 로드 완료: {file_path} ({num_chunks}개 청크)")
        
    #     return num_chunks

    def _load_document(self, file_path):
        """문서 로드 최적화 버전"""
        if isinstance(self.loaded_files, set) :
            self.loaded_files={}

        # 이미 로드된 파일인지 확인
        if file_path in self.loaded_files:
            if self.debug_mode:
                print(f"이미 로드된 파일입니다: {file_path}")
            return self.loaded_files[file_path]
        
        try:
            # 1. 캐시 파일 경로 설정
            cache_dir = os.path.join(os.path.dirname(file_path), '.cache')
            cache_file = os.path.join(cache_dir, os.path.basename(file_path) + '.pickle')
            
            # 2. 캐시 파일이 존재하고 원본보다 최신이면 캐시 로드
            if os.path.exists(cache_file) and os.path.getmtime(cache_file) > os.path.getmtime(file_path):
                with open(cache_file, 'rb') as f:
                    import pickle
                    num_chunks = pickle.load(f)
                    self.loaded_files[file_path] = num_chunks
                    if self.debug_mode:
                        print(f"캐시에서 로드 완료: {file_path}")
                    return num_chunks
            
            # 3. 캐시 없으면 일반 로드 후 캐시 저장
            num_chunks = self.searcher.load_document(file_path)
            self.loaded_files[file_path] = num_chunks
            
            # 캐시 디렉토리 생성
            os.makedirs(cache_dir, exist_ok=True)
            
            # 캐시 파일 저장
            with open(cache_file, 'wb') as f:
                import pickle
                pickle.dump(num_chunks, f)
            
            if self.debug_mode:
                print(f"로드 및 캐시 저장 완료: {file_path}")
            
            return num_chunks
        except Exception as e:
            print(f"문서 로드 중 오류 발생: {e}")
            import traceback
            traceback.print_exc()
            return 0

    def filter_relevant_content(self, query, search_results, threshold=0.7, top_k=5):
        """
        LLM을 사용하여 검색 결과에서 질문과 관련이 있는 내용을 평가하고 
        관련성 점수가 높은 상위 k개 결과만 반환
        
        Args:
            query (str): 사용자 질의
            search_results (list): 검색 결과 목록
            threshold (float): 관련성 점수 임계값 (0.0~1.0)
            top_k (int): 반환할 상위 결과 개수
            
        Returns:
            list: 점수가 높은 상위 k개의 필터링된 관련 정보 목록
        """
        scored_results = []
        
        if self.debug_mode:
            print(f"검색 결과 {len(search_results)}개에 대한 관련성 필터링 시작")
        
        # 각 검색 결과에 대해 관련성 평가
        for result in search_results:
            # 프롬프트 구성 - 관련성 평가용
            relevance_prompt = f"""
    다음은 사용자의 질문입니다:
    "{query}"
    다음은 검색된 텍스트 정보입니다:
    "{result['chunk']}"
    위 텍스트가 사용자 질문에 얼마나 관련이 있는지 평가해주세요.
    평가는 다음과 같이 응답해주세요:
    1. 관련성 점수: 0.0 ~ 1.0 사이의 숫자 (1.0이 가장 관련성 높음)
    2. 이유: 관련성이 높거나 낮은 이유를 간략하게 설명
    응답 형식:
    {{
    "score": 0.0~1.0,
    "reason": "평가 이유"
    }}
    """
            
            relevance_result = self.loader.generate(relevance_prompt)
            
            try:
                # JSON 응답 파싱 (정확한 JSON이 아닐 수 있으므로 예외 처리)
                import re
                import json
                
                # JSON 형식 추출 시도
                json_match = re.search(r'\{.*"score".*:.*,.*"reason".*:.*\}', relevance_result, re.DOTALL)
                if json_match:
                    relevance_data = json.loads(json_match.group(0))
                    score = float(relevance_data.get("score", 0))
                else:
                    # 숫자만 추출 시도
                    score_match = re.search(r'score"?\s*:?\s*(\d+\.\d+|\d+)', relevance_result)
                    score = float(score_match.group(1)) if score_match else 0.0
                
                # 점수와 함께 결과 저장 (임계값 이상인 것만)
                if score >= threshold:
                    if self.debug_mode:
                        print(f"관련성 높음 (점수: {score:.2f}): {result['page']}페이지")
                    # 원본 결과에 점수 정보 추가
                    result_with_score = result.copy()
                    result_with_score['relevance_score'] = score
                    scored_results.append(result_with_score)
                else:
                    if self.debug_mode:
                        print(f"관련성 낮음 (점수: {score:.2f}): {result['page']}페이지")
                    
            except Exception as e:
                # 파싱 실패 시 안전을 위해 낮은 점수로 포함
                if self.debug_mode:
                    print(f"관련성 평가 파싱 오류: {str(e)}")
                result_with_score = result.copy()
                result_with_score['relevance_score'] = 0.1  # 낮은 기본 점수
                scored_results.append(result_with_score)
        
        # 점수를 기준으로 내림차순 정렬
        sorted_results = sorted(scored_results, key=lambda x: x['relevance_score'], reverse=True)
        
        # 상위 k개 결과만 선택
        top_results = sorted_results[:top_k]
        
        if self.debug_mode:
            print(f"필터링 결과: 총 {len(search_results)}개 중 {len(scored_results)}개가 임계값 통과")
            print(f"상위 {min(top_k, len(top_results))}개 결과만 선택됨")
            for i, res in enumerate(top_results):
                print(f"  {i+1}위: 점수 {res['relevance_score']:.2f} - {res['page']}페이지")
        
        # 결과가 없는 경우 원본의 일부라도 반환
        if not top_results and search_results:
            if self.debug_mode:
                print(f"필터링 결과가 없어 원본 상위 결과 {min(top_k, len(search_results))}개 포함")
            top_results = search_results[:min(top_k, len(search_results))]
        
        return top_results
    
    def _format_filtered_results(self, filtered_results):
        """
        필터링된 결과를 문자열로 변환
        
        Args:
            filtered_results (list): 필터링된 검색 결과 리스트
            
        Returns:
            str: 포맷된 문자열
        """
        result_str = ""
        
        for item in filtered_results:
            result_str += f"# 질문: {item['sub_question']}\n\n"
            
            # results가 이미 점수로 정렬되었다고 가정
            for res in item['results']:
                page_info = res['page']
                score_info = ""
                if 'relevance_score' in res:
                    score_info = f" (관련성: {res['relevance_score']:.2f})"
                
                result_str += f"## {page_info}페이지{score_info}\n"
                result_str += f"{res['chunk']}\n\n"
        
        return result_str

    def _generate_hypothetical_document(self, query):
        """
        질문에 대한 가상 문서 생성 (Hyde 기법)
        
        Args:
            query (str): 사용자 질의
            
        Returns:
            str: 생성된 가상 문서
        """
        # Hyde 프롬프트 템플릿
        hyde_prompt = """Please write an ideal answer to the following question:

            Question: {query}

            Please provide a clear and accurate answer with detailed information. Your answer should include important concepts, details, and examples related to this question. Please provide a comprehensive and informative response as if it would be found in an actual document."""
            
        prompt = hyde_prompt.format(query=query)
        
        # LLM을 사용하여 가상 문서 생성
        if hasattr(self.loader, "tokenizer"):
            tokenizer = self.loader.tokenizer
            model = self.loader.model
            
            # 인풋 토크나이즈
            input_ids = tokenizer.encode(prompt, return_tensors="pt", padding=True, truncation=True).to(model.device)
            attention_mask = (input_ids != tokenizer.pad_token_id).long().to(model.device)
            
            # 텍스트 생성
            output = model.generate(
                input_ids=input_ids,
                attention_mask=attention_mask,
                max_new_tokens=400,
                temperature=0.7,  
                do_sample=True,
                top_p=0.85,
                repetition_penalty=1.2,
                early_stopping=True,
                num_beams=1,  
                pad_token_id=tokenizer.pad_token_id,
                eos_token_id=tokenizer.eos_token_id,
            )
            generated_ids = output[0][input_ids.shape[-1]:]
            hypothetical_doc = tokenizer.decode(generated_ids, skip_special_tokens=True).strip()
        else:
            # OpenAI 등 API 기반 모델 사용
            hypothetical_doc = self.loader.generate(prompt)
        
        return hypothetical_doc

    def generate_response(self, query, category, top_n=5, alpha=0.5, target_language=None):
        """
        질의에 대한 응답 생성
        
        Args:
            query (str): 사용자 질의
            category (str): 검색할 카테고리
            top_n (int): 검색 결과 수
            alpha (float): BM25와 벡터 검색 가중치 (높을수록 BM25 중시)
            
        Returns:
            dict: 생성된 응답 및 메타데이터
        """
        import time
        try:
            response_language = target_language if target_language else self.language
            source_language = self.language

            # 파일 로드 확인
            filename = self.category_to_file[category]
            file_path = os.path.join(self.data_folder, filename)
            
            # 해당 파일이 존재하지 않는 경우
            if not os.path.exists(file_path):
                error_msg = f"[오류] 파일을 찾을 수 없습니다: {file_path}"
                print(error_msg)
                return {"답변": error_msg, "후처리": error_msg}
            
            # 파일 로드 (이미 로드된 경우 건너뜀)
            load_start = time.time()
            if not self.preload_all:
            # 기존 코드
                self._load_document(file_path)
                
                # 추가: searcher에도 문서 로드되었는지 확인하고 필요시 로드
                if hasattr(self.searcher, 'chunks') and (self.searcher.chunks is None or len(self.searcher.chunks) == 0):
                    # searcher에 직접 문서 로드 (searcher의 메서드 명칭에 따라 조정)
                    self.searcher.load_document(file_path)
                    print(f"searcher에 문서 로드 완료: {len(self.searcher.chunks) if hasattr(self.searcher, 'chunks') else '알 수 없음'}")
            else:
                # preload_all이 True일 때는 self.searcher에 문서가 로드되었는지 확인
                if hasattr(self.searcher, 'chunks') and (self.searcher.chunks is None or len(self.searcher.chunks) == 0):
                    # searcher에 직접 문서 로드
                    self.searcher.load_document(file_path)
                    print(f"preload 모드 - searcher에 문서 로드 완료: {len(self.searcher.chunks) if hasattr(self.searcher, 'chunks') else '알 수 없음'}")
                
            load_end = time.time()
            if self.debug_mode:
                print("파일 로드 시간 : ", load_end - load_start)

            ####################### Hyde 기법 #######################
            hyde_start = time.time()
            hypothetical_doc = self._generate_hypothetical_document(query)
            if self.debug_mode :
                print(f"가상 문서 : {hypothetical_doc}")
            hyde_end = time.time()
            if self.debug_mode :
                print(f"가상 문서 생성 시간 : {hyde_end - hyde_start}")

            search_start = time.time()
            search_results = self.searcher.search(
                query=hypothetical_doc, 
                top_n=top_n, 
                alpha=alpha,
                use_vector_db=self.use_vector_db
                )   
            # 단계 1: 질문 복잡성 판단
            # is_complex = self.searcher.is_complex_question(query)
            
            # if self.debug_mode:
            #     print(f"질문 복잡성 분석: {'복합적인 질문' if is_complex else '단순 질문'}")
            
            # if is_complex:
            #     # 복합적인 질문 처리
            #     # 단계 2: 질문 분해
            #     sub_questions = self.searcher.decompose_question(query)
            #     print(f"하위 질문 분해 결과: {sub_questions}")
                
            #     # 모든 하위 질문에 대한 검색 결과를 저장할 리스트
            #     all_search_results = []
            #     all_filtered_results = []

            #     # 단계 3: 각 하위 질문에 대해 검색 수행
            #     for i, sub_q in enumerate(sub_questions):
            #         if self.debug_mode:
            #             print(f"하위 질문 {i+1} 검색 중: '{sub_q}'")
                    
            #         if not isinstance(query, str) :
            #             query = str(query)
            #         # 하위 질문에 대한 검색 수행
            #         search_results = self.searcher.search(
            #             query=sub_q, 
            #             top_n=top_n, 
            #             alpha=alpha,
            #             use_vector_db=self.use_vector_db
            #         )
            #         filtered_results = self.filter_relevant_content(query, search_results)

            #         # 검색 결과 저장
            #         all_search_results.append({
            #             "sub_question": sub_q,
            #             "results": search_results
            #         })

            #         all_filtered_results.append({
            #             "sub_question" : sub_q,
            #             "results" : filtered_results
            #         })

            #     # 컨텍스트 구성 - 모든 하위 질문 결과 통합
            #     context = ""
            #     for i, sr in enumerate(all_filtered_results):
            #         context += f"\n### 하위 질문 {i+1}: {sr['sub_question']}\n"
                    
            #         for _, res in enumerate(sr["results"]):
            #             context += f"#### Page {res['page']}\n"
            #             context += f"{res['chunk']}\n\n"
                
            #     # 프롬프트 구성 - 복합 질문용
            #     prompt = self.prompt_template.format(context=context, query=query)
                
            # else:
            #     # 단순 질문 처리 - 기존 방식대로 검색
            #     search_results = self.searcher.search(
            #         query=query, 
            #         top_n=top_n, 
            #         alpha=alpha,
            #         use_vector_db=self.use_vector_db
            #     )
                
            #     filtered_results = self.filter_relevant_content(query, search_results)

            #     # 컨텍스트 구성 - 단순 질문용
            #     context = "\n\n".join([f"#### Page {result['page']}\n{result['chunk']}" for result in filtered_results])
                
            #     # 프롬프트 구성 - 단순 질문용
            #     prompt = self.prompt_template.format(context=context, query=query)
            
            search_start = time.time()
            search_results = self.searcher.search(
                query=query, 
                top_n=top_n, 
                alpha=alpha,
                use_vector_db=self.use_vector_db
            )
            search_end = time.time()

            if self.debug_mode :
                print("검색 시간 : ", search_end - search_start)

            # filtered_results = self.filter_relevant_content(query, search_results)

            # 컨텍스트 구성 - 단순 질문용
            # context = "\n\n".join([f"#### Page {result['page']}\n{result['chunk']}" for result in filtered_results])
            context = "\n\n".join([f"#### Page {result['page']}\n{result['chunk']}" for result in search_results])
            # 프롬프트 구성 - 단순 질문용
            prompt = self.prompt_template.format(context=context, query=query)

            generation_start = time.time()
            # 응답 생성 파트
            if hasattr(self.loader, "tokenizer"):
                # Huggingface 모델 사용
                tokenizer = self.loader.tokenizer
                model = self.loader.model
                
                # 인풋 토크나이즈
                input_ids = tokenizer.encode(prompt, return_tensors="pt", padding=True, truncation=True).to(model.device)
                attention_mask = (input_ids != tokenizer.pad_token_id).long().to(model.device)
                
                # 텍스트 생성
                output = model.generate(
                    input_ids=input_ids,
                    attention_mask=attention_mask,
                    max_new_tokens=400,
                    temperature=0.3,
                    do_sample=False,
                    top_p=0.85,
                    repetition_penalty=1.2,
                    early_stopping=True,
                    num_beams=3,
                    pad_token_id=tokenizer.pad_token_id,
                    eos_token_id=tokenizer.eos_token_id,
                )
                generated_ids = output[0][input_ids.shape[-1]:]
                raw_answer = tokenizer.decode(generated_ids, skip_special_tokens=True).strip()
            else:
                # OpenAI 등 API 기반 모델 사용 (Ollama 포함)
                raw_answer = self.loader.generate(prompt)
            generation_end = time.time()
            if self.debug_mode :
                print("응답 생성 시간 : ", generation_end - generation_start)

            # 응답 후처리
            final_answer = self._extract_answer_content(raw_answer)
            final_answer = self._remove_chinese_characters(final_answer)
            
            translated_answer = None
            if source_language == "en" and response_language == "ko" :
                if self.translate_en_to_ko :
                    try :
                        translate_start = time.time()
                        translated_answer = self.translate_en_to_ko(final_answer)
                        translate_end = time.time()
                        if self.debug_mode :
                            print("영어 -> 한국어 번역 완료, 번역 시간 : ", translate_end - translate_start)
                    except Exception as e :
                        print(f"번역 중 오류 발생 : {e}")
                        translated_answer = f"[번역 오류] {final_answer}"
                else :
                    translated_answer = f"[번역 모듈 없음] {final_answer}"
            # 결과 준비
            response = {
                "답변": raw_answer,
                "후처리": final_answer,
                "문서 일부": context,
                "question_en": query,
                "answer_en": raw_answer,
                # "is_complex": is_complex,
                # "필터링_결과": all_filtered_results
            }
            
            if translated_answer :
                response["번역된 답변"] = translated_answer
                
            # 복합 질문인 경우 하위 질문 정보 추가
            # if is_complex:
            #     response["sub_questions"] = sub_questions
            #     response["sub_search_results"] = all_search_results
            #     response["filtered_search_results"] = all_filtered_results
            # else:
            #     response["검색_결과"] = search_results
            #     response["필터링_결과"] = all_filtered_results
            
            # 결과 저장
            try:
                # result_path가 없으면 상위 스코프나 기본값으로 설정
                result_path = getattr(self, 'result_path', '../result')
                
                # 알파값으로 폴더 경로 생성
                # alpha_str = f"{alpha:.1f}"
                # db_type = "chromadb" if self.use_vector_db else "memory"
                # question_type = "complex" if is_complex else "simple"
                # result_path = os.path.join(result_path, f"{db_type}_{question_type}_alpha_{alpha_str}")
                
                # 폴더가 없으면 생성
                os.makedirs(result_path, exist_ok=True)
                
                # filtered_results_str = ""
                # filtered_results_str = self._format_filtered_results(response["필터링_결과"])

                # 파일 저장
                if self.debug_mode:
                    print(f"저장 시도: {result_path}")
                save_response_to_file(
                    query=query,
                    answer=response["답변"],
                    final_answer=response["번역된 답변"],
                    context=response["문서 일부"],
                    folder=result_path
                    # filtered_results=filtered_results_str
                )
                if self.debug_mode:
                    print(f"저장 완료: {result_path}")
            except Exception as e:
                print(f"결과 저장 중 오류 발생: {e}")
            
            return response
            
        except Exception as e:
            error_msg = f"[생성 오류] {str(e)}"
            print(error_msg)
            import traceback
            traceback.print_exc()
            return {"답변": error_msg, "후처리": error_msg}
    
    def _load_prompt(self, path):
        """프롬프트 템플릿 로드"""
        try:
            with open(path, "r", encoding="utf-8") as f:
                return f.read()
        except Exception as e:
            print(f"[ERROR] 프롬프트 로드 실패: {e}")
            raise
    
    
    def _extract_answer_content(self, text):
        """응답에서 답변 부분만 추출"""
        pattern = r"(?:<\|?|<|)?\|?answer\|?(?:\|?>|>)?(.*?)(?:<\|?|<|)?\|?endanswer\|?(?:\|?>|>)?"
        match = re.search(pattern, text, re.DOTALL | re.IGNORECASE)
        return match.group(1).strip() if match else text.strip()
    
    def _remove_chinese_characters(self, text):
        """중국어 문자 제거"""
        return re.sub(r'[\u4E00-\u9FFF]', '', text)
    
    def get_collection_stats(self):
        """벡터 DB 컬렉션 통계 조회"""
        if hasattr(self.searcher, 'vector_db') and hasattr(self.searcher.vector_db, 'get_collection_stats'):
            return self.searcher.vector_db.get_collection_stats()
        return {"error": "벡터 DB 통계를 조회할 수 없습니다."}
    
    def toggle_vector_db(self, use_vector_db=None):
        """벡터 DB 사용 여부 전환"""
        if use_vector_db is not None:
            self.use_vector_db = use_vector_db
        else:
            self.use_vector_db = not self.use_vector_db
        
        print(f"벡터 DB 사용 여부: {self.use_vector_db}")
        return self.use_vector_db
    
    def set_debug_mode(self, debug_mode=True):
        """디버그 모드 설정"""
        self.debug_mode = debug_mode
        return self.debug_mode

# %%
# vector_db = ChromaVectorDB(
#     embedding_model=embedding_loader,
#     persist_directory="./chroma_db",
#     collection_name="Gray_en"
# )
# vector_db.delete_collection()
# print("기존 컬렉션 삭제 완료")

# %%
from model_loader.config import *
from chroma_db import *
import chromadb
import os
import numpy as np
import time

questions = [
    "How do the processes of ossification differ between the skull and the vertebral column, and what are the developmental implications of these differences?",
    "Compare and contrast the ovum and spermatozoon in terms of their development, maturation process, and contribution to fertilization, explaining how their specialized features facilitate their respective roles.",
    "How does the structure and development of the vertebral column demonstrate both functional adaptation and evolutionary history, and what role does the notochord play in these processes?",
    "How do the various stages of embryonic implantation, placental development, and fetal membrane formation collectively establish the maternal-fetal interface, and what are the critical structural and functional relationships that develop during this process?",
    "What are the primary and secondary curves of the vertebral column, how do they develop chronologically, and what functional advantages do they provide for bipedal locomotion?",
    "How does the skull's composition of dermal and cartilaginous bones reflect both its developmental origins and its functional requirements, and what are the key differences in the ossification patterns of these two bone types?",
    "Explain the process of fertilization and early embryonic development, describing how the male and female pronuclei interact to form the segmentation nucleus, and how this leads to the formation of the blastocyst and subsequent implantation.",
    "How does the development of the thoracic cage from its embryonic origins to its adult form demonstrate both functional adaptation and regional specialization, and what are the key differences between true and false ribs in terms of their structure and functions?",
    "Compare and contrast the development and structural features of the cervical, thoracic, and lumbar vertebrae, explaining how their specialized characteristics relate to their differing functional roles.",
    "How does the structure of the placenta facilitate its multiple physiological functions while maintaining separation between maternal and fetal circulations, and what developmental stages are critical to establishing this complex organ?",
    # "How do the primitive embryonic germ layers (ectoderm, mesoderm, and endoderm) contribute to the formation of the skeletal, nervous, and digestive systems, and what key developmental interactions occur between these systems?",
    # "Compare the processes of intramembranous and intracartilaginous ossification, detailing their anatomical sites, cellular mechanisms, and developmental timelines, and explain how these different processes create the various bones of the skeletal system.",
    # "Describe the embryonic development of the branchial region and explain how its derivatives contribute to adult craniofacial structures, detailing the specific fates of each branchial arch and the developmental abnormalities that can occur when this process is disrupted.",
    # "What is the sequence of events that occurs during the maturation of an ovum, and how does this process differ from spermatogenesis in terms of cellular divisions, chromosome reduction, and the number and viability of resulting cells?",
    # "Describe the development of the limbs from their initial appearance as limb buds to their final form, explaining the molecular signals, tissue interactions, and morphogenetic movements involved in this process, and how developmental abnormalities can lead to congenital limb defects.",
    # "Compare the structure and ossification patterns of the vertebral column, sternum, and ribs, explaining how these components develop together to form the thoracic cage, and how variations in their development can lead to congenital abnormalities.",
    # "How does the skull's development from its embryonic origins demonstrate both segmentation patterns similar to the vertebral column and unique craniofacial adaptations, and what are the key differences in ossification between the cranial base, vault, and facial bones?",
    # "Describe the embryonic development of the body cavities, explaining how the coelom divides to form the pericardial, pleural, and peritoneal cavities, and how the diaphragm develops to separate the thoracic and abdominal compartments.",
    # "How do the neural tube and notochord interact during development to establish the central nervous system and axial skeleton, and what are the key signaling molecules and inductive interactions that guide this process?",
    # "Explain the processes of implantation and placentation, detailing the roles of the trophoblast, decidua, and extraembryonic membranes in establishing the maternal-fetal interface, and how abnormalities in these processes can lead to pregnancy complications.",
    "Compare and contrast the three parts of the axillary artery in terms of their anatomical relations and clinical significance, explaining how these relationships might impact surgical approaches and potential complications during procedures in the axilla.",
    "Describe the course and major branches of the brachial artery, explaining how its anatomical variations affect the collateral circulation after ligation of different segments of the artery, and discuss the clinical implications of these variations for traumatic injuries and surgical procedures in the upper limb.",
    "Analyze the arterial supply of the hand, detailing the formation and clinical significance of the superficial and deep palmar arches, their anastomotic patterns, and how these dual systems provide redundancy that affects treatment strategies for hand injuries and vascular disorders.",
    "Examine the pathway and variations of the radial artery from its origin to the formation of the deep palmar arch, discussing the surgical implications of these variations for procedures such as radial artery harvesting for coronary bypass grafting and the creation of arteriovenous fistulas for hemodialysis access.",
    "Compare and contrast the anatomical course, relations, and branching patterns of the ulnar and radial arteries in the forearm and hand, analyzing how these differences impact the clinical assessment and management of vascular injuries to these vessels.",
    "Analyze the anatomical basis of collateral circulation around the elbow joint following ligation or obstruction of the brachial artery, explaining how the network of anastomosing vessels ensures tissue viability and discussing the clinical implications of this vascular arrangement for traumatic injuries and surgical interventions.",
    "Describe the anatomical boundaries and contents of the axilla, explaining how the neurovascular structures are arranged within this space and discussing the clinical implications of these relationships for procedures such as axillary lymph node dissection, brachial plexus blocks, and approaches to the shoulder joint.",
    "Explain the origin, course, and branching pattern of the abdominal aorta, describing how its major visceral and parietal branches supply different organ systems, and analyzing the clinical significance of important vascular landmarks and anastomoses for surgical procedures and management of vascular diseases.",
    "Compare the anatomical relationships and branching patterns of the axillary and brachial arteries, discussing how these relationships provide landmarks for surgical approaches, and analyzing the implications of anatomical variations for diagnostic procedures, treatment of traumatic injuries, and vascular access in these regions.",
    "Describe the arterial supply to the rectum and anal canal, explaining how the superior, middle, and inferior rectal arteries form a complex anastomotic network, and analyze the clinical significance of this vascular arrangement for colorectal surgical procedures, management of hemorrhoids, and potential consequences of vascular compromise in this region.",
    # "Analyze the vascular supply of the hand through the radial and ulnar arteries, explaining how their terminal branches form the superficial and deep palmar arches, and discuss the clinical implications of these anastomotic patterns for hand injuries, surgical approaches, and the assessment of hand perfusion.",
    # "Describe the origin, course, and major branches of the internal iliac (hypogastric) artery, explaining how its anatomy differs in the fetus compared to the adult, and discuss the clinical significance of these vessels in pelvic surgery, trauma management, and vascular embolization procedures.",
    # "Explain the branching pattern and distribution of the celiac trunk, detailing how its three major divisions (left gastric, splenic, and hepatic arteries) supply the upper abdominal organs, and analyze the clinical significance of their anatomical variations, collateral pathways, and relationships to surrounding structures.",
    # "Compare and contrast the anatomical relationships and distribution patterns of the superior and inferior mesenteric arteries, discussing their embryological significance, anastomotic connections, and the clinical implications of these vascular arrangements for intestinal ischemia, surgical resections, and collateral circulation in occlusive disease.",
    # "Analyze the anatomical relationships and variations of the renal arteries, explaining their importance in surgical approaches to the kidney, renal transplantation, and interventional procedures, while also discussing the clinical significance of accessory renal vessels and their potential role in renovascular hypertension.",
    # "Describe the origin, course, and branches of the external iliac artery, explaining its relationships to surrounding structures and analyzing the clinical implications of these anatomical features for vascular access procedures, traumatic injuries, and surgical approaches to the lower abdomen and pelvis.",
    # "Compare and contrast the arterial supply of the male and female pelvic organs, describing how the internal iliac (hypogastric) artery and its branches distribute blood to these structures, and discuss the clinical significance of these vascular patterns for surgical procedures, hemorrhage control, and interventional radiological techniques.",
    # "Describe the anatomical course and branching pattern of the internal pudendal artery in males and females, explaining how this vessel supplies the perineum and external genitalia, and discuss the clinical significance of its relationships for urogenital and anorectal procedures, traumatic injuries, and erectile dysfunction.",
    # "Explain the anatomical relationships and branching pattern of the thoracic aorta, describing how its branches supply the thoracic walls and viscera, and discuss the clinical significance of these vascular patterns in thoracic surgery, trauma management, and the development of collateral circulation in cases of aortic coarctation.",
    # "Analyze the surgical approaches to the axillary artery and its branches, discussing the potential complications of these procedures, strategies for minimizing vascular injury, and the management of axillary artery trauma in relation to the surrounding neurovascular structures.",
    "How does the female urethra compare to the male urethra in terms of structure, length, and coats? What specific differences in epithelial lining exist between them?",
    "What is the developmental journey of the testes from fetal life to adulthood, and what abnormalities can occur during this process? How do these abnormalities affect fertility and health?",
    "What are the key components of the spermatic cord, and how do they relate to the blood supply, lymphatic drainage, and innervation of the testes? What clinical implications might arise from this anatomical arrangement?",
    "Describe the structure of the tunica vaginalis and its relationship to the peritoneum. How does it contribute to various testicular pathologies, especially different types of hydrocele, and what distinguishes these conditions from each other?",
    "Compare and contrast the structure and function of the vesiculae seminales, prostate gland, and bulbourethral glands. How do their secretions contribute to the composition of semen, and what are the clinical implications of diseases affecting these accessory glands?",
    "How is the penis structured for its dual role in urination and reproduction? What vascular and nervous mechanisms enable erection, and how does this relate to the anatomical organization of the corpora cavernosa and corpus spongiosum?",
    "What is the anatomical relationship between the ovaries, uterine tubes, and uterus? How does this arrangement facilitate conception, and what pathologies might develop when abnormalities occur in this system?",
    "How do the structural and functional changes of the uterus vary across a woman's lifecycle, from fetal development through puberty, pregnancy, and menopause? What cyclical changes occur during the menstrual cycle?",
    "Compare the anatomy of the vagina and its relationship to surrounding structures with that of the male urethra. How do these differences affect susceptibility to infections and other pathological conditions?",
    "What is the embryological origin and development of the ovaries? How does this relate to the structures found in the adult ovary, and what implications does this have for the development of ovarian pathologies?",
    # "Describe the structure and function of the clitoris and penis as homologous organs. How do they compare in terms of erectile tissue arrangement, vascular supply, innervation, and embryological development? What implications does this have for sexual response and dysfunction?",
    # "How do the vestibular bulbs in females compare anatomically and functionally to the corpus spongiosum/bulb of the penis in males? What is their role in sexual arousal, and how do they relate to the greater vestibular glands and other external genital structures?",
    # "What is the anatomical and functional relationship between the mammary glands and the reproductive system? How do they develop embryologically, and what hormonal changes affect their structure and function throughout a woman's life from puberty through pregnancy, lactation, and menopause?",
    # "How does the structure of the uterine tube facilitate the transport of ova and fertilization? What are the different segments of the tube, their specific functions, and how does ectopic pregnancy develop in relation to tubal anatomy?",
    # "What is the structure and function of the prostate gland, and how does its anatomy relate to common pathologies? How do the different anatomical zones of the prostate correspond to the development of conditions like benign prostatic hyperplasia and prostate cancer?",
    # "Compare and contrast the structure, development, and functions of the thyroid gland with the other major endocrine glands. How does the embryological origin of the thyroid relate to its adult position and function, and what common pathologies affect this gland?",
    # "How do the anatomical features of the female reproductive system contribute to both normal fertility and common infertility issues? Consider the ovaries, fallopian tubes, uterus, cervix, and vagina in your analysis, and explain how structural or functional abnormalities in each can impact conception and pregnancy.",
    # "How does the structure of the scrotum and its layers provide optimal temperature regulation for the testes? What vascular adaptations contribute to this function, and how do pathological conditions like varicocele affect testicular function?",
    # "How do the anatomical and histological structures of the breast change throughout a woman's life, particularly during pregnancy and lactation? What cellular mechanisms enable milk production and ejection, and how does the transition from colostrum to mature milk occur?",
    # "Compare and contrast the structure, embryological origin, and function of the male and female external genitalia. How do homologous structures differ in their adult form, and what hormonal factors influence their development and later function?"
]
category_list = ["16"] * 30



generation_loader = generation_loader
# result_base_path = "../result"
qa_system = CarManualQA(
        generation_loader=generation_loader,
        data_folder="./data",
        prompt_path_en="./prompts/en/generation/gemma3/generation_prompt3.txt",
        result_path="./result/5월16일/en-gemma3",
        use_vector_db=True,
        persist_directory="./chroma_db",
        collection_name="Gray",
        language="en"
    )
    
alpha_values = [round(i * 0.1, 1) for i in range(11)]
for alpha in alpha_values :
    alpha_result_path = f"./result/5월16일/en-gemma3/alpha_{alpha}"

    os.makedirs(alpha_result_path, exist_ok=True)

    qa_system.result_path = alpha_result_path

    print(f"\n======================Alpha 값 : {alpha}======================")

    for q, c in zip(questions, category_list):
        print(f"\n새 쿼리: {q}, 카테고리: {c}")
        
        
        # 검색 결과 가져오기 (alpha 값 전달)
        # search_results = test_search_only(q, c, alpha=alpha_formatted)
        # context = "\n\n".join([result["chunk"] for result in search_results])
        
        start_time = time.time()
        # 응답 생성 (alpha 값 전달)
        chroma_response = qa_system.generate_response(q, c, top_n=5, alpha=alpha, target_language="ko")
        end_time = time.time()
        
        
        
        elapsed_time = end_time - start_time

        print(f"추론시간 : {elapsed_time}")
        print(f"LLM 답변: {chroma_response['후처리']}")
# Out:
# 기존 컬렉션 'Gray_en'을 로드했습니다.
#
# ======================Alpha 값 : 0.0======================
#
# 새 쿼리: How do the processes of ossification differ between the skull and the vertebral column, and what are the developmental implications of these differences?, 카테고리: 16
# 캐시에서 로드 완료: ./data/GrayAnatomy_Formatted.md
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16106
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16107
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16108
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16109
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16110
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16111
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16112
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16113
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16114
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16115
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16116
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16117
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16118
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16119
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16120
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16121
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16122
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16123
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16124
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16125
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16126
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16127
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16128
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16129
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16130
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16131
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16132
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16133
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16134
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16135
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16136
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16137
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16138
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16139
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16140
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16141
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16142
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16143
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16144
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16145
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16146
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16147
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16148
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16149
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16150
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16151
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16152
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16153
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16154
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16155
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16156
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16157
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16158
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16159
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16160
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16161
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16162
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16163
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16164
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16165
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16166
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16167
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16168
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16169
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16170
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16171
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16172
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16173
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16174
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16175
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16176
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16177
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16178
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16179
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16180
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16181
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16182
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16183
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16184
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16185
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16186
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16187
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16188
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16189
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16190
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16191
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16192
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16193
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16194
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16195
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16196
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16197
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16198
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16199
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16200
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16201
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16202
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16203
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16204
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16205
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16206
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16207
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16208
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16209
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16210
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16211
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16212
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16213
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16214
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16215
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16216
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16217
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16218
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16219
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16220
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16221
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16222
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16223
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16224
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16225
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16226
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16227
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16228
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16229
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16230
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16231
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16232
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16233
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16234
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16235
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16236
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16237
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16238
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16239
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16240
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16241
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16242
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16243
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16244
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16245
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16246
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16247
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16248
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16249
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16250
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16251
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16252
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16253
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16254
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16255
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16256
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16257
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16258
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16259
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16260
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16261
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16262
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16263
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16264
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16265
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16266
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16267
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16268
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16269
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16270
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16271
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16272
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16273
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16274
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16275
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16276
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16277
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16278
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16279
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16280
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16281
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16282
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16283
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16284
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16285
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16286
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16287
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16288
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16289
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16290
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16291
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16292
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16293
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16294
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16295
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16296
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16297
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16298
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16299
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16300
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16301
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16302
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16303
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16304
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16305
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16306
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16307
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16308
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16309
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16310
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16311
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16312
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16313
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16314
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16315
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16316
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16317
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16318
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16319
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16320
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16321
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16322
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16323
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16324
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16325
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16326
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16327
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16328
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16329
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16330
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16331
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16332
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16333
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16334
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16335
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16336
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16337
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16338
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16339
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16340
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16341
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16342
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16343
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16344
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16345
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16346
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16347
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16348
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16349
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16350
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16351
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16352
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16353
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16354
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16355
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16356
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16357
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16358
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16359
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16360
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16361
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16362
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16363
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16364
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16365
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16366
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16367
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16368
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16369
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16370
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16371
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16372
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16373
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16374
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16375
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16376
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16377
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16378
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16379
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16380
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16381
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16382
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16383
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16384
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16385
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16386
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16387
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16388
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16389
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16390
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16391
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16392
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16393
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16394
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16395
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16396
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16397
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16398
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16399
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16400
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16401
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16402
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16403
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16404
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16405
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16406
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16407
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16408
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16409
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16410
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16411
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16412
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16413
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16414
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16415
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16416
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16417
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16418
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16419
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16420
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16421
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16422
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16423
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16424
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16425
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16426
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16427
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16428
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16429
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16430
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16431
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16432
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16433
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16434
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16435
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16436
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16437
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16438
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16439
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16440
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16441
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16442
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16443
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16444
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16445
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16446
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16447
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16448
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16449
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16450
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16451
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16452
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16453
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16454
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16455
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16456
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16457
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16458
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16459
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16460
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16461
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16462
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16463
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16464
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16465
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16466
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16467
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16468
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16469
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16470
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16471
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16472
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16473
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16474
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16475
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16476
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16477
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16478
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16479
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16480
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16481
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16482
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16483
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16484
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16485
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16486
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16487
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16488
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16489
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16490
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16491
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16492
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16493
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16494
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16495
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16496
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16497
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16498
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16499
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16500
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16501
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16502
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16503
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16504
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16505
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16506
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16507
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16508
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16509
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16510
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16511
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16512
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16513
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16514
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16515
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16516
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16517
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16518
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16519
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16520
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16521
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16522
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16523
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16524
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16525
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16526
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16527
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16528
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16529
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16530
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16531
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16532
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16533
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16534
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16535
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16536
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16537
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16538
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16539
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16540
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16541
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16542
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16543
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16544
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16545
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16546
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16547
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16548
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16549
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16550
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16551
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16552
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16553
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16554
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16555
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16556
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16557
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16558
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16559
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16560
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16561
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16562
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16563
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16564
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16565
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16566
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16567
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16568
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16569
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16570
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16571
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16572
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16573
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16574
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16575
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16576
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16577
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16578
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16579
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16580
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16581
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16582
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16583
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16584
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16585
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16586
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16587
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16588
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16589
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16590
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16591
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16592
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16593
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16594
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16595
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16596
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16597
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16598
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16599
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16600
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16601
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16602
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16603
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16604
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16605
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16606
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16607
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16608
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16609
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16610
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16611
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16612
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16613
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16614
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16615
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16616
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16617
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16618
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16619
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16620
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16621
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16622
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16623
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16624
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16625
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16626
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16627
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16628
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16629
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16630
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16631
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16632
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16633
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16634
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16635
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16636
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16637
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16638
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16639
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16640
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16641
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16642
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16643
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16644
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16645
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16646
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16647
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16648
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16649
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16650
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16651
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16652
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16653
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16654
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16655
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16656
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16657
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16658
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16659
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16660
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16661
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16662
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16663
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16664
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16665
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16666
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16667
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16668
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16669
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16670
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16671
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16672
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16673
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16674
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16675
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16676
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16677
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16678
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16679
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16680
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16681
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16682
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16683
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16684
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16685
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16686
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16687
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16688
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16689
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16690
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16691
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16692
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16693
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16694
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16695
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16696
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16697
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16698
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16699
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16700
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16701
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16702
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16703
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16704
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16705
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16706
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16707
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16708
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16709
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16710
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16711
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16712
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16713
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16714
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16715
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16716
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16717
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16718
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16719
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16720
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16721
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16722
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16723
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16724
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16725
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16726
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16727
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16728
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16729
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16730
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16731
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16732
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16733
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16734
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16735
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16736
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16737
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16738
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16739
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16740
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16741
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16742
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16743
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16744
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16745
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16746
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16747
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16748
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16749
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16750
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16751
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16752
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16753
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16754
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16755
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16756
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16757
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16758
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16759
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16760
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16761
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16762
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16763
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16764
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16765
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16766
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16767
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16768
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16769
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16770
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16771
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16772
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16773
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16774
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16775
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16776
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16777
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16778
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16779
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16780
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16781
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16782
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16783
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16784
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16785
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16786
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16787
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16788
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16789
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16790
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16791
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16792
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16793
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16794
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16795
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16796
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16797
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16798
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16799
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16800
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16801
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16802
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16803
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16804
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16805
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16806
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16807
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16808
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16809
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16810
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16811
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16812
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16813
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16814
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16815
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16816
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16817
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16818
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16819
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16820
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16821
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16822
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16823
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16824
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16825
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16826
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16827
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16828
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16829
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16830
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16831
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16832
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16833
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16834
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16835
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16836
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16837
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16838
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16839
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16840
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16841
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16842
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16843
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16844
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16845
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16846
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16847
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16848
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16849
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16850
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16851
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16852
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16853
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16854
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16855
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16856
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16857
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16858
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16859
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16860
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16861
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16862
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16863
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16864
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16865
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16866
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16867
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16868
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16869
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16870
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16871
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16872
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16873
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16874
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16875
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16876
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16877
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16878
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16879
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16880
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16881
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16882
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16883
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16884
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16885
# Add of existing embedding ID: GrayAnatomy_Formatted.md_16886
# ...
#
# **I. Structural Basis of Placental Function**
#
# The placenta's structure is optimized to maximize surface area for exchange while upholding circulatory separation. The key structural components and their functional contributions are:
#
# * **Chorionic Villi:** These finger-like projections extend from the chorionic plate (fetal portion of the placenta) into the maternal decidua basalis (maternal portion). They are the primary functional units of the placenta, dramatically increasing the surface area available for exchange.  Villi undergo branching, creating *secondary, tertiary, and even quaternary villi*, further expanding the interface.
# * **Syncytiotrophoblast:** This outer layer of the villi is a multinucleated, continuously renewed layer formed by the fusion of cytotrophoblast cells.  It directly interfaces with maternal blood, facilitating nutrient/gas exchange and hormone production. Its unique characteristic is being *avascular* – nutrients diffuse *to* it from the maternal circulation and products diffuse *from* it to the maternal blood.
# * **Cytotrophoblast:**  Lying beneath the syncytiotrophoblast, this cellular layer provides a proliferative source for syncytiotrophoblast renewal and forms a cellular “shell” around the villi, contributing to structural support.  Columns of cytotrophoblast extend from the chorionic plate towards the decidua, anchoring the villi.
# * **Villus Core:** Each villus contains a core of connective tissue containing fetal capillaries, veins, and arterioles.  These vessels are the conduits for oxygen, nutrients, and waste products between the fetal circulation and the villous exchange surface.
# * **Maternal Intervillous Space:**  The area surrounding the chorionic villi is filled with maternal blood, delivered via the spiral arteries. This blood circulates within the intervillous space, bathing the villi and enabling exchange. Importantly, the maternal blood does *not* directly mix with fetal blood.
# * **Decidua Basalis:**  The modified endometrium at the uterine implantation site forms the maternal portion of the placenta. It provides support, nutrition, and immune modulation, and contains the maternal spiral arteries supplying blood to the intervillous space.
#
# **Maintaining Circulatory Separation:**  The crucial separation of maternal and fetal circulations is achieved through multiple layers:
#
# * **The cytotrophoblast layer:** While not fully impermeable, it forms a cellular barrier.
# * **The basement membranes of the syncytiotrophoblast and fetal capillaries:** These act as selective filters.
# * **Tight junctions between syncytiotrophoblast cells:**  These restrict paracellular transport of larger molecules.
#
# This separation is *not absolute*; selective permeability allows passage of gases, nutrients, and waste, while preventing the transfer of blood cells and most proteins, protecting both maternal and fetal systems.
#
#
#
# **II. Placental Physiological Functions & Structural Correlation**
#
# The placenta performs a multitude of functions, all enabled by its unique structure:
#
# * **Gas Exchange:**  The vast surface area of chorionic villi, combined with the thinness of the placental membrane, facilitates efficient diffusion of oxygen from maternal blood to fetal blood and carbon dioxide in the reverse direction.
# * **Nutrient Transfer:** Glucose, amino acids, fatty acids, vitamins, and minerals are transported across the placental membrane via diffusion, facilitated diffusion, and active transport.  Specific transporters are expressed in both the syncytiotrophoblast and fetal capillaries to maximize efficiency.
# * **Waste Removal:**  Fetal metabolic waste products (urea, creatinine, bilirubin) diffuse from fetal blood into maternal blood for excretion by the maternal kidneys and liver.
# * **Immune Protection:** The placenta acts as a selective barrier against maternal immune cells and antibodies, protecting the fetus. It also produces immunosuppressive factors to prevent maternal rejection of the “foreign” fetal tissues. While providing protection, it *does* allow for the transfer of certain maternal antibodies (IgG) conferring passive immunity to the fetus.
# * **Endocrine Function:** The placenta is a major endocrine organ, producing hormones crucial for maintaining pregnancy and fetal development. These include:
#     * **Human Chorionic Gonadotropin (hCG):** Maintains the corpus luteum in early pregnancy.
#     * **Human Placental Lactogen (hPL):** Alters maternal metabolism to favor glucose delivery to the fetus.
#     * **Progesterone & Estrogen:** Maintain the uterine lining and prepare the mother for lactation.
#     * **Relaxin:**  Relaxes pelvic ligaments to facilitate delivery.
#
#
#
# **III. Critical Developmental Stages of the Placenta**
#
# The placenta’s development is a carefully orchestrated process involving several key stages:
#
# * **Week 0-3 (Pre-implantation):** Following fertilization, the zygote undergoes cleavage and develops into a blastocyst.  Trophoblast cells differentiate into *cytotrophoblast* and *syncytiotrophoblast*.  Initial implantation occurs, and the syncytiotrophoblast invades the endometrium.
# * **Week 4-8 (Villous Formation & Establishment of Circulation):** Chorionic villi begin to form, initially appearing as solid cellular projections.  Maternal blood spaces develop within the villi, establishing a primitive circulatory system.  Spiral arteries begin to remodel to provide increased blood flow. This is a *critical period* – disruptions can lead to early pregnancy loss.
# * **Week 8-12 (Completion of Placental Circulation & Organogenesis):**  Maternal blood fills the intervillous space, establishing complete placental circulation.  Spiral artery remodeling is completed, ensuring adequate perfusion.  Fetal capillaries develop within the villi.  Organogenesis in the fetus is rapid, demanding increased placental function.
# * **Second & Third Trimesters (Placental Growth & Maturation):** The placenta continues to grow in size and weight, increasing surface area for exchange.  The villous architecture becomes more complex.  Placental weight increases significantly, ensuring adequate support for the growing fetus.  In late gestation, some degree of villous fibrosis and reduced growth can occur, indicating functional maturation.
#
# **Conclusion:**
#
# The placenta's complex structure is inextricably linked to its diverse physiological functions. The unique arrangement of chorionic villi, the selective permeability of the placental barrier, and the carefully orchestrated developmental stages all contribute to its success as a vital organ supporting fetal development. Understanding these intricate relationships is fundamental to comprehending the complexities of pregnancy and addressing potential complications arising from placental dysfunction.
# 가상 문서 생성 시간 : 47.73998665809631
# [생성 오류] ChromaVectorDB.search() got an unexpected keyword argument 'query_texts'
# 추론시간 : 54.21631336212158
# LLM 답변: [생성 오류] ChromaVectorDB.search() got an unexpected keyword argument 'query_texts'
#
# 새 쿼리: Compare and contrast the three parts of the axillary artery in terms of their anatomical relations and clinical significance, explaining how these relationships might impact surgical approaches and potential complications during procedures in the axilla., 카테고리: 16
# 이미 로드된 파일입니다: ./data/GrayAnatomy_Formatted.md
# 파일 로드 시간 :  6.0558319091796875e-05
# Traceback (most recent call last):
#   File "/tmp/ipykernel_2380510/1323512587.py", line 401, in generate_response
#     search_results = self.searcher.search(
#                      ^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_2380510/2984177227.py", line 210, in search
#     db_results = self.vector_db.search(
#                  ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: ChromaVectorDB.search() got an unexpected keyword argument 'query_texts'
# 가상 문서 : ## The Axillary Artery: A Comparative Analysis of its Three Parts – Anatomical Relations, Clinical Significance & Surgical Implications
#
# The axillary artery is a crucial vessel supplying the upper limb. Understanding its anatomy, particularly the divisions into its three parts, is paramount for surgeons and clinicians operating in the axilla. Each part exhibits distinct anatomical relations and therefore carries unique clinical considerations and impacts surgical approaches. This document will comprehensively compare and contrast these three segments, detailing their relationships and implications for procedures in the axilla.
#
# **I. Overview of the Axillary Artery and its Divisions**
#
# The axillary artery is a continuation of the subclavian artery, typically beginning at the lateral border of the first rib and becoming the brachial artery at the lower border of the teres major muscle. It is conventionally divided into three parts at the pectoralis minor muscle. This division isn't strictly anatomical, but clinically useful as the muscle serves as a landmark and influences the relationship of the artery to surrounding structures.
#
# **II. Part 1: From the First Rib to the Pectoralis Minor**
#
# * **Anatomical Relations:** This segment travels superficially, lying medial to the clavicle, covered by the clavicular head of the sternocleidomastoid, the subclavian vein laterally, and the pleura and lung superiorly.  It rests upon the first rib and is in close proximity to the brachial plexus, specifically the superior and middle trunks, which cross *superior* to it. The thoracodorsal nerve also lies nearby.
# * **Clinical Significance:** This portion is vulnerable to injury from penetrating trauma, particularly from supraclavicular or infraclavicular approaches.  Compression can occur due to thoracic outlet syndrome, though the subclavian artery is more commonly involved.  Aneurysms in this segment, though rare, present a significant risk of neurological compromise due to compression of the brachial plexus.
# * **Surgical Implications:** Surgical access to this segment is often through supraclavicular or infraclavicular incisions for procedures like central venous catheter placement or subclavian artery repair. Careful dissection is critical to avoid injury to the brachial plexus and surrounding nerves. The proximity to the pleura necessitates cautious handling to prevent pneumothorax.  Supraclavicular approaches require careful attention to identify and protect the phrenic nerve, which lies superficial to the artery.
#
#
#
# **III. Part 2: Behind the Pectoralis Minor**
#
# * **Anatomical Relations:** This is the most protected portion of the artery.  It runs behind the pectoralis minor muscle, nestled within the axillary sheath formed by the anterior aspect of the subscapularis muscle and the fascia covering it. The axillary vein lies laterally, and the median nerve and the long thoracic nerve lie anterior to the artery (and often adjacent to the pectoralis minor).  The lateral pectoral nerve crosses *superficial* to the artery as it courses to supply the pectoralis major.
# * **Clinical Significance:** This segment is relatively protected from direct trauma. However, it can be injured during surgical procedures involving the pectoralis major or minor, like mastectomy with axillary node dissection.  The long thoracic nerve is particularly vulnerable during these procedures, potentially leading to winged scapula. Aneurysms are less common here due to the protected nature of the segment but can occur, presenting with a pulsatile mass in the axilla.
# * **Surgical Implications:** Axillary node dissection during breast cancer surgery frequently involves careful identification and preservation of the artery. The long thoracic nerve’s proximity necessitates meticulous dissection, and injury to it should be avoided or repaired. The axillary vein lies directly lateral and is often mobilized along with the artery during complex procedures.  Careful attention to hemostasis is crucial due to the potential for significant bleeding from the intercostal vessels within the axilla.
#
#
# **IV. Part 3: Inferior to the Pectoralis Minor**
#
# * **Anatomical Relations:** The artery now lies inferior to the pectoralis minor muscle, transitioning into the brachial artery. It lies medial to the bicipital groove of the humerus and is accompanied by the median, ulnar, and radial nerves. The thoracodorsal nerve and subscapular vessels lie posterior to the artery.
# * **Clinical Significance:** This segment is susceptible to injury during shoulder dislocations or fractures. The brachial artery and accompanying nerves can be compressed or damaged.  Aneurysms are rare but may present with distal ischemia or neurological symptoms.
# * **Surgical Implications:** Surgical access to this segment is often gained through an anterior approach to the shoulder or via an axillary incision. Procedures may include repair of brachial artery injuries following trauma, reconstruction for arterial insufficiency, or exploration for a suspected aneurysm. The close proximity of the median, ulnar, and radial nerves necessitates meticulous dissection to avoid nerve injury.  The subscapular vessels are at risk during deep dissection for aneurysm repair or exploration.
#
#
#
# **V.  Comparative Table Summarizing Key Differences:**
#
# | Feature | Part 1 | Part 2 | Part 3 |
# |---|---|---|---|
# | **Location** | Superficial, lateral to first rib | Behind pectoralis minor | Inferior to pectoralis minor |
# | **Protective Structures** | Minimal | Pectoralis minor, axillary sheath | Minimal |
# | **Nearby Nerves** | Brachial plexus (superior & middle trunks) | Long thoracic, Median | Median, Ulnar, Radial |
# | **Clinical Vulnerability** | Trauma, Compression (TOS) | Surgical Injury (Node Dissection) | Trauma, Shoulder Dislocation |
# | **Surgical Approach** | Supraclavicular, Infraclavicular | Axillary, Breast Surgery Incisions | Anterior Shoulder, Axillary |
# | **Key Risk during Surgery** | Brachial Plexus Injury, Pneumothorax | Long Thoracic Nerve Injury, Vein Injury | Nerve Injury, Subscapular vessel injury |
#
#
#
#
# **VI. Conclusion**
#
# A thorough understanding of the anatomical relationships of the three parts of the axillary artery is critical for clinicians and surgeons operating in the axilla.  Each segment presents unique challenges and risks.  Careful preoperative planning, meticulous surgical technique, and a comprehensive knowledge of the surrounding structures are essential to minimize complications and achieve optimal patient outcomes. Surgeons must adapt their approach and prioritize the preservation of surrounding neurovascular structures based on the specific anatomical region they are operating in.
#
#
#
# **Disclaimer:** This information is for educational purposes only and should not be considered medical advice. Always consult with a qualified healthcare professional for any health concerns or before making any decisions related to your health or treatment.
# 가상 문서 생성 시간 : 46.222445011138916
# [생성 오류] ChromaVectorDB.search() got an unexpected keyword argument 'query_texts'
# 추론시간 : 53.01755428314209
# LLM 답변: [생성 오류] ChromaVectorDB.search() got an unexpected keyword argument 'query_texts'
#
# 새 쿼리: Describe the course and major branches of the brachial artery, explaining how its anatomical variations affect the collateral circulation after ligation of different segments of the artery, and discuss the clinical implications of these variations for traumatic injuries and surgical procedures in the upper limb., 카테고리: 16
# 이미 로드된 파일입니다: ./data/GrayAnatomy_Formatted.md
# 파일 로드 시간 :  4.792213439941406e-05
# Traceback (most recent call last):
#   File "/tmp/ipykernel_2380510/1323512587.py", line 401, in generate_response
#     search_results = self.searcher.search(
#                      ^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_2380510/2984177227.py", line 210, in search
#     db_results = self.vector_db.search(
#                  ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: ChromaVectorDB.search() got an unexpected keyword argument 'query_texts'

# %%
# import fitz  # PyMuPDF
# import os
# import io
# from PIL import Image

# def extract_images_from_pdf(pdf_path, output_dir):
#     """
#     PDF 파일에서 이미지를 추출하여 지정된 폴더에 저장합니다.
    
#     Args:
#         pdf_path (str): PDF 파일 경로
#         output_dir (str): 이미지를 저장할 폴더 경로
#     """
#     # 출력 디렉토리가 없으면 생성
#     if not os.path.exists(output_dir):
#         os.makedirs(output_dir)
#         print(f"생성된 디렉토리: {output_dir}")
    
#     # PDF 파일 열기
#     pdf_document = fitz.open(pdf_path)
#     image_count = 0
    
#     # 각 페이지에서 이미지 추출
#     for page_num, page in enumerate(pdf_document):
#         image_list = page.get_images(full=True)
        
#         for img_index, img_info in enumerate(image_list):
#             xref = img_info[0]
#             base_image = pdf_document.extract_image(xref)
#             image_bytes = base_image["image"]
#             image_ext = base_image["ext"]
            
#             # 이미지 파일명 생성 (페이지 번호와 이미지 인덱스 포함)
#             image_filename = f"page{page_num+1}_img{img_index+1}.{image_ext}"
#             image_path = os.path.join(output_dir, image_filename)
            
#             # 이미지 저장
#             with open(image_path, "wb") as img_file:
#                 img_file.write(image_bytes)
            
#             # 이미지 크기가 너무 작으면 필터링 (선택 사항)
#             try:
#                 with Image.open(io.BytesIO(image_bytes)) as img:
#                     width, height = img.size
#                     # 작은 이미지(아이콘, 기호 등) 필터링
#                     if width < 100 or height < 100:
#                         os.remove(image_path)
#                         continue
#             except Exception as e:
#                 print(f"이미지 처리 중 오류 발생: {e}")
            
#             image_count += 1
#             if image_count % 10 == 0:
#                 print(f"{image_count}개 이미지 추출 완료...")
    
#     pdf_document.close()
#     print(f"총 {image_count}개 이미지가 {output_dir}에 추출되었습니다.")

# if __name__ == "__main__":
#     pdf_path = "./data/GrayAnatomyPDF.pdf"
#     output_dir = "./data/images"
    
#     extract_images_from_pdf(pdf_path, output_dir)
