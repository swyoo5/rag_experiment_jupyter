# %% [markdown]
# # m-hop 탐색

# %%
import os
import re
import nltk
import json
import torch
import chromadb
import numpy as np
import networkx as nx
import nltk.downloader
from datetime import datetime
from pykeen.models import ComplEx
from model_loader_folder.config import *
from pykeen.pipeline import pipeline
from transformers import AutoTokenizer
from nltk.tokenize import sent_tokenize
from pykeen.triples import TriplesFactory
from chromadb.utils import embedding_functions
from pykeen.optimizers import AdamW as PyKeenAdamW
from typing import List, Dict, Any, Tuple, Optional, Set
from sentence_transformers import CrossEncoder, SentenceTransformer

class CustomEmbeddingFunction(embedding_functions.EmbeddingFunction):
    def __init__(self, embedding_model):
        self.embedding_model = embedding_model
    
    def __call__(self, texts):
        return self.embedding_model.encode(texts).tolist()
    
nltk.download("punkt")
nltk.download("punkt_tab")

generation_loader = generation_loader

class QASystem:
    def __init__(self, 
                 graphml_path: str, 
                 md_path: str,
                 vector_db_path: str = "./chroma_db_split", 
                 similarity_threshold: float = 0.5,
                 chunk_token_threshold: int = 250,
                 embedding_model_path: str = "./model/embedding/bge-m3",
                 m_hop_depth: int=3):
        self.graphml_path = graphml_path
        self.md_path = md_path
        self.similarity_threshold = similarity_threshold
        self.chunk_token_threshold = chunk_token_threshold
        self.llm_loader = None
        self.m_hop_depth = m_hop_depth
        
        self.tokenizer = AutoTokenizer.from_pretrained("cross-encoder/ms-marco-TinyBERT-L-2-v2")
        # self.tokenizer = AutoTokenizer.from_pretrained(embedding_model_path)
        # self.reranker = CrossEncoder("cross-encoder/ms-marco-MiniLM-L6-v2")
        self.reranker = CrossEncoder("colbert-ir/colbertv2.0")

        self.embedding_model = SentenceTransformer(embedding_model_path)
        self.custom_embedding_function = CustomEmbeddingFunction(self.embedding_model)

        self.graph = nx.read_graphml(graphml_path)
        self.node_name_map = {self._preprocess_text(node): node for node in self.graph.nodes()}
        self.client = chromadb.PersistentClient(path=vector_db_path)
        
        self.entity_collection = self.client.get_or_create_collection(name="entities_split", embedding_function=self.custom_embedding_function)
        self.relation_collection = self.client.get_or_create_collection(name="relations_split", embedding_function=self.custom_embedding_function)
        self.chunk_collection = self.client.get_or_create_collection(name="chunks", embedding_function=self.custom_embedding_function)
        self.entity_relation_extraction_prompt_template = """
            Extract entities and their relations from the following sentence.

            **Entities** should be **unique nouns or concepts**, extracted as **noun phrases** whenever possible. Identify **concrete objects or concepts** rather than complex activities or phenomena as entities.

            **Relations** should clearly describe the connection between two entities, preferring **reusable predicate verbs** for a knowledge graph. Use **concise verbs** or clear, hyphenated forms like **'part_of' or 'includes'**.

            Output the result **only in the following JSON format**, with no other explanations or text:

            ```json
            {{
                "entities": [
                    {{"name": "Entity1", "type": "Type (e.g., Organ, System, Substance, Function, Disease)"}},
                    {{"name": "Entity2", "type": "Type"}}
                ],
                "relations": [
                    {{"head": "Entity1", "relation": "Relation_Type (e.g., part_of, causes)", "tail": "Entity2"}},
                    {{"head": "Entity3", "relation": "generates", "tail": "Entity4"}}
                ]
            }}

            sentence : "{text_to_analyze}"
            JSON result :
        """

        self._initialize_vector_db()

    def _preprocess_text(self, text: str) -> str:
        return text.upper().replace(' ', '_')

    def _create_chunks_from_text(self, text: str, page_num: str) -> List[Dict[str, Any]] :
        chunks = []
        paragraphs = re.split("\n\n+", text)
        for para in paragraphs :
            para = para.strip()
            if not para :
                continue

            para_tokens = self.tokenizer.tokenize(para)

            if len(para_tokens) <= self.chunk_token_threshold :
                chunks.append({"document": para, "metadata": {"source_page": page_num}})
            else :
                sentences = sent_tokenize(para)
                current_chunk_sentences = []
                current_chunk_tokens = 0

                for sentence in sentences :
                    sentence_tokens = self.tokenizer.tokenize(sentence)

                    if current_chunk_tokens + len(sentence_tokens) > self.chunk_token_threshold and current_chunk_sentences :
                        chunk_text = " ".join(current_chunk_sentences)
                        chunks.append({"document": chunk_text, "metadata": {"source_page": page_num}})
                        current_chunk_sentences = [sentence]
                        current_chunk_tokens = len(sentence_tokens)
                    else :
                        current_chunk_sentences.append(sentence)
                        current_chunk_tokens += len(sentence_tokens)

                if current_chunk_sentences :
                    chunk_text = " ".join(current_chunk_sentences)
                    chunks.append({"document": chunk_text, "metadata": {"source_page": page_num}})

        return chunks

    def _initialize_vector_db(self):
        if self.entity_collection.count() == 0:
            nodes_to_add = []
            unique_nodes = set()
            for node, data in self.graph.nodes(data=True):
                processed_node = self._preprocess_text(node)
                if processed_node not in unique_nodes :
                    metadata = {k: str(v) for k, v in data.items()}
                    metadata['original_name'] = node
                    nodes_to_add.append({'id': processed_node, 'document': node, 'metadata': metadata})
                    unique_nodes.add(processed_node)
            
            if nodes_to_add:
                ids = [item['id'] for item in nodes_to_add]
                documents = [item['document'] for item in nodes_to_add]
                metadatas = [item['metadata'] for item in nodes_to_add]
                self.entity_collection.add(ids=ids, documents=documents, metadatas=metadatas)

        if self.relation_collection.count() == 0:
            edges_to_add = []
            unique_processed_relations = set()
            for u, v, data in self.graph.edges(data=True):
                relation_type = data.get('type')
                if relation_type:
                    processed_relation = self._preprocess_text(relation_type)
                    if processed_relation not in unique_processed_relations :
                        metadata = {'original_name': relation_type}
                        edges_to_add.append({'id': processed_relation, 'document': processed_relation, 'metadata': metadata})
                        unique_processed_relations.add(processed_relation)

            if edges_to_add:
                ids = [item['id'] for item in edges_to_add]
                documents = [item['document'] for item in edges_to_add]
                metadatas = [item['metadata'] for item in edges_to_add]
                self.relation_collection.add(ids=ids, documents=documents, metadatas=metadatas)
    
    def _extract_entities_relations(self, question) :
        prompt = self.entity_relation_extraction_prompt_template.format(text_to_analyze=question)
        raw_llm_output = self._call_llm_generate(prompt)

        try :
            json_start = raw_llm_output.find("{")
            json_end = raw_llm_output.rfind("}") + 1
            if json_start != -1 and json_end != -1 and json_end > json_start :
                json_str = raw_llm_output[json_start:json_end]
                extracted_data = json.loads(json_str)
                return extracted_data.get("entities", []), extracted_data.get("relations", [])
            else :
                print(f"LLM 답변에서 유효한 JSON 형태를 찾을 수 없음 : {raw_llm_output}")
                return [], []
            
        except json.JSONDecodeError as e :
            print(f"개체 추출 과정에서 JSON 디코딩 오류 발생: {e}")
            print(f"오류 발생 원문: {raw_llm_output}")
            return [], []
    
    def _find_pages_from_entities(self, expanded_entities: List[Dict[str, Any]]) -> Set[str]:
        query_texts = [e['name'] for e in expanded_entities if 'name' in e]
        if not query_texts:
            return set()

        # 유사 엔티티 탐색
        entity_results = self.entity_collection.query(
            query_texts=query_texts,
            n_results=5,
            include=["metadatas", "distances"]
        )
        # print(f"벡터DB 검색 결과 : {entity_results.get('distances')}")
        # print(f"쿼리 : {query_texts}")
        # print(f"검색 결과 : {entity_results}")

        similar_entity_names = set()
        if entity_results.get('distances'):
            for i, dists in enumerate(entity_results['distances']):
                for j, dist in enumerate(dists):
                    if dist <= self.similarity_threshold:
                        meta = entity_results['metadatas'][i][j]
                        similar_entity_names.add(meta['original_name'])
        
        # print(f"유사도 필터링 후 엔티티 : {similar_entity_names}")
        page_numbers = set()
        for entity_name in similar_entity_names:
            standarized_name = self._preprocess_text(entity_name)
            if standarized_name in self.node_name_map :
                original_case_node_name = self.node_name_map[standarized_name]
                node_data = self.graph.nodes[original_case_node_name]
                # print(f"node_data : {node_data}")
                pages_str = node_data.get("source_page")

                # print(f"{entity_name} 노드 데이터 : {node_data}")
                if pages_str :
                    for page in pages_str.split(',') :
                        if page.strip() :
                            page_numbers.add(page.strip())
            # else :
            #     print(f"{entity_name}을 그래프에서 찾을 수 없음")
        return page_numbers
    
    def _retrieve_and_rerank_context(self, question: str, page_numbers: Set[str], top_k_rerank: int = 5) -> List[Dict[str, Any]]:
        if not page_numbers:
            return []

        all_md_content = ""
        for md_file in os.listdir(self.md_path):
            if md_file.endswith(".md"):
                with open(os.path.join(self.md_path, md_file), 'r', encoding='utf-8') as f:
                    all_md_content += f.read() + "\n\n"

        candidate_chunks = []
        for page_num in page_numbers:
            pattern = re.compile(rf"####\s+Page\s+{re.escape(page_num)}\b(.*?)(?=####\s+Page|\Z)", re.S)
            match = pattern.search(all_md_content)
            
            # print(f"Searching for page: '{page_num}'")
            # if not match:
            #     print(f"-> Page '{page_num}' NOT FOUND in markdown content.")
            # else:
            #     print(f"-> Page '{page_num}' FOUND.")

            if match:
                page_content = match.group(1).strip()
                chunks = self._create_chunks_from_text(page_content, page_num)
                candidate_chunks.extend(chunks)
        
        if not candidate_chunks:
            return []
            
        rerank_pairs = [(question, chunk['document']) for chunk in candidate_chunks]
        if not rerank_pairs:
            return []

        scores = self.reranker.predict(rerank_pairs)

        reranked_results = []
        for score, chunk in zip(scores, candidate_chunks):
            chunk["rerank_score"] = score
            reranked_results.append(chunk)

        reranked_results.sort(key=lambda x: x["rerank_score"], reverse=True)

        return reranked_results[:top_k_rerank]

    def _build_llm_prompt(self, question: str, context: str) -> str:
        prompt = f"""
        You are a helpful assistant who answers questions based on the provided context.
        You MUST cite the source page number for every piece of information you use.

        **Instructions:**
        1. Answer the user's question clearly and concisely using ONLY the provided context and knowledge graph information.
        2. For every statement, you MUST provide the source page number in parentheses, like this: (Page XX).
        3. If a single piece of information is supported by multiple pages, cite all of them: (Page X, Y, Z).
        4. If no context is available, state that you are answering based on the graph structure alone.

        **Example of a GOOD answer:**
        The ductus arteriosus degenerates into the ligamentum arteriosum after birth(page 360). This is a normal physiological change that happens post-delivery(page 361).

        **Example of a BAD answer:** -> (This is a bad answer because it lacks the mandatory citation)
        The ductus arteriosus becomes the ligamentum arteriosum.

        ---
        **Context:**
        {context}
        ---
        **Question:**
        {question}
        ---
        **Answer:**
        """
        return prompt.strip()
    
    def _call_llm_generate(self, prompt: str) -> str:
        if self.llm_loader:
            if hasattr(self.llm_loader, "tokenizer") and hasattr(self.llm_loader, "model"):
                tokenizer = self.llm_loader.tokenizer
                model = self.llm_loader.model

                input_ids = tokenizer.encode(prompt, return_tensors="pt", padding=True, truncation=True).to(model.device)
                attention_mask = (input_ids != tokenizer.pad_token_id).long().to(model.device)

                output = model.generate(
                    input_ids=input_ids,
                    attention_mask=attention_mask,
                    max_new_tokens=500,
                    temperature=0.0,
                    do_sample=False,
                    top_p=0.85,
                    repetition_penalty=1.2,
                    early_stopping=True,
                    num_beams=3,
                    pad_token_id=tokenizer.pad_token_id,
                    eos_token_id=tokenizer.eos_token_id
                )
                generated_ids = output[0][input_ids.shape[-1]:]
                raw_answer = tokenizer.decode(generated_ids, skip_special_tokens=True).strip()
                return raw_answer
            else:
                raw_answer = self.llm_loader.generate(prompt)
                return raw_answer
        else:
            print("generation_loader가 로드되지 않음")
            return "LLM 로더가 설정되지 않았습니다."

    def _m_hop_expand_entities(self, initial_entity_names: List[str], max_hops: int) -> Set[str] :
        if not self.graph :
            print("지식 그래프가 로드되지 않음")
            return set(initial_entity_names)
        
        expanded_entity_names = set()
        visited_nodes = set()

        queue = []
        
        for name in initial_entity_names :
            standarized_name = self._preprocess_text(name)

            if standarized_name in self.node_name_map :
                original_case_name = self.node_name_map[standarized_name]
                if original_case_name not in visited_nodes :
                    queue.append((original_case_name, 0))
                    visited_nodes.add(original_case_name)
                    expanded_entity_names.add(original_case_name)
        while queue :
            current_node_name, current_hop = queue.pop(0)

            if current_hop < max_hops :
                for neighbor_node_name in self.graph.neighbors(current_node_name) :
                    if neighbor_node_name not in visited_nodes :
                        visited_nodes.add(neighbor_node_name)
                        expanded_entity_names.add(neighbor_node_name)
                        queue.append((neighbor_node_name, current_hop + 1))

        return expanded_entity_names

    def _expand_entities(self, initial_entities: List[Dict[str, Any]], m_hop_depth: int) -> List[Dict[str, Any]]:
        if not initial_entities:
            return []

        initial_entity_names = [e['name'] for e in initial_entities]
        prompt = f"""
        Given the following list of medical or anatomical entities, provide a list of related or synonymous entities.
        This will be used to improve search recall in a knowledge base.
        Focus on providing closely related concepts, components, or alternative names.
        Provide the output as a simple comma-separated list, without numbers or bullets.

        Initial Entities: {', '.join(initial_entity_names)}

        Expanded Entities:
        """

        raw_llm_output = self._call_llm_generate(prompt.strip())

        llm_expanded_entity_names = {name.strip() for name in raw_llm_output.split(',') if name.strip()}
        graph_expanded_entity_names = self._m_hop_expand_entities(initial_entity_names, m_hop_depth)
        
        all_entity_names = set(initial_entity_names)
        all_entity_names.update(llm_expanded_entity_names)
        all_entity_names.update(graph_expanded_entity_names)

        final_entities = [{'name': name} for name in all_entity_names]

        # print(f"질문에서 추출된 엔티티: {initial_entity_names}")
        # print(f"LLM 확장 엔티티 : {llm_expanded_entity_names}")
        # print(f"M-hop 탐색 엔티티 : {list(graph_expanded_entity_names)}")
        # print(f"최종 확장 엔티티 : {[e['name'] for e in final_entities]}")

        return final_entities

    def generate_response(self, question: str, m_hop_depth: int) -> Tuple[str, str]:
        # 질문 엔티티 추출
        initial_entities, _ = self._extract_entities_relations(question)
        if not initial_entities:
            return "질문에서 유효한 엔티티를 추출할 수 없습니다.", ""

        # llm 기반 엔티티 확장 & m-hop 깊이 확장
        expanded_entities = self._expand_entities(initial_entities, m_hop_depth=m_hop_depth)
        
        # 확장 엔티티 유사도 검색 후 페이지 파싱
        page_numbers = self._find_pages_from_entities(expanded_entities)
        if not page_numbers :
            return "페이지를 찾을 수 없음", ""
        # print(f"찾은 페이지 : {page_numbers}")

        # 파싱된 페이지 원문 청크 검색 & 재정렬
        reranked_chunks = self._retrieve_and_rerank_context(question, page_numbers, top_k_rerank=5)
        print(f"reranked_chunks : {reranked_chunks}")
        if not reranked_chunks:
            return "관련 페이지는 찾았으나, 질문과 직접적으로 연관된 문맥이 없음", ""

        final_context_parts = []
        current_len = 0

        if hasattr(self.llm_loader, 'tokenizer') and self.llm_loader.tokenizer is not None:
            print("LLM 로더의 특정 토크나이저를 사용하여 길이를 계산합니다.")
            llm_tokenizer = self.llm_loader.tokenizer
            max_len = getattr(llm_tokenizer, 'model_max_length', 4096) - 500

            base_prompt = self._build_llm_prompt(question, "")
            base_prompt_len = len(llm_tokenizer.tokenize(base_prompt))
            current_len += base_prompt_len

            for chunk in reranked_chunks:
                page_num = chunk['metadata'].get('source_page', 'N/A')
                context_snippet = f"... {chunk['document']} ... (출처: Page {page_num})"
                chunk_token_len = len(llm_tokenizer.tokenize(context_snippet))

                if current_len + chunk_token_len <= max_len:
                    final_context_parts.append(context_snippet)
                    current_len += chunk_token_len
                else:
                    break
        else:
            print("범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)")
            proxy_tokenizer = self.tokenizer  
            max_len = 2048 - 500

            for chunk in reranked_chunks:
                page_num = chunk['metadata'].get('source_page', 'N/A')
                context_snippet = f"... {chunk['document']} ... (출처: Page {page_num})"
                chunk_token_len = len(proxy_tokenizer.tokenize(context_snippet))

                if current_len + chunk_token_len <= max_len:
                    final_context_parts.append(context_snippet)
                    current_len += chunk_token_len
                else:
                    break

        if not final_context_parts:
            return "관련 정보를 찾았으나, 모델의 입력 길이 제한으로 인해 컨텍스트를 구성할 수 없습니다.", ""

        context = "\n\n".join(final_context_parts)

        prompt = self._build_llm_prompt(question, context)

        answer = self._call_llm_generate(prompt)
        return answer, context

def save_results_to_file(question: str, answer: str, context: str, output_dir: str, file_index: int):
    os.makedirs(output_dir, exist_ok=True)

    timestamp = datetime.now().strftime("%H%M%S_%f")
    file_name = f"result_{file_index}_{timestamp}.txt"
    file_path = os.path.join(output_dir, file_name)
    
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(f"[질문]\n{question}\n\n")
        f.write(f"[답변]\n{answer}\n\n")
        f.write(f"[근거]\n{context}\n\n")

if __name__ == '__main__':
    qa_system = QASystem(
        graphml_path="./data/knowledge_graph/knowledge_graph.graphml",
        md_path="./data/split_file/anatomy/",
        m_hop_depth=1
    )
    
    qa_system.llm_loader = generation_loader
    
    questions = [
        ############## 1_Embryology.md
        "What are the two essential components of a higher organism cell as defined in the text?", # 7페이지
        "Describe the four main phases of indirect cell division (karyokinesis) as outlined in the text.", # 7페이지
        "What is the primary role of the yolk-sac in the embryo's early development?", # 20페이지
        "How does the embryo separate from the yolk-sac, and what does the enclosed part of the yolk-sac form?", # 19페이지
        "What significant developments occur in a human embryo during the Second Week?", # 33페이지
        "What are the key characteristics of the human embryo by the end of the Third Week?", # 33페이지
        
        ############## 2_Osteology.md
        "What are the three groups into which the cells of a primitive segment differentiate, and what do they form?", # 38페이지
        "How is each vertebral body formed from primitive segments during development?", # 38페이지
        "What are the sphenoidal air sinuses, and where are they located within the sphenoid bone?", # 88페이지
        "Describe the sphenoidal rostrum and its articulation.",# 88
        "What is the tibia, and where is it located in the human leg?", # 158
        "Describe the superior articular surface of the tibia's upper extremity.", # 158

        ############## 3_Syndesmology.md
        "What are joints or articulations, and how are immovable joints characterized?", # 174
        "How does the articular lamella differ from ordinary bone tissue?", # 174
        "Where is the synovial membrane located in relation to the glenoid cavity and humerus, and how does it interact with the Biceps brachii tendon?", # 207
        "List some of the bursae located near the shoulder-joint and specify which ones communicate with the synovial cavity.", # 207
        "What is the function of the plantar calcaneonavicular ligament, and what condition results if it yields?", # 236
        "How are the navicular bone and the three cuneiform bones connected, and what type of movement do they permit?", # 236

        ############## 4_Myology.md
        "How does the nervous system serve as an indicator for the origin and migration paths of developing muscles, despite not influencing muscle differentiation?", # 250
        "Describe the structural components of striped or voluntary muscle, from bundles to individual fibers.", # 250
        "What is the triangular ligament and where is it located?", # 290
        "What structures perforate the superficial layer (inferior fascia) of the urogenital diaphragm?", # 290
        "Where does the Extensor digitorum longus muscle originate, and what structures are located between it and the Tibialis anterior?", # 322
        "What is the Peronæus tertius, and where is it inserted?", # 322

        ############## 5_Angiology.md
        "What are the main characteristics of the middle coat (tunica media) of arteries, and how does its composition vary with vessel size?", # 334
        "Describe the composition and variations of the external coat (tunica adventitia) in arteries.", # 334
        "How do the Vitelline Veins develop into parts of the portal and hepatic veins?", # 345
        "What happens to the Umbilical Veins during embryonic development and after birth?", # 345
        "What are the three phases of a cardiac cycle and what happens during each?", # 358
        "What are the main peculiarities observed in the fetal heart's vascular system?" # 359
    ]   
    import time
    today = datetime.now()
    folder_name = f"{today.month}월{today.day}일"
    output_dir = os.path.join("./result", "knowledge_graph", folder_name, "m-3")
    total_time = 0
    for i, q in enumerate(questions):
        print(f"질문: {q}")
        start_time = time.time()
        response, context = qa_system.generate_response(q, m_hop_depth=3)
        end_time = time.time()
        elapse_time = end_time - start_time
        total_time += elapse_time
        print("=" * 30)
        print(f"답변: {response}\n\n\n")
        print("=" * 30)
        save_results_to_file(q, response, context, output_dir, i + 1)
    avg_time = total_time / len(questions)
    print("평균 답변 시간 : %.2f" % avg_time)
# Out:
# =======================Embedding_loader.py 로드됨
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at colbert-ir/colbertv2.0 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 질문: What are the two essential components of a higher organism cell as defined in the text?
# Token indices sequence length is longer than the specified maximum sequence length for this model (565 > 512). Running this sequence through the model will result in indexing errors
# reranked_chunks : [{'document': 'Henry Gray (1821–1865). Anatomy of the Human Body. 1918.\n## 2. The Ovum', 'metadata': {'source_page': '8'}, 'rerank_score': 0.52116}, {'document': '![Diagram showing earliest observed stage of human ovum](./data/images/image_21_1.png)\nFIG. 24– Diagram showing earliest observed stage of human ovum. ( See enlarged image)', 'metadata': {'source_page': '21'}, 'rerank_score': 0.511336}, {'document': '![At birth](./data/images/image_108_3.png)\nFIG. 182– At birth. (See enlarged image)', 'metadata': {'source_page': '108'}, 'rerank_score': 0.5100129}, {'document': '## 4. Fertilization of the Ovum\n![The process of fertilization in the ovum of a mouse](./data/images/image_12_1.png)\nFIG. 8– The process of fertilization in the ovum of a mouse. (After Sobotta.) ( See enlarged image)', 'metadata': {'source_page': '12'}, 'rerank_score': 0.5083677}, {'document': '![Skeleton of foot. Lateral aspect](./data/images/image_172_2.png)\nFIG. 291– Skeleton of foot. Lateral aspect. (See enlarged image)', 'metadata': {'source_page': '172'}, 'rerank_score': 0.5068496}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: The text does not define the two essential components of a higher organism cell. It only contains information about the ovum and fertilization (Page 8, 12, 21, 108, 172). Therefore, I cannot answer your question based on the provided context.
#
#
#
# ==============================
# 질문: Describe the four main phases of indirect cell division (karyokinesis) as outlined in the text.
# reranked_chunks : [{'document': 'Henry Gray (1821–1865). Anatomy of the Human Body. 1918.\n## 2. The Ovum', 'metadata': {'source_page': '8'}, 'rerank_score': 0.5169248}, {'document': '## 4. Fertilization of the Ovum\n![The process of fertilization in the ovum of a mouse](./data/images/image_12_1.png)\nFIG. 8– The process of fertilization in the ovum of a mouse. (After Sobotta.) ( See enlarged image)', 'metadata': {'source_page': '12'}, 'rerank_score': 0.51252145}, {'document': 'mitotic division. (Schäfer.) I to III, prophase; IV, metaphase; V and VI, anaphase; VI I and VIII, telophase.', 'metadata': {'source_page': '7'}, 'rerank_score': 0.50765955}, {'document': '![First stages of segmentation of a mammalian ovum. Semidiagrammatic](./data/images/image_12_2.png)\nFIG. 9– First stages of segmentation of a mammalian ovum. Semidiagrammatic. (From a drawing by Allen\nThomson.) z.p. Zona striata. p.gl. Polar bodies. a. Two-cell stage. b. Four-cell stage. c. Eight-cell stage. d, e.', 'metadata': {'source_page': '12'}, 'rerank_score': 0.50598377}, {'document': 'Reference - Anatomy of the Human Body - I. Embryology > 2. The Ovum', 'metadata': {'source_page': '8'}, 'rerank_score': 0.5055126}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: The four main phases of indirect cell division (karyokinesis) are prophase (I to III), metaphase (IV), anaphase (V and VI), and telophase (VII and VIII) (Page 7).
#
#
#
# ==============================
# 질문: What is the primary role of the yolk-sac in the embryo's early development?
# reranked_chunks : [{'document': 'Henry Gray (1821–1865). Anatomy of the Human Body. 1918.\n## 2. The Ovum', 'metadata': {'source_page': '8'}, 'rerank_score': 0.5069127}, {'document': 'Henry Gray (1821–1865). Anatomy of the Human Body. 1918.\n## 8. The Primitive Segments', 'metadata': {'source_page': '18'}, 'rerank_score': 0.50456834}, {'document': '![The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of formation of the palate](./data/images/image_29_2.png)\nFIG. 50– The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of', 'metadata': {'source_page': '29'}, 'rerank_score': 0.5030567}, {'document': '![Human embryo between eighteen and twenty-one days old](./data/images/image_33_2.png)\nFIG. 59– Human embryo between eighteen and twenty-one days old. (His. (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.5015666}, {'document': '![Human embryo about eight and a half weeks old](./data/images/image_34_3.png)\nFIG. 63– Human embryo about eight and a half weeks old. (His.) (See enlarged image)', 'metadata': {'source_page': '34'}, 'rerank_score': 0.50041753}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am sorry, but the provided context does not contain information about the primary role of the yolk-sac in the embryo's early development. Therefore, I cannot answer your question based on the given text.
#
#
#
# ==============================
# 질문: How does the embryo separate from the yolk-sac, and what does the enclosed part of the yolk-sac form?
# reranked_chunks : [{'document': 'Henry Gray (1821–1865). Anatomy of the Human Body. 1918.\n## 2. The Ovum', 'metadata': {'source_page': '8'}, 'rerank_score': 0.5182286}, {'document': 'Henry Gray (1821–1865). Anatomy of the Human Body. 1918.\n## 8. The Primitive Segments', 'metadata': {'source_page': '18'}, 'rerank_score': 0.51295185}, {'document': 'mitotic division. (Schäfer.) I to III, prophase; IV, metaphase; V and VI, anaphase; VI I and VIII, telophase.', 'metadata': {'source_page': '7'}, 'rerank_score': 0.51134086}, {'document': '![Human embryo about fifteen days old](./data/images/image_33_1.png)\nFIG. 58– Human embryo about fifteen days old. (His.) (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.5107225}, {'document': '![Human embryo of about six weeks](./data/images/image_34_2.png)\nFIG. 62– Human embryo of about six weeks. (His.) (See enlarged image)', 'metadata': {'source_page': '34'}, 'rerank_score': 0.51056373}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am answering based on the graph structure alone, as the provided context does not contain information about how the embryo separates from the yolk-sac or what the enclosed part of the yolk-sac forms.
#
#
#
# ==============================
# 질문: What significant developments occur in a human embryo during the Second Week?
# reranked_chunks : [{'document': '![The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of formation of the palate](./data/images/image_29_2.png)\nFIG. 50– The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of', 'metadata': {'source_page': '29'}, 'rerank_score': 0.51920813}, {'document': '![Embryo of about six weeks](./data/images/image_30_2.png)\nFIG. 53– Embryo of about six weeks. (His.) (See enlarged image)', 'metadata': {'source_page': '30'}, 'rerank_score': 0.5191882}, {'document': '![Human embryo of about six weeks](./data/images/image_34_2.png)\nFIG. 62– Human embryo of about six weeks. (His.) (See enlarged image)', 'metadata': {'source_page': '34'}, 'rerank_score': 0.5186077}, {'document': '![Human embryo about fifteen days old](./data/images/image_33_1.png)\nFIG. 58– Human embryo about fifteen days old. (His.) (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.5185326}, {'document': 'Henry Gray (1821–1865). Anatomy of the Human Body. 1918.\n## 8. The Primitive Segments', 'metadata': {'source_page': '18'}, 'rerank_score': 0.51766133}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am answering based on the graph structure alone, as the provided context does not contain information about developments in the Second Week of a human embryo. However, images of human embryos at fifteen days and six weeks are available (Page 33, Page 30, Page 34). An image of the roof of the mouth of a human embryo, aged about two and a half months, is also available (Page 29).
#
#
#
# ==============================
# 질문: What are the key characteristics of the human embryo by the end of the Third Week?
# reranked_chunks : [{'document': '![The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of formation of the palate](./data/images/image_29_2.png)\nFIG. 50– The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of', 'metadata': {'source_page': '29'}, 'rerank_score': 0.5232139}, {'document': '![Diagram showing earliest observed stage of human ovum](./data/images/image_21_1.png)\nFIG. 24– Diagram showing earliest observed stage of human ovum. ( See enlarged image)', 'metadata': {'source_page': '21'}, 'rerank_score': 0.5224496}, {'document': 'Henry Gray (1821–1865). Anatomy of the Human Body. 1918.\n## 8. The Primitive Segments', 'metadata': {'source_page': '18'}, 'rerank_score': 0.5206455}, {'document': '![Human embryo about fifteen days old](./data/images/image_33_1.png)\nFIG. 58– Human embryo about fifteen days old. (His.) (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.5194248}, {'document': '![Embryo of about six weeks](./data/images/image_30_2.png)\nFIG. 53– Embryo of about six weeks. (His.) (See enlarged image)', 'metadata': {'source_page': '30'}, 'rerank_score': 0.5192344}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: Based on the graph structure alone, the key characteristics of the human embryo by the end of the Third Week are not explicitly stated within the provided context. However, we can see images of a human embryo about fifteen days old (Page 33) and an embryo of about six weeks (Page 30), indicating developmental stages around this timeframe. Additionally, there's a visual representation of a human embryo aged about two and a half months (Page 29).
#
#
#
# ==============================
# 질문: What are the three groups into which the cells of a primitive segment differentiate, and what do they form?
# reranked_chunks : [{'document': 'Henry Gray (1821–1865). Anatomy of the Human Body. 1918.\n## 2. The Ovum', 'metadata': {'source_page': '8'}, 'rerank_score': 0.5179371}, {'document': 'Henry Gray (1821–1865). Anatomy of the Human Body. 1918.\n## 8. The Primitive Segments', 'metadata': {'source_page': '18'}, 'rerank_score': 0.51644975}, {'document': '![The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of formation of the palate](./data/images/image_29_2.png)\nFIG. 50– The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of', 'metadata': {'source_page': '29'}, 'rerank_score': 0.5128962}, {'document': '![Human embryo, twenty-seven to thirty days old](./data/images/image_33_3.png)\nFIG. 60– Human embryo, twenty-seven to thirty days old. (His.) (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.5091973}, {'document': '![Human embryo between eighteen and twenty-one days old](./data/images/image_33_2.png)\nFIG. 59– Human embryo between eighteen and twenty-one days old. (His. (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.50905657}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am answering based on the graph structure alone, as the provided context does not contain information about the differentiation of cells within a primitive segment.
#
#
#
# ==============================
# 질문: How is each vertebral body formed from primitive segments during development?
# reranked_chunks : [{'document': '![The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of formation of the palate](./data/images/image_29_2.png)\nFIG. 50– The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of', 'metadata': {'source_page': '29'}, 'rerank_score': 0.52095026}, {'document': '![Diagram showing earliest observed stage of human ovum](./data/images/image_21_1.png)\nFIG. 24– Diagram showing earliest observed stage of human ovum. ( See enlarged image)', 'metadata': {'source_page': '21'}, 'rerank_score': 0.5181725}, {'document': '![Embryo of about six weeks](./data/images/image_30_2.png)\nFIG. 53– Embryo of about six weeks. (His.) (See enlarged image)', 'metadata': {'source_page': '30'}, 'rerank_score': 0.51611507}, {'document': '## 4. Fertilization of the Ovum\n![The process of fertilization in the ovum of a mouse](./data/images/image_12_1.png)\nFIG. 8– The process of fertilization in the ovum of a mouse. (After Sobotta.) ( See enlarged image)', 'metadata': {'source_page': '12'}, 'rerank_score': 0.51564413}, {'document': '![Human embryo about fifteen days old](./data/images/image_33_1.png)\nFIG. 58– Human embryo about fifteen days old. (His.) (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.5154621}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am sorry, but the provided context does not contain information about how vertebral bodies are formed from primitive segments during development. Therefore, I cannot answer your question using the given text.
#
#
#
# ==============================
# 질문: What are the sphenoidal air sinuses, and where are they located within the sphenoid bone?
# reranked_chunks : [{'document': '![Sphenoid bone. Upper surface](./data/images/image_87_1.png)\nFIG. 145– Sphenoid bone. Upper surface. (See enlarged image)', 'metadata': {'source_page': '87'}, 'rerank_score': 0.5185302}, {'document': '![Human embryo between eighteen and twenty-one days old](./data/images/image_33_2.png)\nFIG. 59– Human embryo between eighteen and twenty-one days old. (His. (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.51655895}, {'document': 'mitotic division. (Schäfer.) I to III, prophase; IV, metaphase; V and VI, anaphase; VI I and VIII, telophase.', 'metadata': {'source_page': '7'}, 'rerank_score': 0.5157246}, {'document': '![Human embryo, twenty-seven to thirty days old](./data/images/image_33_3.png)\nFIG. 60– Human embryo, twenty-seven to thirty days old. (His.) (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.5157133}, {'document': '![Human embryo, thirty-one to thirty-four days old](./data/images/image_34_1.png)\nFIG. 61– Human embryo, thirty-one to thirty-four days old. (His.) ( See enlarged image)', 'metadata': {'source_page': '34'}, 'rerank_score': 0.5156368}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am sorry, but the provided context does not contain information about sphenoidal air sinuses or their location within the sphenoid bone. The context only contains images of the sphenoid bone (Page 87) and human embryos (Page 33, 34) along with information about mitotic division (Page 7). Therefore, I cannot answer your question based on the provided text.
#
#
#
# ==============================
# 질문: Describe the sphenoidal rostrum and its articulation.
# reranked_chunks : [{'document': '![Articulations of pelvis. Anterior view](./data/images/image_198_9.png)\nFIG. 319– Articulations of pelvis. Anterior view. (Quain.) ( See enlarged image)', 'metadata': {'source_page': '198'}, 'rerank_score': 0.51323086}, {'document': '![Articulatios of pelvis. Posterior view](./data/images/image_198_10.png)\nFIG. 320– Articulatios of pelvis. Posterior view. (Quain.) ( See enlarged image)', 'metadata': {'source_page': '198'}, 'rerank_score': 0.5096233}, {'document': '![Sphenoid bone. Upper surface](./data/images/image_87_1.png)\nFIG. 145– Sphenoid bone. Upper surface. (See enlarged image)', 'metadata': {'source_page': '87'}, 'rerank_score': 0.5085951}, {'document': '![Skeleton of foot. Lateral aspect](./data/images/image_172_2.png)\nFIG. 291– Skeleton of foot. Lateral aspect. (See enlarged image)', 'metadata': {'source_page': '172'}, 'rerank_score': 0.5084987}, {'document': '![Articulation of the mandible. Lateral aspect](./data/images/image_189_1.png)\nFIG. 309– Articulation of the mandible. Lateral aspect. ( See enlarged image)', 'metadata': {'source_page': '189'}, 'rerank_score': 0.5081019}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am sorry, but the provided context does not contain information about the sphenoidal rostrum or its articulation. The context includes images and descriptions of the articulations of the pelvis (Page 198), the sphenoid bone (Page 87), the skeleton of the foot (Page 172), and the articulation of the mandible (Page 189), but it does not detail the sphenoidal rostrum. Therefore, I cannot answer your question using the given information.
#
#
#
# ==============================
# 질문: What is the tibia, and where is it located in the human leg?
# reranked_chunks : [{'document': 'Henry Gray (1821–1865). Anatomy of the Human Body. 1918.\n## 8. The Primitive Segments', 'metadata': {'source_page': '18'}, 'rerank_score': 0.52327937}, {'document': '![At birth](./data/images/image_108_3.png)\nFIG. 182– At birth. (See enlarged image)', 'metadata': {'source_page': '108'}, 'rerank_score': 0.5219847}, {'document': 'C li c k h e r e to sh op th e B a r t l eby B oo k sto r e .', 'metadata': {'source_page': '157'}, 'rerank_score': 0.52008414}, {'document': '![The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of formation of the palate](./data/images/image_29_2.png)\nFIG. 50– The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of', 'metadata': {'source_page': '29'}, 'rerank_score': 0.5196882}, {'document': '![Plan of ossification of the tibia. From three centers](./data/images/image_159_3.png)\nFIG. 260– Plan of ossification of the tibia. From three centers. ( See enlarged image)', 'metadata': {'source_page': '159'}, 'rerank_score': 0.5187573}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: The tibia is a bone in the human leg that ossifies from three centers (Page 159). A plan of its ossification is shown in Figure 260 (Page 159).
#
#
#
# ==============================
# 질문: Describe the superior articular surface of the tibia's upper extremity.
# reranked_chunks : [{'document': '![At birth](./data/images/image_108_3.png)\nFIG. 182– At birth. (See enlarged image)', 'metadata': {'source_page': '108'}, 'rerank_score': 0.51597714}, {'document': '![Muscles of the sole of the foot. Second layer](./data/images/image_330_1.png)\nFIG. 444– Muscles of the sole of the foot. Second layer. ( See enlarged image)', 'metadata': {'source_page': '330'}, 'rerank_score': 0.5152262}, {'document': '(Articulatio Talocruralis; Tibiotarsal Articulation)', 'metadata': {'source_page': '232'}, 'rerank_score': 0.5141699}, {'document': '![Muscles of the sole of the foot. Third layer](./data/images/image_330_2.png)\nFIG. 445– Muscles of the sole of the foot. Third layer. ( See enlarged image)', 'metadata': {'source_page': '330'}, 'rerank_score': 0.51310235}, {'document': 'formation of the palate. (His.) (See enlarged image)', 'metadata': {'source_page': '29'}, 'rerank_score': 0.51290244}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am sorry, but the provided context does not contain information about the superior articular surface of the tibia's upper extremity. I am answering based on the graph structure alone.
#
#
#
# ==============================
# 질문: What are joints or articulations, and how are immovable joints characterized?
# reranked_chunks : [{'document': '![Muscles of the sole of the foot. Second layer](./data/images/image_330_1.png)\nFIG. 444– Muscles of the sole of the foot. Second layer. ( See enlarged image)', 'metadata': {'source_page': '330'}, 'rerank_score': 0.51872736}, {'document': '![Muscles of the sole of the foot. Third layer](./data/images/image_330_2.png)\nFIG. 445– Muscles of the sole of the foot. Third layer. ( See enlarged image)', 'metadata': {'source_page': '330'}, 'rerank_score': 0.5165432}, {'document': '![Skeleton of foot. Lateral aspect](./data/images/image_172_2.png)\nFIG. 291– Skeleton of foot. Lateral aspect. (See enlarged image)', 'metadata': {'source_page': '172'}, 'rerank_score': 0.5157725}, {'document': 'mitotic division. (Schäfer.) I to III, prophase; IV, metaphase; V and VI, anaphase; VI I and VIII, telophase.', 'metadata': {'source_page': '7'}, 'rerank_score': 0.5122942}, {'document': '![Plan of ossification of the foot](./data/images/image_171_1.png)\nFIG. 289– Plan of ossification of the foot. ( See enlarged image)', 'metadata': {'source_page': '171'}, 'rerank_score': 0.51193386}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: The provided context does not contain information about joints or articulations, or how immovable joints are characterized. Therefore, I cannot answer your question based on the given text. I am answering based on the graph structure alone.
#
#
#
# ==============================
# 질문: How does the articular lamella differ from ordinary bone tissue?
# reranked_chunks : [{'document': '![The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of formation of the palate](./data/images/image_29_2.png)\nFIG. 50– The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of', 'metadata': {'source_page': '29'}, 'rerank_score': 0.505395}, {'document': 'ordinary expiration; B, quiet inspiration; C, deep inspiration. ( See enlarged image)', 'metadata': {'source_page': '195'}, 'rerank_score': 0.5037651}, {'document': '![Embryo of about six weeks](./data/images/image_30_2.png)\nFIG. 53– Embryo of about six weeks. (His.) (See enlarged image)', 'metadata': {'source_page': '30'}, 'rerank_score': 0.5016456}, {'document': '![Human embryo from thirty-one to thirty-four days](./data/images/image_30_1.png)\nFIG. 52– Human embryo from thirty-one to thirty-four days. (His.) ( See enlarged image)', 'metadata': {'source_page': '30'}, 'rerank_score': 0.4992186}, {'document': '![Costal cartilage from a man](./data/images/image_175_2.png)\nFIG. 294– Costal cartilage from a man, aged seventy-six years, showing the development of fibrous structure in', 'metadata': {'source_page': '175'}, 'rerank_score': 0.49831927}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am sorry, but the provided context does not contain information about how the articular lamella differs from ordinary bone tissue. Therefore, I cannot answer your question based on the given text.
#
#
#
# ==============================
# 질문: Where is the synovial membrane located in relation to the glenoid cavity and humerus, and how does it interact with the Biceps brachii tendon?
# reranked_chunks : [{'document': '![The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of formation of the palate](./data/images/image_29_2.png)\nFIG. 50– The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of', 'metadata': {'source_page': '29'}, 'rerank_score': 0.491496}, {'document': '![Primitive palate of a human embryo of thirty-seven to thirty-eight days](./data/images/image_29_1.png)\nFIG. 49– Primitive palate of a human embryo of thirty-seven to thirty-eight days. (From model by Peters.) On the', 'metadata': {'source_page': '29'}, 'rerank_score': 0.49040163}, {'document': '![Muscles of the sole of the foot. First layer](./data/images/image_329_1.png)\nFIG. 443– Muscles of the sole of the foot. First layer. ( See enlarged image)', 'metadata': {'source_page': '329'}, 'rerank_score': 0.49019036}, {'document': 'ordinary expiration; B, quiet inspiration; C, deep inspiration. ( See enlarged image)', 'metadata': {'source_page': '195'}, 'rerank_score': 0.48936343}, {'document': '![Human embryo from thirty-one to thirty-four days](./data/images/image_30_1.png)\nFIG. 52– Human embryo from thirty-one to thirty-four days. (His.) ( See enlarged image)', 'metadata': {'source_page': '30'}, 'rerank_score': 0.48917896}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am sorry, but the provided context does not contain information about the synovial membrane, glenoid cavity, humerus, or biceps brachii tendon. Therefore, I cannot answer your question based on the given text. I am answering based on the graph structure alone.
#
#
#
# ==============================
# 질문: List some of the bursae located near the shoulder-joint and specify which ones communicate with the synovial cavity.
# reranked_chunks : [{'document': 'I. Hip. V. Intertarsal.\nII. Knee. VI. Tarsometatarsal.', 'metadata': {'source_page': '222'}, 'rerank_score': 0.49241334}, {'document': 'Ossification of the body begins about the second month of fetal life, by the formation of an irregular\nquadrilateral plate of bone, immediately behind the glenoid cavity. This plate extends so as to form the chief\npart of the bone, the spine growing up from its dorsal surface about the third month. At birth, a large part of\nthe scapula is osseous, but the glenoid cavity, the coracoid process, the acromion, the vertebral border, and\nthe inferior angle are cartilaginous. From the fifteenth to the eighteenth month after birth, ossification takes\nplace in the middle of the coracoid process, which as a rule becomes joined with the rest of the bone about\nthe fifteenth year.', 'metadata': {'source_page': '127'}, 'rerank_score': 0.49183986}, {'document': 'Ossification (Figs. 215, 216). —The ulna is ossified from thre e centers: one each for the body, the inferior\nextremity, and the top of the olecranon. Ossification begins near the middle of the body, about the eighth\nweek of fetal life, and soon extends through the greater part of the bone. At birth the ends are cartilaginous.\nAbout the fourth year, a center appears in the middle of the head, and soon extends into the styloid process.\nAbout the tenth year, a center appears in the olecranon near its extremity, the chief part of this process\nbeing formed by an upward extension of the body. The upper epiphysis joins the body about the sixteenth,\nthe lower about the twentieth year.', 'metadata': {'source_page': '133'}, 'rerank_score': 0.49137026}, {'document': 'II. Acromioclavicular. VII. Intercarpal.\nIII. Shoulder. VIII. Carpometacarpal.\nIV. Elbow. IX. Intermetacarpal.\nV. Radioulnar. X. Metacarpophalangeal.\nXI. Articulations of the Digits.', 'metadata': {'source_page': '202'}, 'rerank_score': 0.4912882}, {'document': 'IV. Ankle. VIII. Metatarsophalangeal.\nIX. Articulations of the Digits.', 'metadata': {'source_page': '222'}, 'rerank_score': 0.4901655}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am sorry, but the provided context does not contain information about bursae near the shoulder joint, nor does it specify which ones communicate with the synovial cavity. The text lists shoulder as a joint (Page 202), but provides no further detail about its specific anatomy beyond that.
#
#
#
# ==============================
# 질문: What is the function of the plantar calcaneonavicular ligament, and what condition results if it yields?
# reranked_chunks : [{'document': '![Human embryo, twenty-seven to thirty days old](./data/images/image_33_3.png)\nFIG. 60– Human embryo, twenty-seven to thirty days old. (His.) (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.50559235}, {'document': '![Human embryo, thirty-one to thirty-four days old](./data/images/image_34_1.png)\nFIG. 61– Human embryo, thirty-one to thirty-four days old. (His.) ( See enlarged image)', 'metadata': {'source_page': '34'}, 'rerank_score': 0.5052088}, {'document': '![Human embryo between eighteen and twenty-one days old](./data/images/image_33_2.png)\nFIG. 59– Human embryo between eighteen and twenty-one days old. (His. (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.5051034}, {'document': '![Diagram showing earliest observed stage of human ovum](./data/images/image_21_1.png)\nFIG. 24– Diagram showing earliest observed stage of human ovum. ( See enlarged image)', 'metadata': {'source_page': '21'}, 'rerank_score': 0.5046081}, {'document': '![At birth](./data/images/image_108_3.png)\nFIG. 182– At birth. (See enlarged image)', 'metadata': {'source_page': '108'}, 'rerank_score': 0.50439095}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am sorry, but the provided context does not contain information about the plantar calcaneonavicular ligament or any conditions resulting from it yielding. Therefore, I cannot answer your question based on the given text. I am answering based on the graph structure alone.
#
#
#
# ==============================
# 질문: How are the navicular bone and the three cuneiform bones connected, and what type of movement do they permit?
# reranked_chunks : [{'document': '![Skeleton of foot. Lateral aspect](./data/images/image_172_2.png)\nFIG. 291– Skeleton of foot. Lateral aspect. (See enlarged image)', 'metadata': {'source_page': '172'}, 'rerank_score': 0.50237805}, {'document': '![Muscles of the sole of the foot. Second layer](./data/images/image_330_1.png)\nFIG. 444– Muscles of the sole of the foot. Second layer. ( See enlarged image)', 'metadata': {'source_page': '330'}, 'rerank_score': 0.50171745}, {'document': '![Muscles of the sole of the foot. First layer](./data/images/image_329_1.png)\nFIG. 443– Muscles of the sole of the foot. First layer. ( See enlarged image)', 'metadata': {'source_page': '329'}, 'rerank_score': 0.50147337}, {'document': '![Muscles of the sole of the foot. Third layer](./data/images/image_330_2.png)\nFIG. 445– Muscles of the sole of the foot. Third layer. ( See enlarged image)', 'metadata': {'source_page': '330'}, 'rerank_score': 0.5006845}, {'document': 'ordinary expiration; B, quiet inspiration; C, deep inspiration. ( See enlarged image)', 'metadata': {'source_page': '195'}, 'rerank_score': 0.4991871}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am answering based on the graph structure alone, as the provided context does not contain information about the navicular bone, cuneiform bones, or their movements.
#
#
#
# ==============================
# 질문: How does the nervous system serve as an indicator for the origin and migration paths of developing muscles, despite not influencing muscle differentiation?
# reranked_chunks : [{'document': 'Henry Gray (1821–1865). Anatomy of the Human Body. 1918.\n## 2. The Ovum', 'metadata': {'source_page': '8'}, 'rerank_score': 0.52088654}, {'document': '![Human embryo between eighteen and twenty-one days old](./data/images/image_33_2.png)\nFIG. 59– Human embryo between eighteen and twenty-one days old. (His. (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.51005757}, {'document': '![Human embryo, twenty-seven to thirty days old](./data/images/image_33_3.png)\nFIG. 60– Human embryo, twenty-seven to thirty days old. (His.) (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.50933176}, {'document': '![Human embryo about fifteen days old](./data/images/image_33_1.png)\nFIG. 58– Human embryo about fifteen days old. (His.) (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.50912666}, {'document': 'Note 10. Bryce and Teacher ( Early Development and Imbedding of the Human Ovum, 1908) have described\nan ovum which they regard as thirteen to fourteen days old. In it the two vesicles, the amnion and yolk-sac,\nwere present, but there was no trace of a layer of embryonic ectoderm. They are of opinion that the age of\nPeters’ ovum has been understated, and estimate it as between thirteen and one-half and fourteen and\none-half days. [back]', 'metadata': {'source_page': '35'}, 'rerank_score': 0.5080792}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: The provided context does not contain information about how the nervous system indicates the origin and migration paths of developing muscles. Therefore, I cannot answer this question based on the given text.
#
#
#
# ==============================
# 질문: Describe the structural components of striped or voluntary muscle, from bundles to individual fibers.
# reranked_chunks : [{'document': 'Note 76. Consult in this connection the Croonian Lectures (1903) on “Muscular Movements and Their\nRepresentation in the Central Nervous System.” by Charles E. Beevor, M.D. [ back]', 'metadata': {'source_page': '247'}, 'rerank_score': 0.49281353}, {'document': '![Muscles of the head, face, and neck](./data/images/image_255_9.png)\nFIG. 378– Muscles of the head, face, and neck. (See enlarged image)', 'metadata': {'source_page': '255'}, 'rerank_score': 0.49116102}, {'document': '![Left orbicularis oculi, seen from behind](./data/images/image_257_9.png)\nFIG. 379– Left orbicularis oculi, seen from behind. ( See enlarged image)', 'metadata': {'source_page': '257'}, 'rerank_score': 0.49066332}, {'document': 'Actions. —The Orbicularis oculi is the sphincter muscle of the eyelids. The palpebral portion acts\ninvoluntarily, closing the lids gently, as in sleep or in blinking; the orbital portion is subject to the will. When\nthe entire muscle is brought into action, the skin of the forehead, temple, and cheek is drawn toward the\nmedial angle of the orbit, and the eyelids are firmly closed, as in photophobia. The skin thus drawn upon is\nthrown into folds, especially radiating from the lateral angle of the eyelids; these folds become permanent in\nold age, and form the so-called “crows’ feet.” The Levator palpebræ superioris is the direct antagonist of this\nmuscle; it raises the upper eyelid and exposes the front of the bulb of the eye. Each time the eyelids are\nclosed through the action of the Orbicularis, the medial palpebral ligament is tightened, the wall of the\nlacrimal sac is thus drawn lateralward and forward, so that a vacuum is made in it and the tears are sucked\nalong the lacrimal canals into it.', 'metadata': {'source_page': '257'}, 'rerank_score': 0.4867324}, {'document': 'In vertebrate animals the development of a new being can only take place when a female germ cell or\novum has been fertilized by a male germ cell or spermatozoön. The ovum is a nucleated cell, and all the\ncomplicated changes by which the various tissues and organs of the body are formed from it, after it has\nbeen fertilized, are the result of two general processes, viz., segmentation and differentiation of cells.\nThus, the fertilized ovum undergoes repeated segmentation into a number of cells which at first closely\nresemble one another, but are, sooner or later, differentiated into two groups: (1) somatic cells, the function\nof which is to build up the various tissues of the body; and (2) germinal cells, which become imbedded in\nthe sexual glands—the ovaries in the female and the testes in the male—and are destined for the\nperpetuation of the species.', 'metadata': {'source_page': '6'}, 'rerank_score': 0.48669788}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: The provided text does not contain information about the structural components of striped or voluntary muscle. Therefore, I cannot answer your question based on the given context. I am answering based on the graph structure alone.
#
#
#
# ==============================
# 질문: What is the triangular ligament and where is it located?
# reranked_chunks : [{'document': 'Henry Gray (1821–1865). Anatomy of the Human Body. 1918.\n## 2. The Ovum', 'metadata': {'source_page': '8'}, 'rerank_score': 0.5054115}, {'document': 'year.', 'metadata': {'source_page': '141'}, 'rerank_score': 0.5046087}, {'document': '![The left triangular bone](./data/images/image_137_3.png)\nFIG. 223– The left triangular bone. ( See enlarged image)', 'metadata': {'source_page': '137'}, 'rerank_score': 0.5001903}, {'document': '![Plan of ossification of the hand](./data/images/image_141_9.png)\nFIG. 234– Plan of ossification of the hand. ( See enlarged image)', 'metadata': {'source_page': '141'}, 'rerank_score': 0.50000554}, {'document': '—', 'metadata': {'source_page': '37'}, 'rerank_score': 0.4983902}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am answering based on the graph structure alone, as the provided context does not contain information about the triangular ligament. However, the context does mention a “left triangular bone” (Page 137).
#
#
#
# ==============================
# 질문: What structures perforate the superficial layer (inferior fascia) of the urogenital diaphragm?
# reranked_chunks : [{'document': '![Sacrum, pelvic surface](./data/images/image_56_9.png)\nFIG. 95– Sacrum, pelvic surface. (See enlarged image)', 'metadata': {'source_page': '56'}, 'rerank_score': 0.50912833}, {'document': '![Base of skull. Inferior surface](./data/images/image_111_1.png)\nFIG. 187– Base of skull. Inferior surface. ( See enlarged image)', 'metadata': {'source_page': '111'}, 'rerank_score': 0.5074949}, {'document': '![At birth](./data/images/image_108_3.png)\nFIG. 182– At birth. (See enlarged image)', 'metadata': {'source_page': '108'}, 'rerank_score': 0.5060846}, {'document': '![Mandible. Inner surface. Side view](./data/images/image_106_2.png)\nFIG. 177– Mandible. Inner surface. Side view. (See enlarged image)', 'metadata': {'source_page': '106'}, 'rerank_score': 0.5044362}, {'document': '![Left calcaneus, inferior surface](./data/images/image_162_2.png)\nFIG. 265– Left calcaneus, inferior surface. ( See enlarged image)', 'metadata': {'source_page': '162'}, 'rerank_score': 0.50397515}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am sorry, but the provided context does not contain information about the structures that perforate the superficial layer (inferior fascia) of the urogenital diaphragm. Therefore, I cannot answer your question.
#
#
#
# ==============================
# 질문: Where does the Extensor digitorum longus muscle originate, and what structures are located between it and the Tibialis anterior?
# reranked_chunks : [{'document': '![Human embryo, thirty-one to thirty-four days old](./data/images/image_34_1.png)\nFIG. 61– Human embryo, thirty-one to thirty-four days old. (His.) ( See enlarged image)', 'metadata': {'source_page': '34'}, 'rerank_score': 0.50095755}, {'document': '![Muscles of the sole of the foot. Second layer](./data/images/image_330_1.png)\nFIG. 444– Muscles of the sole of the foot. Second layer. ( See enlarged image)', 'metadata': {'source_page': '330'}, 'rerank_score': 0.50033003}, {'document': '![Muscles of the sole of the foot. First layer](./data/images/image_329_1.png)\nFIG. 443– Muscles of the sole of the foot. First layer. ( See enlarged image)', 'metadata': {'source_page': '329'}, 'rerank_score': 0.5002501}, {'document': '![Human embryo of about six weeks](./data/images/image_34_2.png)\nFIG. 62– Human embryo of about six weeks. (His.) (See enlarged image)', 'metadata': {'source_page': '34'}, 'rerank_score': 0.50019294}, {'document': '![Human embryo, twenty-seven to thirty days old](./data/images/image_33_3.png)\nFIG. 60– Human embryo, twenty-seven to thirty days old. (His.) (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.49992168}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am answering based on the graph structure alone, as the provided context does not contain information about the Extensor digitorum longus muscle or its relationship to the Tibialis anterior. Therefore, I cannot answer your question using the given context.
#
#
#
# ==============================
# 질문: What is the Peronæus tertius, and where is it inserted?
# reranked_chunks : [{'document': '![Skeleton of foot. Lateral aspect](./data/images/image_172_2.png)\nFIG. 291– Skeleton of foot. Lateral aspect. (See enlarged image)', 'metadata': {'source_page': '172'}, 'rerank_score': 0.51640475}, {'document': '![Muscles of the sole of the foot. Second layer](./data/images/image_330_1.png)\nFIG. 444– Muscles of the sole of the foot. Second layer. ( See enlarged image)', 'metadata': {'source_page': '330'}, 'rerank_score': 0.5160588}, {'document': '![Occipita bone. Inner surface](./data/images/image_74_2.png)\nFIG. 130– Occipita bone. Inner surface. ( See enlarged image)', 'metadata': {'source_page': '74'}, 'rerank_score': 0.5155413}, {'document': '![First cervical vertebra, or atlas](./data/images/image_51_1.png)\nFIG. 86– First cervical vertebra, or atlas. ( See enlarged image)', 'metadata': {'source_page': '51'}, 'rerank_score': 0.5153598}, {'document': '![Plan of ossification of the foot](./data/images/image_171_1.png)\nFIG. 289– Plan of ossification of the foot. ( See enlarged image)', 'metadata': {'source_page': '171'}, 'rerank_score': 0.5151775}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am sorry, but the provided context does not contain information about the Peronæus tertius or its insertion point. Therefore, I cannot answer your question based on the given text.
#
#
#
# ==============================
# 질문: What are the main characteristics of the middle coat (tunica media) of arteries, and how does its composition vary with vessel size?
# reranked_chunks : [{'document': '![The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of formation of the palate](./data/images/image_29_2.png)\nFIG. 50– The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of', 'metadata': {'source_page': '29'}, 'rerank_score': 0.50216246}, {'document': '![Human embryo of about six weeks](./data/images/image_34_2.png)\nFIG. 62– Human embryo of about six weeks. (His.) (See enlarged image)', 'metadata': {'source_page': '34'}, 'rerank_score': 0.4986063}, {'document': '![Embryo of about six weeks](./data/images/image_30_2.png)\nFIG. 53– Embryo of about six weeks. (His.) (See enlarged image)', 'metadata': {'source_page': '30'}, 'rerank_score': 0.4984745}, {'document': '![Head of a human embryo of about eight weeks, in which the nose and mouth are formed](./data/images/image_28_3.png)\nFIG. 47– Head of a human embryo of about eight weeks, in which the nose and mouth are formed. (His.) (See', 'metadata': {'source_page': '28'}, 'rerank_score': 0.4984213}, {'document': '![Muscles of the sole of the foot. Second layer](./data/images/image_330_1.png)\nFIG. 444– Muscles of the sole of the foot. Second layer. ( See enlarged image)', 'metadata': {'source_page': '330'}, 'rerank_score': 0.49821615}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am sorry, but the provided context does not contain information about the characteristics of the middle coat (tunica media) of arteries, nor does it discuss how its composition varies with vessel size. Therefore, I cannot answer your question using the given text. I am answering based on the graph structure alone.
#
#
#
# ==============================
# 질문: Describe the composition and variations of the external coat (tunica adventitia) in arteries.
# reranked_chunks : [{'document': '![Muscles of the sole of the foot. Second layer](./data/images/image_330_1.png)\nFIG. 444– Muscles of the sole of the foot. Second layer. ( See enlarged image)', 'metadata': {'source_page': '330'}, 'rerank_score': 0.5109236}, {'document': '![Muscles of the sole of the foot. Third layer](./data/images/image_330_2.png)\nFIG. 445– Muscles of the sole of the foot. Third layer. ( See enlarged image)', 'metadata': {'source_page': '330'}, 'rerank_score': 0.509303}, {'document': '![Plan of ossification of the foot](./data/images/image_171_1.png)\nFIG. 289– Plan of ossification of the foot. ( See enlarged image)', 'metadata': {'source_page': '171'}, 'rerank_score': 0.5080467}, {'document': '![At birth](./data/images/image_108_3.png)\nFIG. 182– At birth. (See enlarged image)', 'metadata': {'source_page': '108'}, 'rerank_score': 0.5052413}, {'document': '![The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of formation of the palate](./data/images/image_29_2.png)\nFIG. 50– The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of', 'metadata': {'source_page': '29'}, 'rerank_score': 0.5052237}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am sorry, but the provided context does not contain information about the composition and variations of the external coat (tunica adventitia) in arteries. Therefore, I cannot answer your question based on the given text. I am answering based on the graph structure alone.
#
#
#
# ==============================
# 질문: How do the Vitelline Veins develop into parts of the portal and hepatic veins?
# reranked_chunks : [{'document': '![Human embryo between eighteen and twenty-one days old](./data/images/image_33_2.png)\nFIG. 59– Human embryo between eighteen and twenty-one days old. (His. (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.49798238}, {'document': '![Head of a human embryo of about eight weeks, in which the nose and mouth are formed](./data/images/image_28_3.png)\nFIG. 47– Head of a human embryo of about eight weeks, in which the nose and mouth are formed. (His.) (See', 'metadata': {'source_page': '28'}, 'rerank_score': 0.49610618}, {'document': '![Human embryo, thirty-one to thirty-four days old](./data/images/image_34_1.png)\nFIG. 61– Human embryo, thirty-one to thirty-four days old. (His.) ( See enlarged image)', 'metadata': {'source_page': '34'}, 'rerank_score': 0.4960588}, {'document': '![Human embryo, twenty-seven to thirty days old](./data/images/image_33_3.png)\nFIG. 60– Human embryo, twenty-seven to thirty days old. (His.) (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.49556822}, {'document': '## 4. Fertilization of the Ovum\n![The process of fertilization in the ovum of a mouse](./data/images/image_12_1.png)\nFIG. 8– The process of fertilization in the ovum of a mouse. (After Sobotta.) ( See enlarged image)', 'metadata': {'source_page': '12'}, 'rerank_score': 0.49476302}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am sorry, but the provided context does not contain information about how the Vitelline Veins develop into parts of the portal and hepatic veins. Therefore, I cannot answer your question based on the given text. I am answering based on the graph structure alone.
#
#
#
# ==============================
# 질문: What happens to the Umbilical Veins during embryonic development and after birth?
# reranked_chunks : [{'document': '![The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of formation of the palate](./data/images/image_29_2.png)\nFIG. 50– The roof of the mouth of a human embryo, aged about two and a half months, showing the mode of', 'metadata': {'source_page': '29'}, 'rerank_score': 0.5156081}, {'document': '![Human embryo about fifteen days old](./data/images/image_33_1.png)\nFIG. 58– Human embryo about fifteen days old. (His.) (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.5113515}, {'document': '![Human embryo of about six weeks](./data/images/image_34_2.png)\nFIG. 62– Human embryo of about six weeks. (His.) (See enlarged image)', 'metadata': {'source_page': '34'}, 'rerank_score': 0.5112824}, {'document': '![Human embryo between eighteen and twenty-one days old](./data/images/image_33_2.png)\nFIG. 59– Human embryo between eighteen and twenty-one days old. (His. (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.51044214}, {'document': '![Human embryo, twenty-seven to thirty days old](./data/images/image_33_3.png)\nFIG. 60– Human embryo, twenty-seven to thirty days old. (His.) (See enlarged image)', 'metadata': {'source_page': '33'}, 'rerank_score': 0.5103499}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: The provided context does not contain information about what happens to the Umbilical Veins during embryonic development or after birth. Therefore, I cannot answer your question based on the given text. I am answering based on the graph structure alone.
#
#
#
# ==============================
# 질문: What are the three phases of a cardiac cycle and what happens during each?
# reranked_chunks : [{'document': 'Coronary sinus. Valves » Valve of the inferior vena cava.\nForamina venarum minimarum. Valve of the coronary sinus.', 'metadata': {'source_page': '353'}, 'rerank_score': 0.50070256}, {'document': '![Front view of heart and lungs](./data/images/image_352_1.png)\nFIG. 490– Front view of heart and lungs. (See enlarged image)', 'metadata': {'source_page': '352'}, 'rerank_score': 0.5004839}, {'document': '![Profile view of a human embryo estimated at twenty or twenty-one days old](./data/images/image_343_1.png)\nFIG. 472– Profile view of a human embryo estimated at twenty or twenty-one days old. (After His.) ( See', 'metadata': {'source_page': '343'}, 'rerank_score': 0.49911857}, {'document': '![Same heart as in Fig. 467, opened on right side](./data/images/image_342_1.png)\nFIG. 468– Same heart as in Fig. 467, opened on right side. (From model by His.) ( See enlarged image)', 'metadata': {'source_page': '342'}, 'rerank_score': 0.4990978}, {'document': '![Scheme of the aortic arches and their destination](./data/images/image_343_2.png)\nFIG. 473– Scheme of the aortic arches and their destination. (Modified from Kollmann.) ( See enlarged image)', 'metadata': {'source_page': '343'}, 'rerank_score': 0.49817094}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: The provided context does not contain information about the phases of a cardiac cycle or what happens during each phase. Therefore, I cannot answer your question based on the given text. I am answering based on the graph structure alone.
#
#
#
# ==============================
# 질문: What are the main peculiarities observed in the fetal heart's vascular system?
# reranked_chunks : [{'document': '![Human embryo of about six weeks](./data/images/image_34_2.png)\nFIG. 62– Human embryo of about six weeks. (His.) (See enlarged image)', 'metadata': {'source_page': '34'}, 'rerank_score': 0.495567}, {'document': '![Human embryo, thirty-one to thirty-four days old](./data/images/image_34_1.png)\nFIG. 61– Human embryo, thirty-one to thirty-four days old. (His.) ( See enlarged image)', 'metadata': {'source_page': '34'}, 'rerank_score': 0.49523908}, {'document': '![Human embryo about eight and a half weeks old](./data/images/image_34_3.png)\nFIG. 63– Human embryo about eight and a half weeks old. (His.) (See enlarged image)', 'metadata': {'source_page': '34'}, 'rerank_score': 0.49462053}, {'document': 'Seventh Month. —The pupillary membrane atrophies and the eyelids are open. The testis descends with the\nvaginal sac of the peritoneum. From vertex to heels the total length at the end of the seventh month is from\n35 to 36 cm. The weight is a little over three pounds.', 'metadata': {'source_page': '34'}, 'rerank_score': 0.49234885}, {'document': '![Profile view of a human embryo estimated at twenty or twenty-one days old](./data/images/image_343_1.png)\nFIG. 472– Profile view of a human embryo estimated at twenty or twenty-one days old. (After His.) ( See', 'metadata': {'source_page': '343'}, 'rerank_score': 0.49159116}]
# 범용 토크나이저를 사용하여 길이를 근사치로 계산합니다. (Ollama 등)
# ==============================
# 답변: I am answering based on the graph structure alone, as the provided context does not contain information about the peculiarities observed in the fetal heart's vascular system. The context only provides images of human embryos at different stages of development (Page 34, Page 343) and a description of the development at the seventh month (Page 34).
#
#
#
# ==============================
# 평균 답변 시간 : 10.69
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
