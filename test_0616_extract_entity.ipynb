# %% [markdown]
# # 객체-관계 추출

# %%
import os
import re
import json
import torch
from model_loader.config import generation_loader
from model_loader.local_loader import LocalModelLoader
from model_loader.ollama_loader import OllamaModelLoader

def extract_entities_and_relations_with_llm(text_to_analyze) :
    if isinstance(generation_loader, LocalModelLoader) :
        llm_model = generation_loader.model
        llm_tokenizer = generation_loader.tokenizer

        if llm_model is None or llm_tokenizer is None :
            return None, None
        
        try :
            llm_model.eval()
        except Exception as e :
            return None, None
        
        is_local_model = True

    elif isinstance(generation_loader, OllamaModelLoader) :
        is_local_model = False

    else :
        return None, None
    
    prompt = f"""
        Extract entities and their relations from the following sentence.

        **Entities** should be **unique nouns or concepts**, extracted as **noun phrases** whenever possible. Identify **concrete objects or concepts** rather than complex activities or phenomena as entities.

        **Relations** should clearly describe the connection between two entities, preferring **reusable predicate verbs** for a knowledge graph. Use **concise verbs** or clear, hyphenated forms like **'part_of' or 'includes'**.

        Use the following specific and concise relation verbs:
        * 'X circulates through Y' -> **'circulates_through'**
        * 'X supplies Y' -> **'supplies'**
        * 'X is a part of Y' -> **'part_of'**
        * 'X causes Y' -> **'causes'**
        * 'X generates Y' -> **'generates'**
        * 'X exists_in Y' -> **'exists_in'**
        * 'X is the central organ of Y' -> **'central_organ_of'**
        * 'X regulates Y' -> **'regulates'**
        * 'X is caused_by Y' -> **'caused_by'**
        * 'X mediates Y' -> **'mediates'**

        Avoid descriptive or ambiguous relations (e.g., 'X is related to Y', 'X is responsible for Y', 'X performs Y', 'X plays an important role in Y'), and convert them into more precise relations.

        Output the result **only in the following JSON format**, with no other explanations or text:

        ```json
        {{
            "entities": [
                {{"name": "Entity1", "type": "Type (e.g., Organ, System, Substance, Function, Disease)"}},
                {{"name": "Entity2", "type": "Type"}}
            ],
            "relations": [
                {{"head": "Entity1", "relation": "Relation_Type (e.g., part_of, causes)", "tail": "Entity2"}},
                {{"head": "Entity3", "relation": "generates", "tail": "Entity4"}}
            ]
        }}

        sentence : "{text_to_analyze}"
        JSON result : 
    """

    generated_text = ""
    if is_local_model :
        inputs = llm_tokenizer(prompt, return_tensors="pt").to(llm_model.device)
        max_new_tokens = 512

        with torch.no_grad() :
            outputs = llm_model.generate(
                **inputs,
                max_new_tokens = max_new_tokens,
                num_return_sequences = 1,
                do_sample = True,
                temperature = 0.4,
                top_p = 0.9,
                repetition_penalty = 1.2,
                eos_token_id = llm_tokenizer.eos_token_id
            )
        generated_text = llm_tokenizer.decode(outputs[0][inputs.input_ids.shape[1]:], skip_special_tokens=True)
    else :
        generated_text = generation_loader.generate(prompt)

    print("--- LLM 원본 출력 ---")
    print(generated_text)

    try :
        generated_text = re.sub(r"```json\s*", '', generated_text, flags = re.IGNORECASE)
        generated_text = re.sub(r"\s*```", '', generated_text)

        json_start = generated_text.find('{')
        json_end = generated_text.rfind('}')

        if json_start != -1 and json_end != -1 and json_end > json_start :
            json_str = generated_text[json_start:json_end + 1]
            parsed_result = json.loads(json_str.strip())

            extracted_entities = parsed_result.get("entities", [])
            extracted_relations = parsed_result.get("relations", [])

            return extracted_entities, extracted_relations
        
        else :
            return None, None
        
    except json.JSONDecodeError as e :
        print(f"JSON 파싱 오류 : {e}")
        return None, None
    except Exception as e :
        print(f"JSON 파싱 중 오류 : {e}")
        return None, None
    
if __name__ == "__main__" :
    data_folder = "./data/split_file/anatomy"
    output_base_folder = "./data/extracted_results"
    os.makedirs(output_base_folder, exist_ok = True)
    file_list = ["1_Embryology.md", "2_Osteology.md", "3_Syndesmology.md"]
    for filename in os.listdir(data_folder) :
        if filename in file_list :
            filepath = os.path.join(data_folder, filename)
            output_filename = os.path.splitext(filename)[0] + "_1" + ".json"
            output_filepath = os.path.join(output_base_folder, output_filename)

            if os.path.exists(output_filepath) :
                print(f"파일 {output_filename}이 존재")
                continue
            
            with open(filepath, 'r', encoding="utf-8") as f :
                text_content = f.read()

            paragraphs = re.split(r"\n\s*\n+", text_content)

            document_extracted_data = {
                "filename" : filename,
                "full_original_text" : text_content,
                "paragraphs_data" : []
            }

            for i, paragraph in enumerate(paragraphs) :
                if not paragraph.strip() :
                    continue

                entities, relations = extract_entities_and_relations_with_llm(paragraph)

                paragraph_data = {
                    "paragraph_id" : i,
                    "original_paragraph_text" : paragraph.strip(),
                    "entities" : entities if entities is not None else [],
                    "relations" : relations if relations is not None else []
                }
                document_extracted_data["paragraphs_data"].append(paragraph_data)

                if entities is None and relations is None :
                    print("관게 추출 실패")

            if document_extracted_data["paragraphs_data"] :
                with open(output_filepath, 'w', encoding="utf-8") as f :
                    json.dump(document_extracted_data, f, ensure_ascii=False, indent=4)
            else :
                print(f"파일 {filename}에서 개체, 관계 추출 실패")
            print("\n" + '=' * 50 + "\n")
# Out:
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# The new lm_head weights will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Embryology", "type": "Field_of_Study"}
#     ],
#     "relations": []
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Embryology", "type": "Field"},
#         {"name": "changes", "type": "Process"},
#         {"name": "animal", "type": "Organism"},
#         {"name": "egg", "type": "Biological_Structure"},
#         {"name": "adult condition", "type": "Life_Stage"},
#         {"name": "ontogeny", "type": "Field"},
#         {"name": "individual", "type": "Organism"},
#         {"name": "phylogeny", "type": "Field"},
#         {"name": "animal kingdom", "type": "Taxonomic_Group"}
#     ],
#     "relations": [
#         {"head": "Embryology", "relation": "deals_with", "tail": "changes"},
#         {"head": "changes", "relation": "occur_during", "tail": "growth"},
#         {"head": "animal", "relation": "undergoes", "tail": "growth"},
#         {"head": "growth", "relation": "starts_from", "tail": "egg"},
#         {"head": "growth", "relation": "ends_at", "tail": "adult condition"},
#         {"head": "Embryology", "relation": "deals_with", "tail": "ontogeny"},
#         {"head": "ontogeny", "relation": "deals_with", "tail": "individual"},
#         {"head": "Embryology", "relation": "deals_with", "tail": "phylogeny"},
#         {"head": "phylogeny", "relation": "concerns", "tail": "animal kingdom"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "vertebrate animals", "type": "Organism"},
#         {"name": "development", "type": "Process"},
#         {"name": "being", "type": "Organism"},
#         {"name": "female germ cell", "type": "Cell"},
#         {"name": "ovum", "type": "Cell"},
#         {"name": "male germ cell", "type": "Cell"},
#         {"name": "spermatozoön", "type": "Cell"},
#         {"name": "nucleated cell", "type": "Cell"},
#         {"name": "tissues", "type": "Tissue"},
#         {"name": "organs", "type": "Organ"},
#         {"name": "body", "type": "Body"},
#         {"name": "segmentation", "type": "Process"},
#         {"name": "differentiation of cells", "type": "Process"},
#         {"name": "cells", "type": "Cell"},
#         {"name": "somatic cells", "type": "Cell"},
#         {"name": "function", "type": "Function"},
#         {"name": "germinal cells", "type": "Cell"},
#         {"name": "sexual glands", "type": "Organ"},
#         {"name": "ovaries", "type": "Organ"},
#         {"name": "female", "type": "Sex"},
#         {"name": "testes", "type": "Organ"},
#         {"name": "male", "type": "Sex"},
#         {"name": "species", "type": "Taxon"}
#     ],
#     "relations": [
#         {"head": "development", "relation": "exists_in", "tail": "vertebrate animals"},
#         {"head": "being", "relation": "caused_by", "tail": "female germ cell"},
#         {"head": "being", "relation": "caused_by", "tail": "spermatozoön"},
#         {"head": "ovum", "relation": "is_a", "tail": "nucleated cell"},
#         {"head": "segmentation", "relation": "generates", "tail": "tissues"},
#         {"head": "segmentation", "relation": "generates", "tail": "organs"},
#         {"head": "differentiation of cells", "relation": "generates", "tail": "tissues"},
#         {"head": "differentiation of cells", "relation": "generates", "tail": "organs"},
#         {"head": "somatic cells", "relation": "part_of", "tail": "body"},
#         {"head": "function", "relation": "mediates", "tail": "somatic cells"},
#         {"head": "germinal cells", "relation": "part_of", "tail": "sexual glands"},
#         {"head": "ovaries", "relation": "part_of", "tail": "female"},
#         {"head": "testes", "relation": "part_of", "tail": "male"},
#         {"head": "germinal cells", "relation": "causes", "tail": "species"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "work", "type": "Concept"},
#         {"name": "purpose", "type": "Concept"},
#         {"name": "space", "type": "Concept"},
#         {"name": "section", "type": "Concept"},
#         {"name": "phenomena", "type": "Concept"},
#         {"name": "stages", "type": "Concept"},
#         {"name": "development", "type": "Process"},
#         {"name": "human body", "type": "Organism"},
#         {"name": "facts", "type": "Concept"},
#         {"name": "student", "type": "Person"},
#         {"name": "details", "type": "Concept"},
#         {"name": "text-books", "type": "Document"},
#         {"name": "human embryology", "type": "Field"},
#         {"name": "Animal Cell", "type": "Cell"}
#     ],
#     "relations": [
#         {"head": "work", "relation": "has_purpose", "tail": "purpose"},
#         {"head": "phenomena", "relation": "occurs_in", "tail": "stages"},
#         {"head": "stages", "relation": "part_of", "tail": "development"},
#         {"head": "development", "relation": "of", "tail": "human body"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "tissues", "type": "Organ"},
#         {"name": "organs", "type": "Organ"},
#         {"name": "body", "type": "Organ"},
#         {"name": "microscopic structure", "type": "Structure"},
#         {"name": "fertilized ovum", "type": "Cell"},
#         {"name": "material", "type": "Substance"},
#         {"name": "membrane", "type": "Structure"},
#         {"name": "vesicle", "type": "Structure"},
#         {"name": "spots", "type": "Structure"},
#         {"name": "cell", "type": "Cell"},
#         {"name": "solid tissues", "type": "Organ"}
#     ],
#     "relations": [
#         {"head": "tissues", "relation": "part_of", "tail": "body"},
#         {"head": "organs", "relation": "part_of", "tail": "body"},
#         {"head": "tissues", "relation": "originate_from", "tail": "microscopic structure"},
#         {"head": "organs", "relation": "originate_from", "tail": "microscopic structure"},
#         {"head": "material", "relation": "part_of", "tail": "fertilized ovum"},
#         {"head": "membrane", "relation": "encloses", "tail": "material"},
#         {"head": "vesicle", "relation": "exists_in", "tail": "fertilized ovum"},
#         {"head": "spots", "relation": "exists_in", "tail": "vesicle"},
#         {"head": "fertilized ovum", "relation": "is_a", "tail": "cell"},
#         {"head": "solid tissues", "relation": "consists_of", "tail": "cell"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "higher organisms", "type": "Organism"},
#         {"name": "cell", "type": "Biological_Unit"},
#         {"name": "nucleated mass of protoplasm", "type": "Substance"},
#         {"name": "cytoplasm", "type": "Substance"},
#         {"name": "ovum", "type": "Biological_Unit"},
#         {"name": "nucleus", "type": "Organ"},
#         {"name": "unicellular protozoa", "type": "Organism"},
#         {"name": "granular particles", "type": "Substance"},
#         {"name": "basic dyes", "type": "Substance"},
#         {"name": "limiting membrane", "type": "Organ"},
#         {"name": "denser spot", "type": "Substance"},
#         {"name": "nucleolus", "type": "Organ"}
#     ],
#     "relations": [
#         {"head": "cell", "relation": "part_of", "tail": "higher organisms"},
#         {"head": "cytoplasm", "relation": "part_of", "tail": "ovum"},
#         {"head": "nucleus", "relation": "exists_in", "tail": "cytoplasm"},
#         {"head": "granular particles", "relation": "exists_in", "tail": "unicellular protozoa"},
#         {"head": "granular particles", "relation": "mediates", "tail": "basic dyes"},
#         {"head": "limiting membrane", "relation": "part_of", "tail": "ovum"},
#         {"head": "denser spot", "relation": "part_of", "tail": "nucleus"},
#         {"head": "nucleolus", "relation": "part_of", "tail": "denser spot"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Cytoplasm", "type": "Organ"},
#         {"name": "protoplasm", "type": "Substance"},
#         {"name": "bodies", "type": "Substance"},
#         {"name": "proteid", "type": "Substance"},
#         {"name": "Lecithin", "type": "Substance"},
#         {"name": "cholesterin", "type": "Substance"},
#         {"name": "inorganic salts", "type": "Substance"},
#         {"name": "phosphates", "type": "Substance"},
#         {"name": "chlorides", "type": "Substance"},
#         {"name": "potassium", "type": "Element"},
#         {"name": "sodium", "type": "Element"},
#         {"name": "calcium", "type": "Element"},
#         {"name": "granules", "type": "Structure"},
#         {"name": "mitochondria", "type": "Organ"},
#         {"name": "fat", "type": "Substance"},
#         {"name": "glycogen", "type": "Substance"},
#         {"name": "pigment", "type": "Substance"},
#         {"name": "cell-inclusions", "type": "Structure"},
#         {"name": "paraplasm", "type": "Substance"},
#         {"name": "reagents", "type": "Substance"},
#         {"name": "fibrils", "type": "Structure"},
#         {"name": "network", "type": "Structure"},
#         {"name": "reticulum", "type": "Structure"},
#         {"name": "spongioplasm", "type": "Structure"},
#         {"name": "hyaloplasm", "type": "Structure"},
#         {"name": "meshes", "type": "Structure"},
#         {"name": "cell", "type": "Structure"},
#         {"name": "cell membrane", "type": "Structure"},
#         {"name": "ovum", "type": "Cell"}
#     ],
#     "relations": [
#         {"head": "Cytoplasm", "relation": "part_of", "tail": "protoplasm"},
#         {"head": "bodies", "relation": "part_of", "tail": "proteid"},
#         {"head": "Lecithin", "relation": "exists_in", "tail": "Cytoplasm"},
#         {"head": "cholesterin", "relation": "exists_in", "tail": "Cytoplasm"},
#         {"head": "inorganic salts", "relation": "exists_in", "tail": "Cytoplasm"},
#         {"head": "phosphates", "relation": "part_of", "tail": "inorganic salts"},
#         {"head": "chlorides", "relation": "part_of", "tail": "inorganic salts"},
#         {"head": "potassium", "relation": "part_of", "tail": "chlorides"},
#         {"head": "sodium", "relation": "part_of", "tail": "chlorides"},
#         {"head": "calcium", "relation": "part_of", "tail": "chlorides"},
#         {"head": "granules", "relation": "exists_in", "tail": "Cytoplasm"},
#         {"head": "mitochondria", "relation": "part_of", "tail": "granules"},
#         {"head": "fat", "relation": "part_of", "tail": "granules"},
#         {"head": "glycogen", "relation": "part_of", "tail": "granules"},
#         {"head": "pigment", "relation": "part_of", "tail": "granules"},
#         {"head": "cell-inclusions", "relation": "part_of", "tail": "granules"},
#         {"head": "paraplasm", "relation": "part_of", "tail": "cell-inclusions"},
#         {"head": "fibrils", "relation": "part_of", "tail": "network"},
#         {"head": "network", "relation": "part_of", "tail": "reticulum"},
#         {"head": "spongioplasm", "relation": "part_of", "tail": "reticulum"},
#         {"head": "hyaloplasm", "relation": "part_of", "tail": "reticulum"},
#         {"head": "meshes", "relation": "part_of", "tail": "spongioplasm"},
#         {"head": "cell", "relation": "part_of", "tail": "cell membrane"},
#         {"head": "ovum", "relation": "part_of", "tail": "cell"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "cell", "type": "Organ"}
#     ],
#     "relations": []
# }
# ```
# --- LLM 원본 출력 ---
# Please provide the sentence you want me to process. I need the sentence to extract entities and relations and generate the JSON output.
# 관게 추출 실패
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "nucleus", "type": "Organ"},
#         {"name": "protoplasm", "type": "Substance"},
#         {"name": "cell", "type": "Organ"},
#         {"name": "nuclear membrane", "type": "Organ"},
#         {"name": "nuclear substance", "type": "Substance"},
#         {"name": "nuclear matrix", "type": "Substance"},
#         {"name": "nucleoli", "type": "Organ"},
#         {"name": "karyoplasm", "type": "Substance"},
#         {"name": "karyomitome", "type": "Organ"},
#         {"name": "hyaloplasm", "type": "Substance"},
#         {"name": "spongioplasm", "type": "Substance"},
#         {"name": "filaments", "type": "Substance"},
#         {"name": "linin", "type": "Substance"},
#         {"name": "acid dyes", "type": "Substance"},
#         {"name": "basic dyes", "type": "Substance"},
#         {"name": "basophil granules", "type": "Substance"},
#         {"name": "chromatin", "type": "Substance"},
#         {"name": "nucleic acid", "type": "Substance"},
#         {"name": "pseudo-nucleoli", "type": "Organ"}
#     ],
#     "relations": [
#         {"head": "nucleus", "relation": "exists_in", "tail": "protoplasm"},
#         {"head": "nucleus", "relation": "part_of", "tail": "cell"},
#         {"head": "nuclear membrane", "relation": "surrounds", "tail": "nucleus"},
#         {"head": "nuclear membrane", "relation": "surrounds", "tail": "nuclear substance"},
#         {"head": "nuclear substance", "relation": "composed_of", "tail": "nuclear matrix"},
#         {"head": "nuclear matrix", "relation": "includes", "tail": "nucleoli"},
#         {"head": "karyoplasm", "relation": "part_of", "tail": "nucleus"},
#         {"head": "karyomitome", "relation": "part_of", "tail": "nucleus"},
#         {"head": "karyoplasm", "relation": "same_nature_as", "tail": "hyaloplasm"},
#         {"head": "filaments", "relation": "part_of", "tail": "karyomitome"},
#         {"head": "linin", "relation": "composed_of", "tail": "filaments"},
#         {"head": "linin", "relation": "stains_with", "tail": "acid dyes"},
#         {"head": "linin", "relation": "includes", "tail": "basophil granules"},
#         {"head": "basophil granules", "relation": "named", "tail": "chromatin"},
#         {"head": "chromatin", "relation": "contains", "tail": "nucleic acid"},
#         {"head": "nucleoli", "relation": "connected_with", "tail": "nuclear membrane"},
#         {"head": "pseudo-nucleoli", "relation": "part_of", "tail": "chromatin"},
#         {"head": "nucleoli", "relation": "part_of", "tail": "nuclear matrix"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "living cells", "type": "Organ"},
#         {"name": "protoplasm", "type": "Substance"},
#         {"name": "nucleus", "type": "Organ"},
#         {"name": "centrosome", "type": "Organ"},
#         {"name": "centriole", "type": "Organ"},
#         {"name": "centrosphere", "type": "Substance"},
#         {"name": "fibrillar rows", "type": "Structure"},
#         {"name": "granules", "type": "Substance"},
#         {"name": "attraction sphere", "type": "Structure"}
#     ],
#     "relations": [
#         {"head": "living cells", "relation": "includes", "tail": "protoplasm"},
#         {"head": "living cells", "relation": "includes", "tail": "nucleus"},
#         {"head": "living cells", "relation": "includes", "tail": "centrosome"},
#         {"head": "centrosome", "relation": "includes", "tail": "centriole"},
#         {"head": "centrosome", "relation": "includes", "tail": "centrosphere"},
#         {"head": "centrosphere", "relation": "exists_in", "tail": "protoplasm"},
#         {"head": "protoplasm", "relation": "includes", "tail": "fibrillar rows"},
#         {"head": "fibrillar rows", "relation": "includes", "tail": "granules"},
#         {"head": "fibrillar rows", "relation": "forms", "tail": "attraction sphere"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Reproduction", "type": "Process"},
#         {"name": "Cells", "type": "Organ"},
#         {"name": "direct division", "type": "Process"},
#         {"name": "nucleus", "type": "Organ"},
#         {"name": "center", "type": "Location"},
#         {"name": "hour-glass shape", "type": "Shape"},
#         {"name": "cleavage", "type": "Process"},
#         {"name": "protoplasmic mass", "type": "Substance"},
#         {"name": "daughter cells", "type": "Organ"},
#         {"name": "mother cell", "type": "Organ"},
#         {"name": "tissues", "type": "Organ"},
#         {"name": "generative cells", "type": "Organ"},
#         {"name": "epithelial tissue", "type": "Organ"},
#         {"name": "connective tissue", "type": "Organ"},
#         {"name": "muscular tissue", "type": "Organ"},
#         {"name": "nerve tissue", "type": "Organ"},
#         {"name": "cell division", "type": "Process"},
#         {"name": "indirect division", "type": "Process"},
#         {"name": "karyokinesis", "type": "Process"},
#         {"name": "karyomitosis", "type": "Process"}
#     ],
#     "relations": [
#         {"head": "Reproduction", "relation": "generates", "tail": "Cells"},
#         {"head": "direct division", "relation": "causes", "tail": "nucleus"},
#         {"head": "nucleus", "relation": "exists_in", "tail": "center"},
#         {"head": "nucleus", "relation": "causes", "tail": "karyokinesis"},
#         {"head": "cleavage", "relation": "causes", "tail": "daughter cells"},
#         {"head": "daughter cells", "relation": "part_of", "tail": "mother cell"},
#         {"head": "cell division", "relation": "takes_place_in", "tail": "tissues"},
#         {"head": "generative cells", "relation": "part_of", "tail": "tissues"},
#         {"head": "epithelial tissue", "relation": "part_of", "tail": "tissues"},
#         {"head": "connective tissue", "relation": "part_of", "tail": "tissues"},
#         {"head": "muscular tissue", "relation": "part_of", "tail": "tissues"},
#         {"head": "nerve tissue", "relation": "part_of", "tail": "tissues"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "process of indirect cell division", "type": "Process"},
#         {"name": "nucleus", "type": "Organ"},
#         {"name": "subdivision", "type": "Process"},
#         {"name": "cleavage", "type": "Process"},
#         {"name": "cell protoplasm", "type": "Substance"},
#         {"name": "nucleus", "type": "Organ"},
#         {"name": "quiescent stage", "type": "State"},
#         {"name": "phases", "type": "Process"}
#     ],
#     "relations": [
#         {"head": "process of indirect cell division", "relation": "causes", "tail": "subdivision"},
#         {"head": "process of indirect cell division", "relation": "causes", "tail": "cleavage"},
#         {"head": "cleavage", "relation": "mediates", "tail": "cell protoplasm"},
#         {"head": "nucleus", "relation": "exists_in", "tail": "quiescent stage"},
#         {"head": "phases", "relation": "part_of", "tail": "process of indirect cell division"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Prophase", "type": "Stage"},
#         {"name": "nuclear network", "type": "Structure"},
#         {"name": "chromatin filaments", "type": "Molecule"},
#         {"name": "nuclear membrane", "type": "Structure"},
#         {"name": "nucleolus", "type": "Structure"},
#         {"name": "skein", "type": "Structure"},
#         {"name": "chromosomes", "type": "Structure"},
#         {"name": "animals", "type": "Organism"},
#         {"name": "cells", "type": "Structure"},
#         {"name": "species", "type": "Taxon"},
#         {"name": "man", "type": "Organism"},
#         {"name": "Flemming", "type": "Person"},
#         {"name": "Duesberg", "type": "Person"},
#         {"name": "centriole", "type": "Structure"},
#         {"name": "nucleus", "type": "Structure"},
#         {"name": "centrosphere", "type": "Structure"},
#         {"name": "spindle", "type": "Structure"},
#         {"name": "fibers", "type": "Structure"},
#         {"name": "equator", "type": "Structure"},
#         {"name": "poles", "type": "Structure"},
#         {"name": "mother star", "type": "Structure"}
#     ],
#     "relations": [
#         {"head": "chromatin filaments", "relation": "part_of", "tail": "nuclear network"},
#         {"head": "nuclear membrane", "relation": "exists_in", "tail": "nucleus"},
#         {"head": "nucleolus", "relation": "exists_in", "tail": "nucleus"},
#         {"head": "chromosomes", "relation": "part_of", "tail": "species"},
#         {"head": "chromosomes", "relation": "part_of", "tail": "cells"},
#         {"head": "centriole", "relation": "exists_in", "tail": "nucleus"},
#         {"head": "centrosphere", "relation": "part_of", "tail": "centriole"},
#         {"head": "spindle", "relation": "includes", "tail": "fibers"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Metaphase", "type": "Stage"},
#         {"name": "V-shaped chromosome", "type": "Chromosome"},
#         {"name": "longitudinal cleavage", "type": "Process"},
#         {"name": "two equal parts", "type": "Part"},
#         {"name": "daughter chromosomes", "type": "Chromosome"},
#         {"name": "apex", "type": "Structure"},
#         {"name": "divergent limbs", "type": "Structure"}
#     ],
#     "relations": [
#         {"head": "V-shaped chromosome", "relation": "undergoes", "tail": "longitudinal cleavage"},
#         {"head": "longitudinal cleavage", "relation": "generates", "tail": "two equal parts"},
#         {"head": "two equal parts", "relation": "are", "tail": "daughter chromosomes"},
#         {"head": "longitudinal cleavage", "relation": "commences_at", "tail": "apex"},
#         {"head": "longitudinal cleavage", "relation": "extends_along", "tail": "divergent limbs"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "daughter chromosomes", "type": "Cellular Component"},
#         {"name": "fibrils", "type": "Cellular Component"},
#         {"name": "achromatic spindle", "type": "Cellular Component"},
#         {"name": "centrioles", "type": "Cellular Component"},
#         {"name": "diaster", "type": "Biological Process"},
#         {"name": "skein", "type": "Structure"},
#         {"name": "spirem", "type": "Structure"},
#         {"name": "network of chromatin", "type": "Cellular Component"},
#         {"name": "resting nucleus", "type": "Cellular Component"}
#     ],
#     "relations": [
#         {"head": "daughter chromosomes", "relation": "travels_through", "tail": "fibrils"},
#         {"head": "daughter chromosomes", "relation": "exists_in", "tail": "achromatic spindle"},
#         {"head": "daughter chromosomes", "relation": "travels_through", "tail": "achromatic spindle"},
#         {"head": "daughter chromosomes", "relation": "exists_in", "tail": "centrioles"},
#         {"head": "diaster", "relation": "caused_by", "tail": "daughter chromosomes"},
#         {"head": "daughter chromosomes", "relation": "arranges_into", "tail": "skein"},
#         {"head": "skein", "relation": "forms", "tail": "spirem"},
#         {"head": "spirem", "relation": "forms", "tail": "network of chromatin"},
#         {"head": "network of chromatin", "relation": "exists_in", "tail": "resting nucleus"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "cell protoplasm", "type": "Substance"},
#         {"name": "equator", "type": "Structure"},
#         {"name": "achromatic spindle", "type": "Structure"},
#         {"name": "granules", "type": "Structure"},
#         {"name": "constriction", "type": "Process"},
#         {"name": "cell", "type": "Organ"},
#         {"name": "cells", "type": "Organ"},
#         {"name": "nucleus", "type": "Organ"},
#         {"name": "centrosome", "type": "Organ"},
#         {"name": "nuclear membrane", "type": "Structure"},
#         {"name": "nucleolus", "type": "Structure"}
#     ],
#     "relations": [
#         {"head": "cell protoplasm", "relation": "exists_in", "tail": "cell"},
#         {"head": "constriction", "relation": "exists_in", "tail": "cell protoplasm"},
#         {"head": "constriction", "relation": "mediates", "tail": "cell"},
#         {"head": "nucleus", "relation": "part_of", "tail": "cells"},
#         {"head": "centrosome", "relation": "part_of", "tail": "cells"},
#         {"head": "nuclear membrane", "relation": "part_of", "tail": "nucleus"},
#         {"head": "nucleolus", "relation": "part_of", "tail": "nucleus"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "centrosomes", "type": "Organ"},
#         {"name": "nucleus", "type": "Organ"},
#         {"name": "cell", "type": "Organ"},
#         {"name": "mitotic division", "type": "Process"}
#     ],
#     "relations": [
#         {"head": "centrosomes", "relation": "exists_in", "tail": "cell"},
#         {"head": "nucleus", "relation": "exists_in", "tail": "cell"},
#         {"head": "mitotic division", "relation": "causes", "tail": "centrosomes"},
#         {"head": "mitotic division", "relation": "causes", "tail": "nucleus"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "mitotic division", "type": "Process"},
#         {"name": "prophase", "type": "Stage"},
#         {"name": "metaphase", "type": "Stage"},
#         {"name": "anaphase", "type": "Stage"},
#         {"name": "telophase", "type": "Stage"}
#     ],
#     "relations": []
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "image", "type": "Object"}
#     ],
#     "relations": []
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Manual of Human Embryology", "type": "Book"},
#         {"name": "Keibel and Mall", "type": "Author"},
#         {"name": "Handbuch der vergleichenden und experimentellen Entwickelungslehre der Wirbeltiere", "type": "Book"},
#         {"name": "Oskar Hertwig", "type": "Author"},
#         {"name": "Lehrbuch der Entwickelungsgeschichte", "type": "Book"},
#         {"name": "Bonnet", "type": "Author"},
#         {"name": "The Physiology of Reproduction", "type": "Book"},
#         {"name": "Marshall", "type": "Author"}
#     ],
#     "relations": []
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Dr. J. Duesberg", "type": "Person"},
#         {"name": "Anat. Anz.", "type": "Publication"},
#         {"name": "Band xxviii", "type": "Volume"},
#         {"name": "S. 475", "type": "Page"}
#     ],
#     "relations": [
#         {"head": "Dr. J. Duesberg", "relation": "exists_in", "tail": "Anat. Anz."},
#         {"head": "Anat. Anz.", "relation": "includes", "tail": "Band xxviii"},
#         {"head": "Band xxviii", "relation": "includes", "tail": "S. 475"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# Please provide the sentence you want me to process. I need the text of the sentence to extract entities and relations and format the output in the specified JSON structure.
# 관게 추출 실패
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Human Body", "type": "Organ"},
#         {"name": "Embryology", "type": "Field_of_Study"},
#         {"name": "Ovum", "type": "Cell"}
#     ],
#     "relations": [
#         {"head": "Ovum", "relation": "part_of", "tail": "Human Body"},
#         {"head": "Ovum", "relation": "exists_in", "tail": "Embryology"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# Please provide the sentence you want me to process. I need the text between "sentence : " and "JSON result : " to generate the JSON output.
# 관게 추출 실패
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "CONTENTS", "type": "Section"},
#         {"name": "BIBLIOGRAPHIC RECORD", "type": "Record"},
#         {"name": "ILLUSTRATIONS", "type": "Section"},
#         {"name": "SUBJECT INDEX", "type": "Index"}
#     ],
#     "relations": []
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Henry Gray", "type": "Person"},
#         {"name": "Anatomy", "type": "Field_of_Study"},
#         {"name": "Human Body", "type": "Organism"},
#         {"name": "Ovum", "type": "Cell"}
#     ],
#     "relations": [
#         {"head": "Anatomy", "relation": "part_of", "tail": "Human Body"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "ova", "type": "Cell"},
#         {"name": "primitive germ cells", "type": "Cell"},
#         {"name": "ovaries", "type": "Organ"},
#         {"name": "oögonia", "type": "Cell"},
#         {"name": "primary oöcytes", "type": "Cell"}
#     ],
#     "relations": [
#         {"head": "ova", "relation": "developed_from", "tail": "primitive germ cells"},
#         {"head": "primitive germ cells", "relation": "exists_in", "tail": "ovaries"},
#         {"head": "primitive germ cells", "relation": "generates", "tail": "oögonia"},
#         {"head": "oögonia", "relation": "generates", "tail": "primary oöcytes"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Human ova", "type": "Cell"},
#         {"name": "egg follicles", "type": "Organ"},
#         {"name": "ovaries", "type": "Organ"},
#         {"name": "follicle", "type": "Organ"},
#         {"name": "ovum", "type": "Cell"},
#         {"name": "uterine tube", "type": "Organ"},
#         {"name": "cavity of the uterus", "type": "Anatomical Structure"},
#         {"name": "uterus", "type": "Organ"},
#         {"name": "fertilization", "type": "Process"},
#         {"name": "new being", "type": "Organism"}
#     ],
#     "relations": [
#         {"head": "Human ova", "relation": "exists_in", "tail": "egg follicles"},
#         {"head": "egg follicles", "relation": "part_of", "tail": "ovaries"},
#         {"head": "ovum", "relation": "exists_in", "tail": "follicle"},
#         {"head": "follicle", "relation": "part_of", "tail": "ovary"},
#         {"head": "ovum", "relation": "mediates", "tail": "fertilization"},
#         {"head": "uterine tube", "relation": "supplies", "tail": "cavity of the uterus"},
#         {"head": "uterus", "relation": "supplies", "tail": "cavity of the uterus"},
#         {"head": "fertilization", "relation": "causes", "tail": "new being"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "ovum", "type": "Cell"},
#         {"name": "cell", "type": "Cell"},
#         {"name": "yolk", "type": "Substance"},
#         {"name": "oöplasm", "type": "Substance"},
#         {"name": "nucleus", "type": "Organ"},
#         {"name": "germinal vesicle", "type": "Organ"},
#         {"name": "nucleolus", "type": "Organ"},
#         {"name": "germinal spot", "type": "Organ"},
#         {"name": "envelope", "type": "Structure"},
#         {"name": "zona striata", "type": "Structure"},
#         {"name": "zona pellucida", "type": "Structure"},
#         {"name": "layers of cells", "type": "Structure"},
#         {"name": "follicle", "type": "Organ"},
#         {"name": "corona radiata", "type": "Structure"}
#     ],
#     "relations": [
#         {"head": "ovum", "relation": "part_of", "tail": "cell"},
#         {"head": "yolk", "relation": "part_of", "tail": "ovum"},
#         {"head": "oöplasm", "relation": "part_of", "tail": "ovum"},
#         {"head": "nucleus", "relation": "part_of", "tail": "ovum"},
#         {"head": "germinal vesicle", "relation": "part_of", "tail": "nucleus"},
#         {"head": "nucleolus", "relation": "part_of", "tail": "nucleus"},
#         {"head": "germinal spot", "relation": "part_of", "tail": "nucleolus"},
#         {"head": "ovum", "relation": "exists_in", "tail": "envelope"},
#         {"head": "envelope", "relation": "part_of", "tail": "zona striata"},
#         {"head": "envelope", "relation": "part_of", "tail": "zona pellucida"},
#         {"head": "layers of cells", "relation": "derived_from", "tail": "follicle"},
#         {"head": "layers of cells", "relation": "constitutes", "tail": "corona radiata"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Human ovum", "type": "Cell"},
#         {"name": "liquor folliculi", "type": "Fluid"},
#         {"name": "zona pellucida", "type": "Structure"}
#     ],
#     "relations": [
#         {"head": "Human ovum", "relation": "exists_in", "tail": "liquor folliculi"},
#         {"head": "zona pellucida", "relation": "part_of", "tail": "Human ovum"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "girdle", "type": "Structure"},
#         {"name": "cells", "type": "Structure"},
#         {"name": "corona radiata", "type": "Structure"},
#         {"name": "egg", "type": "Structure"},
#         {"name": "area", "type": "Structure"},
#         {"name": "deutoplasm", "type": "Substance"},
#         {"name": "layer", "type": "Structure"},
#         {"name": "germinal vesicle", "type": "Structure"}
#     ],
#     "relations": [
#         {"head": "girdle", "relation": "surrounded_by", "tail": "cells"},
#         {"head": "cells", "relation": "part_of", "tail": "corona radiata"},
#         {"head": "egg", "relation": "encloses", "tail": "germinal vesicle"},
#         {"head": "egg", "relation": "shows", "tail": "area"},
#         {"head": "area", "relation": "contains", "tail": "deutoplasm"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "germinal spot", "type": "Organ"}
#     ],
#     "relations": []
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "yolk", "type": "Substance"},
#         {"name": "cytoplasm", "type": "Substance"},
#         {"name": "spongioplasm", "type": "Substance"},
#         {"name": "hyaloplasm", "type": "Substance"},
#         {"name": "formative yolk", "type": "Substance"},
#         {"name": "nutritive yolk", "type": "Substance"},
#         {"name": "deutoplasm", "type": "Substance"},
#         {"name": "granules", "type": "Substance"},
#         {"name": "fatty substances", "type": "Substance"},
#         {"name": "albuminoid substances", "type": "Substance"},
#         {"name": "ovum", "type": "Organ"},
#         {"name": "embryo", "type": "Organ"},
#         {"name": "chick", "type": "Organ"},
#         {"name": "incubation", "type": "Process"},
#         {"name": "cytoplasm", "type": "Substance"},
#         {"name": "pole", "type": "Anatomical_Structure"},
#         {"name": "centrosome", "type": "Organ"},
#         {"name": "centriole", "type": "Organ"},
#         {"name": "nucleus", "type": "Organ"}
#     ],
#     "relations": [
#         {"head": "yolk", "relation": "comprises", "tail": "cytoplasm"},
#         {"head": "cytoplasm", "relation": "includes", "tail": "spongioplasm"},
#         {"head": "cytoplasm", "relation": "includes", "tail": "hyaloplasm"},
#         {"head": "nutritive yolk", "relation": "consists_of", "tail": "granules"},
#         {"head": "granules", "relation": "consists_of", "tail": "fatty substances"},
#         {"head": "granules", "relation": "consists_of", "tail": "albuminoid substances"},
#         {"head": "nutritive yolk", "relation": "supplies", "tail": "embryo"},
#         {"head": "nutritive yolk", "relation": "supplies", "tail": "chick"},
#         {"head": "chick", "relation": "exists_in", "tail": "incubation"},
#         {"head": "centrosome", "relation": "exists_in", "tail": "neighborhood"},
#         {"head": "centriole", "relation": "exists_in", "tail": "neighborhood"},
#         {"head": "nucleus", "relation": "exists_in", "tail": "neighborhood"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Germinal Vesicle", "type": "Organ"},
#         {"name": "nucleus", "type": "Organ"},
#         {"name": "ovum", "type": "Cell"},
#         {"name": "reticulum", "type": "Structure"},
#         {"name": "karyomitome", "type": "Structure"},
#         {"name": "meshes", "type": "Structure"},
#         {"name": "karyoplasm", "type": "Substance"},
#         {"name": "chromatin masses", "type": "Structure"},
#         {"name": "chromosomes", "type": "Structure"},
#         {"name": "nuclear membrane", "type": "Structure"},
#         {"name": "nucleolus", "type": "Structure"},
#         {"name": "germinal spot", "type": "Structure"}
#     ],
#     "relations": [
#         {"head": "Germinal Vesicle", "relation": "part_of", "tail": "nucleus"},
#         {"head": "nucleus", "relation": "exists_in", "tail": "ovum"},
#         {"head": "reticulum", "relation": "part_of", "tail": "nucleus"},
#         {"head": "karyomitome", "relation": "part_of", "tail": "reticulum"},
#         {"head": "meshes", "relation": "part_of", "tail": "reticulum"},
#         {"head": "karyoplasm", "relation": "fills", "tail": "meshes"},
#         {"head": "chromatin masses", "relation": "part_of", "tail": "reticulum"},
#         {"head": "chromosomes", "relation": "part_of", "tail": "reticulum"},
#         {"head": "nuclear membrane", "relation": "encloses", "tail": "nucleus"},
#         {"head": "nucleolus", "relation": "exists_in", "tail": "nucleus"},
#         {"head": "germinal spot", "relation": "part_of", "tail": "nucleolus"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Coverings", "type": "Anatomy"},
#         {"name": "Ovum", "type": "Cell"},
#         {"name": "zona striata", "type": "Membrane"},
#         {"name": "zona pellucida", "type": "Membrane"},
#         {"name": "microscope", "type": "Instrument"},
#         {"name": "fertilization", "type": "Process"},
#         {"name": "segmentation", "type": "Process"},
#         {"name": "cytoplasm", "type": "Substance"},
#         {"name": "corona radiata", "type": "Structure"},
#         {"name": "cells", "type": "Cell"}
#     ],
#     "relations": [
#         {"head": "zona striata", "relation": "part_of", "tail": "Ovum"},
#         {"head": "zona pellucida", "relation": "part_of", "tail": "Ovum"},
#         {"head": "microscope", "relation": "exists_in", "tail": "Ovum"},
#         {"head": "fertilization", "relation": "causes", "tail": "segmentation"},
#         {"head": "cytoplasm", "relation": "part_of", "tail": "Ovum"},
#         {"head": "cells", "relation": "part_of", "tail": "corona radiata"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "corona radiata", "type": "Organ"},
#         {"name": "strata of cells", "type": "Tissue"},
#         {"name": "cells", "type": "Cell"},
#         {"name": "follicle", "type": "Organ"},
#         {"name": "outer surface", "type": "Surface"},
#         {"name": "zona striata", "type": "Organ"},
#         {"name": "ovum", "type": "Cell"},
#         {"name": "adhesive protein", "type": "Substance"}
#     ],
#     "relations": [
#         {"head": "corona radiata", "relation": "consists", "tail": "strata of cells"},
#         {"head": "strata of cells", "relation": "derived_from", "tail": "cells"},
#         {"head": "cells", "relation": "derived_from", "tail": "follicle"},
#         {"head": "cells", "relation": "adhere_to", "tail": "outer surface"},
#         {"head": "cells", "relation": "adhere_to", "tail": "zona striata"},
#         {"head": "ovum", "relation": "exists_in", "tail": "follicle"},
#         {"head": "cells", "relation": "secrete", "tail": "adhesive protein"},
#         {"head": "adhesive protein", "relation": "mediates", "tail": "ovum"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "phenomena", "type": "Process"},
#         {"name": "discharge", "type": "Process"},
#         {"name": "ova", "type": "Substance"},
#         {"name": "follicles", "type": "Organ"},
#         {"name": "functions", "type": "Process"},
#         {"name": "ovary", "type": "Organ"},
#         {"name": "subject", "type": "Concept"},
#         {"name": "embryology", "type": "Field_of_Study"},
#         {"name": "anatomy", "type": "Field_of_Study"},
#         {"name": "ovaries", "type": "Organ"}
#     ],
#     "relations": [
#         {"head": "phenomena", "relation": "attends", "tail": "discharge"},
#         {"head": "discharge", "relation": "of", "tail": "ova"},
#         {"head": "ova", "relation": "from", "tail": "follicles"},
#         {"head": "phenomena", "relation": "part_of", "tail": "functions"},
#         {"head": "functions", "relation": "of", "tail": "ovary"},
#         {"head": "phenomena", "relation": "part_of", "tail": "subject"},
#         {"head": "subject", "relation": "of", "tail": "embryology"},
#         {"head": "phenomena", "relation": "described_with", "tail": "anatomy"},
#         {"head": "anatomy", "relation": "of", "tail": "ovaries"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# Please provide the sentence you want me to process. I need the text of the sentence to extract entities and relations and format the output as requested.
# 관게 추출 실패
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Ovum", "type": "Cell"},
#         {"name": "fertilization", "type": "Process"},
#         {"name": "maturation", "type": "Process"},
#         {"name": "ripening", "type": "Process"},
#         {"name": "follicle", "type": "Organ"},
#         {"name": "subdivision", "type": "Process"},
#         {"name": "cells", "type": "Cell"},
#         {"name": "polar bodies", "type": "Cell"},
#         {"name": "polocytes", "type": "Cell"},
#         {"name": "animals", "type": "Organism"}
#     ],
#     "relations": [
#         {"head": "Ovum", "relation": "causes", "tail": "fertilization"},
#         {"head": "Ovum", "relation": "undergoes", "tail": "maturation"},
#         {"head": "maturation", "relation": "is_a", "tail": "ripening"},
#         {"head": "Ovum", "relation": "exists_in", "tail": "follicle"},
#         {"head": "maturation", "relation": "includes", "tail": "subdivision"},
#         {"head": "subdivision", "relation": "generates", "tail": "cells"},
#         {"head": "polar bodies", "relation": "is_a", "tail": "cells"},
#         {"head": "polocytes", "relation": "is_a", "tail": "cells"},
#         {"head": "Ovum", "relation": "exists_in", "tail": "animals"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "number of chromosomes", "type": "Substance"},
#         {"name": "nucleus", "type": "Organ"},
#         {"name": "cells", "type": "Organ"},
#         {"name": "animal", "type": "Organism"},
#         {"name": "species", "type": "Organism"},
#         {"name": "man", "type": "Organism"},
#         {"name": "somatic cells", "type": "Organ"},
#         {"name": "primitive ova", "type": "Organ"},
#         {"name": "descendants", "type": "Organ"},
#         {"name": "process of maturation", "type": "Process"},
#         {"name": "nuclear chromosomes", "type": "Substance"},
#         {"name": "ovum", "type": "Organ"},
#         {"name": "chromosomes", "type": "Substance"},
#         {"name": "granules", "type": "Substance"},
#         {"name": "tetrad", "type": "Structure"},
#         {"name": "metaphase", "type": "Process"},
#         {"name": "dyads", "type": "Structure"},
#         {"name": "nuclei", "type": "Organ"},
#         {"name": "cells", "type": "Organ"},
#         {"name": "ovum", "type": "Organ"},
#         {"name": "secondary oöcyte", "type": "Organ"},
#         {"name": "first polar body", "type": "Organ"}
#     ],
#     "relations": [
#         {"head": "number of chromosomes", "relation": "exists_in", "tail": "nucleus"},
#         {"head": "nucleus", "relation": "part_of", "tail": "cells"},
#         {"head": "cells", "relation": "part_of", "tail": "animal"},
#         {"head": "cells", "relation": "part_of", "tail": "species"},
#         {"head": "somatic cells", "relation": "part_of", "tail": "descendants"},
#         {"head": "primitive ova", "relation": "part_of", "tail": "descendants"},
#         {"head": "number of chromosomes", "relation": "exists_in", "tail": "primitive ova"},
#         {"head": "process of maturation", "relation": "circulates_through", "tail": "species"},
#         {"head": "number of chromosomes", "relation": "exists_in", "tail": "ovum"},
#         {"head": "tetrad", "relation": "causes", "tail": "chromosomes"},
#         {"head": "tetrad", "relation": "generates", "tail": "chromosomes"},
#         {"head": "dyads", "relation": "part_of", "tail": "nuclei"},
#         {"head": "dyads", "relation": "part_of", "tail": "cells"},
#         {"head": "secondary oöcyte", "relation": "part_of", "tail": "ovum"},
#         {"head": "first polar body", "relation": "part_of", "tail": "ovum"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "polar bodies", "type": "Substance"},
#         {"name": "Asterias glacialis", "type": "Organism"},
#         {"name": "polar spindle", "type": "Organ"},
#         {"name": "surface", "type": "Organ"},
#         {"name": "egg", "type": "Organ"},
#         {"name": "elevation", "type": "Organ"}
#     ],
#     "relations": [
#         {"head": "polar bodies", "relation": "exists_in", "tail": "Asterias glacialis"},
#         {"head": "polar spindle", "relation": "exists_in", "tail": "egg"},
#         {"head": "polar spindle", "relation": "part_of", "tail": "egg"},
#         {"head": "elevation", "relation": "part_of", "tail": "egg"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "spindle", "type": "Organ"},
#         {"name": "elevation", "type": "Structure"},
#         {"name": "polar body", "type": "Structure"}
#     ],
#     "relations": [
#         {"head": "elevation", "relation": "forms", "tail": "polar body"},
#         {"head": "spindle", "relation": "forms", "tail": "polar body"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "spindle", "type": "Organ"},
#         {"name": "remainder", "type": "Substance"},
#         {"name": "female pronucleus", "type": "Organ"}
#     ],
#     "relations": [
#         {"head": "female pronucleus", "relation": "generated", "tail": "remainder"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "chromosomes", "type": "Substance"},
#         {"name": "ovum", "type": "Cell"},
#         {"name": "maturation", "type": "Process"}
#     ],
#     "relations": [
#         {"head": "chromosomes", "relation": "exists_in", "tail": "ovum"},
#         {"head": "maturation", "relation": "causes", "tail": "reduction"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "ovum", "type": "Cell"}
#     ],
#     "relations": []
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "second division", "type": "Process"},
#         {"name": "large cell", "type": "Cell"},
#         {"name": "mature ovum", "type": "Cell"},
#         {"name": "small cell", "type": "Cell"},
#         {"name": "second polar body", "type": "Cell"},
#         {"name": "first polar body", "type": "Cell"},
#         {"name": "four cells", "type": "Cell"},
#         {"name": "chromosomes", "type": "Substance"},
#         {"name": "nuclei", "type": "Organ"},
#         {"name": "somatic cells", "type": "Cell"},
#         {"name": "species", "type": "Organism"},
#         {"name": "nucleus", "type": "Organ"},
#         {"name": "female pronucleus", "type": "Organ"}
#     ],
#     "relations": [
#         {"head": "second division", "relation": "generates", "tail": "large cell"},
#         {"head": "large cell", "relation": "part_of", "tail": "mature ovum"},
#         {"head": "second division", "relation": "generates", "tail": "small cell"},
#         {"head": "small cell", "relation": "part_of", "tail": "second polar body"},
#         {"head": "first polar body", "relation": "part_of", "tail": "four cells"},
#         {"head": "second polar body", "relation": "part_of", "tail": "four cells"},
#         {"head": "four cells", "relation": "includes", "tail": "mature ovum"},
#         {"head": "four cells", "relation": "includes", "tail": "polar bodies"},
#         {"head": "chromosomes", "relation": "exists_in", "tail": "polar bodies"},
#         {"head": "chromosomes", "relation": "exists_in", "tail": "mature ovum"},
#         {"head": "nuclei", "relation": "exists_in", "tail": "somatic cells"},
#         {"head": "somatic cells", "relation": "part_of", "tail": "species"},
#         {"head": "nucleus", "relation": "part_of", "tail": "mature ovum"},
#         {"head": "nucleus", "relation": "part_of", "tail": "female pronucleus"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "ovary", "type": "Organ"}
#     ],
#     "relations": []
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "ovary", "type": "Organ"}
#     ],
#     "relations": []
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Spermatozoön", "type": "Cell"}
#     ],
#     "relations": []
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "spermatozoa", "type": "Cell"},
#         {"name": "male germ cells", "type": "Cell"},
#         {"name": "testes", "type": "Organ"},
#         {"name": "seminal fluid", "type": "Substance"},
#         {"name": "cell", "type": "Cell"},
#         {"name": "head", "type": "Body_Part"},
#         {"name": "neck", "type": "Body_Part"},
#         {"name": "connecting piece", "type": "Body_Part"},
#         {"name": "body", "type": "Body_Part"},
#         {"name": "tail", "type": "Body_Part"}
#     ],
#     "relations": [
#         {"head": "spermatozoa", "relation": "exists_in", "tail": "seminal fluid"},
#         {"head": "male germ cells", "relation": "exists_in", "tail": "testes"},
# ...
#         {"name": "sides of the grooves", "type": "Anatomical_Structure"},
#         {"name": "deep surfaces", "type": "Anatomical_Structure"},
#         {"name": "articular facets", "type": "Anatomical_Structure"},
#         {"name": "synovial membrane", "type": "Tissue"}
#     ],
#     "relations": [
#         {"head": "Plantar Ligaments", "relation": "part_of", "tail": "surfaces"},
#         {"head": "Plantar Ligaments", "relation": "exists_in", "tail": "joints"},
#         {"head": "Plantar Ligaments", "relation": "exists_in", "tail": "intervals"},
#         {"head": "Plantar Ligaments", "relation": "connected", "tail": "collateral ligaments"},
#         {"head": "Plantar Ligaments", "relation": "connected", "tail": "metatarsal bones"},
#         {"head": "Plantar Ligaments", "relation": "connected", "tail": "first phalanges"},
#         {"head": "Plantar Ligaments", "relation": "part_of", "tail": "transverse metatarsal ligament"},
#         {"head": "Flexor tendons", "relation": "exists_in", "tail": "sheaths"},
#         {"head": "sheaths", "relation": "connected", "tail": "sides of the grooves"},
#         {"head": "deep surfaces", "relation": "part_of", "tail": "articular facets"},
#         {"head": "deep surfaces", "relation": "lined_by", "tail": "synovial membrane"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Collateral Ligaments", "type": "Organ"},
#         {"name": "joint", "type": "Anatomical Structure"},
#         {"name": "metatarsal bone", "type": "Bone"},
#         {"name": "posterior tubercle", "type": "Anatomical Structure"},
#         {"name": "phalanx", "type": "Bone"}
#     ],
#     "relations": [
#         {"head": "Collateral Ligaments", "relation": "part_of", "tail": "joint"},
#         {"head": "Collateral Ligaments", "relation": "attached_to", "tail": "metatarsal bone"},
#         {"head": "Collateral Ligaments", "relation": "attached_to", "tail": "phalanx"},
#         {"head": "posterior tubercle", "relation": "part_of", "tail": "metatarsal bone"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "dorsal ligament s", "type": "Organ"},
#         {"name": "Extensor tendons", "type": "Organ"},
#         {"name": "dorsal surfaces", "type": "Anatomical Structure"},
#         {"name": "joints", "type": "Anatomical Structure"}
#     ],
#     "relations": [
#         {"head": "dorsal ligament s", "relation": "supplies", "tail": "Extensor tendons"},
#         {"head": "Extensor tendons", "relation": "exists_in", "tail": "dorsal surfaces"},
#         {"head": "dorsal surfaces", "relation": "part_of", "tail": "joints"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Movements", "type": "Function"},
#         {"name": "metatarsophalangeal articulations", "type": "Organ"},
#         {"name": "flexion", "type": "Function"},
#         {"name": "extension", "type": "Function"},
#         {"name": "abduction", "type": "Function"},
#         {"name": "adduction", "type": "Function"}
#     ],
#     "relations": [
#         {"head": "Movements", "relation": "exists_in", "tail": "metatarsophalangeal articulations"},
#         {"head": "flexion", "relation": "exists_in", "tail": "metatarsophalangeal articulations"},
#         {"head": "extension", "relation": "exists_in", "tail": "metatarsophalangeal articulations"},
#         {"head": "abduction", "relation": "exists_in", "tail": "metatarsophalangeal articulations"},
#         {"head": "adduction", "relation": "exists_in", "tail": "metatarsophalangeal articulations"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Articulations", "type": "Anatomical Structure"},
#         {"name": "Digits", "type": "Anatomical Structure"}
#     ],
#     "relations": [
#         {"head": "Articulations", "relation": "part_of", "tail": "Digits"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Articulationes Digitorum Pedis", "type": "Anatomical Structure"},
#         {"name": "Articulations of the Phalanges", "type": "Anatomical Structure"}
#     ],
#     "relations": []
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "interphalangeal articulations", "type": "Anatomical Structure"},
#         {"name": "ginglymoid joints", "type": "Joint"},
#         {"name": "plantar ligament", "type": "Ligament"},
#         {"name": "collateral ligaments", "type": "Ligament"}
#     ],
#     "relations": [
#         {"head": "interphalangeal articulations", "relation": "part_of", "tail": "ginglymoid joints"},
#         {"head": "ginglymoid joints", "relation": "includes", "tail": "plantar ligament"},
#         {"head": "ginglymoid joints", "relation": "includes", "tail": "collateral ligaments"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "ligaments", "type": "Organ"},
#         {"name": "metatarsophalangeal articulations", "type": "Anatomical_Structure"},
#         {"name": "Extensor tendons", "type": "Anatomical_Structure"},
#         {"name": "places", "type": "Location"},
#         {"name": "dorsal ligaments", "type": "Organ"}
#     ],
#     "relations": [
#         {"head": "Extensor tendons", "relation": "supplies", "tail": "places"},
#         {"head": "places", "relation": "part_of", "tail": "dorsal ligaments"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "movements", "type": "Function"},
#         {"name": "joints", "type": "Organ"},
#         {"name": "digits", "type": "Organ"},
#         {"name": "flexion", "type": "Function"},
#         {"name": "extension", "type": "Function"},
#         {"name": "first phalanges", "type": "Organ"},
#         {"name": "second phalanges", "type": "Organ"},
#         {"name": "third phalanges", "type": "Organ"},
#         {"name": "amount of flexion", "type": "Function"},
#         {"name": "extension", "type": "Function"},
#         {"name": "plantar ligaments", "type": "Organ"},
#         {"name": "collateral ligaments", "type": "Organ"}
#     ],
#     "relations": [
#         {"head": "movements", "relation": "exists_in", "tail": "joints"},
#         {"head": "flexion", "relation": "exists_in", "tail": "digits"},
#         {"head": "extension", "relation": "exists_in", "tail": "digits"},
#         {"head": "flexion", "relation": "exists_in", "tail": "first phalanges"},
#         {"head": "flexion", "relation": "exists_in", "tail": "second phalanges"},
#         {"head": "extension", "relation": "exists_in", "tail": "first phalanges"},
#         {"head": "extension", "relation": "exists_in", "tail": "second phalanges"},
#         {"head": "extension", "relation": "caused_by", "tail": "plantar ligaments"},
#         {"head": "extension", "relation": "caused_by", "tail": "collateral ligaments"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Arches", "type": "Anatomical Structure"},
#         {"name": "Foot", "type": "Anatomical Structure"}
#     ],
#     "relations": [
#         {"head": "Arches", "relation": "part_of", "tail": "Foot"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "foot", "type": "Organ"},
#         {"name": "weight", "type": "Substance"},
#         {"name": "body", "type": "Organ"},
#         {"name": "posture", "type": "Function"},
#         {"name": "material", "type": "Substance"},
#         {"name": "series of arches", "type": "Structure"},
#         {"name": "tarsal bones", "type": "Organ"},
#         {"name": "metatarsal bones", "type": "Organ"},
#         {"name": "ligaments", "type": "Tissue"},
#         {"name": "tendons", "type": "Tissue"}
#     ],
#     "relations": [
#         {"head": "foot", "relation": "supports", "tail": "weight"},
#         {"head": "weight", "relation": "exists_in", "tail": "body"},
#         {"head": "foot", "relation": "supports", "tail": "posture"},
#         {"head": "series of arches", "relation": "part_of", "tail": "foot"},
#         {"head": "series of arches", "relation": "formed_by", "tail": "tarsal bones"},
#         {"head": "series of arches", "relation": "formed_by", "tail": "metatarsal bones"},
#         {"head": "foot", "relation": "strengthened_by", "tail": "ligaments"},
#         {"head": "foot", "relation": "strengthened_by", "tail": "tendons"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "main arches", "type": "Anatomical Structure"},
#         {"name": "antero-posterior arches", "type": "Anatomical Structure"},
#         {"name": "medial arch", "type": "Anatomical Structure"},
#         {"name": "calcaneus", "type": "Bone"},
#         {"name": "talus", "type": "Bone"},
#         {"name": "navicular", "type": "Bone"},
#         {"name": "cuneiforms", "type": "Bone"},
#         {"name": "metatarsals", "type": "Bone"},
#         {"name": "superior articular surface", "type": "Anatomical Structure"},
#         {"name": "tuberosity", "type": "Anatomical Structure"},
#         {"name": "plantar surface", "type": "Anatomical Structure"},
#         {"name": "elasticity", "type": "Property"},
#         {"name": "joints", "type": "Anatomical Structure"},
#         {"name": "plantar calcaneonavicular ligament", "type": "Ligament"},
#         {"name": "deltoid ligament", "type": "Ligament"},
#         {"name": "ankle-joint", "type": "Joint"},
#         {"name": "tendon of Tibialis posterior", "type": "Tendon"},
#         {"name": "plantar aponeurosis", "type": "Tissue"},
#         {"name": "small muscles", "type": "Muscle"},
#         {"name": "sole of the foot", "type": "Anatomical Structure"},
#         {"name": "tendons of Tibialis anterior", "type": "Tendon"},
#         {"name": "Peronæus longus", "type": "Muscle"},
#         {"name": "ligaments", "type": "Tissue"},
#         {"name": "articulations", "type": "Joint"},
#         {"name": "lateral arch", "type": "Anatomical Structure"},
#         {"name": "cuboid", "type": "Bone"},
#         {"name": "talocalcaneal articulation", "type": "Joint"},
#         {"name": "calcaneocuboid", "type": "Joint"},
#         {"name": "long plantar", "type": "Ligament"},
#         {"name": "Extensor tendons", "type": "Tendon"}
#     ],
#     "relations": [
#         {"head": "medial arch", "relation": "part_of", "tail": "main arches"},
#         {"head": "calcaneus", "relation": "part_of", "tail": "medial arch"},
#         {"head": "talus", "relation": "part_of", "tail": "medial arch"},
#         {"head": "navicular", "relation": "part_of", "tail": "medial arch"},
#         {"head": "cuneiforms", "relation": "part_of", "tail": "medial arch"},
#         {"head": "metatarsals", "relation": "part_of", "tail": "medial arch"},
#         {"head": "plantar calcaneonavicular ligament", "relation": "part_of", "tail": "medial arch"},
#         {"head": "deltoid ligament", "relation": "part_of", "tail": "ankle-joint"},
#         {"head": "tendon of Tibialis posterior", "relation": "part_of", "tail": "medial arch"},
#         {"head": "plantar aponeurosis", "relation": "part_of", "tail": "medial arch"},
#         {"head": "tendons of Tibialis anterior", "relation": "part_of", "tail": "medial arch"},
#         {"head": "Peronæus longus", "relation": "part_of", "tail": "medial arch"},
#         {"head": "ligaments", "relation": "part_of", "tail": "articulations"},
#         {"head": "lateral arch", "relation": "part_of", "tail": "main arches"},
#         {"head": "calcaneus", "relation": "part_of", "tail": "lateral arch"},
#         {"head": "cuboid", "relation": "part_of", "tail": "lateral arch"},
#         {"head": "long plantar", "relation": "part_of", "tail": "lateral arch"},
#         {"head": "Extensor tendons", "relation": "part_of", "tail": "lateral arch"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "medial arches", "type": "Anatomical Structure"},
#         {"name": "lateral arches", "type": "Anatomical Structure"},
#         {"name": "foot", "type": "Anatomical Structure"},
#         {"name": "antero-posterior arches", "type": "Anatomical Structure"},
#         {"name": "longitudinal arc", "type": "Anatomical Structure"},
#         {"name": "calcaneus", "type": "Bone"},
#         {"name": "cuboid", "type": "Bone"},
#         {"name": "third cuneiform", "type": "Bone"},
#         {"name": "third metatarsal", "type": "Bone"},
#         {"name": "bones", "type": "Bone"}
#     ],
#     "relations": [
#         {"head": "medial arches", "relation": "part_of", "tail": "foot"},
#         {"head": "lateral arches", "relation": "part_of", "tail": "foot"},
#         {"head": "antero-posterior arches", "relation": "part_of", "tail": "foot"},
#         {"head": "calcaneus", "relation": "part_of", "tail": "longitudinal arc"},
#         {"head": "cuboid", "relation": "part_of", "tail": "longitudinal arc"},
#         {"head": "third cuneiform", "relation": "part_of", "tail": "longitudinal arc"},
#         {"head": "third metatarsal", "relation": "part_of", "tail": "longitudinal arc"},
#         {"head": "bones", "relation": "part_of", "tail": "foot"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "longitudinal arches", "type": "Anatomical Structure"},
#         {"name": "foot", "type": "Organ"},
#         {"name": "transverse arches", "type": "Anatomical Structure"},
#         {"name": "metatarsus", "type": "Bone"},
#         {"name": "tarsus", "type": "Bone"},
#         {"name": "arches", "type": "Anatomical Structure"},
#         {"name": "half-domes", "type": "Anatomical Structure"},
#         {"name": "concavities", "type": "Anatomical Structure"},
#         {"name": "medial borders", "type": "Anatomical Structure"},
#         {"name": "feet", "type": "Organ"},
#         {"name": "tarsal dome", "type": "Anatomical Structure"},
#         {"name": "interosseous ligaments", "type": "Ligament"},
#         {"name": "plantar ligaments", "type": "Ligament"},
#         {"name": "dorsal ligaments", "type": "Ligament"},
#         {"name": "short muscles", "type": "Muscle"},
#         {"name": "first toes", "type": "Body Part"},
#         {"name": "fifth toes", "type": "Body Part"},
#         {"name": "Adductor hallucis", "type": "Muscle"},
#         {"name": "Peronæus longus", "type": "Muscle"},
#         {"name": "tendon", "type": "Tissue"},
#         {"name": "piers", "type": "Anatomical Structure"}
#     ],
#     "relations": [
#         {"head": "transverse arches", "relation": "part_of", "tail": "foot"},
#         {"head": "arches", "relation": "exists_in", "tail": "metatarsus"},
#         {"head": "arches", "relation": "exists_in", "tail": "tarsus"},
#         {"head": "half-domes", "relation": "part_of", "tail": "tarsus"},
#         {"head": "concavities", "relation": "part_of", "tail": "half-domes"},
#         {"head": "tarsal dome", "relation": "formed_by", "tail": "medial borders"},
#         {"head": "tarsal dome", "relation": "formed_by", "tail": "feet"},
#         {"head": "interosseous ligaments", "relation": "strengthens", "tail": "transverse arches"},
#         {"head": "plantar ligaments", "relation": "strengthens", "tail": "transverse arches"},
#         {"head": "dorsal ligaments", "relation": "strengthens", "tail": "transverse arches"},
#         {"head": "short muscles", "relation": "strengthens", "tail": "transverse arches"},
#         {"head": "Adductor hallucis", "relation": "part_of", "tail": "short muscles"},
#         {"head": "Peronæus longus", "relation": "strengthens", "tail": "transverse arches"},
#         {"head": "tendon", "relation": "part_of", "tail": "Peronæus longus"},
#         {"head": "tendon", "relation": "exists_in", "tail": "piers"}
#     ]
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "Bibliography", "type": "Document"}
#     ],
#     "relations": []
# }
# ```
# --- LLM 원본 출력 ---
# ```json
# {
#     "entities": [
#         {"name": "R. F ICK", "type": "Person"},
#         {"name": "Handbuch der Anatomie und Mechanik der Gelenke", "type": "Book"},
#         {"name": "Bardeleben’s Handbuch der Anatomie", "type": "Book"}
#     ],
#     "relations": [
#         {"head": "Handbuch der Anatomie und Mechanik der Gelenke", "relation": "caused_by", "tail": "R. F ICK"},
#         {"head": "Handbuch der Anatomie und Mechanik der Gelenke", "relation": "caused_by", "tail": "Bardeleben’s Handbuch der Anatomie"}
#     ]
# }
# ```
#
# ==================================================

# %% [markdown]
# # 고유 관게, 객체 추출

# %%
import json

def extract_unique_entites_and_relations(json_file_path) :
    unique_entities = set()
    unique_relations = []

    try :
        with open(json_file_path, 'r', encoding="utf-8") as f :
            data = json.load(f)
    except FileNotFoundError :
        print(f"경로 없음 : {json_file_path}")
        return set(), []
    except json.JSONDecodeError :
        print(f"json 디코딩 실패 : {json_file_path}")
        return set(), []
    
    print(f"json 파일 : {data}")
    if "paragraphs_data" in data :
        for paragraph in data["paragraphs_data"] :
            if "entities" in paragraph :
                for entity in paragraph["entities"] :
                    if "name" in entity and "type" in entity :
                        if entity["name"] and entity["type"] :
                            unique_entities.add((entity["name"], entity["type"]))
                        elif entity["name"] and not entity["type"] :
                            unique_entities.add((entity["name"], "UNKNOWN_TYPE"))
                        elif not entity["name"] and entity["type"] :
                            unique_entities.add(("UNKNOWN_NAME", entity["type"]))

            if "relations" in paragraph :
                for relation in paragraph["relations"] :
                    if relation not in unique_relations :
                        unique_relations.append(relation)

    return unique_entities, unique_relations

if __name__ == "__main__" :
    json_file_path = "./data/extracted_results/5_Angiology.json"
    unique_entity_path = "./data/unique/5_Angiology_unique.txt"
    entities, relations = extract_unique_entites_and_relations(json_file_path)

    print("고유 엔티티 : ")
    for entity in sorted(list(entities)) :
        print(f"name : {entity[0]}, type : {entity[1]}")

    print("고유 관계 : ")
    if relations :
        for relation in relations :
            print(relation)
    else :
        print("추출된 관계 없음")

    try :
        with open(unique_entity_path, 'w', encoding="utf-8") as f :
            f.write("<고유 엔티티>\n")
            for entity in sorted(list(entities)) :
                f.write(f"이름 : {entity[0]}, 타입 : {entity[1]}\n")

            f.write("\n<고유 관계> : \n")
            if relations :
                for relation in relations :
                    f.write(json.dumps(relation, ensure_ascii=False) + "\n")
            else :
                f.write("추출된 관계 없음\n")
    except IOError as e :
        print(f"파일 저장 중 오류 : {e}")
# Out:
# json 파일 : {'filename': '5_Angiology.md', 'full_original_text': '#### Page 333\n# V. Angiology\n## Introduction\n\nT HE VASCULA R system is divided for descriptive purposes into ( a ) the blood vascular system, which\ncomprises the heart and bloodvessels for the circulation of the blood; and ( b ) the lymph vascular system,\nconsisting of lymph glands and lymphatic vessels, through which a colorless fluid, the lymph, circulates. It\nmust be noted, however, that the two systems communicate with each other and are intimately associated\ndevelopmentally.\n\nThe heart is the central organ of the blood vascular system, and consists of a hollow muscle; by its\ncontraction the blood is pumped to all parts of the body through a complicated series of tubes, termed\narteries. The arteries undergo enormous ramification in their course throughout the body, and end in minute\nvessels, called arterioles, which in their turn open into a close-meshed network of microscopic vessels,\ntermed capillaries. After the blood has passed through the capillaries it is collected into a series of larger\nvessels, called veins, by which it is returned to the heart. The passage of the blood through the heart and\nblood-vessels constitutes what is termed the circulation of the blood, of which the following is an outline.\n\nThe human heart is divided by septa into right and left halves, and each half is further divided into two\ncavities, an upper termed the atriu m and a lower the ventricle. The heart therefore consists of four\nchambers, two, the right atrium and right ventricle, forming the right half, and two, the left atrium and left\nventricle the left half. The right half of the heart contains venous or impure blood; the left, arterial or pure\nblood. The atria are receiving chambers, and the ventricles distributing ones. From the cavity of the left\nventricle the pure blood is carried into a large artery, the aorta, through the numerous branches of which it is\ndistributed to all parts of the body, with the exception of the lungs. In its passage through the capillaries of\nthe body the blood gives up to the tissues the materials necessary for their growth and nourishment, and at\nthe same time receives from the tissues the waste products resulting from their metabolism. In doing so it is\nchanged from arterial into venous blood, which is collected by the veins and through them returned to the\nright atrium of the heart. From this cavity the impure blood passes into the right ventricle, and is thence\nconveyed through the pulmonary arterie s to the lungs. In the capillaries of the lungs it again becomes\narterialized, and is then carried to the left atrium by the pulmonary veins. From the left atrium it passes into\nthe left ventricle, from which the cycle once more begins.\n\nThe course of the blood from the left ventricle through the body generally to the right side of the heart\nconstitutes the greater or systemic circulation, while its passage from the right ventricle through the lungs\nto the left side of the heart is termed the lesser or pulmonary circulation.\n\nIt is necessary, however, to state that the blood which circulates through the spleen, pancreas, stomach,\nsmall intestine, and the greater part of the large intestine is not returned directly from these organs to the\nheart, but is conveyed by the portal vei n to the liver. In the liver this vein divides, like an artery, and\nultimately ends in capillary-like vessels ( sinusoids ), from which the rootlets of a series of veins, called the\nhepatic veins, arise; these carry the blood into the inferior vena cava, whence it is conveyed to the right\natrium. From this it will be seen that the blood contained in the portal vein passes through two sets of\nvessels: (1) the capillaries in the spleen, pancreas, stomach, etc., and (2) the sinusoids in the liver. The\nblood in the portal vein carries certain of the products of digestion: the carbohydrates, which are mostly\ntaken up by the liver  ...
# 고유 엔티티 :
# name : 1909, type : Year
# name : 1915, type : Year
# name : 35 mm., type : Measurement
# name : 485, type : Measurement
# name : 50 mm. crown-rump length, type : Measurement
# name : 80 mm. crown-rump length, type : Measurement
# name : Am. Jour. Anat., type : Publication
# name : American Journal of Anatomy, type : Publication
# name : Anat. Anzeiger, type : Publication
# name : Anatomical Record, type : Publication
# name : Angiology, type : Field_of_Study
# name : Anterior Ventral Aortæ, type : Organ
# name : Aorta, type : Organ
# name : Aorta, type : Vessel
# name : Aortic, type : Organ
# name : Aortic Arches, type : Organ
# name : Apex, type : Organ
# name : Arteries, type : Organ
# name : Artery, type : Organ
# name : Artery, type : Vessel
# name : Atrial diastole, type : Physiological Process
# name : Atrial systole, type : Physiological Process
# name : Atrioventricular, type : Anatomical Structure
# name : Auricula, type : Organ
# name : Base, type : Anatomical Structure
# name : Bicuspid or Mitral, type : Valve
# name : Birth, type : Time
# name : Blood, type : Fluid
# name : Blood, type : Substance
# name : Blood Corpuscles, type : Cell
# name : Blood corpuscles, type : Cell
# name : Blood platelets, type : Cell
# name : Bloodvessels, type : Organ
# name : Capillaries, type : Organ
# name : Cardiac Cycle, type : Process
# name : Cardiac Muscular Tissue, type : Tissue
# name : Cavity of the Thorax, type : Organ
# name : Cells, type : Organ
# name : Chordæ tendineæ, type : Tissue
# name : Complete diastole, type : Physiological Process
# name : Coronary sinus, type : Organ
# name : Crista terminalis, type : Anatomical Structure
# name : Cuvierian ducts, type : Vessel
# name : Dorsal Aortæ, type : Organ
# name : Dr. A. Morison 9 5, type : Person
# name : Dura Mater, type : Organ
# name : Ecker-Ziegler model, type : Model
# name : Ectoderm, type : Tissue
# name : Endothelial lining of heart, type : Tissue
# name : Entoderm, type : Tissue
# name : Eternod 8 9, type : Book
# name : Eustachian valve, type : Body_Part
# name : FIG. 481– 4 mm, type : Image
# name : FIG. 482– 14 mm, type : Figure
# name : FIG. 483– 18 mm, type : Figure
# name : FIG. 484– 21 mm, type : Image
# name : FIG. 485– 35 mm, type : Figure
# name : February, type : Month
# name : Fetal Circulation, type : System
# name : Fetus, type : Organism
# name : Fig. 486, type : Figure
# name : Fig. 487, type : Figure
# name : Fig. 488, type : Figure
# name : Foramina venarum minimarum, type : Organ
# name : Fossa ovalis, type : Anatomical Structure
# name : Glass slide, type : Object
# name : Head, type : Organ
# name : Heart, type : Organ
# name : Henle, type : Person
# name : Human colorles blood corpuscle, type : Cell
# name : Human embryo, type : Organ
# name : Human red blood corpuscles, type : Cell
# name : Inferior Vena Cava, type : Organ
# name : Inferior vena cava, type : Organ
# name : Intervenous tubercle, type : Anatomical Structure
# name : Johns Hopkins Hospital, type : Hospital
# name : Journal of Anatomy and Physiology, type : Publication
# name : Jugular veins, type : Vessel
# name : Kölliker, type : Person
# name : Left Atrium, type : Organ
# name : Left Ventricle, type : Organ
# name : Left atrioventricular, type : Valve
# name : Lewis, type : Person
# name : Ligament of the Left Vena Cava, type : Structure
# name : Limbus fossæ ovalis, type : Anatomical Structure
# name : Longus colli muscles, type : Muscle
# name : Lower Opening of the Thorax, type : Anatomical Structure
# name : Musculi pectinati, type : Anatomical Structure
# name : Musculi pectinati, type : Structure
# name : Nerves, type : Anatomical Structure
# name : No. 1, type : Issue
# name : Note 89, type : Note
# name : Note 90, type : Note
# name : Openings, type : Anatomical Structure
# name : Outer wall of heart, type : Anatomical_Structure
# name : Page 336, type : Page
# name : Page 338, type : Page
# name : Page 341, type : Page
# name : Page 345, type : Page
# name : Page 347, type : Page
# name : Page 353, type : Page
# name : Page 355, type : Page
# name : Page 357, type : Page
# name : Parietal System, type : System
# name : Parietal Veins, type : Organ
# name : Pericardium, type : Organ
# name : Pharynx, type : Organ
# name : Plasma, type : Fluid
# name : Proamnion, type : Tissue
# name : Pulmonary, type : Organ
# name : Pulmonary artery, type : Organ
# name : Purkinje Fibers, type : Tissue
# name : Purkinje fibers, type : Substance
# name : Purkinje’s fibers, type : Tissue
# name : Reports, type : Document
# name : Right Atrium, type : Organ
# name : Right Ventricle, type : Organ
# name : Right atrioventricular, type : Organ
# name : Robinson, type : Person
# name : Rollett, type : Person
# name : S-shaped form, type : Shape
# name : S-shaped loop, type : Structure
# name : Schäfer, type : Person
# name : Septum, type : Anatomical_Structure
# name : Sinus Venarum, type : Organ
# name : Sinusoids, type : Structure
# name : Somatopleure, type : Tissue
# name : Splanchnopleure, type : Tissue
# name : Sternocostal surface, type : Surface
# name : Sternohyoideus muscles, type : Muscle
# name : Sternothyreoideus muscles, type : Muscle
# name : Streeter, type : Person
# name : Superior vena cava, type : Vessel
# name : Thoracic Cavity, type : Organ
# name : Total systole, type : Physiological Process
# name : Trabeculæ carneæ, type : Tissue
# name : Tricuspid, type : Organ
# name : Umbilical Vein s, type : Organ
# name : Upper Opening of the Thorax, type : Anatomical Structure
# name : V. Vein, type : Organ
# name : VASCULAR system, type : System
# name : Valsalva, type : Anatomical Structure
# name : Valve of the coronary sinus, type : Organ
# name : Valve of the inferior vena cava, type : Organ
# name : Valves, type : Anatomical Structure
# name : Valves, type : Organ
# name : Valves of the Heart, type : Organ
# name : Vascular System, type : System
# name : Veins, type : Organ
# name : Venous Sinuses, type : Organ
# name : Ventricular Septum, type : Organ
# name : Ventricular diastole, type : Physiological Process
# name : Ventricular systole, type : Physiological Process
# name : Vessels, type : Anatomical Structure
# name : Visceral Veins, type : Organ
# name : Vitelline Vein, type : Organ
# name : Wolffian bodies, type : Organ
# name : Young, type : Person
# name : abdomen, type : Anatomical Structure
# name : abdomen, type : Body_Part
# name : abdomen, type : Organ
# name : abdominal cavity, type : Body Cavity
# name : abdominal viscera, type : Organ
# name : abdominal wall, type : Organ
# name : accessory hemiazygos veins, type : Organ
# name : acid dyes, type : Substance
# name : acute margin, type : Anatomical Structure
# name : acute margin, type : Structure
# name : adult, type : Developmental_Stage
# name : adult, type : Life_Stage
# name : adult, type : Organism
# name : adult right atrium, type : Organ
# name : adventitia, type : Structure
# name : adventitia, type : Tissue
# name : alterations, type : Process
# name : amphibia, type : Organism
# name : amphibians, type : Organism
# name : anastomosis, type : Structure
# name : anastomotic branches, type : Organ
# name : anemia, type : Disease
# name : angioblast, type : Cell
# name : angïoblasts, type : Cell
# name : animals, type : Animal
# name : animals, type : Organism
# name : annular constriction, type : Structure
# name : annular fibers, type : Substance
# name : annulus ovalis, type : Structure
# name : anterior abdominal wall, type : Anatomical Structure
# name : anterior and middle cerebral arteries, type : Organ
# name : anterior body-wall, type : Body_Part
# name : anterior cusp, type : Anatomical Structure
# name : anterior dural plexus, type : Organ
# name : anterior longitudinal sulci, type : Structure
# name : anterior longitudinal sulcus, type : Structure
# name : anterior longitudinal sulcus, type : Sulcus
# name : anterior papillary muscle, type : Structure
# name : anterior papillary muscle, type : Tissue
# name : anterior plexus, type : Organ
# name : anterior portions of the primitive aortæ, type : Vessel
# name : anterior tibial arteries, type : Organ
# name : anterior vena cava, type : Organ
# name : anterior ventral aorta, type : Vessel
# name : anterior ventral aortæ, type : Vessel
# name : anterior wall, type : Structure
# name : anteror plexus, type : Vessel
# name : aorta, type : Anatomical Structure
# name : aorta, type : Organ
# name : aorta, type : Structure
# name : aorta, type : Vessel
# name : aortic and pulmonary semilunar valves, type : Organ
# name : aortic arch, type : Artery
# name : aortic arch, type : Organ
# name : aortic arches, type : Anatomical_Structure
# name : aortic arches, type : Organ
# name : aortic arches, type : Vessel
# name : aortic arterial ring, type : Structure
# name : aortic bulb, type : Organ
# name : aortic isthmus, type : Structure
# name : aortic opening, type : Anatomical Structure
# name : aortic orifice, type : Anatomical Structure
# name : aortic orifice, type : Structure
# name : aortic orifices, type : Anatomy
# name : aortic semilunar valves, type : Anatomical Structure
# name : aortic semilunar valves, type : Organ
# name : aortic semilunar valves, type : Structure
# name : aortic septum, type : Anatomical Structure
# name : aortic septum, type : Organ
# name : aortic sinuses, type : Anatomical Structure
# name : aortic vestibule, type : Anatomical Structure
# name : aortic vestibule, type : Structure
# name : aperture, type : Anatomical Structure
# name : apertures, type : Structure
# name : apex, type : Anatomical Structure
# name : apex, type : Location
# name : apex, type : Structure
# name : apex cordis, type : Organ
# name : apex of each lung, type : Anatomical Structure
# name : apex of the heart, type : Anatomical Structure
# name : apex of the heart, type : Anatomical_Structure
# name : apex of the heart, type : Structure
# name : apices, type : Structure
# name : arch, type : Structure
# name : arch of the aorta, type : Anatomical Structure
# name : arch of the aorta, type : Organ
# name : arch of the aorta, type : Vessel
# name : arches, type : Structure
# name : area, type : Anatomical_Structure
# name : area vasculosa, type : Area
# name : area vasculosa, type : Region
# name : areolar, type : Tissue
# name : areolar tissue, type : Tissue
# name : arrangement, type : Concept
# name : arrangement, type : Structure
# name : arrows, type : Object
# name : arterial and venous blood, type : Substance
# name : arterial blood, type : Substance
# name : arterial branches, type : Organ
# name : arterial mesocardium, type : Organ
# name : arterial orifices, type : Structure
# name : arterial stem, type : Organ
# name : arterial stem, type : Structure
# name : arterial system, type : System
# name : arteries, type : Anatomical Structure
# name : arteries, type : Artery
# name : arteries, type : Organ
# name : arteries, type : Structure
# name : arteries, type : Vessel
# name : arterioles, type : Vessel
# name : artery, type : Organ
# name : artery, type : Vessel
# name : ascending aorta, type : Artery
# name : ascending veins, type : Organ
# name : atria, type : Organ
# name : atrial canal, type : Anatomical Structure
# name : atrial canal, type : Organ
# name : atrial canal, type : Structure
# name : atrial portion, type : Anatomical Structure
# name : atrial portion, type : Organ
# name : atrial septum, type : Body_Part
# name : atrial septum, type : Organ
# name : atrial septum, type : Structure
# name : atrial systole, type : Process
# name : atrioventricular, type : Anatomical Structure
# name : atrioventricular bundle, type : Organ
# name : atrioventricular bundle of His, type : Anatomical Structure
# name : atrioventricular bundle of His, type : Organ
# name : atrioventricular bundle of His, type : Structure
# name : atrioventricular junction, type : Anatomical Structure
# name : atrioventricular node, type : Organ
# name : atrioventricular opening, type : Anatomical Structure
# name : atrioventricular opening, type : Opening
# name : atrioventricular opening, type : Organ
# name : atrioventricular openings, type : Structure
# name : atrioventricular orifice, type : Anatomical Structure
# name : atrioventricular orifice, type : Body_Part
# name : atrioventricular orifices, type : Structure
# name : atrioventricular ring, type : Structure
# name : atrioventricular septum, type : Structure
# name : atrioventricular valves, type : Organ
# name : atrioventricular valves, type : Structure
# name : atrium, type : Organ
# name : atrium, type : Organ_Part
# name : atrium, type : Structure
# name : atrophy, type : Disease
# name : atrophy, type : Process
# name : auricula, type : Anatomical Structure
# name : auricula, type : Organ
# name : auricula, type : Structure
# name : auricula dextra, type : Organ
# name : auricula sinistra, type : Organ
# name : auricular heart, type : Organ
# name : auriculoventricular groove, type : Structure
# name : auriculæ, type : Organ
# name : axillary arteries, type : Organ
# name : azygos vein, type : Organ
# name : azygos vein, type : Vessel
# name : azygos veins, type : Organ
# name : bag, type : Structure
# name : band, type : Anatomical Structure
# name : bands, type : Structure
# name : bands, type : Tissue
# name : bands of fibers, type : Structure
# name : base, type : Structure
# name : base (basis cordis), type : Organ
# name : base of ventricles, type : Organ
# name : bases, type : Structure
# name : bases of the ventricles, type : Anatomical Structure
# name : basic dyes, type : Substance
# name : basilar artery, type : Vessel
# name : basophil, type : Substance
# name : bicuspid valve, type : Anatomical Structure
# name : bicuspid valve, type : Organ
# name : bicuspid valves, type : Structure
# name : birds, type : Animal
# name : birds, type : Organism
# name : birth, type : Biological Process
# name : birth, type : Event
# name : birth, type : Process
# name : birth, type : Time
# name : bladder, type : Organ
# name : blood, type : Body_Fluid
# name : blood, type : Fluid
# name : blood, type : Substance
# name : blood current, type : Substance
# name : blood island, type : Structure
# name : blood platelets, type : Cell
# name : blood space, type : Structure
# name : blood spaces, type : Structure
# name : blood vascular system, type : System
# name : bloodvessel, type : Structure
# name : bloodvessels, type : Organ
# name : bloodvessels, type : Structure
# name : bloodvessels, type : Vessel
# name : blue dotted lines, type : Structure
# name : body, type : Cell
# name : body, type : Organ
# name : body, type : Organism
# name : body, type : System
# name : body-stalk, type : Body_Part
# name : body-stalk, type : Structure
# name : bone, type : Organ
# name : bones, type : Organ
# name : brachial arteries, type : Organ
# name : brain, type : Organ
# name : brain tube, type : Organ
# name : branch, type : Structure
# name : branches, type : Organ
# name : branches, type : Structure
# name : breadth, type : Measurement
# name : bronchi, type : Organ
# name : bulbus cordis, type : Organ
# name : bulbus cordis, type : Structure
# name : bundle, type : Organ
# name : bundle of His, type : Structure
# name : bundles, type : Structure
# name : canal, type : Structure
# name : capacity, type : Function
# name : capillaries, type : Organ
# name : capillaries, type : Structure
# name : capillaries, type : Vessel
# name : capillary anastomosis, type : Structure
# name : capillary net, type : Structure
# name : capillary network, type : Organ
# name : capillary plexuses, type : Structure
# name : capillary tube, type : Organ
# name : capillary vessels, type : Structure
# name : capillary wall, type : Tissue
# name : capillary-like vessels, type : Organ
# name : capillary-like vessels, type : Vessel
# name : carbohydrates, type : Substance
# name : cardiac cells, type : Cell
# name : cardiac cycle, type : Process
# name : cardiac muscle, type : Tissue
# name : cardiac muscle cells, type : Substance
# name : cardiac nerve, type : Nerve
# name : cardiac plexus, type : Organ
# name : cardinal portion, type : Vessel
# name : cardinal veins, type : Organ
# name : cardinal veins, type : Vessel
# name : cardinals, type : Vessel
# name : carmine, type : Substance
# name : carotid, type : Artery
# name : carotid arch, type : Vessel
# name : carotid arteries, type : Organ
# name : cartilages of the ribs, type : Tissue
# name : cartilaginous capsule, type : Organ
# name : cavernous sinus, type : Sinus
# name : cavit y, type : Organ
# name : cavities, type : Structure
# name : cavity, type : Anatomical Structure
# name : cavity, type : Anatomical_Structure
# name : cavity, type : Body_Part
# name : cavity, type : Space
# name : cavity, type : Structure
# name : cells, type : Cell
# name : cells, type : Organ
# name : cells, type : Structure
# name : cells, type : Substance
# name : center, type : Location
# name : central nervous system, type : System
# name : central tendon, type : Organ
# name : central tendon, type : Structure
# name : central tendon of the diaphragm, type : Structure
# name : cerebral part of the vertebral artery, type : Organ
# name : cerebral part of the vertebral artery, type : Vessel
# name : cerebral veins, type : Organ
# name : cerebrospinal nerves, type : Organ
# name : chambers, type : Structure
# name : change, type : Process
# name : changes, type : Phenomenon
# name : changes, type : Process
# name : channel, type : Structure
# name : channels, type : Structure
# name : chest, type : Body_Part
# name : chick embryo, type : Organism
# name : child, type : Organism
# name : cholesterin, type : Molecule
# name : chordæ tendineæ, type : Anatomy
# name : chordæ tendineæ, type : Structure
# name : chorion, type : Structure
# name : chorionic villi, type : Structure
# name : choroid coat, type : Structure
# name : chromatin, type : Substance
# name : chromatin mass, type : Substance
# name : circular aperture, type : Anatomical Structure
# name : circular muscle coat, type : Tissue
# name : circulation, type : Process
# name : circulation of the blood, type : Function
# name : circumference, type : Anatomy
# name : circumference, type : Organ
# name : coarsely granular protoplasm, type : Substance
# name : coat, type : Structure
# name : coats, type : Structure
# name : coats, type : Tissue
# name : color, type : Property
# name : columns, type : Structure
# name : columnœ carneœ, type : Structure
# name : common iliac, type : Organ
# name : common net-work, type : Structure
# name : common vein, type : Vein
# name : communication, type : Function
# name : communications, type : Structure
# name : concavity, type : Structure
# name : condition, type : Phenomenon
# name : conjunctiva, type : Structure
# name : connective tissue, type : Structure
# name : connective tissue, type : Substance
# name : connective tissue, type : Tissue
# name : connective tissue cells, type : Cell
# name : connective tissue corpuscles, type : Cell
# name : connective tissue fibers, type : Substance
# name : connective-tissue coat, type : Structure
# name : constriction, type : Structure
# name : contents, type : Substance
# name : continuity, type : Structure
# name : contraction, type : Physiological Process
# name : contraction of the atrium, type : Process
# name : contraction wave, type : Physiological Process
# name : contractions, type : Process
# name : conus arteriosus, type : Anatomical Structure
# name : conus arteriosus, type : Anatomical_Structure
# name : conus arteriosus, type : Organ
# name : conus arteriosus, type : Structure
# name : cord, type : Structure
# name : cornua, type : Anatomical Structure
# name : coronary sinus, type : Organ
# name : coronary sinus, type : Vessel
# name : coronary sulcus, type : Organ
# name : coronary sulcus, type : Structure
# name : coronary sulcus, type : Sulcus
# name : corpora Arantii, type : Anatomical Structure
# name : corpora cavernosa, type : Organ
# name : corpus Aranti i, type : Structure
# name : corpuscles, type : Cell
# name : corpuscles of the blood, type : Cell
# name : costal attachments, type : Anatomical Structure
# name : costocervical trunks, type : Anatomical Structure
# name : costosternal surface, type : Structure
# name : course of the blood, type : Substance
# name : cranium, type : Organ
# name : cranium, type : Structure
# name : crista terminalis of His, type : Structure
# name : cross branches, type : Structure
# name : cross communications, type : Structure
# name : crown-rump length, type : Measurement
# name : cubic millimetre, type : Unit
# name : current of blood, type : Substance
# name : currents, type : Substance
# name : cusps, type : Anatomy
# name : cusps, type : Organ
# name : cusps, type : Structure
# name : cutis, type : Structure
# name : cutis, type : Tissue
# name : day, type : Time
# name : days, type : Time
# name : dead body, type : Body_Part
# name : deep cervical fascia, type : Structure
# name : deep layers, type : Tissue
# name : depression, type : Structure
# name : descending aorta, type : Organ
# name : descending aorta, type : Vessel
# name : descending thoracic aorta, type : Vessel
# name : descending veins, type : Organ
# name : destination, type : Concept
# name : developing liver, type : Organ
# name : development, type : Process
# name : diagram, type : Image
# name : diameter, type : Measurement
# name : diameter, type : Property
# name : diameters, type : Property
# name : diaphragm, type : Organ
# name : diaphragmatic surface, type : Anatomical Structure
# name : diaphragmatic surface, type : Organ
# name : diaphragmatic surface, type : Structure
# name : diaphragmatic surface, type : Surface
# name : diaphragmatic surface of the heart, type : Anatomical_Structure
# name : diaphragmatic surface of the right ventricle, type : Structure
# name : difference, type : Property
# name : differentiation, type : Process
# name : digestive tube, type : Organ
# name : direction, type : Property
# name : distention, type : Property
# name : division, type : Structure
# name : dorsal aorta, type : Aorta
# name : dorsal aorta, type : Vessel
# name : dorsal aortæ, type : Organ
# name : dorsal aortæ, type : Vessel
# name : dorsal half, type : Anatomical Structure
# name : dorsal half, type : Anatomical_Structure
# name : dorsal part, type : Anatomical_Part
# name : dorsal part, type : Part
# name : dorsal surface, type : Anatomical Structure
# name : dorsal wall, type : Structure
# name : double aortic arch, type : Anatomical Structure
# name : duct of Cuvier, type : Organ
# name : duct of Cuvier, type : Vessel
# name : ducts of Cuvier, type : Organ
# name : ductus arteriosus, type : Organ
# name : ductus arteriosus, type : Vessel
# name : ductus venosus, type : Body_Part
# name : ductus venosus, type : Organ
# name : ductus venosus, type : Vessel
# name : duodenal portion of the intestine, type : Organ
# name : dura mater, type : Organ
# name : dural veins, type : Organ
# name : ear, type : Organ
# name : edge, type : Anatomical Structure
# name : edges, type : Structure
# name : eighth thoracic vertebra, type : Organ
# name : elastic fibers, type : Structure
# name : elastic fibers, type : Substance
# name : elastic fibers, type : Tissue
# name : elastic lamina, type : Tissue
# name : elastic layer, type : Structure
# name : elastic tissue, type : Tissue
# name : electric shock, type : Event
# name : elephant, type : Animal
# name : elongated meshes, type : Structure
# name : embryo, type : Organ
# name : embryo, type : Organism
# name : embryonic organ, type : Structure
# name : endocardial cushions, type : Organ
# name : endocardial cushions, type : Structure
# name : endocardial thickenings, type : Anatomical Structure
# name : endocardium, type : Membrane
# name : endocardium, type : Organ
# name : endocardium, type : Tissue
# name : endosmosis, type : Process
# name : endothelial, type : Tissue
# name : endothelial cells, type : Cell
# name : endothelial coat, type : Structure
# name : endothelial layer, type : Tissue
# name : endothelial lining, type : Tissue
# name : endothelial membrane, type : Tissue
# name : endothelium, type : Tissue
# name : entoderm, type : Tissue
# name : envelope, type : Organ
# name : envelope, type : Structure
# name : eosin, type : Substance
# name : eosinophil corpuscles, type : Cell
# name : epicardium, type : Membrane
# name : epicardium, type : Organ
# name : epiglottis, type : Organ
# name : epithelial cells, type : Cell
# name : erythrocytes, type : Cell
# name : esophagus, type : Anatomical Structure
# name : esophagus, type : Organ
# name : evidence, type : Substance
# name : excretion, type : Function
# name : external carotid, type : Vessel
# name : external coat, type : Tissue
# name : external coats, type : Structure
# name : external jugular vein, type : Vein
# name : extremities, type : Body_Part
# name : extremities, type : Location
# name : extremities, type : Structure
# name : eye, type : Organ
# name : face, type : Body_Part
# name : falciform ligament, type : Ligament
# name : fasciculi, type : Organ
# name : fat, type : Molecule
# name : female, type : Sex
# name : femoral, type : Artery
# name : femoral artery, type : Organ
# name : fenestrated layer, type : Structure
# name : fetal aperture, type : Structure
# name : fetal blood, type : Substance
# name : fetal circulation, type : System
# name : fetal heart, type : Organ
# name : fetal life, type : Developmental_Stage
# name : fetal life, type : Life_Stage
# name : fetal life, type : Stage
# name : fetal lungs, type : Organ
# name : fetus, type : Organ
# name : fetus, type : Organism
# name : fibers, type : Structure
# name : fibers, type : Substance
# name : fibers, type : Tissue
# name : fibers of the atria, type : Structure
# name : fibers of the ventricles, type : Structure
# name : fibrils, type : Organ
# name : fibro-areolar investments, type : Tissue
# name : fibrous band, type : Structure
# name : fibrous cords, type : Anatomical Structure
# name : fibrous layer, type : Tissue
# name : fibrous pericardium, type : Organ
# name : fibrous prolongations, type : Structure
# name : fibrous ring, type : Structure
# name : fibrous ring, type : Tissue
# name : fibrous rings, type : Structure
# name : fibrous tissue, type : Substance
# name : fibrous tissue, type : Tissue
# name : fibrous walls, type : Tissue
# name : fifteen days, type : Time
# name : fifth arch, type : Body_Part
# name : fifth costal cartilage, type : Anatomical Structure
# name : fifth left intercostal space, type : Anatomical_Structure
# name : fifth right costal cartilage, type : Anatomical Structure
# name : fifth thoracic vertebra, type : Organ
# name : figure, type : Visual_Representation
# name : filaments, type : Structure
# name : fingers, type : Body Part
# name : first aortic arch, type : Anatomical_Structure
# name : first cephalic arch, type : Structure
# name : first rib, type : Bone
# name : first ribs, type : Organ
# name : first thoracic nerves, type : Nerve
# name : fishes, type : Organism
# name : floor, type : Anatomical Structure
# name : folds of peritoneum, type : Tissue
# name : foramen ovale, type : Anatomical Structure
# name : foramen ovale, type : Organ
# name : foramen ovale, type : Structure
# name : foramina venarum minimarum, type : Structure
# name : force, type : Physical Property
# name : fore-gut, type : Organ
# name : forearm, type : Organ
# name : forelimb bud, type : Body_Part
# name : form, type : Characteristic
# name : form, type : Property
# name : form, type : Structure
# name : formen ovale, type : Organ
# name : fossa ovalis, type : Organ
# name : fossa ovalis, type : Structure
# name : fourteen days, type : Time
# name : fourth arch, type : Body_Part
# name : fourth lumbar segment, type : Anatomical_Location
# name : fourth right arch, type : Anatomical Structure
# name : fourth right arch, type : Artery
# name : fourth right costal cartilage, type : Anatomical Structure
# name : fourth thoracic segment, type : Anatomical_Location
# name : frequency, type : Physical Property
# name : function, type : Process
# name : furrow, type : Structure
# name : fusion, type : Process
# name : ganglia, type : Organ
# name : general circulation, type : System
# name : gills, type : Organ
# name : glands, type : Organ
# name : globulin, type : Molecule
# name : glomeruli, type : Organ
# name : glomus caroticum, type : Structure
# name : glomus coccygeum, type : Structure
# name : glycogen, type : Molecule
# name : glycogen, type : Substance
# name : goose-quill, type : Object
# name : grams, type : Unit
# name : granular masses, type : Structure
# name : granules, type : Particle
# name : granules, type : Substance
# name : gravity, type : Property
# name : great vessels, type : Organ
# name : great vessels, type : Structure
# name : greater or systemic circulation, type : System
# name : groove, type : Structure
# name : grooves, type : Structure
# name : ground glass, type : Substance
# name : group of veins, type : Vein
# name : groups, type : Concept
# name : groups of Purkinje cells, type : Cell_Group
# name : growth, type : Process
# name : guinea-pig, type : Organism
# name : head, type : Body_Part
# name : head, type : Organ
# name : head vein, type : Vessel
# name : heart, type : Organ
# name : heart muscle, type : Organ
# name : heart muscle, type : Tissue
# name : heart tubes, type : Organ
# name : hearts of quadrupeds, type : Organ
# name : hematoxylin, type : Substance
# name : hemiazygos veins, type : Organ
# name : hemispheres, type : Organ
# name : hemoglobin, type : Molecule
# name : hemoglobin, type : Substance
# name : hepatic veins, type : Organ
# name : hepatic veins, type : Vessel
# name : highest left intercostal vein, type : Organ
# name : highest left intercostal vein, type : Vessel
# name : hind-brain, type : Organ
# name : horse-shoe shaped nuclei, type : Organ
# name : hours’ incubation, type : Time
# name : human being, type : Organism
# name : human blood, type : Body_Fluid
# name : human blood, type : Fluid
# name : human blood, type : Tissue
# name : human body, type : Organism
# name : human embryo, type : Organ
# name : human embryo, type : Organism
# name : human embryos, type : Organism
# name : human heart, type : Organ
# name : hyaline cel l, type : Cell
# name : hyaline ground plates, type : Tissue
# name : hyaline internal coat, type : Tissue
# name : hypogastric arteries, type : Artery
# name : hypogastric arteries, type : Organ
# name : hypogastric veins, type : Organ
# name : hypoglossal arteries, type : Vessel
# name : hypoglossal nerves, type : Nerve
# name : iliac, type : Artery
# name : iliac veins, type : Organ
# name : image, type : Image
# name : image, type : Object
# name : image, type : Visual
# name : image, type : Visual Representation
# name : image, type : Visual_Representation
# name : impression, type : Structure
# name : impulse, type : Function
# name : inch, type : Unit
# name : incisura apicis cordis, type : Structure
# name : individual cells, type : Cell
# name : inferior gluteal artery, type : Organ
# name : inferior petrosal sinus, type : Organ
# name : inferior thyroid veins, type : Vein
# name : inferior vena cava, type : Organ
# name : inferior vena cava, type : Vessel
# name : infraorbital branches, type : Vessel
# name : infundibulum, type : Anatomical Structure
# name : inner coat, type : Organ
# name : inner coat, type : Tissue
# name : inner surface, type : Anatomical Structure
# name : inner wall, type : Structure
# name : innominate artery, type : Artery
# name : innominate artery, type : Organ
# name : innominate vein, type : Vessel
# name : innominate veins, type : Vein
# name : interatrial groove, type : Structure
# name : intercellular cement, type : Substance
# name : intercellular substance, type : Substance
# name : intercostal veins, type : Organ
# name : interior, type : Anatomical Structure
# name : interior, type : Anatomical_Structure
# name : interior, type : Organ
# name : internal carotid, type : Vessel
# name : internal carotid arteries, type : Organ
# name : internal carotid artery, type : Vessel
# name : internal coat, type : Tissue
# name : internal jugular, type : Vessel
# name : internal mammary, type : Vessel
# name : internal mammary arteries, type : Artery
# name : internal mammary branch, type : Vessel
# name : internal maxillary artery, type : Vessel
# name : interspaces, type : Structure
# name : interstitial cement substance, type : Substance
# name : intertubular plexus, type : Structure
# name : intervenous tubercle, type : Organ
# name : interventricular foramen, type : Structure
# name : intestinal canal, type : Organ
# name : intestines, type : Organ
# name : intima, type : Tissue
# name : intralobular vein, type : Structure
# name : intrathoracic pressure, type : Physical_Property
# name : intravascular pressure, type : Property
# name : invaginated margin, type : Anatomical Structure
# name : inverted U, type : Shape
# name : jugulars, type : Vessel
# name : kidney, type : Organ
# name : kidneys, type : Organ
# name : knee, type : Body_Part
# name : lamellæ, type : Structure
# name : large intestine, type : Organ
# name : larger trunks, type : Organ
# name : larynx, type : Organ
# name : lateral cusps, type : Anatomical Structure
# name : lateral umbilical ligaments, type : Ligament
# name : layer, type : Structure
# name : layer of mesoderm, type : Tissue
# name : layers, type : Structure
# name : layers, type : Tissue
# name : lecithin, type : Molecule
# name : left, type : Organ
# name : left, type : Spatial_Location
# name : left Cuvierian duct, type : Vessel
# name : left atrioventricular opening, type : Anatomical Structure
# name : left atrioventricular orifice, type : Anatomy
# name : left atrioventricular orifices, type : Structure
# name : left atrioventricular ring, type : Structure
# name : left atrium, type : Organ
# name : left atrium, type : Structure
# name : left auricular appendix, type : Organ
# name : left cardinal vein, type : Organ
# name : left carotid artery, type : Vessel
# name : left common carotid, type : Artery
# name : left common carotid arteries, type : Organ
# name : left common carotid artery, type : Organ
# name : left common iliac vein, type : Organ
# name : left coronary artery, type : Anatomical Structure
# name : left dorsal aorta, type : Organ
# name : left external carotid arteries, type : Organ
# name : left half, type : Part
# name : left halves, type : Organ_Part
# name : left horn, type : Structure
# name : left lobe, type : Organ
# name : left lung, type : Organ
# name : left mammary papilla, type : Anatomical_Structure
# name : left margin, type : Anatomical Structure
# name : left margin, type : Structure
# name : left primitive jugular vein, type : Vessel
# name : left pulmonary arteries, type : Organ
# name : left pulmonary artery, type : Organ
# name : left pulmonary artery, type : Vessel
# name : left renal vein, type : Organ
# name : left side, type : Anatomical Structure
# name : left side, type : Anatomical_Structure
# name : left side, type : Body_Part
# name : left side, type : Location
# name : left side of the heart, type : Organ
# name : left subclavian, type : Artery
# name : left subclavian, type : Organ
# name : left subclavian artery, type : Artery
# name : left subclavian artery, type : Organ
# name : left suprarenal vein, type : Organ
# name : left umbilical vein, type : Organ
# name : left ventricle, type : Organ
# name : left ventricle, type : Structure
# name : left ventricles, type : Organ
# name : left vitelline vein, type : Organ
# name : length, type : Measurement
# name : length, type : Property
# name : lesser or pulmonary circulation, type : System
# name : leucocytes, type : Cell
# name : ligament, type : Organ
# name : ligament of the left vena cava, type : Structure
# name : ligamentum arteriosum, type : Structure
# name : ligamentum teres, type : Body_Part
# name : ligamentum teres, type : Organ
# name : ligamentum venosum, type : Body_Part
# name : ligamentum venosum, type : Organ
# name : ligature, type : Object
# name : limb, type : Organ
# name : limbs, type : Organ
# name : limbus fossæ ovalis, type : Anatomical Structure
# name : limbus fossæ ovalis, type : Structure
# name : lines, type : Structure
# name : lines of reflection, type : Structure
# name : lingual region, type : Body_Part
# name : linguo-facial, type : Vein
# name : lining membrane, type : Tissue
# name : lining membrane of the atrium, type : Tissue
# name : lining membrane of the heart, type : Tissue
# name : liver, type : Organ
# name : liver cells, type : Cell
# name : lobus caudatus, type : Organ
# name : lobus quadratus, type : Organ
# name : long axis of the mesh, type : Structure
# name : long axis of the nerve, type : Structure
# name : longitudinal section, type : Anatomical Structure
# name : longitudinal section, type : Section
# name : longitudinal striation, type : Structure
# name : looped fibers, type : Substance
# name : loops, type : Structure
# name : lower extremities, type : Organ
# name : lower half of the body, type : Body_Part
# name : lower limb, type : Body_Part
# name : lower limbs, type : Organ
# name : lower ribs, type : Organ
# name : lumen, type : Anatomical Structure
# name : lumen, type : Structure
# name : lung, type : Organ
# name : lungs, type : Organ
# name : lunulæ, type : Anatomical Structure
# name : lunulæ, type : Structure
# name : lymph, type : Substance
# name : lymph glands, type : Organ
# name : lymph vascular system, type : System
# name : lymphatic s, type : System
# name : lymphatic vessels, type : Organ
# name : lymphatic vessels, type : Vessel
# name : lymphocyte, type : Cell
# name : lymphoid tissue, type : Tissue
# name : maceration, type : Process
# name : macrocyte, type : Cell
# name : main arterial stem, type : Organ
# name : main branches, type : Organ
# name : male, type : Sex
# name : mammals, type : Organism
# name : man, type : Organism
# name : mandibular arch, type : Structure
# name : mandibular arches, type : Anatomical_Structure
# name : mandibular arches, type : Structure
# name : mandibular branches, type : Vessel
# name : manubrium, type : Structure
# name : margin, type : Anatomical Structure
# name : margin, type : Organ
# name : margin, type : Structure
# name : margins, type : Anatomical Structure
# name : margins, type : Organ
# name : marrow, type : Tissue
# name : maternal blood, type : Substance
# name : maternal part of the placenta, type : Organ
# name : media, type : Tissue
# name : median artery, type : Organ
# name : median nerve, type : Organ
# name : median plane, type : Body_Part
# name : mediastinal cavity, type : Body_Part
# name : mediastinal surface, type : Anatomical_Structure
# name : medium, type : Environment
# name : medulla spinalis, type : Organ
# name : membrane, type : Structure
# name : membrane, type : Tissue
# name : membranous envelope, type : Structure
# name : membranous ventricular septum, type : Structure
# name : mesentery, type : Organ
# name : mesh, type : Structure
# name : meshes, type : Structure
# name : mesial or septal cusps, type : Anatomical Structure
# name : mesoderm, type : Tissue
# name : mesodermal tissue, type : Tissue
# name : metabolism, type : Process
# name : microcytes, type : Cell
# name : micromillimetre, type : Unit
# name : mid-sternal line, type : Anatomical_Structure
# name : midbrain, type : Organ
# name : middle coat, type : Tissue
# name : middle dural plexus, type : Organ
# name : middle ear, type : Organ
# name : middle mediastinum, type : Body_Part
# name : middle meningeal artery, type : Vessel
# name : middle plexus, type : Vessel
# name : millimetre, type : Unit
# name : minute masses of nucleated protoplasm, type : Substance
# name : minute veins, type : Vessel
# name : mitral orifice, type : Anatomical Structure
# name : moderator band, type : Structure
# name : mouth, type : Structure
# name : mucous membrane, type : Tissue
# name : mucous membranes, type : Tissue
# name : muscle, type : Tissue
# name : muscle cells, type : Cell
# name : muscle fiber cells, type : Cell
# name : muscle fibers, type : Tissue
# name : muscles, type : Organ
# name : muscular, type : Tissue
# name : muscular coat, type : Structure
# name : muscular coats, type : Tissue
# name : muscular fibers, type : Cell
# name : muscular fibers, type : Structure
# name : muscular fibers, type : Tissue
# name : muscular structure, type : Structure
# name : muscular structure, type : Tissue
# name : muscular substance, type : Tissue
# name : muscular ventricular septum, type : Structure
# name : muscular wall, type : Structure
# name : muscular walls, type : Tissue
# name : musculi papillare s, type : Structure
# name : musculi papillares, type : Structure
# name : musculi pectinati, type : Organ
# name : musculi pectinati, type : Structure
# name : musculophrenic branch, type : Vessel
# name : myocardium, type : Tissue
# name : neck, type : Anatomical_Structure
# name : neck, type : Body_Part
# name : neck, type : Structure
# name : nerve, type : Organ
# name : nerve filaments, type : Organ
# name : nerve s, type : Organ
# name : nerve trunks, type : Organ
# name : nerves, type : Organ
# name : nerves, type : Substance
# name : nervous stimulation, type : Physiological Process
# name : network, type : Structure
# name : neutral dyes, type : Substance
# name : neutrophil, type : Substance
# name : nitrate of silver, type : Substance
# name : node, type : Organ
# name : noduli, type : Anatomical Structure
# name : non-placental chorionic villi, type : Tissue
# name : notch, type : Structure
# name : notches, type : Structure
# name : notochord, type : Anatomical_Structure
# name : notochord, type : Structure
# name : nuclei, type : Cell Component
# name : nuclei, type : Cell_Component
# name : nuclei, type : Organ
# name : nuclei, type : Structure
# name : nucleoprotein, type : Molecule
# name : nucleus, type : Cell_Part
# name : nucleus, type : Organ
# name : nucleus, type : Organelle
# name : nucleus, type : Structure
# name : nutrient vessels, type : Structure
# name : nutrient vessels, type : Vessel
# name : nutrition, type : Function
# name : nutritive materials, type : Substance
# name : oblique sinus, type : Space
# name : oblique vein of Marshall, type : Vessel
# name : oblique vein of the left atrium, type : Vessel
# name : odor, type : Function
# name : offsets, type : Structure
# name : omphalomesenteric vein, type : Vein
# name : omphalomesenteric veins, type : Organ
# name : opening, type : Anatomical Structure
# name : openings, type : Structure
# name : ophthalmic arteries, type : Organ
# name : orbital twigs, type : Vessel
# name : orbital veins, type : Vessel
# name : organ, type : Organ
# name : organ, type : Structure
# name : organism, type : Biological Entity
# name : organs, type : Organ
# name : orifice, type : Anatomical Structure
# name : orifice, type : Body_Part
# name : orifice, type : Organ
# name : orifice of the coronary sinus, type : Location
# name : orifice of the coronary sinus, type : Structure
# name : orifice of the inferior vena cava, type : Anatomical Structure
# name : orifices, type : Structure
# name : origin, type : Location
# name : origin of the innominate artery, type : Body_Part
# name : origins, type : Anatomical_Structure
# name : os cordi, type : Structure
# name : ostium primum of Born, type : Structure
# name : ostium secundum of Born, type : Structure
# name : otic capsule, type : Organ
# name : outer wall, type : Tissue
# name : outline, type : Property
# name : outline, type : Shape
# name : ovarian veins, type : Organ
# name : ox, type : Animal
# name : oxyphi l, type : Substance
# name : p. 199, type : Page
# name : palm of the hand, type : Organ
# name : pancreas, type : Organ
# name : papillary eminences, type : Structure
# name : papillary muscles, type : Organ
# name : papillary muscles, type : Structure
# name : papillary muscles, type : Tissue
# name : papillæ of the tongue, type : Structure
# name : parallel ridges, type : Structure
# name : parallelograms, type : Shape
# name : parathyroid glands, type : Organ
# name : parietal, type : Organ
# name : parietal layer, type : Organ
# name : parietal portion, type : Organ
# name : parietal veins, type : Organ
# name : parietes, type : Organ
# name : part, type : Structure
# name : particle, type : Particle
# name : parts, type : Anatomical Structure
# name : parts, type : Anatomical_Structure
# name : parts, type : Anatomy
# name : parts, type : Organ
# name : passage from the right ventricle, type : Substance
# name : paths, type : Structure
# name : pavement endothelium, type : Structure
# name : peculiarities, type : Feature
# name : pelvis, type : Organ
# name : percardium, type : Organ
# name : pericardial area, type : Area
# name : pericardial region, type : Area
# name : pericardial sac, type : Organ
# name : pericardium, type : Body_Part
# name : pericardium, type : Organ
# name : period of life, type : Time
# name : period of rest, type : Process
# name : periods, type : Time
# name : peroneal artery, type : Organ
# name : pharynx, type : Organ
# name : phases, type : Process
# name : phrenic nerve, type : Nerve
# name : phrenic nerves, type : Nerve
# name : pia mater, type : Organ
# name : pia mater, type : Tissue
# name : pig, type : Animal
# name : placenta, type : Organ
# name : placental circulation, type : Circulation
# name : placental circulation, type : System
# name : plain muscle fibers, type : Tissue
# name : plasma, type : Fluid
# name : plasma, type : Substance
# name : plates, type : Tissue
# name : pleura, type : Organ
# name : pleura, type : Tissue
# name : pleuræ, type : Organ
# name : plexuses, type : Organ
# name : plexuses, type : Structure
# name : polymorphonuclear leucocytes, type : Cell
# name : porta hepatis, type : Body_Part
# name : portal vein, type : Organ
# name : portal vein, type : Vessel
# name : portal venous system, type : System
# name : posterior branch, type : Structure
# name : posterior dural plexus, type : Organ
# ...
# {'head': 'looped fibers', 'relation': 'pass_over', 'tail': 'atrium'}
# {'head': 'looped fibers', 'relation': 'attached_to', 'tail': 'atrioventricular ring'}
# {'head': 'annular fibers', 'relation': 'surround', 'tail': 'auriculæ'}
# {'head': 'annular fibers', 'relation': 'form', 'tail': 'bands'}
# {'head': 'bands', 'relation': 'around', 'tail': 'terminations'}
# {'head': 'bands', 'relation': 'around', 'tail': 'veins'}
# {'head': 'bands', 'relation': 'around', 'tail': 'fossa ovalis'}
# {'head': 'fibers', 'relation': 'part_of', 'tail': 'ventricles'}
# {'head': 'fibers', 'relation': 'exists_in', 'tail': 'ventricles'}
# {'head': 'fibers', 'relation': 'exists_in', 'tail': 'papillary muscles'}
# {'head': 'fibers', 'relation': 'exists_in', 'tail': 'tendon of the conus arteriosus'}
# {'head': 'fibers', 'relation': 'exists_in', 'tail': 'left ventricle'}
# {'head': 'fibers', 'relation': 'exists_in', 'tail': 'right ventricle'}
# {'head': 'deep layers', 'relation': 'part_of', 'tail': 'ventricles'}
# {'head': 'bands', 'relation': 'part_of', 'tail': 'ventricles'}
# {'head': 'atrioventricular bundle of His', 'relation': 'exists_in', 'tail': 'ventricles'}
# {'head': 'atrioventricular bundle of His', 'relation': 'exists_in', 'tail': 'atria'}
# {'head': 'vascular supply', 'relation': 'supplies', 'tail': 'heart muscle'}
# {'head': 'sinoatrial node', 'relation': 'exists_in', 'tail': 'atrium'}
# {'head': 'atrioventricular node', 'relation': 'exists_in', 'tail': 'right atrium'}
# {'head': 'fasciculi', 'relation': 'exists_in', 'tail': 'right ventricles'}
# {'head': 'fasciculi', 'relation': 'exists_in', 'tail': 'left ventricles'}
# {'head': 'Purkinje fibers', 'relation': 'part_of', 'tail': 'atrioventricular bundle of His'}
# {'head': 'atrioventricular bundle', 'relation': 'circulates_through', 'tail': 'nerves'}
# {'head': 'nerves', 'relation': 'mediates', 'tail': 'transmission'}
# {'head': 'nerve trunks', 'relation': 'part_of', 'tail': 'atrioventricular bundle'}
# {'head': 'plexuses', 'relation': 'part_of', 'tail': 'groups of Purkinje cells'}
# {'head': 'fibrils', 'relation': 'part_of', 'tail': 'plexuses'}
# {'head': 'fibrils', 'relation': 'exists_in', 'tail': 'individual cells'}
# {'head': 'bundle', 'relation': 'mediates', 'tail': 'impulse'}
# {'head': 'impulse', 'relation': 'causes', 'tail': 'systolic contraction'}
# {'head': 'impulse', 'relation': 'circulates_through', 'tail': 'atrial septum'}
# {'head': 'impulse', 'relation': 'circulates_through', 'tail': 'ventricles'}
# {'head': 'atrioventricular bundle of His', 'relation': 'exists_in', 'tail': 'orifice of the coronary sinus'}
# {'head': 'atrioventricular bundle of His', 'relation': 'generates', 'tail': 'node'}
# {'head': 'node', 'relation': 'exists_in', 'tail': 'ventricular septum'}
# {'head': 'node', 'relation': 'generates', 'tail': 'limbs'}
# {'head': 'diagram', 'relation': 'includes', 'tail': 'image'}
# {'head': 'arteries', 'relation': 'supplies', 'tail': 'heart'}
# {'head': 'right coronary artery', 'relation': 'part_of', 'tail': 'arteries'}
# {'head': 'left coronary artery', 'relation': 'part_of', 'tail': 'arteries'}
# {'head': 'arteries', 'relation': 'circulates_through', 'tail': 'aorta'}
# {'head': 'veins', 'relation': 'exists_in', 'tail': 'right atrium'}
# {'head': 'lymphatic s', 'relation': 'part_of', 'tail': 'thoracic and right lymphatic ducts'}
# {'head': 'nerve s', 'relation': 'derived_from', 'tail': 'cardiac plexus'}
# {'head': 'cardiac plexus', 'relation': 'part_of', 'tail': 'vagi'}
# {'head': 'cardiac plexus', 'relation': 'part_of', 'tail': 'sympathetic trunks'}
# {'head': 'nerve s', 'relation': 'exists_in', 'tail': 'surface'}
# {'head': 'nerve s', 'relation': 'exists_in', 'tail': 'substance'}
# {'head': 'nerve filaments', 'relation': 'part_of', 'tail': 'nerve s'}
# {'head': 'nerve filaments', 'relation': 'supplied_with', 'tail': 'ganglia'}
# {'head': 'contractions', 'relation': 'causes', 'tail': 'blood'}
# {'head': 'Cardiac Cycle', 'relation': 'includes', 'tail': 'contractions'}
# {'head': 'Cardiac Cycle', 'relation': 'includes', 'tail': 'period of rest'}
# {'head': 'cardiac cycle', 'relation': 'consists_of', 'tail': 'phases'}
# {'head': 'atrial systole', 'relation': 'part_of', 'tail': 'cardiac cycle'}
# {'head': 'ventricular systole', 'relation': 'part_of', 'tail': 'cardiac cycle'}
# {'head': 'contents', 'relation': 'flows_through', 'tail': 'atrioventricular openings'}
# {'head': 'muscular coats', 'relation': 'part_of', 'tail': 'veins'}
# {'head': 'tricuspid valves', 'relation': 'prevents', 'tail': 'blood'}
# {'head': 'bicuspid valves', 'relation': 'prevents', 'tail': 'blood'}
# {'head': 'musculi papillares', 'relation': 'prevents', 'tail': 'inversion'}
# {'head': 'chordæ tendineæ', 'relation': 'prevents', 'tail': 'inversion'}
# {'head': 'pressure', 'relation': 'opens', 'tail': 'valves'}
# {'head': 'blood', 'relation': 'flows_from', 'tail': 'right ventricle'}
# {'head': 'blood', 'relation': 'flows_from', 'tail': 'left ventricle'}
# {'head': 'blood', 'relation': 'flows_into', 'tail': 'pulmonary artery'}
# {'head': 'blood', 'relation': 'flows_into', 'tail': 'aorta'}
# {'head': 'pressure', 'relation': 'closes', 'tail': 'pulmonary semilunar valves'}
# {'head': 'pressure', 'relation': 'closes', 'tail': 'aortic semilunar valves'}
# {'head': 'blood', 'relation': 'flows_into', 'tail': 'atria'}
# {'head': 'intrathoracic pressure', 'relation': 'mediates', 'tail': 'blood'}
# {'head': 'heart muscle', 'relation': 'possesses', 'tail': 'contraction'}
# {'head': 'nerves', 'relation': 'regulates', 'tail': 'force'}
# {'head': 'nerves', 'relation': 'regulates', 'tail': 'frequency'}
# {'head': 'contraction wave', 'relation': 'passes_through', 'tail': 'atrioventricular junction'}
# {'head': 'contraction wave', 'relation': 'propagates_to', 'tail': 'ventricles'}
# {'head': 'band', 'relation': 'part_of', 'tail': 'atrioventricular junction'}
# {'head': 'band', 'relation': 'composed_of', 'tail': 'fibers'}
# {'head': 'atrioventricular bundle of His', 'relation': 'part_of', 'tail': 'band'}
# {'head': 'force', 'relation': 'subserves', 'tail': 'organism'}
# {'head': 'frequency', 'relation': 'subserves', 'tail': 'organism'}
# {'head': 'Reports', 'relation': 'exists_in', 'tail': 'Johns Hopkins Hospital'}
# {'head': 'Journal of Anatomy and Physiology', 'relation': 'part_of', 'tail': 'Note 95'}
# {'head': 'Vascular System', 'relation': 'exists_in', 'tail': 'Fetus'}
# {'head': 'fetal heart', 'relation': 'exists_in', 'tail': 'body'}
# {'head': 'atria', 'relation': 'part_of', 'tail': 'fetal heart'}
# {'head': 'foramen ovale', 'relation': 'mediates', 'tail': 'communication'}
# {'head': 'valve of the inferior vena cava', 'relation': 'part_of', 'tail': 'fetal heart'}
# {'head': 'heart', 'relation': 'exists_in', 'tail': 'body'}
# {'head': 'atrial portion', 'relation': 'part_of', 'tail': 'heart'}
# {'head': 'ventricular portion', 'relation': 'part_of', 'tail': 'heart'}
# {'head': 'wall of the left ventricle', 'relation': 'part_of', 'tail': 'ventricle'}
# {'head': 'wall of the right ventricle', 'relation': 'part_of', 'tail': 'ventricle'}
# {'head': 'size', 'relation': 'regulates', 'tail': 'fetal heart'}
# {'head': 'size', 'relation': 'regulates', 'tail': 'ventricle'}
# {'head': 'foramen ovale', 'relation': 'part_of', 'tail': 'atrial septum'}
# {'head': 'communication', 'relation': 'between', 'tail': 'atria'}
# {'head': 'communication', 'relation': 'exists_in', 'tail': 'fetal life'}
# {'head': 'septum secundum', 'relation': 'part_of', 'tail': 'atrium'}
# {'head': 'septum secundum', 'relation': 'grows', 'tail': 'primary septum'}
# {'head': 'foramen ovale', 'relation': 'exists_in', 'tail': 'primary septum'}
# {'head': 'foramen ovale', 'relation': 'is_caused_by', 'tail': 'birth'}
# {'head': 'foramen ovale', 'relation': 'is_caused_by', 'tail': 'septum secundum'}
# {'head': 'valve of the inferior vena cava', 'relation': 'circulates_through', 'tail': 'foramen ovale'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'valve of the inferior vena cava'}
# {'head': 'foramen ovale', 'relation': 'part_of', 'tail': 'vessel'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'left atrium'}
# {'head': 'communication', 'relation': 'mediates', 'tail': 'arterial system'}
# {'head': 'communication', 'relation': 'exists_in', 'tail': 'fetus'}
# {'head': 'communication', 'relation': 'part_of', 'tail': 'pulmonary artery'}
# {'head': 'communication', 'relation': 'part_of', 'tail': 'aorta'}
# {'head': 'ductus arteriosus', 'relation': 'part_of', 'tail': 'communication'}
# {'head': 'umbilical arteries', 'relation': 'part_of', 'tail': 'hypogastric arteries'}
# {'head': 'ductus arteriosus', 'relation': 'part_of', 'tail': 'pulmonary artery'}
# {'head': 'ductus arteriosus', 'relation': 'is a', 'tail': 'tube'}
# {'head': 'tube', 'relation': 'has', 'tail': 'length'}
# {'head': 'length', 'relation': 'exists_in', 'tail': 'birth'}
# {'head': 'tube', 'relation': 'has', 'tail': 'diameter'}
# {'head': 'diameter', 'relation': 'related_to', 'tail': 'goose-quill'}
# {'head': 'ductus arteriosus', 'relation': 'opens_into', 'tail': 'aorta'}
# {'head': 'aorta', 'relation': 'located_beyond', 'tail': 'origin'}
# {'head': 'origin', 'relation': 'of', 'tail': 'left subclavian artery'}
# {'head': 'ductus arteriosus', 'relation': 'conducts', 'tail': 'blood'}
# {'head': 'blood', 'relation': 'from', 'tail': 'right ventricle'}
# {'head': 'blood', 'relation': 'into', 'tail': 'aorta'}
# {'head': 'branches', 'relation': 'part_of', 'tail': 'pulmonary artery'}
# {'head': 'ductus arteriosus', 'relation': 'connected_to', 'tail': 'pulmonary artery'}
# {'head': 'hypogastric arteries', 'relation': 'circulates_through', 'tail': 'sides'}
# {'head': 'hypogastric arteries', 'relation': 'exists_in', 'tail': 'abdomen'}
# {'head': 'umbilical arteries', 'relation': 'part_of', 'tail': 'umbilical cord'}
# {'head': 'umbilical cord', 'relation': 'supplies', 'tail': 'placenta'}
# {'head': 'fetal blood', 'relation': 'supplies', 'tail': 'placenta'}
# {'head': 'hypogastric arteries', 'relation': 'supplies', 'tail': 'fetal blood'}
# {'head': 'peculiarities', 'relation': 'exists_in', 'tail': 'venous system'}
# {'head': 'venous system', 'relation': 'exists_in', 'tail': 'fetus'}
# {'head': 'communications', 'relation': 'mediates', 'tail': 'placenta'}
# {'head': 'communications', 'relation': 'mediates', 'tail': 'liver'}
# {'head': 'communications', 'relation': 'mediates', 'tail': 'portal vein'}
# {'head': 'communications', 'relation': 'circulates_through', 'tail': 'umbilical vein'}
# {'head': 'umbilical vein', 'relation': 'circulates_through', 'tail': 'inferior vena cava'}
# {'head': 'umbilical vein', 'relation': 'circulates_through', 'tail': 'ductus venosus'}
# {'head': 'umbilical vein', 'relation': 'circulates_through', 'tail': 'fetus'}
# {'head': 'umbilical vein', 'relation': 'supplies', 'tail': 'fetus'}
# {'head': 'placenta', 'relation': 'supplies', 'tail': 'umbilical vein'}
# {'head': 'falciform ligament', 'relation': 'part_of', 'tail': 'liver'}
# {'head': 'umbilical vein', 'relation': 'exists_in', 'tail': 'abdomen'}
# {'head': 'umbilical vein', 'relation': 'exists_in', 'tail': 'liver'}
# {'head': 'portal vein', 'relation': 'joins', 'tail': 'umbilical vein'}
# {'head': 'hepatic veins', 'relation': 'supplies', 'tail': 'inferior vena cava'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'ductus venosus'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'inferior vena cava'}
# {'head': 'blood', 'relation': 'supplied', 'tail': 'ductus venosus'}
# {'head': 'blood', 'relation': 'supplied', 'tail': 'hepatic veins'}
# {'head': 'blood', 'relation': 'supplied', 'tail': 'lower extremities'}
# {'head': 'blood', 'relation': 'supplied', 'tail': 'abdominal wall'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'right atrium'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'formen ovale'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'pulmonary veins'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'left ventricle'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'aorta'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'head'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'upper extremities'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'descending aorta'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'right ventricle'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'pulmonary artery'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'right pulmonary arteries'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'left pulmonary arteries'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'ductus arteriosus'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'umbilical arteries'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'placenta'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'fetal lungs'}
# {'head': 'arrows', 'relation': 'represents', 'tail': 'blood'}
# {'head': 'arterial blood', 'relation': 'circulates_through', 'tail': 'vessels'}
# {'head': 'venous blood', 'relation': 'circulates_through', 'tail': 'vessels'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'fetus'}
# {'head': 'placenta', 'relation': 'supplies', 'tail': 'nutrition'}
# {'head': 'placenta', 'relation': 'supplies', 'tail': 'excretion'}
# {'head': 'placenta', 'relation': 'receives', 'tail': 'blood'}
# {'head': 'umbilical vein', 'relation': 'traverses', 'tail': 'liver'}
# {'head': 'liver', 'relation': 'part_of', 'tail': 'fetus'}
# {'head': 'inferior vena cava', 'relation': 'opens_into', 'tail': 'left atrium'}
# {'head': 'valve', 'relation': 'part_of', 'tail': 'inferior vena cava'}
# {'head': 'right atrium', 'relation': 'part_of', 'tail': 'fetus'}
# {'head': 'blood', 'relation': 'passes_to', 'tail': 'aorta'}
# {'head': 'aorta', 'relation': 'supplies', 'tail': 'head'}
# {'head': 'aorta', 'relation': 'supplies', 'tail': 'upper extremities'}
# {'head': 'descending aorta', 'relation': 'supplies', 'tail': 'abdomen'}
# {'head': 'descending aorta', 'relation': 'supplies', 'tail': 'lower extremities'}
# {'head': 'blood', 'relation': 'derived_from', 'tail': 'head'}
# {'head': 'blood', 'relation': 'derived_from', 'tail': 'limbs'}
# {'head': 'Vascular System', 'relation': 'exists_in', 'tail': 'Birth'}
# {'head': 'respiration', 'relation': 'establishes', 'tail': 'Birth'}
# {'head': 'blood', 'relation': 'circulates_through', 'tail': 'lungs'}
# {'head': 'placental circulation', 'relation': 'is_cut_off', 'tail': 'Birth'}
# {'head': 'foramen ovale', 'relation': 'is_closed', 'tail': 'Birth'}
# {'head': 'valvular fold', 'relation': 'adheres_to', 'tail': 'margin'}
# {'head': 'valvular fold', 'relation': 'part_of', 'tail': 'foramen ovale'}
# {'head': 'slit-like opening', 'relation': 'exists_in', 'tail': 'atria'}
# {'head': 'slit-like opening', 'relation': 'part_of', 'tail': 'foramen ovale'}
# {'head': 'ductus arteriosus', 'relation': 'caused_by', 'tail': 'respiration'}
# {'head': 'ductus arteriosus', 'relation': 'degenerates', 'tail': 'cord'}
# {'head': 'cord', 'relation': 'is', 'tail': 'ligamentum arteriosum'}
# {'head': 'ligamentum arteriosum', 'relation': 'connects', 'tail': 'left pulmonary artery'}
# {'head': 'ligamentum arteriosum', 'relation': 'connects', 'tail': 'arch of the aorta'}
# {'head': 'parts', 'relation': 'part_of', 'tail': 'hypogastric arteries'}
# {'head': 'parts', 'relation': 'extends_from', 'tail': 'sides of the bladder'}
# {'head': 'parts', 'relation': 'extends_to', 'tail': 'umbilicus'}
# {'head': 'parts', 'relation': 'obliterated_after', 'tail': 'days'}
# {'head': 'days', 'relation': 'after', 'tail': 'birth'}
# {'head': 'parts', 'relation': 'projects_as', 'tail': 'fibrous cords'}
# {'head': 'fibrous cords', 'relation': 'projects_toward', 'tail': 'abdominal cavity'}
# {'head': 'fibrous cords', 'relation': 'are', 'tail': 'lateral umbilical ligaments'}
# {'head': 'folds of peritoneum', 'relation': 'exists_on', 'tail': 'fibrous cords'}
# {'head': 'umbilical vein', 'relation': 'exists_in', 'tail': 'birth'}
# {'head': 'ductus venosus', 'relation': 'exists_in', 'tail': 'birth'}
# {'head': 'umbilical vein', 'relation': 'generates', 'tail': 'ligamentum teres'}
# {'head': 'ductus venosus', 'relation': 'generates', 'tail': 'ligamentum venosum'}

# %% [markdown]
# # 고유 객체-관계 정제 후 json파일에 반영

# %%
import json
import os

def parse_txt_data(txt_filepath):
    unique_entities = {}  
    unique_relations = set() 

    with open(txt_filepath, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            
            if line.startswith("이름 :"):
                parts = line.split(', ')
                if len(parts) == 2:
                    name_part = parts[0].replace("이름 : ", "").strip()
                    type_part = parts[1].replace("타입 : ", "").strip()
                    unique_entities[name_part] = type_part
            
            elif line.startswith("{") and line.endswith("}"):
                try:
                    rel_data = json.loads(line)
                    if all(k in rel_data for k in ["head", "relation", "tail"]):
                        unique_relations.add((rel_data["head"], rel_data["relation"], rel_data["tail"]))
                except json.JSONDecodeError:
                    print(f"경고: 관계 파싱 오류 - {line}")
    return unique_entities, unique_relations

def update_json_data(json_data, unique_entities, unique_relations):
    for paragraph_data in json_data.get("paragraphs_data", []):
        for entity in paragraph_data.get("entities", []):
            if entity["name"] in unique_entities:
                entity["type"] = unique_entities[entity["name"]]
        
        filtered_relations = []
        for relation in paragraph_data.get("relations", []):
            rel_tuple = (relation.get("head"), relation.get("relation"), relation.get("tail"))
            if rel_tuple in unique_relations:
                filtered_relations.append(relation)
        paragraph_data["relations"] = filtered_relations
    return json_data

def main():
    txt_filename = "5_Angiology_unique.txt"
    json_filename = "5_Angiology.json"
    
    txt_filepath = os.path.join("data", "unique", txt_filename)
    json_filepath = os.path.join("data", "extracted_results", json_filename)

    if not os.path.exists(txt_filepath):
        print(f"오류: {txt_filepath} 파일을 찾을 수 없습니다.")
        return
    if not os.path.exists(json_filepath):
        print(f"오류: {json_filepath} 파일을 찾을 수 없습니다.")
        return

    unique_entities, unique_relations = parse_txt_data(txt_filepath)

    with open(json_filepath, 'r', encoding='utf-8') as f:
        json_data = json.load(f)

    updated_json_data = update_json_data(json_data, unique_entities, unique_relations)

    with open(json_filepath, 'w', encoding='utf-8') as f:
        json.dump(updated_json_data, f, ensure_ascii=False, indent=4)

if __name__ == "__main__":
    main()

# %%
def generate_knowledge_graph_from_json(json_folder = "./data/extracted_results", output_kg_file = "./data/knowledge_graphs") :
    os.makedirs(output_kg_file, exist_ok=True)

    for filename in os.listdir(json_folder) :
        if filename in os.listdir(json_folder) :
            if filename.endswith(".json") :
                filepath = os.path.join(json_folder, filename)
                all_entities = {}
                all_relations = []
                try :
                    with open(filepath, 'r', encoding="utf-8") as f :
                        data = json.load(f)
                    for entity in data.get("entities", []) :
                        name = entity.get("name")
                        entity_type = entity.get("type")
                        if name and entity_type :
                            all_entities[name] = entity_type

                    for relation in data.get("relations", []) :
                        head = relation.get("head")
                        rel_type = relation.get("relation")
                        tail = relation.get("tail")
                        if head and rel_type and tail :
                            all_relations.append({"head" : head, "relation" : rel_type, "tail" : tail})

                    base_filename = os.path.splitext(filename)[0]
                    output_kg_file = os.path.join(output_kg_file, f"{base_filename}_kg.txt")

                    with open(output_kg_file, 'w', encoding="utf-8") as f :
                        f.write("<엔티티> : \n")
                        for name in sorted(all_entities.keys()) :
                            f.write(f"Entity : {name}, Type : {all_entities[name]}")
                        f.write("<관계> : \n")
                        for rel in all_relations :
                            f.write(f'Relation : {rel["head"]} -- ({rel["relation"]}) --> {rel["tail"]}\n')

                    print(f"지식 그래프 요약 정보 : {output_kg_file}")
                    print(f"총 {len(all_entities)}개의 고유 엔티티와 {len(all_relations)}개의 관계 추출")
                    print("=" * 100)
                except json.JSONDecodeError as e :
                    print(f"경고 : {filename} 파일 파싱 오류 : {e}")
                except Exception as e :
                    print(f"경고 : {filename} 파일 처리 중 알 수 없는 오류 : {e}")

    

if __name__ == "__main__" : 
    extracted_json_folder = "./data/extracted_results"
    knowledge_graph_output_file = "./data/extracted_results/knowledge_graphs"
    generate_knowledge_graph_from_json(extracted_json_folder, knowledge_graph_output_file)
# Out:
# 지식 그래프 요약 정보 : ./data/extracted_results/knowledge_graphs/1_Embryology_kg.txt
# 총 1130개의 고유 엔티티와 1308개의 관계 추출
# ====================================================================================================

# %%
# Out:
# 이름 : 19998
# ----------------------------------------------------------------------------------------------------
# 타입 : type
