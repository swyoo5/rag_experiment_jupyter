# %% [markdown]
# # Pytesseract

# %%
import io
import os
import fitz
import pytesseract
from PIL import Image

def ocr_pdf_to_text(pdf_path, output_txt_path, lang="kor+eng", dpi=400) :
    if not os.path.exists(pdf_path) :
        print(f"{pdf_path} 경로 없음")
        return
    
    extracted_text = []

    try :
        pdf_document = fitz.open(pdf_path)

        for page_num in range(len(pdf_document)) :
            page = pdf_document.load_page(page_num)

            pix = page.get_pixmap(matrix=fitz.Matrix(dpi/72, dpi/72))

            image_byte_arr = io.BytesIO(pix.tobytes("png"))
            img = Image.open(image_byte_arr)

            text = pytesseract.image_to_string(img, lang=lang, config="--psm 3 --oem 3")
            extracted_text.append(f"--- Page {page_num + 1} --- \n")
            extracted_text.append(text)
            extracted_text.append("\n\n")
            print(f"페이지 {page_num + 1} OCR 완료")

    except Exception as e :
        print(f"PDF 처리 중 오류 : {e}")
        return
    
    finally :
        if "pdf_document" in locals() and pdf_document :
            pdf_document.close()

    try :
        with open(output_txt_path, 'w', encoding="utf-8") as f :
            f.writelines(extracted_text)
        print(f"텍스트 추출 완료 : {output_txt_path}")
    except IOError as e :
        print(f"파일 저장 중 오류 : {e}")

if __name__ == "__main__" :
    input_pdf_file = "./data/KEPIC/KEPIC_FULL.pdf"
    for i in [500, 600] :
        output_text_file = f"./data/KEPIC/kepic_tesseract_{i}.txt"
        ocr_pdf_to_text(input_pdf_file, output_text_file, lang="kor+eng", dpi=i)

    if os.path.exists(output_text_file) :
        with open(output_text_file, 'r', encoding="utf-8") as f :
            print(f.read())
# Out:
# 페이지 1 OCR 완료
# 페이지 2 OCR 완료
# 페이지 3 OCR 완료
# 페이지 4 OCR 완료
# 페이지 5 OCR 완료
# 페이지 6 OCR 완료
# 페이지 7 OCR 완료
# 페이지 8 OCR 완료
# 페이지 9 OCR 완료
# 페이지 10 OCR 완료
# 페이지 11 OCR 완료
# 페이지 12 OCR 완료
# 페이지 13 OCR 완료
# 페이지 14 OCR 완료
# 페이지 15 OCR 완료
# 페이지 16 OCR 완료
# 페이지 17 OCR 완료
# 페이지 18 OCR 완료
# 페이지 19 OCR 완료
# 페이지 20 OCR 완료
# 페이지 21 OCR 완료
# 페이지 22 OCR 완료
# 페이지 23 OCR 완료
# 페이지 24 OCR 완료
# 페이지 25 OCR 완료
# 페이지 26 OCR 완료
# 페이지 27 OCR 완료
# 페이지 28 OCR 완료
# 페이지 29 OCR 완료
# 페이지 30 OCR 완료
# 페이지 31 OCR 완료
# 페이지 32 OCR 완료
# 페이지 33 OCR 완료
# 페이지 34 OCR 완료
# 페이지 35 OCR 완료
# 페이지 36 OCR 완료
# 페이지 37 OCR 완료
# 페이지 38 OCR 완료
# 페이지 39 OCR 완료
# 페이지 40 OCR 완료
# 페이지 41 OCR 완료
# 페이지 42 OCR 완료
# 페이지 43 OCR 완료
# 페이지 44 OCR 완료
# 페이지 45 OCR 완료
# 페이지 46 OCR 완료
# 페이지 47 OCR 완료
# 페이지 48 OCR 완료
# 페이지 49 OCR 완료
# 페이지 50 OCR 완료
# 페이지 51 OCR 완료
# 페이지 52 OCR 완료
# 페이지 53 OCR 완료
# 페이지 54 OCR 완료
# 페이지 55 OCR 완료
# 페이지 56 OCR 완료
# 페이지 57 OCR 완료
# 페이지 58 OCR 완료
# 페이지 59 OCR 완료
# 페이지 60 OCR 완료
# 페이지 61 OCR 완료
# 페이지 62 OCR 완료
# 페이지 63 OCR 완료
# 페이지 64 OCR 완료
# 페이지 65 OCR 완료
# 페이지 66 OCR 완료
# 페이지 67 OCR 완료
# 페이지 68 OCR 완료
# 페이지 69 OCR 완료
# 페이지 70 OCR 완료
# 페이지 71 OCR 완료
# 페이지 72 OCR 완료
# 페이지 73 OCR 완료
# 페이지 74 OCR 완료
# 페이지 75 OCR 완료
# 페이지 76 OCR 완료
# 페이지 77 OCR 완료
# 페이지 78 OCR 완료
# 페이지 79 OCR 완료
# 페이지 80 OCR 완료
# 페이지 81 OCR 완료
# 페이지 82 OCR 완료
# 페이지 83 OCR 완료
# 페이지 84 OCR 완료
# 페이지 85 OCR 완료
# 페이지 86 OCR 완료
# 페이지 87 OCR 완료
# 페이지 88 OCR 완료
# 페이지 89 OCR 완료
# 페이지 90 OCR 완료
# 페이지 91 OCR 완료
# 페이지 92 OCR 완료
# 페이지 93 OCR 완료
# 페이지 94 OCR 완료
# 페이지 95 OCR 완료
# 페이지 96 OCR 완료
# 페이지 97 OCR 완료
# 페이지 98 OCR 완료
# 페이지 99 OCR 완료
# 페이지 100 OCR 완료
# 페이지 101 OCR 완료
# 페이지 102 OCR 완료
# 페이지 103 OCR 완료
# 페이지 104 OCR 완료
# 페이지 105 OCR 완료
# 페이지 106 OCR 완료
# 페이지 107 OCR 완료
# 페이지 108 OCR 완료
# 페이지 109 OCR 완료
# 페이지 110 OCR 완료
# 페이지 111 OCR 완료
# 페이지 112 OCR 완료
# 페이지 113 OCR 완료
# 페이지 114 OCR 완료
# 페이지 115 OCR 완료
# 페이지 116 OCR 완료
# 페이지 117 OCR 완료
# 페이지 118 OCR 완료
# 페이지 119 OCR 완료
# 페이지 120 OCR 완료
# 페이지 121 OCR 완료
# 페이지 122 OCR 완료
# 페이지 123 OCR 완료
# 페이지 124 OCR 완료
# 페이지 125 OCR 완료
# 페이지 126 OCR 완료
# 페이지 127 OCR 완료
# 페이지 128 OCR 완료
# 페이지 129 OCR 완료
# 페이지 130 OCR 완료
# 페이지 131 OCR 완료
# 페이지 132 OCR 완료
# 페이지 133 OCR 완료
# 페이지 134 OCR 완료
# 페이지 135 OCR 완료
# 페이지 136 OCR 완료
# 페이지 137 OCR 완료
# 페이지 138 OCR 완료
# 페이지 139 OCR 완료
# 페이지 140 OCR 완료
# 페이지 141 OCR 완료
# 페이지 142 OCR 완료
# 페이지 143 OCR 완료
# 페이지 144 OCR 완료
# 페이지 145 OCR 완료
# 페이지 146 OCR 완료
# 페이지 147 OCR 완료
# 페이지 148 OCR 완료
# 페이지 149 OCR 완료
# 페이지 150 OCR 완료
# 페이지 151 OCR 완료
# 페이지 152 OCR 완료
# 페이지 153 OCR 완료
# 페이지 154 OCR 완료
# 페이지 155 OCR 완료
# 페이지 156 OCR 완료
# 페이지 157 OCR 완료
# 페이지 158 OCR 완료
# 페이지 159 OCR 완료
# 페이지 160 OCR 완료
# 페이지 161 OCR 완료
# 페이지 162 OCR 완료
# 페이지 163 OCR 완료
# 페이지 164 OCR 완료
# 페이지 165 OCR 완료
# 페이지 166 OCR 완료
# 페이지 167 OCR 완료
# 페이지 168 OCR 완료
# 페이지 169 OCR 완료
# 페이지 170 OCR 완료
# 페이지 171 OCR 완료
# 페이지 172 OCR 완료
# 페이지 173 OCR 완료
# 페이지 174 OCR 완료
# 페이지 175 OCR 완료
# 페이지 176 OCR 완료
# 페이지 177 OCR 완료
# 페이지 178 OCR 완료
# 페이지 179 OCR 완료
# 페이지 180 OCR 완료
# 페이지 181 OCR 완료
# 페이지 182 OCR 완료
# 페이지 183 OCR 완료
# 페이지 184 OCR 완료
# 페이지 185 OCR 완료
# 페이지 186 OCR 완료
# 페이지 187 OCR 완료
# 페이지 188 OCR 완료
# 페이지 189 OCR 완료
# 페이지 190 OCR 완료
# 페이지 191 OCR 완료
# 페이지 192 OCR 완료
# 페이지 193 OCR 완료
# 페이지 194 OCR 완료
# 페이지 195 OCR 완료
# 페이지 196 OCR 완료
# 페이지 197 OCR 완료
# 페이지 198 OCR 완료
# 페이지 199 OCR 완료
# 페이지 200 OCR 완료
# 페이지 201 OCR 완료
# 페이지 202 OCR 완료
# 페이지 203 OCR 완료
# 페이지 204 OCR 완료
# 페이지 205 OCR 완료
# 페이지 206 OCR 완료
# 페이지 207 OCR 완료
# 페이지 208 OCR 완료
# 페이지 209 OCR 완료
# 페이지 210 OCR 완료
# 페이지 211 OCR 완료
# 페이지 212 OCR 완료
# 페이지 213 OCR 완료
# 페이지 214 OCR 완료
# 페이지 215 OCR 완료
# 페이지 216 OCR 완료
# 페이지 217 OCR 완료
# 페이지 218 OCR 완료
# 페이지 219 OCR 완료
# 페이지 220 OCR 완료
# 페이지 221 OCR 완료
# 페이지 222 OCR 완료
# 페이지 223 OCR 완료
# 페이지 224 OCR 완료
# 페이지 225 OCR 완료
# 페이지 226 OCR 완료
# 페이지 227 OCR 완료
# 페이지 228 OCR 완료
# 페이지 229 OCR 완료
# 페이지 230 OCR 완료
# 페이지 231 OCR 완료
# 페이지 232 OCR 완료
# 페이지 233 OCR 완료
# 페이지 234 OCR 완료
# 페이지 235 OCR 완료
# 페이지 236 OCR 완료
# 페이지 237 OCR 완료
# 페이지 238 OCR 완료
# 페이지 239 OCR 완료
# 페이지 240 OCR 완료
# 페이지 241 OCR 완료
# 페이지 242 OCR 완료
# 페이지 243 OCR 완료
# 페이지 244 OCR 완료
# 페이지 245 OCR 완료
# 페이지 246 OCR 완료
# 페이지 247 OCR 완료
# 페이지 248 OCR 완료
# 페이지 249 OCR 완료
# 페이지 250 OCR 완료
# 페이지 251 OCR 완료
# 페이지 252 OCR 완료
# 페이지 253 OCR 완료
# 페이지 254 OCR 완료
# 페이지 255 OCR 완료
# 페이지 256 OCR 완료
# 페이지 257 OCR 완료
# 페이지 258 OCR 완료
# 페이지 259 OCR 완료
# 페이지 260 OCR 완료
# 페이지 261 OCR 완료
# 페이지 262 OCR 완료
# 페이지 263 OCR 완료
# 페이지 264 OCR 완료
# 페이지 265 OCR 완료
# 페이지 266 OCR 완료
# 페이지 267 OCR 완료
# 페이지 268 OCR 완료
# 페이지 269 OCR 완료
# 페이지 270 OCR 완료
# 페이지 271 OCR 완료
# 페이지 272 OCR 완료
# 페이지 273 OCR 완료
# 페이지 274 OCR 완료
# 페이지 275 OCR 완료
# 페이지 276 OCR 완료
# 페이지 277 OCR 완료
# 페이지 278 OCR 완료
# 페이지 279 OCR 완료
# 페이지 280 OCR 완료
# 페이지 281 OCR 완료
# 페이지 282 OCR 완료
# 페이지 283 OCR 완료
# 페이지 284 OCR 완료
# 페이지 285 OCR 완료
# 페이지 286 OCR 완료
# 페이지 287 OCR 완료
# 페이지 288 OCR 완료
# 페이지 289 OCR 완료
# 페이지 290 OCR 완료
# 페이지 291 OCR 완료
# 페이지 292 OCR 완료
# 페이지 293 OCR 완료
# 페이지 294 OCR 완료
# 페이지 295 OCR 완료
# 페이지 296 OCR 완료
# 페이지 297 OCR 완료
# 페이지 298 OCR 완료
# 페이지 299 OCR 완료
# 페이지 300 OCR 완료
# 페이지 301 OCR 완료
# 페이지 302 OCR 완료
# 페이지 303 OCR 완료
# 페이지 304 OCR 완료
# 페이지 305 OCR 완료
# 페이지 306 OCR 완료
# 페이지 307 OCR 완료
# 페이지 308 OCR 완료
# 페이지 309 OCR 완료
# 페이지 310 OCR 완료
# 페이지 311 OCR 완료
# 페이지 312 OCR 완료
# 페이지 313 OCR 완료
# 페이지 314 OCR 완료
# 페이지 315 OCR 완료
# 페이지 316 OCR 완료
# 페이지 317 OCR 완료
# 페이지 318 OCR 완료
# 페이지 319 OCR 완료
# 페이지 320 OCR 완료
# 페이지 321 OCR 완료
# 페이지 322 OCR 완료
# 페이지 323 OCR 완료
# 페이지 324 OCR 완료
# 페이지 325 OCR 완료
# 페이지 326 OCR 완료
# 페이지 327 OCR 완료
# 페이지 328 OCR 완료
# 페이지 329 OCR 완료
# 페이지 330 OCR 완료
# 페이지 331 OCR 완료
# 페이지 332 OCR 완료
# 페이지 333 OCR 완료
# 페이지 334 OCR 완료
# 페이지 335 OCR 완료
# 페이지 336 OCR 완료
# 페이지 337 OCR 완료
# 페이지 338 OCR 완료
# 페이지 339 OCR 완료
# 페이지 340 OCR 완료
# 페이지 341 OCR 완료
# 페이지 342 OCR 완료
# 페이지 343 OCR 완료
# 페이지 344 OCR 완료
# 페이지 345 OCR 완료
# 페이지 346 OCR 완료
# 페이지 347 OCR 완료
# 페이지 348 OCR 완료
# 페이지 349 OCR 완료
# 페이지 350 OCR 완료
# 페이지 351 OCR 완료
# 페이지 352 OCR 완료
# 페이지 353 OCR 완료
# 페이지 354 OCR 완료
# 페이지 355 OCR 완료
# 페이지 356 OCR 완료
# 페이지 357 OCR 완료
# 페이지 358 OCR 완료
# 페이지 359 OCR 완료
# 페이지 360 OCR 완료
# 페이지 361 OCR 완료
# 페이지 362 OCR 완료
# 페이지 363 OCR 완료
# 페이지 364 OCR 완료
# 페이지 365 OCR 완료
# 페이지 366 OCR 완료
# 페이지 367 OCR 완료
# 페이지 368 OCR 완료
# 페이지 369 OCR 완료
# 페이지 370 OCR 완료
# 페이지 371 OCR 완료
# 페이지 372 OCR 완료
# 페이지 373 OCR 완료
# 페이지 374 OCR 완료
# 페이지 375 OCR 완료
# 페이지 376 OCR 완료
# 페이지 377 OCR 완료
# 페이지 378 OCR 완료
# 페이지 379 OCR 완료
# 페이지 380 OCR 완료
# 페이지 381 OCR 완료
# 페이지 382 OCR 완료
# 페이지 383 OCR 완료
# 페이지 384 OCR 완료
# 페이지 385 OCR 완료
# 페이지 386 OCR 완료
# 페이지 387 OCR 완료
# 페이지 388 OCR 완료
# 페이지 389 OCR 완료
# 페이지 390 OCR 완료
# 페이지 391 OCR 완료
# 페이지 392 OCR 완료
# 페이지 393 OCR 완료
# 페이지 394 OCR 완료
# 페이지 395 OCR 완료
# 페이지 396 OCR 완료
# 페이지 397 OCR 완료
# 페이지 398 OCR 완료
# 페이지 399 OCR 완료
# 페이지 400 OCR 완료
# 페이지 401 OCR 완료
# 페이지 402 OCR 완료
# 페이지 403 OCR 완료
# 페이지 404 OCR 완료
# 페이지 405 OCR 완료
# 페이지 406 OCR 완료
# 페이지 407 OCR 완료
# 페이지 408 OCR 완료
# 페이지 409 OCR 완료
# 페이지 410 OCR 완료
# 페이지 411 OCR 완료
# 페이지 412 OCR 완료
# 페이지 413 OCR 완료
# 페이지 414 OCR 완료
# 페이지 415 OCR 완료
# 페이지 416 OCR 완료
# 페이지 417 OCR 완료
# 페이지 418 OCR 완료
# 페이지 419 OCR 완료
# 페이지 420 OCR 완료
# 페이지 421 OCR 완료
# 페이지 422 OCR 완료
# 페이지 423 OCR 완료
# 페이지 424 OCR 완료
# 페이지 425 OCR 완료
# 페이지 426 OCR 완료
# 페이지 427 OCR 완료
# 페이지 428 OCR 완료
# 페이지 429 OCR 완료
# 페이지 430 OCR 완료
# 페이지 431 OCR 완료
# 페이지 432 OCR 완료
# 페이지 433 OCR 완료
# 페이지 434 OCR 완료
# 페이지 435 OCR 완료
# 페이지 436 OCR 완료
# 페이지 437 OCR 완료
# 페이지 438 OCR 완료
# 페이지 439 OCR 완료
# 페이지 440 OCR 완료
# 페이지 441 OCR 완료
# 페이지 442 OCR 완료
# 페이지 443 OCR 완료
# 페이지 444 OCR 완료
# 페이지 445 OCR 완료
# 페이지 446 OCR 완료
# 페이지 447 OCR 완료
# 페이지 448 OCR 완료
# 페이지 449 OCR 완료
# 페이지 450 OCR 완료
# 페이지 451 OCR 완료
# 페이지 452 OCR 완료
# 페이지 453 OCR 완료
# 페이지 454 OCR 완료
# 페이지 455 OCR 완료
# 페이지 456 OCR 완료
# 페이지 457 OCR 완료
# 페이지 458 OCR 완료
# 페이지 459 OCR 완료
# 페이지 460 OCR 완료
# 페이지 461 OCR 완료
# 페이지 462 OCR 완료
# 페이지 463 OCR 완료
# 페이지 464 OCR 완료
# 페이지 465 OCR 완료
# 페이지 466 OCR 완료
# 페이지 467 OCR 완료
# 페이지 468 OCR 완료
# 페이지 469 OCR 완료
# 페이지 470 OCR 완료
# 페이지 471 OCR 완료
# 페이지 472 OCR 완료
# 페이지 473 OCR 완료
# 페이지 474 OCR 완료
# 페이지 475 OCR 완료
# 페이지 476 OCR 완료
# 페이지 477 OCR 완료
# 페이지 478 OCR 완료
# 페이지 479 OCR 완료
# 페이지 480 OCR 완료
# 페이지 481 OCR 완료
# 페이지 482 OCR 완료
# 페이지 483 OCR 완료
# 페이지 484 OCR 완료
# 페이지 485 OCR 완료
# 페이지 486 OCR 완료
# 페이지 487 OCR 완료
# 페이지 488 OCR 완료
# 페이지 489 OCR 완료
# 페이지 490 OCR 완료
# 페이지 491 OCR 완료
# 페이지 492 OCR 완료
# 페이지 493 OCR 완료
# 페이지 494 OCR 완료
# 페이지 495 OCR 완료
# 페이지 496 OCR 완료
# 페이지 497 OCR 완료
# 페이지 498 OCR 완료
# 페이지 499 OCR 완료
# 페이지 500 OCR 완료
# 페이지 501 OCR 완료
# 페이지 502 OCR 완료
# 페이지 503 OCR 완료
# 페이지 504 OCR 완료
# 페이지 505 OCR 완료
# 페이지 506 OCR 완료
# 페이지 507 OCR 완료
# 페이지 508 OCR 완료
# 페이지 509 OCR 완료
# 페이지 510 OCR 완료
# 페이지 511 OCR 완료
# 페이지 512 OCR 완료
# 페이지 513 OCR 완료
# 페이지 514 OCR 완료
# 페이지 515 OCR 완료
# 페이지 516 OCR 완료
# 페이지 517 OCR 완료
# 페이지 518 OCR 완료
# 페이지 519 OCR 완료
# 페이지 520 OCR 완료
# 페이지 521 OCR 완료
# 페이지 522 OCR 완료
# 페이지 523 OCR 완료
# 페이지 524 OCR 완료
# 페이지 525 OCR 완료
# 페이지 526 OCR 완료
# 페이지 527 OCR 완료
# 페이지 528 OCR 완료
# 페이지 529 OCR 완료
# 페이지 530 OCR 완료
# 페이지 531 OCR 완료
# 페이지 532 OCR 완료
# 페이지 533 OCR 완료
# 페이지 534 OCR 완료
# 페이지 535 OCR 완료
# 페이지 536 OCR 완료
# 페이지 537 OCR 완료
# 페이지 538 OCR 완료
# 페이지 539 OCR 완료
# 페이지 540 OCR 완료
# 페이지 541 OCR 완료
# 페이지 542 OCR 완료
# 페이지 543 OCR 완료
# 페이지 544 OCR 완료
# 페이지 545 OCR 완료
# 페이지 546 OCR 완료
# 페이지 547 OCR 완료
# 페이지 548 OCR 완료
# 페이지 549 OCR 완료
# 페이지 550 OCR 완료
# 페이지 551 OCR 완료
# 페이지 552 OCR 완료
# 페이지 553 OCR 완료
# 페이지 554 OCR 완료
# 페이지 555 OCR 완료
# 페이지 556 OCR 완료
# 페이지 557 OCR 완료
# 페이지 558 OCR 완료
# 페이지 559 OCR 완료
# 페이지 560 OCR 완료
# 페이지 561 OCR 완료
# 페이지 562 OCR 완료
# 페이지 563 OCR 완료
# 페이지 564 OCR 완료
# 페이지 565 OCR 완료
# 페이지 566 OCR 완료
# 페이지 567 OCR 완료
# 페이지 568 OCR 완료
# 페이지 569 OCR 완료
# 페이지 570 OCR 완료
# 페이지 571 OCR 완료
# 페이지 572 OCR 완료
# 페이지 573 OCR 완료
# 페이지 574 OCR 완료
# 페이지 575 OCR 완료
# 페이지 576 OCR 완료
# 페이지 577 OCR 완료
# 페이지 578 OCR 완료
# 페이지 579 OCR 완료
# 페이지 580 OCR 완료
# 페이지 581 OCR 완료
# 페이지 582 OCR 완료
# 페이지 583 OCR 완료
# 페이지 584 OCR 완료
# 페이지 585 OCR 완료
# 페이지 586 OCR 완료
# 페이지 587 OCR 완료
# 페이지 588 OCR 완료
# 페이지 589 OCR 완료
# 페이지 590 OCR 완료
# 페이지 591 OCR 완료
# 페이지 592 OCR 완료
# 페이지 593 OCR 완료
# 페이지 594 OCR 완료
# 페이지 595 OCR 완료
# 페이지 596 OCR 완료
# 페이지 597 OCR 완료
# 페이지 598 OCR 완료
# 페이지 599 OCR 완료
# 페이지 600 OCR 완료
# 페이지 601 OCR 완료
# 페이지 602 OCR 완료
# 페이지 603 OCR 완료
# 페이지 604 OCR 완료
# 페이지 605 OCR 완료
# 페이지 606 OCR 완료
# 페이지 607 OCR 완료
# 페이지 608 OCR 완료
# 페이지 609 OCR 완료
# 페이지 610 OCR 완료
# 페이지 611 OCR 완료
# 페이지 612 OCR 완료
# 페이지 613 OCR 완료
# 페이지 614 OCR 완료
# 페이지 615 OCR 완료
# 페이지 616 OCR 완료
# 페이지 617 OCR 완료
# 페이지 618 OCR 완료
# 페이지 619 OCR 완료
# 페이지 620 OCR 완료
# 페이지 621 OCR 완료
# 페이지 622 OCR 완료
# 페이지 623 OCR 완료
# 페이지 624 OCR 완료
# 페이지 625 OCR 완료
# 페이지 626 OCR 완료
# 페이지 627 OCR 완료
# 페이지 628 OCR 완료
# 페이지 629 OCR 완료
# 페이지 630 OCR 완료
# 페이지 631 OCR 완료
# 페이지 632 OCR 완료
# 페이지 633 OCR 완료
# 페이지 634 OCR 완료
# 페이지 635 OCR 완료
# 페이지 636 OCR 완료
# 페이지 637 OCR 완료
# 페이지 638 OCR 완료
# 페이지 639 OCR 완료
# 페이지 640 OCR 완료
# 페이지 641 OCR 완료
# 페이지 642 OCR 완료
# 페이지 643 OCR 완료
# 페이지 644 OCR 완료
# 페이지 645 OCR 완료
# 페이지 646 OCR 완료
# 페이지 647 OCR 완료
# 페이지 648 OCR 완료
# 페이지 649 OCR 완료
# 페이지 650 OCR 완료
# 페이지 651 OCR 완료
# 페이지 652 OCR 완료
# 페이지 653 OCR 완료
# 페이지 654 OCR 완료
# 페이지 655 OCR 완료
# 페이지 656 OCR 완료
# 페이지 657 OCR 완료
# 페이지 658 OCR 완료
# 페이지 659 OCR 완료
# 페이지 660 OCR 완료
# 페이지 661 OCR 완료
# 페이지 662 OCR 완료
# 페이지 663 OCR 완료
# 페이지 664 OCR 완료
# 페이지 665 OCR 완료
# 페이지 666 OCR 완료
# 페이지 667 OCR 완료
# 페이지 668 OCR 완료
# 페이지 669 OCR 완료
# 페이지 670 OCR 완료
# 페이지 671 OCR 완료
# 페이지 672 OCR 완료
# 페이지 673 OCR 완료
# 페이지 674 OCR 완료
# 페이지 675 OCR 완료
# 페이지 676 OCR 완료
# 페이지 677 OCR 완료
# 페이지 678 OCR 완료
# 페이지 679 OCR 완료
# 페이지 680 OCR 완료
# 페이지 681 OCR 완료
# 페이지 682 OCR 완료
# 페이지 683 OCR 완료
# 페이지 684 OCR 완료
# 페이지 685 OCR 완료
# 페이지 686 OCR 완료
# 페이지 687 OCR 완료
# 페이지 688 OCR 완료
# 페이지 689 OCR 완료
# 페이지 690 OCR 완료
# 페이지 691 OCR 완료
# 페이지 692 OCR 완료
# 페이지 693 OCR 완료
# 페이지 694 OCR 완료
# 페이지 695 OCR 완료
# 페이지 696 OCR 완료
# 페이지 697 OCR 완료
# 페이지 698 OCR 완료
# 페이지 699 OCR 완료
# 페이지 700 OCR 완료
# 페이지 701 OCR 완료
# 페이지 702 OCR 완료
# 페이지 703 OCR 완료
# 페이지 704 OCR 완료
# 페이지 705 OCR 완료
# 페이지 706 OCR 완료
# 페이지 707 OCR 완료
# 페이지 708 OCR 완료
# 페이지 709 OCR 완료
# 페이지 710 OCR 완료
# 페이지 711 OCR 완료
# 페이지 712 OCR 완료
# 페이지 713 OCR 완료
# 페이지 714 OCR 완료
# 페이지 715 OCR 완료
# 페이지 716 OCR 완료
# 페이지 717 OCR 완료
# 페이지 718 OCR 완료
# 페이지 719 OCR 완료
# 페이지 720 OCR 완료
# 페이지 721 OCR 완료
# 페이지 722 OCR 완료
# 페이지 723 OCR 완료
# 페이지 724 OCR 완료
# 페이지 725 OCR 완료
# 페이지 726 OCR 완료
# 페이지 727 OCR 완료
# 페이지 728 OCR 완료
# 페이지 729 OCR 완료
# 페이지 730 OCR 완료
# 페이지 731 OCR 완료
# 페이지 732 OCR 완료
# 페이지 733 OCR 완료
# 페이지 734 OCR 완료
# 페이지 735 OCR 완료
# 페이지 736 OCR 완료
# 페이지 737 OCR 완료
# 페이지 738 OCR 완료
# 페이지 739 OCR 완료
# 페이지 740 OCR 완료
# 페이지 741 OCR 완료
# 페이지 742 OCR 완료
# 페이지 743 OCR 완료
# 페이지 744 OCR 완료
# 페이지 745 OCR 완료
# 페이지 746 OCR 완료
# 페이지 747 OCR 완료
# 페이지 748 OCR 완료
# 페이지 749 OCR 완료
# 페이지 750 OCR 완료
# 페이지 751 OCR 완료
# 페이지 752 OCR 완료
# 페이지 753 OCR 완료
# 페이지 754 OCR 완료
# 페이지 755 OCR 완료
# 페이지 756 OCR 완료
# 페이지 757 OCR 완료
# 페이지 758 OCR 완료
# 페이지 759 OCR 완료
# 페이지 760 OCR 완료
# 페이지 761 OCR 완료
# 페이지 762 OCR 완료
# 페이지 763 OCR 완료
# 페이지 764 OCR 완료
# 페이지 765 OCR 완료
# 페이지 766 OCR 완료
# 페이지 767 OCR 완료
# 페이지 768 OCR 완료
# 페이지 769 OCR 완료
# 페이지 770 OCR 완료
# 페이지 771 OCR 완료
# 페이지 772 OCR 완료
# 페이지 773 OCR 완료
# 페이지 774 OCR 완료
# 페이지 775 OCR 완료
# 페이지 776 OCR 완료
# 페이지 777 OCR 완료
# 페이지 778 OCR 완료
# 페이지 779 OCR 완료
# 페이지 780 OCR 완료
# 페이지 781 OCR 완료
# 페이지 782 OCR 완료
# 페이지 783 OCR 완료
# 페이지 784 OCR 완료
# 페이지 785 OCR 완료
# 페이지 786 OCR 완료
# 페이지 787 OCR 완료
# 페이지 788 OCR 완료
# 페이지 789 OCR 완료
# 페이지 790 OCR 완료
# 페이지 791 OCR 완료
# 페이지 792 OCR 완료
# 페이지 793 OCR 완료
# 페이지 794 OCR 완료
# 페이지 795 OCR 완료
# 페이지 796 OCR 완료
# 페이지 797 OCR 완료
# 페이지 798 OCR 완료
# 페이지 799 OCR 완료
# 페이지 800 OCR 완료
# 페이지 801 OCR 완료
# 페이지 802 OCR 완료
# 페이지 803 OCR 완료
# 페이지 804 OCR 완료
# 페이지 805 OCR 완료
# 페이지 806 OCR 완료
# 페이지 807 OCR 완료
# 페이지 808 OCR 완료
# 페이지 809 OCR 완료
# 페이지 810 OCR 완료
# 페이지 811 OCR 완료
# 페이지 812 OCR 완료
# 페이지 813 OCR 완료
# 페이지 814 OCR 완료
# 페이지 815 OCR 완료
# 페이지 816 OCR 완료
# 페이지 817 OCR 완료
# 페이지 818 OCR 완료
# 페이지 819 OCR 완료
# 페이지 820 OCR 완료
# 페이지 821 OCR 완료
# 페이지 822 OCR 완료
# 페이지 823 OCR 완료
# 페이지 824 OCR 완료
# 페이지 825 OCR 완료
# 페이지 826 OCR 완료
# 페이지 827 OCR 완료
# 페이지 828 OCR 완료
# 페이지 829 OCR 완료
# 페이지 830 OCR 완료
# 페이지 831 OCR 완료
# 페이지 832 OCR 완료
# 페이지 833 OCR 완료
# 페이지 834 OCR 완료
# 페이지 835 OCR 완료
# 페이지 836 OCR 완료
# 페이지 837 OCR 완료
# 페이지 838 OCR 완료
# 페이지 839 OCR 완료
# 페이지 840 OCR 완료
# 페이지 841 OCR 완료
# 페이지 842 OCR 완료
# 페이지 843 OCR 완료
# 페이지 844 OCR 완료
# 페이지 845 OCR 완료
# 페이지 846 OCR 완료
# 페이지 847 OCR 완료
# 페이지 848 OCR 완료
# 페이지 849 OCR 완료
# 페이지 850 OCR 완료
# 페이지 851 OCR 완료
# 페이지 852 OCR 완료
# 페이지 853 OCR 완료
# 페이지 854 OCR 완료
# 페이지 855 OCR 완료
# 페이지 856 OCR 완료
# 페이지 857 OCR 완료
# 페이지 858 OCR 완료
# 페이지 859 OCR 완료
# 페이지 860 OCR 완료
# 페이지 861 OCR 완료
# 페이지 862 OCR 완료
# 페이지 863 OCR 완료
# 페이지 864 OCR 완료
# 페이지 865 OCR 완료
# 페이지 866 OCR 완료
# 페이지 867 OCR 완료
# 페이지 868 OCR 완료
# 페이지 869 OCR 완료
# 페이지 870 OCR 완료
# 페이지 871 OCR 완료
# 페이지 872 OCR 완료
# 페이지 873 OCR 완료
# 페이지 874 OCR 완료
# 페이지 875 OCR 완료
# 페이지 876 OCR 완료
# 페이지 877 OCR 완료
# 페이지 878 OCR 완료
# 페이지 879 OCR 완료
# 페이지 880 OCR 완료
# 페이지 881 OCR 완료
# 페이지 882 OCR 완료
# 페이지 883 OCR 완료
# 페이지 884 OCR 완료
# 페이지 885 OCR 완료
# 페이지 886 OCR 완료
# 페이지 887 OCR 완료
# 페이지 888 OCR 완료
# 페이지 889 OCR 완료
# 페이지 890 OCR 완료
# 페이지 891 OCR 완료
# 페이지 892 OCR 완료
# 페이지 893 OCR 완료
# 페이지 894 OCR 완료
# 페이지 895 OCR 완료
# 페이지 896 OCR 완료
# 페이지 897 OCR 완료
# 페이지 898 OCR 완료
# 페이지 899 OCR 완료
# 페이지 900 OCR 완료
# 페이지 901 OCR 완료
# 페이지 902 OCR 완료
# 페이지 903 OCR 완료
# 페이지 904 OCR 완료
# 페이지 905 OCR 완료
# 페이지 906 OCR 완료
# 페이지 907 OCR 완료
# 페이지 908 OCR 완료
# 페이지 909 OCR 완료
# 페이지 910 OCR 완료
# 페이지 911 OCR 완료
# 페이지 912 OCR 완료
# 페이지 913 OCR 완료
# 페이지 914 OCR 완료
# 페이지 915 OCR 완료
# 페이지 916 OCR 완료
# 페이지 917 OCR 완료
# 페이지 918 OCR 완료
# 페이지 919 OCR 완료
# 페이지 920 OCR 완료
# 페이지 921 OCR 완료
# 페이지 922 OCR 완료
# 페이지 923 OCR 완료
# 페이지 924 OCR 완료
# 페이지 925 OCR 완료
# 페이지 926 OCR 완료
# 페이지 927 OCR 완료
# 페이지 928 OCR 완료
# 페이지 929 OCR 완료
# 페이지 930 OCR 완료
# 페이지 931 OCR 완료
# 페이지 932 OCR 완료
# 페이지 933 OCR 완료
# 페이지 934 OCR 완료
# 페이지 935 OCR 완료
# 페이지 936 OCR 완료
# 페이지 937 OCR 완료
# 페이지 938 OCR 완료
# 페이지 939 OCR 완료
# 페이지 940 OCR 완료
# 페이지 941 OCR 완료
# 페이지 942 OCR 완료
# 페이지 943 OCR 완료
# 페이지 944 OCR 완료
# 페이지 945 OCR 완료
# 페이지 946 OCR 완료
# 페이지 947 OCR 완료
# 페이지 948 OCR 완료
# 페이지 949 OCR 완료
# 페이지 950 OCR 완료
# 페이지 951 OCR 완료
# 페이지 952 OCR 완료
# 페이지 953 OCR 완료
# 페이지 954 OCR 완료
# 페이지 955 OCR 완료
# 페이지 956 OCR 완료
# 페이지 957 OCR 완료
# 페이지 958 OCR 완료
# 페이지 959 OCR 완료
# 페이지 960 OCR 완료
# 페이지 961 OCR 완료
# 페이지 962 OCR 완료
# 페이지 963 OCR 완료
# 페이지 964 OCR 완료
# 페이지 965 OCR 완료
# 페이지 966 OCR 완료
# 페이지 967 OCR 완료
# 페이지 968 OCR 완료
# 페이지 969 OCR 완료
# 페이지 970 OCR 완료
# 페이지 971 OCR 완료
# 페이지 972 OCR 완료
# 페이지 973 OCR 완료
# 페이지 974 OCR 완료
# 페이지 975 OCR 완료
# 페이지 976 OCR 완료
# 페이지 977 OCR 완료
# 페이지 978 OCR 완료
# 페이지 979 OCR 완료
# 페이지 980 OCR 완료
# 페이지 981 OCR 완료
# 페이지 982 OCR 완료
# 페이지 983 OCR 완료
# 페이지 984 OCR 완료
# 페이지 985 OCR 완료
# 페이지 986 OCR 완료
# 페이지 987 OCR 완료
# 페이지 988 OCR 완료
# 페이지 989 OCR 완료
# 페이지 990 OCR 완료
# 페이지 991 OCR 완료
# 페이지 992 OCR 완료
# 페이지 993 OCR 완료
# 페이지 994 OCR 완료
# 페이지 995 OCR 완료
# 페이지 996 OCR 완료
# 페이지 997 OCR 완료
# 페이지 998 OCR 완료
# 페이지 999 OCR 완료
# 페이지 1000 OCR 완료
# 페이지 1001 OCR 완료
# 페이지 1002 OCR 완료
# 페이지 1003 OCR 완료
# 페이지 1004 OCR 완료
# 페이지 1005 OCR 완료
# 페이지 1006 OCR 완료
# 페이지 1007 OCR 완료
# 페이지 1008 OCR 완료
# 페이지 1009 OCR 완료
# 페이지 1010 OCR 완료
# 페이지 1011 OCR 완료
# 페이지 1012 OCR 완료
# 페이지 1013 OCR 완료
# 페이지 1014 OCR 완료
# 페이지 1015 OCR 완료
# 페이지 1016 OCR 완료
# 페이지 1017 OCR 완료
# 페이지 1018 OCR 완료
# 페이지 1019 OCR 완료
# 페이지 1020 OCR 완료
# 페이지 1021 OCR 완료
# 페이지 1022 OCR 완료
# 페이지 1023 OCR 완료
# 페이지 1024 OCR 완료
# 페이지 1025 OCR 완료
# 페이지 1026 OCR 완료
# 페이지 1027 OCR 완료
# 페이지 1028 OCR 완료
# 페이지 1029 OCR 완료
# 페이지 1030 OCR 완료
# 페이지 1031 OCR 완료
# 페이지 1032 OCR 완료
# 페이지 1033 OCR 완료
# 페이지 1034 OCR 완료
# 페이지 1035 OCR 완료
# 페이지 1036 OCR 완료
# 페이지 1037 OCR 완료
# 페이지 1038 OCR 완료
# 페이지 1039 OCR 완료
# 페이지 1040 OCR 완료
# 페이지 1041 OCR 완료
# 페이지 1042 OCR 완료
# 페이지 1043 OCR 완료
# 페이지 1044 OCR 완료
# 페이지 1045 OCR 완료
# 페이지 1046 OCR 완료
# 페이지 1047 OCR 완료
# 페이지 1048 OCR 완료
# 페이지 1049 OCR 완료
# 페이지 1050 OCR 완료
# 페이지 1051 OCR 완료
# 페이지 1052 OCR 완료
# 페이지 1053 OCR 완료
# 페이지 1054 OCR 완료
# 페이지 1055 OCR 완료
# 페이지 1056 OCR 완료
# 페이지 1057 OCR 완료
# 페이지 1058 OCR 완료
# 페이지 1059 OCR 완료
# 페이지 1060 OCR 완료
# 페이지 1061 OCR 완료
# 페이지 1062 OCR 완료
# 페이지 1063 OCR 완료
# 페이지 1064 OCR 완료
# 페이지 1065 OCR 완료
# 페이지 1066 OCR 완료
# 페이지 1067 OCR 완료
# 페이지 1068 OCR 완료
# 페이지 1069 OCR 완료
# 페이지 1070 OCR 완료
# 페이지 1071 OCR 완료
# 페이지 1072 OCR 완료
# 페이지 1073 OCR 완료
# 페이지 1074 OCR 완료
# 페이지 1075 OCR 완료
# 페이지 1076 OCR 완료
# 페이지 1077 OCR 완료
# 페이지 1078 OCR 완료
# 페이지 1079 OCR 완료
# 페이지 1080 OCR 완료
# 페이지 1081 OCR 완료
# 페이지 1082 OCR 완료
# 페이지 1083 OCR 완료
# 페이지 1084 OCR 완료
# 페이지 1085 OCR 완료
# 페이지 1086 OCR 완료
# 페이지 1087 OCR 완료
# 페이지 1088 OCR 완료
# 페이지 1089 OCR 완료
# 페이지 1090 OCR 완료
# 페이지 1091 OCR 완료
# 페이지 1092 OCR 완료
# 페이지 1093 OCR 완료
# 페이지 1094 OCR 완료
# 페이지 1095 OCR 완료
# 페이지 1096 OCR 완료
# 페이지 1097 OCR 완료
# 페이지 1098 OCR 완료
# 페이지 1099 OCR 완료
# 페이지 1100 OCR 완료
# 페이지 1101 OCR 완료
# 페이지 1102 OCR 완료
# 페이지 1103 OCR 완료
# 페이지 1104 OCR 완료
# 페이지 1105 OCR 완료
# 페이지 1106 OCR 완료
# 페이지 1107 OCR 완료
# 페이지 1108 OCR 완료
# 페이지 1109 OCR 완료
# 페이지 1110 OCR 완료
# 페이지 1111 OCR 완료
# 페이지 1112 OCR 완료
# 페이지 1113 OCR 완료
# 페이지 1114 OCR 완료
# 페이지 1115 OCR 완료
# 페이지 1116 OCR 완료
# 페이지 1117 OCR 완료
# 페이지 1118 OCR 완료
# 페이지 1119 OCR 완료
# 페이지 1120 OCR 완료
# 페이지 1121 OCR 완료
# 페이지 1122 OCR 완료
# 페이지 1123 OCR 완료
# 페이지 1124 OCR 완료
# 페이지 1125 OCR 완료
# 페이지 1126 OCR 완료
# 페이지 1127 OCR 완료
# 페이지 1128 OCR 완료
# 페이지 1129 OCR 완료
# 페이지 1130 OCR 완료
# 페이지 1131 OCR 완료
# 페이지 1132 OCR 완료
# 페이지 1133 OCR 완료
# 페이지 1134 OCR 완료
# 페이지 1135 OCR 완료
# 페이지 1136 OCR 완료
# 페이지 1137 OCR 완료
# 페이지 1138 OCR 완료
# 페이지 1139 OCR 완료
# 페이지 1140 OCR 완료
# 페이지 1141 OCR 완료
# 페이지 1142 OCR 완료
# 페이지 1143 OCR 완료
# 페이지 1144 OCR 완료
# 페이지 1145 OCR 완료
# 페이지 1146 OCR 완료
# 페이지 1147 OCR 완료
# 페이지 1148 OCR 완료
# 페이지 1149 OCR 완료
# 페이지 1150 OCR 완료
# 페이지 1151 OCR 완료
# 페이지 1152 OCR 완료
# 페이지 1153 OCR 완료
# 페이지 1154 OCR 완료
# 페이지 1155 OCR 완료
# 페이지 1156 OCR 완료
# 페이지 1157 OCR 완료
# 페이지 1158 OCR 완료
# 페이지 1159 OCR 완료
# 페이지 1160 OCR 완료
# 페이지 1161 OCR 완료
# 페이지 1162 OCR 완료
# 페이지 1163 OCR 완료
# 페이지 1164 OCR 완료
# 페이지 1165 OCR 완료
# 페이지 1166 OCR 완료
# 페이지 1167 OCR 완료
# 페이지 1168 OCR 완료
# 페이지 1169 OCR 완료
# 페이지 1170 OCR 완료
# 페이지 1171 OCR 완료
# 페이지 1172 OCR 완료
# 페이지 1173 OCR 완료
# 페이지 1174 OCR 완료
# 페이지 1175 OCR 완료
# 페이지 1176 OCR 완료
# 페이지 1177 OCR 완료
# 페이지 1178 OCR 완료
# 페이지 1179 OCR 완료
# 페이지 1180 OCR 완료
# 페이지 1181 OCR 완료
# 페이지 1182 OCR 완료
# 페이지 1183 OCR 완료
# 페이지 1184 OCR 완료
# 페이지 1185 OCR 완료
# 페이지 1186 OCR 완료
# 페이지 1187 OCR 완료
# 페이지 1188 OCR 완료
# 페이지 1189 OCR 완료
# 페이지 1190 OCR 완료
# 페이지 1191 OCR 완료
# 페이지 1192 OCR 완료
# 페이지 1193 OCR 완료
# 페이지 1194 OCR 완료
# 페이지 1195 OCR 완료
# 페이지 1196 OCR 완료
# 페이지 1197 OCR 완료
# 페이지 1198 OCR 완료
# 페이지 1199 OCR 완료
# 페이지 1200 OCR 완료
# 페이지 1201 OCR 완료
# 페이지 1202 OCR 완료
# 페이지 1203 OCR 완료
# 페이지 1204 OCR 완료
# 페이지 1205 OCR 완료
# 페이지 1206 OCR 완료
# 페이지 1207 OCR 완료
# 페이지 1208 OCR 완료
# 페이지 1209 OCR 완료
# 페이지 1210 OCR 완료
# 페이지 1211 OCR 완료
# 페이지 1212 OCR 완료
# 페이지 1213 OCR 완료
# 페이지 1214 OCR 완료
# 페이지 1215 OCR 완료
# 페이지 1216 OCR 완료
# 페이지 1217 OCR 완료
# 페이지 1218 OCR 완료
# 페이지 1219 OCR 완료
# 페이지 1220 OCR 완료
# 페이지 1221 OCR 완료
# 페이지 1222 OCR 완료
# 페이지 1223 OCR 완료
# 페이지 1224 OCR 완료
# 페이지 1225 OCR 완료
# 페이지 1226 OCR 완료
# 페이지 1227 OCR 완료
# 페이지 1228 OCR 완료
# 페이지 1229 OCR 완료
# 페이지 1230 OCR 완료
# 페이지 1231 OCR 완료
# 페이지 1232 OCR 완료
# 페이지 1233 OCR 완료
# 페이지 1234 OCR 완료
# 페이지 1235 OCR 완료
# 페이지 1236 OCR 완료
# 페이지 1237 OCR 완료
# 페이지 1238 OCR 완료
# 페이지 1239 OCR 완료
# 페이지 1240 OCR 완료
# 페이지 1241 OCR 완료
# 페이지 1242 OCR 완료
# 페이지 1243 OCR 완료
# 페이지 1244 OCR 완료
# 페이지 1245 OCR 완료
# 페이지 1246 OCR 완료
# 페이지 1247 OCR 완료
# 페이지 1248 OCR 완료
# 페이지 1249 OCR 완료
# 페이지 1250 OCR 완료
# 페이지 1251 OCR 완료
# 페이지 1252 OCR 완료
# 페이지 1253 OCR 완료
# 페이지 1254 OCR 완료
# 페이지 1255 OCR 완료
# 페이지 1256 OCR 완료
# 페이지 1257 OCR 완료
# 페이지 1258 OCR 완료
# 페이지 1259 OCR 완료
# 페이지 1260 OCR 완료
# 페이지 1261 OCR 완료
# 페이지 1262 OCR 완료
# 페이지 1263 OCR 완료
# 페이지 1264 OCR 완료
# 페이지 1265 OCR 완료
# 페이지 1266 OCR 완료
# 페이지 1267 OCR 완료
# 페이지 1268 OCR 완료
# 페이지 1269 OCR 완료
# 페이지 1270 OCR 완료
# 페이지 1271 OCR 완료
# 페이지 1272 OCR 완료
# 페이지 1273 OCR 완료
# 페이지 1274 OCR 완료
# 페이지 1275 OCR 완료
# 페이지 1276 OCR 완료
# 페이지 1277 OCR 완료
# 페이지 1278 OCR 완료
# 페이지 1279 OCR 완료
# 페이지 1280 OCR 완료
# 페이지 1281 OCR 완료
# 페이지 1282 OCR 완료
# 페이지 1283 OCR 완료
# 페이지 1284 OCR 완료
# 페이지 1285 OCR 완료
# 페이지 1286 OCR 완료
# 페이지 1287 OCR 완료
# 페이지 1288 OCR 완료
# 페이지 1289 OCR 완료
# 페이지 1290 OCR 완료
# 페이지 1291 OCR 완료
# 페이지 1292 OCR 완료
# 페이지 1293 OCR 완료
# 페이지 1294 OCR 완료
# 페이지 1295 OCR 완료
# 페이지 1296 OCR 완료
# 페이지 1297 OCR 완료
# 페이지 1298 OCR 완료
# 페이지 1299 OCR 완료
# 페이지 1300 OCR 완료
# 페이지 1301 OCR 완료
# 페이지 1302 OCR 완료
# 페이지 1303 OCR 완료
# 페이지 1304 OCR 완료
# 페이지 1305 OCR 완료
# 페이지 1306 OCR 완료
# 페이지 1307 OCR 완료
# 페이지 1308 OCR 완료
# 페이지 1309 OCR 완료
# 페이지 1310 OCR 완료
# 페이지 1311 OCR 완료
# 페이지 1312 OCR 완료
# 페이지 1313 OCR 완료
# 페이지 1314 OCR 완료
# 페이지 1315 OCR 완료
# 페이지 1316 OCR 완료
# 페이지 1317 OCR 완료
# 페이지 1318 OCR 완료
# 페이지 1319 OCR 완료
# 페이지 1320 OCR 완료
# 페이지 1321 OCR 완료
# 페이지 1322 OCR 완료
# 페이지 1323 OCR 완료
# 페이지 1324 OCR 완료
# 페이지 1325 OCR 완료
# 페이지 1326 OCR 완료
# 페이지 1327 OCR 완료
# 페이지 1328 OCR 완료
# 페이지 1329 OCR 완료
# 페이지 1330 OCR 완료
# 페이지 1331 OCR 완료
# 페이지 1332 OCR 완료
# 페이지 1333 OCR 완료
# 페이지 1334 OCR 완료
# 페이지 1335 OCR 완료
# 페이지 1336 OCR 완료
# 페이지 1337 OCR 완료
# 페이지 1338 OCR 완료
# 페이지 1339 OCR 완료
# 페이지 1340 OCR 완료
# 페이지 1341 OCR 완료
# 페이지 1342 OCR 완료
# 페이지 1343 OCR 완료
# 페이지 1344 OCR 완료
# 페이지 1345 OCR 완료
# 페이지 1346 OCR 완료
# 페이지 1347 OCR 완료
# 페이지 1348 OCR 완료
# 페이지 1349 OCR 완료
# 페이지 1350 OCR 완료
# 페이지 1351 OCR 완료
# 페이지 1352 OCR 완료
# 페이지 1353 OCR 완료
# 페이지 1354 OCR 완료
# 페이지 1355 OCR 완료
# 페이지 1356 OCR 완료
# 페이지 1357 OCR 완료
# 페이지 1358 OCR 완료
# 페이지 1359 OCR 완료
# 페이지 1360 OCR 완료
# 페이지 1361 OCR 완료
# 페이지 1362 OCR 완료
# 페이지 1363 OCR 완료
# 페이지 1364 OCR 완료
# 페이지 1365 OCR 완료
# 페이지 1366 OCR 완료
# 페이지 1367 OCR 완료
# 페이지 1368 OCR 완료
# 페이지 1369 OCR 완료
# 페이지 1370 OCR 완료
# 페이지 1371 OCR 완료
# 페이지 1372 OCR 완료
# 페이지 1373 OCR 완료
# 페이지 1374 OCR 완료
# 페이지 1375 OCR 완료
# 페이지 1376 OCR 완료
# 페이지 1377 OCR 완료
# 페이지 1378 OCR 완료
# 페이지 1379 OCR 완료
# 페이지 1380 OCR 완료
# 페이지 1381 OCR 완료
# 페이지 1382 OCR 완료
# 페이지 1383 OCR 완료
# 페이지 1384 OCR 완료
# 페이지 1385 OCR 완료
# 페이지 1386 OCR 완료
# 페이지 1387 OCR 완료
# 페이지 1388 OCR 완료
# 페이지 1389 OCR 완료
# 페이지 1390 OCR 완료
# 페이지 1391 OCR 완료
# 페이지 1392 OCR 완료
# 페이지 1393 OCR 완료
# 페이지 1394 OCR 완료
# 페이지 1395 OCR 완료
# 페이지 1396 OCR 완료
# 페이지 1397 OCR 완료
# 페이지 1398 OCR 완료
# 페이지 1399 OCR 완료
# 페이지 1400 OCR 완료
# 페이지 1401 OCR 완료
# 페이지 1402 OCR 완료
# 페이지 1403 OCR 완료
# 페이지 1404 OCR 완료
# 페이지 1405 OCR 완료
# 페이지 1406 OCR 완료
# 페이지 1407 OCR 완료
# 페이지 1408 OCR 완료
# 페이지 1409 OCR 완료
# 페이지 1410 OCR 완료
# 페이지 1411 OCR 완료
# 페이지 1412 OCR 완료
# 페이지 1413 OCR 완료
# 페이지 1414 OCR 완료
# 페이지 1415 OCR 완료
# 페이지 1416 OCR 완료
# 페이지 1417 OCR 완료
# 페이지 1418 OCR 완료
# 페이지 1419 OCR 완료
# 페이지 1420 OCR 완료
# 페이지 1421 OCR 완료
# 페이지 1422 OCR 완료
# 페이지 1423 OCR 완료
# 페이지 1424 OCR 완료
# 페이지 1425 OCR 완료
# 페이지 1426 OCR 완료
# 페이지 1427 OCR 완료
# 페이지 1428 OCR 완료
# 페이지 1429 OCR 완료
# 페이지 1430 OCR 완료
# 페이지 1431 OCR 완료
# 페이지 1432 OCR 완료
# 페이지 1433 OCR 완료
# 페이지 1434 OCR 완료
# 페이지 1435 OCR 완료
# 페이지 1436 OCR 완료
# 페이지 1437 OCR 완료
# 페이지 1438 OCR 완료
# 페이지 1439 OCR 완료
# 페이지 1440 OCR 완료
# 페이지 1441 OCR 완료
# 페이지 1442 OCR 완료
# 페이지 1443 OCR 완료
# 페이지 1444 OCR 완료
# 페이지 1445 OCR 완료
# 페이지 1446 OCR 완료
# 페이지 1447 OCR 완료
# 페이지 1448 OCR 완료
# 페이지 1449 OCR 완료
# 페이지 1450 OCR 완료
# 페이지 1451 OCR 완료
# 페이지 1452 OCR 완료
# 페이지 1453 OCR 완료
# 페이지 1454 OCR 완료
# 페이지 1455 OCR 완료
# 페이지 1456 OCR 완료
# 페이지 1457 OCR 완료
# 페이지 1458 OCR 완료
# 페이지 1459 OCR 완료
# 페이지 1460 OCR 완료
# 페이지 1461 OCR 완료
# 페이지 1462 OCR 완료
# 페이지 1463 OCR 완료
# 페이지 1464 OCR 완료
# 페이지 1465 OCR 완료
# 페이지 1466 OCR 완료
# 페이지 1467 OCR 완료
# 페이지 1468 OCR 완료
# 페이지 1469 OCR 완료
# 페이지 1470 OCR 완료
# 페이지 1471 OCR 완료
# 페이지 1472 OCR 완료
# 페이지 1473 OCR 완료
# 페이지 1474 OCR 완료
# 페이지 1475 OCR 완료
# 페이지 1476 OCR 완료
# 페이지 1477 OCR 완료
# 페이지 1478 OCR 완료
# 페이지 1479 OCR 완료
# 페이지 1480 OCR 완료
# 페이지 1481 OCR 완료
# 페이지 1482 OCR 완료
# 페이지 1483 OCR 완료
# 페이지 1484 OCR 완료
# 페이지 1485 OCR 완료
# 페이지 1486 OCR 완료
# 페이지 1487 OCR 완료
# 페이지 1488 OCR 완료
# 페이지 1489 OCR 완료
# 페이지 1490 OCR 완료
# 페이지 1491 OCR 완료
# 페이지 1492 OCR 완료
# 페이지 1493 OCR 완료
# 페이지 1494 OCR 완료
# 페이지 1495 OCR 완료
# 페이지 1496 OCR 완료
# 페이지 1497 OCR 완료
# 페이지 1498 OCR 완료
# 페이지 1499 OCR 완료
# 페이지 1500 OCR 완료
# 페이지 1501 OCR 완료
# 페이지 1502 OCR 완료
# 페이지 1503 OCR 완료
# 페이지 1504 OCR 완료
# 페이지 1505 OCR 완료
# 페이지 1506 OCR 완료
# 페이지 1507 OCR 완료
# 페이지 1508 OCR 완료
# 페이지 1509 OCR 완료
# 페이지 1510 OCR 완료
# 페이지 1511 OCR 완료
# 페이지 1512 OCR 완료
# 페이지 1513 OCR 완료
# 페이지 1514 OCR 완료
# 페이지 1515 OCR 완료
# 페이지 1516 OCR 완료
# 페이지 1517 OCR 완료
# 페이지 1518 OCR 완료
# 페이지 1519 OCR 완료
# 페이지 1520 OCR 완료
# 페이지 1521 OCR 완료
# 페이지 1522 OCR 완료
# 페이지 1523 OCR 완료
# 페이지 1524 OCR 완료
# 페이지 1525 OCR 완료
# 페이지 1526 OCR 완료
# 페이지 1527 OCR 완료
# 페이지 1528 OCR 완료
# 페이지 1529 OCR 완료
# 페이지 1530 OCR 완료
# 페이지 1531 OCR 완료
# 페이지 1532 OCR 완료
# 페이지 1533 OCR 완료
# 페이지 1534 OCR 완료
# 페이지 1535 OCR 완료
# 페이지 1536 OCR 완료
# 페이지 1537 OCR 완료
# 페이지 1538 OCR 완료
# 페이지 1539 OCR 완료
# 페이지 1540 OCR 완료
# 페이지 1541 OCR 완료
# 페이지 1542 OCR 완료
# 페이지 1543 OCR 완료
# 페이지 1544 OCR 완료
# 페이지 1545 OCR 완료
# 페이지 1546 OCR 완료
# 페이지 1547 OCR 완료
# 페이지 1548 OCR 완료
# 페이지 1549 OCR 완료
# 페이지 1550 OCR 완료
# 페이지 1551 OCR 완료
# 페이지 1552 OCR 완료
# 페이지 1553 OCR 완료
# 페이지 1554 OCR 완료
# 페이지 1555 OCR 완료
# 페이지 1556 OCR 완료
# 페이지 1557 OCR 완료
# 페이지 1558 OCR 완료
# 페이지 1559 OCR 완료
# 페이지 1560 OCR 완료
# 페이지 1561 OCR 완료
# 페이지 1562 OCR 완료
# 페이지 1563 OCR 완료
# 페이지 1564 OCR 완료
# 페이지 1565 OCR 완료
# 페이지 1566 OCR 완료
# 페이지 1567 OCR 완료
# 페이지 1568 OCR 완료
# 페이지 1569 OCR 완료
# 페이지 1570 OCR 완료
# 페이지 1571 OCR 완료
# 페이지 1572 OCR 완료
# 페이지 1573 OCR 완료
# 페이지 1574 OCR 완료
# 페이지 1575 OCR 완료
# 페이지 1576 OCR 완료
# 페이지 1577 OCR 완료
# 페이지 1578 OCR 완료
# 페이지 1579 OCR 완료
# 페이지 1580 OCR 완료
# 페이지 1581 OCR 완료
# 페이지 1582 OCR 완료
# 페이지 1583 OCR 완료
# 페이지 1584 OCR 완료
# 페이지 1585 OCR 완료
# 페이지 1586 OCR 완료
# 페이지 1587 OCR 완료
# 페이지 1588 OCR 완료
# 페이지 1589 OCR 완료
# 페이지 1590 OCR 완료
# 페이지 1591 OCR 완료
# 페이지 1592 OCR 완료
# 페이지 1593 OCR 완료
# 페이지 1594 OCR 완료
# 페이지 1595 OCR 완료
# 페이지 1596 OCR 완료
# 페이지 1597 OCR 완료
# 페이지 1598 OCR 완료
# 페이지 1599 OCR 완료
# 페이지 1600 OCR 완료
# 페이지 1601 OCR 완료
# 페이지 1602 OCR 완료
# 페이지 1603 OCR 완료
# 페이지 1604 OCR 완료
# 페이지 1605 OCR 완료
# 페이지 1606 OCR 완료
# 페이지 1607 OCR 완료
# 페이지 1608 OCR 완료
# 페이지 1609 OCR 완료
# 페이지 1610 OCR 완료
# 페이지 1611 OCR 완료
# 페이지 1612 OCR 완료
# 페이지 1613 OCR 완료
# 페이지 1614 OCR 완료
# 페이지 1615 OCR 완료
# 페이지 1616 OCR 완료
# 페이지 1617 OCR 완료
# 페이지 1618 OCR 완료
# 페이지 1619 OCR 완료
# 페이지 1620 OCR 완료
# 페이지 1621 OCR 완료
# 페이지 1622 OCR 완료
# 페이지 1623 OCR 완료
# 페이지 1624 OCR 완료
# 페이지 1625 OCR 완료
# 페이지 1626 OCR 완료
# 페이지 1627 OCR 완료
# 페이지 1628 OCR 완료
# 페이지 1629 OCR 완료
# 페이지 1630 OCR 완료
# 페이지 1631 OCR 완료
# 페이지 1632 OCR 완료
# 페이지 1633 OCR 완료
# 페이지 1634 OCR 완료
# 페이지 1635 OCR 완료
# 페이지 1636 OCR 완료
# 페이지 1637 OCR 완료
# 페이지 1638 OCR 완료
# 페이지 1639 OCR 완료
# 페이지 1640 OCR 완료
# 페이지 1641 OCR 완료
# 페이지 1642 OCR 완료
# 페이지 1643 OCR 완료
# 페이지 1644 OCR 완료
# 페이지 1645 OCR 완료
# 페이지 1646 OCR 완료
# 페이지 1647 OCR 완료
# 페이지 1648 OCR 완료
# 페이지 1649 OCR 완료
# 페이지 1650 OCR 완료
# 페이지 1651 OCR 완료
# 페이지 1652 OCR 완료
# 페이지 1653 OCR 완료
# 페이지 1654 OCR 완료
# 페이지 1655 OCR 완료
# 페이지 1656 OCR 완료
# 페이지 1657 OCR 완료
# 페이지 1658 OCR 완료
# 페이지 1659 OCR 완료
# 페이지 1660 OCR 완료
# 페이지 1661 OCR 완료
# 페이지 1662 OCR 완료
# 페이지 1663 OCR 완료
# 페이지 1664 OCR 완료
# 페이지 1665 OCR 완료
# 페이지 1666 OCR 완료
# 페이지 1667 OCR 완료
# 페이지 1668 OCR 완료
# 페이지 1669 OCR 완료
# 페이지 1670 OCR 완료
# 페이지 1671 OCR 완료
# 페이지 1672 OCR 완료
# 페이지 1673 OCR 완료
# 페이지 1674 OCR 완료
# 페이지 1675 OCR 완료
# 페이지 1676 OCR 완료
# 페이지 1677 OCR 완료
# 페이지 1678 OCR 완료
# 페이지 1679 OCR 완료
# 페이지 1680 OCR 완료
# 페이지 1681 OCR 완료
# 페이지 1682 OCR 완료
# 페이지 1683 OCR 완료
# 페이지 1684 OCR 완료
# 페이지 1685 OCR 완료
# 페이지 1686 OCR 완료
# 페이지 1687 OCR 완료
# 페이지 1688 OCR 완료
# 페이지 1689 OCR 완료
# 페이지 1690 OCR 완료
# 페이지 1691 OCR 완료
# 페이지 1692 OCR 완료
# 페이지 1693 OCR 완료
# 페이지 1694 OCR 완료
# 페이지 1695 OCR 완료
# 페이지 1696 OCR 완료
# 페이지 1697 OCR 완료
# 페이지 1698 OCR 완료
# 페이지 1699 OCR 완료
# 페이지 1700 OCR 완료
# 페이지 1701 OCR 완료
# 페이지 1702 OCR 완료
# 페이지 1703 OCR 완료
# 페이지 1704 OCR 완료
# 페이지 1705 OCR 완료
# 페이지 1706 OCR 완료
# 페이지 1707 OCR 완료
# 페이지 1708 OCR 완료
# 페이지 1709 OCR 완료
# 페이지 1710 OCR 완료
# 페이지 1711 OCR 완료
# 페이지 1712 OCR 완료
# 페이지 1713 OCR 완료
# 페이지 1714 OCR 완료
# 페이지 1715 OCR 완료
# 페이지 1716 OCR 완료
# 페이지 1717 OCR 완료
# 페이지 1718 OCR 완료
# 페이지 1719 OCR 완료
# 페이지 1720 OCR 완료
# 페이지 1721 OCR 완료
# 페이지 1722 OCR 완료
# 페이지 1723 OCR 완료
# 페이지 1724 OCR 완료
# 페이지 1725 OCR 완료
# 페이지 1726 OCR 완료
# 페이지 1727 OCR 완료
# 페이지 1728 OCR 완료
# 페이지 1729 OCR 완료
# 페이지 1730 OCR 완료
# 페이지 1731 OCR 완료
# 페이지 1732 OCR 완료
# 페이지 1733 OCR 완료
# 페이지 1734 OCR 완료
# 페이지 1735 OCR 완료
# 페이지 1736 OCR 완료
# 페이지 1737 OCR 완료
# 페이지 1738 OCR 완료
# 페이지 1739 OCR 완료
# 페이지 1740 OCR 완료
# 페이지 1741 OCR 완료
# 페이지 1742 OCR 완료
# 페이지 1743 OCR 완료
# 페이지 1744 OCR 완료
# 페이지 1745 OCR 완료
# 페이지 1746 OCR 완료
# 페이지 1747 OCR 완료
# 페이지 1748 OCR 완료
# 페이지 1749 OCR 완료
# 페이지 1750 OCR 완료
# 페이지 1751 OCR 완료
# 페이지 1752 OCR 완료
# 페이지 1753 OCR 완료
# 페이지 1754 OCR 완료
# 페이지 1755 OCR 완료
# 페이지 1756 OCR 완료
# 페이지 1757 OCR 완료
# 페이지 1758 OCR 완료
# 페이지 1759 OCR 완료
# 페이지 1760 OCR 완료
# 페이지 1761 OCR 완료
# 페이지 1762 OCR 완료
# 페이지 1763 OCR 완료
# 페이지 1764 OCR 완료
# 페이지 1765 OCR 완료
# 페이지 1766 OCR 완료
# 페이지 1767 OCR 완료
# 페이지 1768 OCR 완료
# 페이지 1769 OCR 완료
# 페이지 1770 OCR 완료
# 페이지 1771 OCR 완료
# 페이지 1772 OCR 완료
# 페이지 1773 OCR 완료
# 페이지 1774 OCR 완료
# 페이지 1775 OCR 완료
# 페이지 1776 OCR 완료
# 페이지 1777 OCR 완료
# 페이지 1778 OCR 완료
# 페이지 1779 OCR 완료
# 페이지 1780 OCR 완료
# 페이지 1781 OCR 완료
# 페이지 1782 OCR 완료
# 페이지 1783 OCR 완료
# 페이지 1784 OCR 완료
# 페이지 1785 OCR 완료
# 페이지 1786 OCR 완료
# 페이지 1787 OCR 완료
# 페이지 1788 OCR 완료
# 페이지 1789 OCR 완료
# 페이지 1790 OCR 완료
# 페이지 1791 OCR 완료
# 페이지 1792 OCR 완료
# 페이지 1793 OCR 완료
# 페이지 1794 OCR 완료
# 페이지 1795 OCR 완료
# 페이지 1796 OCR 완료
# 페이지 1797 OCR 완료
# 페이지 1798 OCR 완료
# 페이지 1799 OCR 완료
# 페이지 1800 OCR 완료
# 페이지 1801 OCR 완료
# 페이지 1802 OCR 완료
# 페이지 1803 OCR 완료
# 페이지 1804 OCR 완료
# 페이지 1805 OCR 완료
# 페이지 1806 OCR 완료
# 페이지 1807 OCR 완료
# 페이지 1808 OCR 완료
# 페이지 1809 OCR 완료
# 페이지 1810 OCR 완료
# 페이지 1811 OCR 완료
# 페이지 1812 OCR 완료
# 페이지 1813 OCR 완료
# 페이지 1814 OCR 완료
# 페이지 1815 OCR 완료
# 페이지 1816 OCR 완료
# 페이지 1817 OCR 완료
# 페이지 1818 OCR 완료
# 페이지 1819 OCR 완료
# 페이지 1820 OCR 완료
# 페이지 1821 OCR 완료
# 페이지 1822 OCR 완료
# 페이지 1823 OCR 완료
# 페이지 1824 OCR 완료
# 페이지 1825 OCR 완료
# 페이지 1826 OCR 완료
# 페이지 1827 OCR 완료
# 페이지 1828 OCR 완료
# 페이지 1829 OCR 완료
# 페이지 1830 OCR 완료
# 페이지 1831 OCR 완료
# 페이지 1832 OCR 완료
# 페이지 1833 OCR 완료
# 페이지 1834 OCR 완료
# 페이지 1835 OCR 완료
# 페이지 1836 OCR 완료
# 페이지 1837 OCR 완료
# 페이지 1838 OCR 완료
# 페이지 1839 OCR 완료
# 페이지 1840 OCR 완료
# 페이지 1841 OCR 완료
# 페이지 1842 OCR 완료
# 페이지 1843 OCR 완료
# 페이지 1844 OCR 완료
# 페이지 1845 OCR 완료
# 페이지 1846 OCR 완료
# 페이지 1847 OCR 완료
# 페이지 1848 OCR 완료
# 페이지 1849 OCR 완료
# 페이지 1850 OCR 완료
# 페이지 1851 OCR 완료
# 페이지 1852 OCR 완료
# 페이지 1853 OCR 완료
# 페이지 1854 OCR 완료
# 페이지 1855 OCR 완료
# 페이지 1856 OCR 완료
# 페이지 1857 OCR 완료
# 페이지 1858 OCR 완료
# 페이지 1859 OCR 완료
# 페이지 1860 OCR 완료
# 페이지 1861 OCR 완료
# 페이지 1862 OCR 완료
# 페이지 1863 OCR 완료
# 페이지 1864 OCR 완료
# 페이지 1865 OCR 완료
# 페이지 1866 OCR 완료
# 페이지 1867 OCR 완료
# 페이지 1868 OCR 완료
# 페이지 1869 OCR 완료
# 페이지 1870 OCR 완료
# 페이지 1871 OCR 완료
# 페이지 1872 OCR 완료
# 페이지 1873 OCR 완료
# 페이지 1874 OCR 완료
# 페이지 1875 OCR 완료
# 페이지 1876 OCR 완료
# 페이지 1877 OCR 완료
# 페이지 1878 OCR 완료
# 페이지 1879 OCR 완료
# 페이지 1880 OCR 완료
# 페이지 1881 OCR 완료
# 페이지 1882 OCR 완료
# 페이지 1883 OCR 완료
# 페이지 1884 OCR 완료
# 페이지 1885 OCR 완료
# 페이지 1886 OCR 완료
# 페이지 1887 OCR 완료
# 페이지 1888 OCR 완료
# 페이지 1889 OCR 완료
# 페이지 1890 OCR 완료
# 페이지 1891 OCR 완료
# 페이지 1892 OCR 완료
# 페이지 1893 OCR 완료
# 페이지 1894 OCR 완료
# 페이지 1895 OCR 완료
# 페이지 1896 OCR 완료
# 페이지 1897 OCR 완료
# 페이지 1898 OCR 완료
# 페이지 1899 OCR 완료
# 페이지 1900 OCR 완료
# 페이지 1901 OCR 완료
# 페이지 1902 OCR 완료
# 페이지 1903 OCR 완료
# 페이지 1904 OCR 완료
# 페이지 1905 OCR 완료
# 페이지 1906 OCR 완료
# 페이지 1907 OCR 완료
# 페이지 1908 OCR 완료
# 페이지 1909 OCR 완료
# 페이지 1910 OCR 완료
# 페이지 1911 OCR 완료
# 페이지 1912 OCR 완료
# 페이지 1913 OCR 완료
# 페이지 1914 OCR 완료
# 페이지 1915 OCR 완료
# 페이지 1916 OCR 완료
# 페이지 1917 OCR 완료
# 페이지 1918 OCR 완료
# 페이지 1919 OCR 완료
# 페이지 1920 OCR 완료
# 페이지 1921 OCR 완료
# 페이지 1922 OCR 완료
# 페이지 1923 OCR 완료
# 페이지 1924 OCR 완료
# 페이지 1925 OCR 완료
# 페이지 1926 OCR 완료
# 페이지 1927 OCR 완료
# 페이지 1928 OCR 완료
# 페이지 1929 OCR 완료
# 페이지 1930 OCR 완료
# 페이지 1931 OCR 완료
# 페이지 1932 OCR 완료
# 페이지 1933 OCR 완료
# 페이지 1934 OCR 완료
# 페이지 1935 OCR 완료
# 페이지 1936 OCR 완료
# 페이지 1937 OCR 완료
# 페이지 1938 OCR 완료
# 페이지 1939 OCR 완료
# 페이지 1940 OCR 완료
# 페이지 1941 OCR 완료
# 페이지 1942 OCR 완료
# 페이지 1943 OCR 완료
# 페이지 1944 OCR 완료
# 페이지 1945 OCR 완료
# 페이지 1946 OCR 완료
# 페이지 1947 OCR 완료
# 페이지 1948 OCR 완료
# 페이지 1949 OCR 완료
# 페이지 1950 OCR 완료
# 페이지 1951 OCR 완료
# 페이지 1952 OCR 완료
# 페이지 1953 OCR 완료
# 페이지 1954 OCR 완료
# 페이지 1955 OCR 완료
# 페이지 1956 OCR 완료
# 페이지 1957 OCR 완료
# 페이지 1958 OCR 완료
# 페이지 1959 OCR 완료
# 페이지 1960 OCR 완료
# 페이지 1961 OCR 완료
# 페이지 1962 OCR 완료
# 페이지 1963 OCR 완료
# 페이지 1964 OCR 완료
# 페이지 1965 OCR 완료
# 페이지 1966 OCR 완료
# 페이지 1967 OCR 완료
# 페이지 1968 OCR 완료
# 페이지 1969 OCR 완료
# 페이지 1970 OCR 완료
# 페이지 1971 OCR 완료
# 페이지 1972 OCR 완료
# 페이지 1973 OCR 완료
# 페이지 1974 OCR 완료
# 페이지 1975 OCR 완료
# 페이지 1976 OCR 완료
# 페이지 1977 OCR 완료
# 페이지 1978 OCR 완료
# 페이지 1979 OCR 완료
# 페이지 1980 OCR 완료
# 페이지 1981 OCR 완료
# 페이지 1982 OCR 완료
# 페이지 1983 OCR 완료
# 페이지 1984 OCR 완료
# 페이지 1985 OCR 완료
# 페이지 1986 OCR 완료
# 페이지 1987 OCR 완료
# 페이지 1988 OCR 완료
# 페이지 1989 OCR 완료
# 페이지 1990 OCR 완료
# 페이지 1991 OCR 완료
# 페이지 1992 OCR 완료
# 페이지 1993 OCR 완료
# 페이지 1994 OCR 완료
# 페이지 1995 OCR 완료
# 페이지 1996 OCR 완료
# 페이지 1997 OCR 완료
# 페이지 1998 OCR 완료
# 페이지 1999 OCR 완료
# 페이지 2000 OCR 완료
# 페이지 2001 OCR 완료
# 페이지 2002 OCR 완료
# 페이지 2003 OCR 완료
# 페이지 2004 OCR 완료
# 페이지 2005 OCR 완료
# 페이지 2006 OCR 완료
# 페이지 2007 OCR 완료
# 페이지 2008 OCR 완료
# 페이지 2009 OCR 완료
# 페이지 2010 OCR 완료
# 페이지 2011 OCR 완료
# 페이지 2012 OCR 완료
# 페이지 2013 OCR 완료
# 페이지 2014 OCR 완료
# 페이지 2015 OCR 완료
# 페이지 2016 OCR 완료
# 페이지 2017 OCR 완료
# 페이지 2018 OCR 완료
# 페이지 2019 OCR 완료
# 페이지 2020 OCR 완료
# 페이지 2021 OCR 완료
# 페이지 2022 OCR 완료
# 페이지 2023 OCR 완료
# 페이지 2024 OCR 완료
# 페이지 2025 OCR 완료
# 페이지 2026 OCR 완료
# 페이지 2027 OCR 완료
# 페이지 2028 OCR 완료
# 페이지 2029 OCR 완료
# 페이지 2030 OCR 완료
# 페이지 2031 OCR 완료
# 페이지 2032 OCR 완료
# 페이지 2033 OCR 완료
# 페이지 2034 OCR 완료
# 페이지 2035 OCR 완료
# 페이지 2036 OCR 완료
# 텍스트 추출 완료 : ./data/KEPIC/kepic_tesseract_500.txt
# 페이지 1 OCR 완료
# 페이지 2 OCR 완료
# 페이지 3 OCR 완료
# 페이지 4 OCR 완료
# 페이지 5 OCR 완료
# 페이지 6 OCR 완료
# 페이지 7 OCR 완료
# 페이지 8 OCR 완료
# 페이지 9 OCR 완료
# 페이지 10 OCR 완료
# 페이지 11 OCR 완료
# 페이지 12 OCR 완료
# 페이지 13 OCR 완료
# 페이지 14 OCR 완료
# 페이지 15 OCR 완료
# 페이지 16 OCR 완료
# 페이지 17 OCR 완료
# 페이지 18 OCR 완료
# 페이지 19 OCR 완료
# 페이지 20 OCR 완료
# 페이지 21 OCR 완료
# 페이지 22 OCR 완료
# 페이지 23 OCR 완료
# 페이지 24 OCR 완료
# 페이지 25 OCR 완료
# 페이지 26 OCR 완료
# 페이지 27 OCR 완료
# 페이지 28 OCR 완료
# 페이지 29 OCR 완료
# 페이지 30 OCR 완료
# 페이지 31 OCR 완료
# 페이지 32 OCR 완료
# 페이지 33 OCR 완료
# 페이지 34 OCR 완료
# 페이지 35 OCR 완료
# 페이지 36 OCR 완료
# 페이지 37 OCR 완료
# 페이지 38 OCR 완료
# 페이지 39 OCR 완료
# 페이지 40 OCR 완료
# 페이지 41 OCR 완료
# 페이지 42 OCR 완료
# 페이지 43 OCR 완료
# 페이지 44 OCR 완료
# 페이지 45 OCR 완료
# 페이지 46 OCR 완료
# 페이지 47 OCR 완료
# 페이지 48 OCR 완료
# 페이지 49 OCR 완료
# 페이지 50 OCR 완료
# 페이지 51 OCR 완료
# 페이지 52 OCR 완료
# 페이지 53 OCR 완료
# 페이지 54 OCR 완료
# 페이지 55 OCR 완료
# 페이지 56 OCR 완료
# 페이지 57 OCR 완료
# 페이지 58 OCR 완료
# 페이지 59 OCR 완료
# 페이지 60 OCR 완료
# 페이지 61 OCR 완료
# 페이지 62 OCR 완료
# 페이지 63 OCR 완료
# 페이지 64 OCR 완료
# 페이지 65 OCR 완료
# 페이지 66 OCR 완료
# 페이지 67 OCR 완료
# 페이지 68 OCR 완료
# 페이지 69 OCR 완료
# 페이지 70 OCR 완료
# 페이지 71 OCR 완료
# 페이지 72 OCR 완료
# 페이지 73 OCR 완료
# 페이지 74 OCR 완료
# 페이지 75 OCR 완료
# 페이지 76 OCR 완료
# 페이지 77 OCR 완료
# 페이지 78 OCR 완료
# 페이지 79 OCR 완료
# 페이지 80 OCR 완료
# 페이지 81 OCR 완료
# 페이지 82 OCR 완료
# 페이지 83 OCR 완료
# 페이지 84 OCR 완료
# 페이지 85 OCR 완료
# 페이지 86 OCR 완료
# 페이지 87 OCR 완료
# 페이지 88 OCR 완료
# 페이지 89 OCR 완료
# 페이지 90 OCR 완료
# 페이지 91 OCR 완료
# 페이지 92 OCR 완료
# 페이지 93 OCR 완료
# 페이지 94 OCR 완료
# 페이지 95 OCR 완료
# 페이지 96 OCR 완료
# 페이지 97 OCR 완료
# 페이지 98 OCR 완료
# 페이지 99 OCR 완료
# 페이지 100 OCR 완료
# 페이지 101 OCR 완료
# 페이지 102 OCR 완료
# 페이지 103 OCR 완료
# 페이지 104 OCR 완료
# 페이지 105 OCR 완료
# 페이지 106 OCR 완료
# 페이지 107 OCR 완료
# 페이지 108 OCR 완료
# 페이지 109 OCR 완료
# 페이지 110 OCR 완료
# 페이지 111 OCR 완료
# 페이지 112 OCR 완료
# 페이지 113 OCR 완료
# 페이지 114 OCR 완료
# 페이지 115 OCR 완료
# 페이지 116 OCR 완료
# 페이지 117 OCR 완료
# 페이지 118 OCR 완료
# 페이지 119 OCR 완료
# 페이지 120 OCR 완료
# 페이지 121 OCR 완료
# 페이지 122 OCR 완료
# 페이지 123 OCR 완료
# 페이지 124 OCR 완료
# 페이지 125 OCR 완료
# 페이지 126 OCR 완료
# 페이지 127 OCR 완료
# 페이지 128 OCR 완료
# 페이지 129 OCR 완료
# 페이지 130 OCR 완료
# 페이지 131 OCR 완료
# 페이지 132 OCR 완료
# 페이지 133 OCR 완료
# 페이지 134 OCR 완료
# 페이지 135 OCR 완료
# 페이지 136 OCR 완료
# 페이지 137 OCR 완료
# 페이지 138 OCR 완료
# 페이지 139 OCR 완료
# 페이지 140 OCR 완료
# 페이지 141 OCR 완료
# 페이지 142 OCR 완료
# 페이지 143 OCR 완료
# 페이지 144 OCR 완료
# 페이지 145 OCR 완료
# 페이지 146 OCR 완료
# 페이지 147 OCR 완료
# 페이지 148 OCR 완료
# 페이지 149 OCR 완료
# 페이지 150 OCR 완료
# 페이지 151 OCR 완료
# 페이지 152 OCR 완료
# 페이지 153 OCR 완료
# 페이지 154 OCR 완료
# 페이지 155 OCR 완료
# 페이지 156 OCR 완료
# 페이지 157 OCR 완료
# 페이지 158 OCR 완료
# 페이지 159 OCR 완료
# 페이지 160 OCR 완료
# 페이지 161 OCR 완료
# 페이지 162 OCR 완료
# 페이지 163 OCR 완료
# 페이지 164 OCR 완료
# 페이지 165 OCR 완료
# 페이지 166 OCR 완료
# 페이지 167 OCR 완료
# 페이지 168 OCR 완료
# 페이지 169 OCR 완료
# 페이지 170 OCR 완료
# 페이지 171 OCR 완료
# 페이지 172 OCR 완료
# 페이지 173 OCR 완료
# 페이지 174 OCR 완료
# 페이지 175 OCR 완료
# 페이지 176 OCR 완료
# 페이지 177 OCR 완료
# 페이지 178 OCR 완료
# 페이지 179 OCR 완료
# 페이지 180 OCR 완료
# 페이지 181 OCR 완료
# 페이지 182 OCR 완료
# 페이지 183 OCR 완료
# 페이지 184 OCR 완료
# 페이지 185 OCR 완료
# 페이지 186 OCR 완료
# 페이지 187 OCR 완료
# 페이지 188 OCR 완료
# 페이지 189 OCR 완료
# 페이지 190 OCR 완료
# 페이지 191 OCR 완료
# 페이지 192 OCR 완료
# 페이지 193 OCR 완료
# 페이지 194 OCR 완료
# 페이지 195 OCR 완료
# 페이지 196 OCR 완료
# 페이지 197 OCR 완료
# 페이지 198 OCR 완료
# 페이지 199 OCR 완료
# 페이지 200 OCR 완료
# 페이지 201 OCR 완료
# 페이지 202 OCR 완료
# 페이지 203 OCR 완료
# 페이지 204 OCR 완료
# 페이지 205 OCR 완료
# 페이지 206 OCR 완료
# 페이지 207 OCR 완료
# 페이지 208 OCR 완료
# 페이지 209 OCR 완료
# 페이지 210 OCR 완료
# 페이지 211 OCR 완료
# 페이지 212 OCR 완료
# 페이지 213 OCR 완료
# 페이지 214 OCR 완료
# 페이지 215 OCR 완료
# 페이지 216 OCR 완료
# 페이지 217 OCR 완료
# 페이지 218 OCR 완료
# 페이지 219 OCR 완료
# 페이지 220 OCR 완료
# 페이지 221 OCR 완료
# 페이지 222 OCR 완료
# 페이지 223 OCR 완료
# 페이지 224 OCR 완료
# 페이지 225 OCR 완료
# 페이지 226 OCR 완료
# 페이지 227 OCR 완료
# 페이지 228 OCR 완료
# 페이지 229 OCR 완료
# 페이지 230 OCR 완료
# 페이지 231 OCR 완료
# 페이지 232 OCR 완료
# 페이지 233 OCR 완료
# 페이지 234 OCR 완료
# 페이지 235 OCR 완료
# 페이지 236 OCR 완료
# 페이지 237 OCR 완료
# 페이지 238 OCR 완료
# 페이지 239 OCR 완료
# 페이지 240 OCR 완료
# 페이지 241 OCR 완료
# 페이지 242 OCR 완료
# 페이지 243 OCR 완료
# 페이지 244 OCR 완료
# 페이지 245 OCR 완료
# 페이지 246 OCR 완료
# 페이지 247 OCR 완료
# 페이지 248 OCR 완료
# 페이지 249 OCR 완료
# 페이지 250 OCR 완료
# 페이지 251 OCR 완료
# 페이지 252 OCR 완료
# 페이지 253 OCR 완료
# 페이지 254 OCR 완료
# 페이지 255 OCR 완료
# 페이지 256 OCR 완료
# 페이지 257 OCR 완료
# 페이지 258 OCR 완료
# 페이지 259 OCR 완료
# 페이지 260 OCR 완료
# 페이지 261 OCR 완료
# 페이지 262 OCR 완료
# 페이지 263 OCR 완료
# 페이지 264 OCR 완료
# 페이지 265 OCR 완료
# 페이지 266 OCR 완료
# 페이지 267 OCR 완료
# 페이지 268 OCR 완료
# 페이지 269 OCR 완료
# 페이지 270 OCR 완료
# 페이지 271 OCR 완료
# 페이지 272 OCR 완료
# 페이지 273 OCR 완료
# 페이지 274 OCR 완료
# 페이지 275 OCR 완료
# 페이지 276 OCR 완료
# 페이지 277 OCR 완료
# 페이지 278 OCR 완료
# 페이지 279 OCR 완료
# 페이지 280 OCR 완료
# 페이지 281 OCR 완료
# 페이지 282 OCR 완료
# 페이지 283 OCR 완료
# 페이지 284 OCR 완료
# 페이지 285 OCR 완료
# 페이지 286 OCR 완료
# 페이지 287 OCR 완료
# 페이지 288 OCR 완료
# 페이지 289 OCR 완료
# 페이지 290 OCR 완료
# 페이지 291 OCR 완료
# 페이지 292 OCR 완료
# 페이지 293 OCR 완료
# 페이지 294 OCR 완료
# 페이지 295 OCR 완료
# 페이지 296 OCR 완료
# 페이지 297 OCR 완료
# 페이지 298 OCR 완료
# 페이지 299 OCR 완료
# 페이지 300 OCR 완료
# 페이지 301 OCR 완료
# 페이지 302 OCR 완료
# 페이지 303 OCR 완료
# 페이지 304 OCR 완료
# 페이지 305 OCR 완료
# 페이지 306 OCR 완료
# 페이지 307 OCR 완료
# 페이지 308 OCR 완료
# 페이지 309 OCR 완료
# 페이지 310 OCR 완료
# 페이지 311 OCR 완료
# 페이지 312 OCR 완료
# 페이지 313 OCR 완료
# 페이지 314 OCR 완료
# 페이지 315 OCR 완료
# 페이지 316 OCR 완료
# 페이지 317 OCR 완료
# 페이지 318 OCR 완료
# 페이지 319 OCR 완료
# 페이지 320 OCR 완료
# 페이지 321 OCR 완료
# 페이지 322 OCR 완료
# 페이지 323 OCR 완료
# 페이지 324 OCR 완료
# 페이지 325 OCR 완료
# 페이지 326 OCR 완료
# 페이지 327 OCR 완료
# 페이지 328 OCR 완료
# 페이지 329 OCR 완료
# 페이지 330 OCR 완료
# 페이지 331 OCR 완료
# 페이지 332 OCR 완료
# 페이지 333 OCR 완료
# 페이지 334 OCR 완료
# 페이지 335 OCR 완료
# 페이지 336 OCR 완료
# 페이지 337 OCR 완료
# 페이지 338 OCR 완료
# 페이지 339 OCR 완료
# 페이지 340 OCR 완료
# 페이지 341 OCR 완료
# 페이지 342 OCR 완료
# 페이지 343 OCR 완료
# 페이지 344 OCR 완료
# 페이지 345 OCR 완료
# 페이지 346 OCR 완료
# 페이지 347 OCR 완료
# 페이지 348 OCR 완료
# 페이지 349 OCR 완료
# 페이지 350 OCR 완료
# 페이지 351 OCR 완료
# 페이지 352 OCR 완료
# 페이지 353 OCR 완료
# 페이지 354 OCR 완료
# 페이지 355 OCR 완료
# 페이지 356 OCR 완료
# 페이지 357 OCR 완료
# 페이지 358 OCR 완료
# 페이지 359 OCR 완료
# 페이지 360 OCR 완료
# 페이지 361 OCR 완료
# 페이지 362 OCR 완료
# 페이지 363 OCR 완료
# 페이지 364 OCR 완료
# 페이지 365 OCR 완료
# 페이지 366 OCR 완료
# 페이지 367 OCR 완료
# 페이지 368 OCR 완료
# 페이지 369 OCR 완료
# 페이지 370 OCR 완료
# 페이지 371 OCR 완료
# 페이지 372 OCR 완료
# 페이지 373 OCR 완료
# 페이지 374 OCR 완료
# 페이지 375 OCR 완료
# 페이지 376 OCR 완료
# 페이지 377 OCR 완료
# 페이지 378 OCR 완료
# 페이지 379 OCR 완료
# 페이지 380 OCR 완료
# 페이지 381 OCR 완료
# 페이지 382 OCR 완료
# 페이지 383 OCR 완료
# 페이지 384 OCR 완료
# 페이지 385 OCR 완료
# 페이지 386 OCR 완료
# 페이지 387 OCR 완료
# 페이지 388 OCR 완료
# 페이지 389 OCR 완료
# 페이지 390 OCR 완료
# 페이지 391 OCR 완료
# 페이지 392 OCR 완료
# 페이지 393 OCR 완료
# 페이지 394 OCR 완료
# 페이지 395 OCR 완료
# 페이지 396 OCR 완료
# 페이지 397 OCR 완료
# 페이지 398 OCR 완료
# 페이지 399 OCR 완료
# 페이지 400 OCR 완료
# 페이지 401 OCR 완료
# 페이지 402 OCR 완료
# 페이지 403 OCR 완료
# 페이지 404 OCR 완료
# 페이지 405 OCR 완료
# 페이지 406 OCR 완료
# 페이지 407 OCR 완료
# 페이지 408 OCR 완료
# 페이지 409 OCR 완료
# 페이지 410 OCR 완료
# 페이지 411 OCR 완료
# 페이지 412 OCR 완료
# 페이지 413 OCR 완료
# 페이지 414 OCR 완료
# 페이지 415 OCR 완료
# 페이지 416 OCR 완료
# 페이지 417 OCR 완료
# 페이지 418 OCR 완료
# 페이지 419 OCR 완료
# 페이지 420 OCR 완료
# 페이지 421 OCR 완료
# 페이지 422 OCR 완료
# 페이지 423 OCR 완료
# 페이지 424 OCR 완료
# 페이지 425 OCR 완료
# 페이지 426 OCR 완료
# 페이지 427 OCR 완료
# 페이지 428 OCR 완료
# 페이지 429 OCR 완료
# 페이지 430 OCR 완료
# 페이지 431 OCR 완료
# 페이지 432 OCR 완료
# 페이지 433 OCR 완료
# 페이지 434 OCR 완료
# 페이지 435 OCR 완료
# 페이지 436 OCR 완료
# 페이지 437 OCR 완료
# 페이지 438 OCR 완료
# 페이지 439 OCR 완료
# 페이지 440 OCR 완료
# 페이지 441 OCR 완료
# 페이지 442 OCR 완료
# 페이지 443 OCR 완료
# 페이지 444 OCR 완료
# 페이지 445 OCR 완료
# 페이지 446 OCR 완료
# 페이지 447 OCR 완료
# 페이지 448 OCR 완료
# 페이지 449 OCR 완료
# 페이지 450 OCR 완료
# 페이지 451 OCR 완료
# 페이지 452 OCR 완료
# 페이지 453 OCR 완료
# 페이지 454 OCR 완료
# 페이지 455 OCR 완료
# 페이지 456 OCR 완료
# 페이지 457 OCR 완료
# 페이지 458 OCR 완료
# 페이지 459 OCR 완료
# 페이지 460 OCR 완료
# 페이지 461 OCR 완료
# 페이지 462 OCR 완료
# 페이지 463 OCR 완료
# 페이지 464 OCR 완료
# 페이지 465 OCR 완료
# 페이지 466 OCR 완료
# 페이지 467 OCR 완료
# 페이지 468 OCR 완료
# 페이지 469 OCR 완료
# 페이지 470 OCR 완료
# 페이지 471 OCR 완료
# 페이지 472 OCR 완료
# 페이지 473 OCR 완료
# 페이지 474 OCR 완료
# 페이지 475 OCR 완료
# 페이지 476 OCR 완료
# 페이지 477 OCR 완료
# 페이지 478 OCR 완료
# 페이지 479 OCR 완료
# 페이지 480 OCR 완료
# 페이지 481 OCR 완료
# 페이지 482 OCR 완료
# 페이지 483 OCR 완료
# 페이지 484 OCR 완료
# 페이지 485 OCR 완료
# 페이지 486 OCR 완료
# 페이지 487 OCR 완료
# 페이지 488 OCR 완료
# 페이지 489 OCR 완료
# 페이지 490 OCR 완료
# 페이지 491 OCR 완료
# 페이지 492 OCR 완료
# 페이지 493 OCR 완료
# 페이지 494 OCR 완료
# 페이지 495 OCR 완료
# 페이지 496 OCR 완료
# 페이지 497 OCR 완료
# 페이지 498 OCR 완료
# 페이지 499 OCR 완료
# 페이지 500 OCR 완료
# 페이지 501 OCR 완료
# 페이지 502 OCR 완료
# 페이지 503 OCR 완료
# 페이지 504 OCR 완료
# 페이지 505 OCR 완료
# 페이지 506 OCR 완료
# 페이지 507 OCR 완료
# 페이지 508 OCR 완료
# 페이지 509 OCR 완료
# 페이지 510 OCR 완료
# 페이지 511 OCR 완료
# 페이지 512 OCR 완료
# 페이지 513 OCR 완료
# 페이지 514 OCR 완료
# 페이지 515 OCR 완료
# 페이지 516 OCR 완료
# 페이지 517 OCR 완료
# 페이지 518 OCR 완료
# 페이지 519 OCR 완료
# 페이지 520 OCR 완료
# 페이지 521 OCR 완료
# 페이지 522 OCR 완료
# 페이지 523 OCR 완료
# 페이지 524 OCR 완료
# 페이지 525 OCR 완료
# 페이지 526 OCR 완료
# 페이지 527 OCR 완료
# 페이지 528 OCR 완료
# 페이지 529 OCR 완료
# 페이지 530 OCR 완료
# 페이지 531 OCR 완료
# 페이지 532 OCR 완료
# 페이지 533 OCR 완료
# 페이지 534 OCR 완료
# 페이지 535 OCR 완료
# 페이지 536 OCR 완료
# 페이지 537 OCR 완료
# 페이지 538 OCR 완료
# 페이지 539 OCR 완료
# 페이지 540 OCR 완료
# 페이지 541 OCR 완료
# 페이지 542 OCR 완료
# 페이지 543 OCR 완료
# 페이지 544 OCR 완료
# 페이지 545 OCR 완료
# 페이지 546 OCR 완료
# 페이지 547 OCR 완료
# 페이지 548 OCR 완료
# 페이지 549 OCR 완료
# 페이지 550 OCR 완료
# 페이지 551 OCR 완료
# 페이지 552 OCR 완료
# 페이지 553 OCR 완료
# 페이지 554 OCR 완료
# 페이지 555 OCR 완료
# 페이지 556 OCR 완료
# 페이지 557 OCR 완료
# 페이지 558 OCR 완료
# 페이지 559 OCR 완료
# 페이지 560 OCR 완료
# 페이지 561 OCR 완료
# 페이지 562 OCR 완료
# 페이지 563 OCR 완료
# 페이지 564 OCR 완료
# 페이지 565 OCR 완료
# 페이지 566 OCR 완료
# 페이지 567 OCR 완료
# 페이지 568 OCR 완료
# 페이지 569 OCR 완료
# 페이지 570 OCR 완료
# 페이지 571 OCR 완료
# 페이지 572 OCR 완료
# 페이지 573 OCR 완료
# 페이지 574 OCR 완료
# 페이지 575 OCR 완료
# 페이지 576 OCR 완료
# 페이지 577 OCR 완료
# 페이지 578 OCR 완료
# 페이지 579 OCR 완료
# 페이지 580 OCR 완료
# 페이지 581 OCR 완료
# 페이지 582 OCR 완료
# 페이지 583 OCR 완료
# 페이지 584 OCR 완료
# 페이지 585 OCR 완료
# 페이지 586 OCR 완료
# 페이지 587 OCR 완료
# 페이지 588 OCR 완료
# 페이지 589 OCR 완료
# 페이지 590 OCR 완료
# 페이지 591 OCR 완료
# 페이지 592 OCR 완료
# 페이지 593 OCR 완료
# 페이지 594 OCR 완료
# 페이지 595 OCR 완료
# 페이지 596 OCR 완료
# 페이지 597 OCR 완료
# 페이지 598 OCR 완료
# 페이지 599 OCR 완료
# 페이지 600 OCR 완료
# 페이지 601 OCR 완료
# 페이지 602 OCR 완료
# 페이지 603 OCR 완료
# 페이지 604 OCR 완료
# 페이지 605 OCR 완료
# 페이지 606 OCR 완료
# 페이지 607 OCR 완료
# 페이지 608 OCR 완료
# 페이지 609 OCR 완료
# 페이지 610 OCR 완료
# 페이지 611 OCR 완료
# 페이지 612 OCR 완료
# 페이지 613 OCR 완료
# 페이지 614 OCR 완료
# 페이지 615 OCR 완료
# 페이지 616 OCR 완료
# 페이지 617 OCR 완료
# 페이지 618 OCR 완료
# 페이지 619 OCR 완료
# 페이지 620 OCR 완료
# 페이지 621 OCR 완료
# 페이지 622 OCR 완료
# 페이지 623 OCR 완료
# 페이지 624 OCR 완료
# 페이지 625 OCR 완료
# 페이지 626 OCR 완료
# 페이지 627 OCR 완료
# 페이지 628 OCR 완료
# 페이지 629 OCR 완료
# 페이지 630 OCR 완료
# 페이지 631 OCR 완료
# 페이지 632 OCR 완료
# 페이지 633 OCR 완료
# 페이지 634 OCR 완료
# 페이지 635 OCR 완료
# 페이지 636 OCR 완료
# 페이지 637 OCR 완료
# 페이지 638 OCR 완료
# 페이지 639 OCR 완료
# 페이지 640 OCR 완료
# 페이지 641 OCR 완료
# 페이지 642 OCR 완료
# 페이지 643 OCR 완료
# 페이지 644 OCR 완료
# 페이지 645 OCR 완료
# 페이지 646 OCR 완료
# 페이지 647 OCR 완료
# 페이지 648 OCR 완료
# 페이지 649 OCR 완료
# 페이지 650 OCR 완료
# 페이지 651 OCR 완료
# 페이지 652 OCR 완료
# 페이지 653 OCR 완료
# 페이지 654 OCR 완료
# 페이지 655 OCR 완료
# 페이지 656 OCR 완료
# 페이지 657 OCR 완료
# 페이지 658 OCR 완료
# 페이지 659 OCR 완료
# 페이지 660 OCR 완료
# 페이지 661 OCR 완료
# 페이지 662 OCR 완료
# 페이지 663 OCR 완료
# 페이지 664 OCR 완료
# 페이지 665 OCR 완료
# 페이지 666 OCR 완료
# 페이지 667 OCR 완료
# 페이지 668 OCR 완료
# 페이지 669 OCR 완료
# 페이지 670 OCR 완료
# 페이지 671 OCR 완료
# 페이지 672 OCR 완료
# 페이지 673 OCR 완료
# 페이지 674 OCR 완료
# 페이지 675 OCR 완료
# 페이지 676 OCR 완료
# 페이지 677 OCR 완료
# 페이지 678 OCR 완료
# 페이지 679 OCR 완료
# 페이지 680 OCR 완료
# 페이지 681 OCR 완료
# 페이지 682 OCR 완료
# 페이지 683 OCR 완료
# 페이지 684 OCR 완료
# 페이지 685 OCR 완료
# 페이지 686 OCR 완료
# 페이지 687 OCR 완료
# 페이지 688 OCR 완료
# 페이지 689 OCR 완료
# 페이지 690 OCR 완료
# 페이지 691 OCR 완료
# 페이지 692 OCR 완료
# 페이지 693 OCR 완료
# 페이지 694 OCR 완료
# 페이지 695 OCR 완료
# 페이지 696 OCR 완료
# 페이지 697 OCR 완료
# 페이지 698 OCR 완료
# 페이지 699 OCR 완료
# 페이지 700 OCR 완료
# 페이지 701 OCR 완료
# 페이지 702 OCR 완료
# 페이지 703 OCR 완료
# 페이지 704 OCR 완료
# 페이지 705 OCR 완료
# 페이지 706 OCR 완료
# 페이지 707 OCR 완료
# 페이지 708 OCR 완료
# 페이지 709 OCR 완료
# 페이지 710 OCR 완료
# 페이지 711 OCR 완료
# 페이지 712 OCR 완료
# 페이지 713 OCR 완료
# 페이지 714 OCR 완료
# 페이지 715 OCR 완료
# 페이지 716 OCR 완료
# 페이지 717 OCR 완료
# 페이지 718 OCR 완료
# 페이지 719 OCR 완료
# 페이지 720 OCR 완료
# 페이지 721 OCR 완료
# 페이지 722 OCR 완료
# 페이지 723 OCR 완료
# 페이지 724 OCR 완료
# 페이지 725 OCR 완료
# 페이지 726 OCR 완료
# 페이지 727 OCR 완료
# 페이지 728 OCR 완료
# 페이지 729 OCR 완료
# 페이지 730 OCR 완료
# 페이지 731 OCR 완료
# 페이지 732 OCR 완료
# 페이지 733 OCR 완료
# 페이지 734 OCR 완료
# 페이지 735 OCR 완료
# 페이지 736 OCR 완료
# 페이지 737 OCR 완료
# 페이지 738 OCR 완료
# 페이지 739 OCR 완료
# 페이지 740 OCR 완료
# 페이지 741 OCR 완료
# 페이지 742 OCR 완료
# 페이지 743 OCR 완료
# 페이지 744 OCR 완료
# 페이지 745 OCR 완료
# 페이지 746 OCR 완료
# 페이지 747 OCR 완료
# 페이지 748 OCR 완료
# 페이지 749 OCR 완료
# 페이지 750 OCR 완료
# 페이지 751 OCR 완료
# 페이지 752 OCR 완료
# 페이지 753 OCR 완료
# 페이지 754 OCR 완료
# 페이지 755 OCR 완료
# 페이지 756 OCR 완료
# 페이지 757 OCR 완료
# 페이지 758 OCR 완료
# 페이지 759 OCR 완료
# 페이지 760 OCR 완료
# 페이지 761 OCR 완료
# 페이지 762 OCR 완료
# 페이지 763 OCR 완료
# 페이지 764 OCR 완료
# 페이지 765 OCR 완료
# 페이지 766 OCR 완료
# 페이지 767 OCR 완료
# 페이지 768 OCR 완료
# 페이지 769 OCR 완료
# 페이지 770 OCR 완료
# 페이지 771 OCR 완료
# 페이지 772 OCR 완료
# 페이지 773 OCR 완료
# 페이지 774 OCR 완료
# 페이지 775 OCR 완료
# 페이지 776 OCR 완료
# 페이지 777 OCR 완료
# 페이지 778 OCR 완료
# 페이지 779 OCR 완료
# 페이지 780 OCR 완료
# 페이지 781 OCR 완료
# 페이지 782 OCR 완료
# 페이지 783 OCR 완료
# 페이지 784 OCR 완료
# 페이지 785 OCR 완료
# 페이지 786 OCR 완료
# 페이지 787 OCR 완료
# 페이지 788 OCR 완료

# %% [markdown]
# # PaddleOCR

# %%
import io
import os
import fitz 
from PIL import Image
from paddleocr import PaddleOCR 

def ocr_pdf_to_text_paddle(pdf_path, output_txt_path, lang="en", dpi=400):
    if not os.path.exists(pdf_path):
        print(f"{pdf_path} 경로 없음")
        return

    extracted_text = []

    ocr_model = PaddleOCR(use_angle_cls=True, lang=lang) 

    try:
        pdf_document = fitz.open(pdf_path)

        for page_num in range(len(pdf_document)):
            page = pdf_document.load_page(page_num)

            pix = page.get_pixmap(matrix=fitz.Matrix(dpi/72, dpi/72))
            
            img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)

            result = ocr_model.ocr(img, cls=True)
            
            page_text = []
            if result and result[0]: 
                for line in result[0]:
                    if line:
                        page_text.append(line[1][0]) 

            extracted_text.append(f"--- Page {page_num + 1} --- \n")
            extracted_text.append("\n".join(page_text)) 
            extracted_text.append("\n\n")
            print(f"페이지 {page_num + 1} OCR 완료 (PaddleOCR)")

    except Exception as e:
        print(f"PDF 처리 중 오류 (PaddleOCR): {e}")
        return
    
    finally:
        if "pdf_document" in locals() and pdf_document:
            pdf_document.close()

    try:
        with open(output_txt_path, 'w', encoding="utf-8") as f:
            f.writelines(extracted_text)
        print(f"텍스트 추출 완료 (PaddleOCR): {output_txt_path}")
    except IOError as e:
        print(f"파일 저장 중 오류 (PaddleOCR): {e}")

if __name__ == "__main__":
    input_pdf_file = "./data/KEPIC/KEPIC_FULL.pdf"
    for i in [500, 600] :
        output_text_file_paddle = f"./data/KEPIC/kepic_paddleocr_{i}.txt"
        ocr_pdf_to_text_paddle(input_pdf_file, output_text_file_paddle, lang="korean", dpi=i)
    
    if os.path.exists(output_text_file_paddle):
        with open(output_text_file_paddle, 'r', encoding="utf-8") as f:
            print(f.read())
# Out:
# Connecting to https://paddle-model-ecology.bj.bcebos.com/paddlex/PaddleX3.0/fonts/PingFang-SC-Regular.ttf ...
# Downloading PingFang-SC-Regular.ttf ...
# [==================================================] 100.00%
# Connecting to https://paddle-model-ecology.bj.bcebos.com/paddlex/PaddleX3.0/fonts/simfang.ttf ...
# Downloading simfang.ttf ...
# [==================================================] 100.00%
# /tmp/ipykernel_1374159/4109186701.py:14: DeprecationWarning: The parameter `use_angle_cls` has been deprecated and will be removed in the future. Please use `use_textline_orientation` instead.
#   ocr_model = PaddleOCR(use_angle_cls=True, lang=lang, show_log=False)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 57
#      55 input_pdf_file = "./data/KEPIC/KEPIC_FULL.pdf"
#      56 output_text_file_paddle = "./data/KEPIC/kepic_paddleocr.txt"
# ---> 57 ocr_pdf_to_text_paddle(input_pdf_file, output_text_file_paddle, lang="korean", dpi=400)
#      59 if os.path.exists(output_text_file_paddle):
#      60     with open(output_text_file_paddle, 'r', encoding="utf-8") as f:
#
# Cell In[4], line 14, in ocr_pdf_to_text_paddle(pdf_path, output_txt_path, lang, dpi)
#      10     return
#      12 extracted_text = []
# ---> 14 ocr_model = PaddleOCR(use_angle_cls=True, lang=lang, show_log=False)
#      16 try:
#      17     pdf_document = fitz.open(pdf_path)
#
# File /opt/conda/envs/sangwon/lib/python3.11/site-packages/paddleocr/_pipelines/ocr.py:161, in PaddleOCR.__init__(self, doc_orientation_classify_model_name, doc_orientation_classify_model_dir, doc_unwarping_model_name, doc_unwarping_model_dir, text_detection_model_name, text_detection_model_dir, textline_orientation_model_name, textline_orientation_model_dir, textline_orientation_batch_size, text_recognition_model_name, text_recognition_model_dir, text_recognition_batch_size, use_doc_orientation_classify, use_doc_unwarping, use_textline_orientation, text_det_limit_side_len, text_det_limit_type, text_det_thresh, text_det_box_thresh, text_det_unclip_ratio, text_det_input_shape, text_rec_score_thresh, text_rec_input_shape, lang, ocr_version, **kwargs)
#     157         base_params[name] = val
#     159 self._params = params
# --> 161 super().__init__(**base_params)
#
# File /opt/conda/envs/sangwon/lib/python3.11/site-packages/paddleocr/_pipelines/base.py:62, in PaddleXPipelineWrapper.__init__(self, paddlex_config, **common_args)
#      60 super().__init__()
#      61 self._paddlex_config = paddlex_config
# ---> 62 self._common_args = parse_common_args(
#      63     common_args, default_enable_hpi=_DEFAULT_ENABLE_HPI
#      64 )
#      65 self._merged_paddlex_config = self._get_merged_paddlex_config()
#      66 self.paddlex_pipeline = self._create_paddlex_pipeline()
#
# File /opt/conda/envs/sangwon/lib/python3.11/site-packages/paddleocr/_common_args.py:43, in parse_common_args(kwargs, default_enable_hpi)
#      41 unknown_names = kwargs.keys() - default_vals.keys()
#      42 for name in unknown_names:
# ---> 43     raise ValueError(f"Unknown argument: {name}")
#      45 kwargs = {**default_vals, **kwargs}
#      47 if kwargs["precision"] not in SUPPORTED_PRECISION_LIST:
#
# ValueError: Unknown argument: show_log

# %% [markdown]
# # TrOCR

# %%
import io
import os
import fitz 
from PIL import Image
from transformers import TrOCRProcessor, VisionEncoderDecoderModel 
import torch 

def ocr_pdf_to_text_trocr(pdf_path, output_txt_path, dpi=400):
    if not os.path.exists(pdf_path):
        print(f"{pdf_path} 경로 없음")
        return

    extracted_text = []

    model_name = "nlpconnect/vit-base-patch16-224-multilingual-gec" 
    processor = TrOCRProcessor.from_pretrained(model_name)
    model = VisionEncoderDecoderModel.from_pretrained(model_name)

    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)
    print(f"TrOCR using device: {device} (Model: {model_name})")

    try:
        pdf_document = fitz.open(pdf_path)

        for page_num in range(len(pdf_document)):
            page = pdf_document.load_page(page_num)

            pix = page.get_pixmap(matrix=fitz.Matrix(dpi/72, dpi/72))
            img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)

            pixel_values = processor(images=img, return_tensors="pt").pixel_values
            pixel_values = pixel_values.to(device)

            generated_ids = model.generate(pixel_values)
            generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

            extracted_text.append(f"--- Page {page_num + 1} --- \n")
            extracted_text.append(generated_text)
            extracted_text.append("\n\n")
            print(f"페이지 {page_num + 1} OCR 완료 (TrOCR)")

    except Exception as e:
        print(f"PDF 처리 중 오류 (TrOCR): {e}")
        return
    
    finally:
        if "pdf_document" in locals() and pdf_document:
            pdf_document.close()

    try:
        with open(output_txt_path, 'w', encoding="utf-8") as f:
            f.writelines(extracted_text)
        print(f"텍스트 추출 완료 (TrOCR): {output_txt_path}")
    except IOError as e:
        print(f"파일 저장 중 오류 (TrOCR): {e}")

if __name__ == "__main__":
    input_pdf_file = "./data/KEPIC/KEPIC_FULL.pdf" 
    for i in [500, 600] :
        output_text_file_trocr = f"./data/KEPIC/kepic_trocr_{i}.txt"
        ocr_pdf_to_text_trocr(input_pdf_file, output_text_file_trocr, dpi=i)
    
    if os.path.exists(output_text_file_trocr):
        with open(output_text_file_trocr, 'r', encoding="utf-8") as f:
            print("\n--- TrOCR Extracted Text Sample ---")
            print(f.read()[:2000])
# Out:
# 페이지 1 OCR 완료
# 페이지 2 OCR 완료
# 페이지 3 OCR 완료
# 페이지 4 OCR 완료
# 페이지 5 OCR 완료
# 페이지 6 OCR 완료
# 페이지 7 OCR 완료
# 페이지 8 OCR 완료
# 페이지 9 OCR 완료
# 페이지 10 OCR 완료
# 페이지 11 OCR 완료
# 페이지 12 OCR 완료
# 페이지 13 OCR 완료
# 페이지 14 OCR 완료
# 페이지 15 OCR 완료
# 페이지 16 OCR 완료
# 페이지 17 OCR 완료
# 페이지 18 OCR 완료
# 페이지 19 OCR 완료
# 페이지 20 OCR 완료
# 페이지 21 OCR 완료
# 페이지 22 OCR 완료
# 페이지 23 OCR 완료
# 페이지 24 OCR 완료
# 페이지 25 OCR 완료
# 페이지 26 OCR 완료
# 페이지 27 OCR 완료
# 페이지 28 OCR 완료
# 페이지 29 OCR 완료
# 페이지 30 OCR 완료
# 페이지 31 OCR 완료
# 페이지 32 OCR 완료
# 페이지 33 OCR 완료
# 페이지 34 OCR 완료
# 페이지 35 OCR 완료
# 페이지 36 OCR 완료
# 페이지 37 OCR 완료
# 페이지 38 OCR 완료
# 페이지 39 OCR 완료
# 페이지 40 OCR 완료
# 페이지 41 OCR 완료
# 페이지 42 OCR 완료
# 페이지 43 OCR 완료
# 페이지 44 OCR 완료
# 페이지 45 OCR 완료
# 페이지 46 OCR 완료
# 페이지 47 OCR 완료
# 페이지 48 OCR 완료
# 페이지 49 OCR 완료
# 페이지 50 OCR 완료
# 페이지 51 OCR 완료
# 페이지 52 OCR 완료
# 페이지 53 OCR 완료
# 페이지 54 OCR 완료
# 페이지 55 OCR 완료
# 페이지 56 OCR 완료
# 페이지 57 OCR 완료
# 페이지 58 OCR 완료
# 페이지 59 OCR 완료
# 페이지 60 OCR 완료
# 페이지 61 OCR 완료
# 페이지 62 OCR 완료
# 페이지 63 OCR 완료
# 페이지 64 OCR 완료
# 페이지 65 OCR 완료
# 페이지 66 OCR 완료
# 페이지 67 OCR 완료
# 페이지 68 OCR 완료
# 페이지 69 OCR 완료
# 페이지 70 OCR 완료
# 페이지 71 OCR 완료
# 페이지 72 OCR 완료
# 페이지 73 OCR 완료
# 페이지 74 OCR 완료
# 페이지 75 OCR 완료
# 페이지 76 OCR 완료
# 페이지 77 OCR 완료
# 페이지 78 OCR 완료
# 페이지 79 OCR 완료
# 페이지 80 OCR 완료
# 페이지 81 OCR 완료
# 페이지 82 OCR 완료
# 페이지 83 OCR 완료
# 페이지 84 OCR 완료
# 페이지 85 OCR 완료
# 페이지 86 OCR 완료
# 페이지 87 OCR 완료
# 페이지 88 OCR 완료
# 페이지 89 OCR 완료
# 페이지 90 OCR 완료
# 페이지 91 OCR 완료
# 페이지 92 OCR 완료
# 페이지 93 OCR 완료
# 페이지 94 OCR 완료
# 페이지 95 OCR 완료
# 페이지 96 OCR 완료
# 페이지 97 OCR 완료
# 페이지 98 OCR 완료
# 페이지 99 OCR 완료
# 페이지 100 OCR 완료
# 텍스트 추출 완료 : ./data/KEPIC/kepic_1601_1700_tesseract.txt
# --- Page 1 ---
# MEN(202014 판)
# [2022 45]
#
# 첨가한 것, 녹이기 위해 잘 교반하고 5사의 NaOH
# 용액을 사용하여 01 5.3으로 맞춘다. 냉각시키고 1
# Ｌ로 희석한다.
# A3.6.8 SAE HS
# A3.7 Zo AA}
# 43.7.1 고압분해장치와 시료의 준비
#
# 착화선을 약 10) 0ㅁ길이로 자른다. 중앙부분(약 20
# 0000)를 감아서 양단을 단자에 연결한다. 코일이 시료
# 컵의 상단 한쪽에 오도록 코일을 배열한다. 고압분해장
# Alo] 10 mL2] Ha4Ak UERS Ya S7jq FAs
# 넣는다. 그리고, 고압분해장치 내에서 용액을 잘 섞기
# 위해 15조 동안 흔들어 준다. 고압분해장치를 열고 단
# 자 집게로 시료를 채운 시료컵을 놓고 시료와 착화
# 선 사이에 짧은 실을 넣는다. 사용된 시료의 중량은
# 1 을 넘지 않아야 한다. 만약 시료가 고체라면 시
# 료의 점화를 확실히 하기 위해 이때 백유를 몇 방
#
# 울 떨어뜨린다.
#
# 2105
# 5 1010
#
# 10 to 20
#
# 20 to 50
#
#
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# to 5.3 using 5 N NaOH solution. Cool and dilute to 1 L.
#
# A3.6.8 White Oil, refined
# A3.7 Decomposition Procedure
# A3.7.1 Preparation of Bomb and Sample
#
# Cut a piece of firing wire approximately 100 mm in
# length. Coil the middle section (about 20 mm) and attach
# the free ends to the terminals. Arrange the coil so that it
# will be above and to one side of the sample cup. Place 10
# mL of sodium citrate solution in the bomb, place the cover
# on the bomb, and vigorously shake for 15 s to distribute
# the solution over the inside of the bomb. Open the bomb,
# place the sample- filled sample cup in the terminal holder,
# and insert a short length of thread between the firing wire
# and the sample. The sample weight used should not
# exceed | g. If the sample is a solid, add a few drops of
#
# white oil at this time to ensure ignition of the sample.
#
# NOTE A3.3 Use of sample weights containing over 20 mg of chlorine
# may cause corrosion of the bomb. To avoid this it is recommended that
# for samples containing over 2% chlorine, the sample weight be based on
#
# the following table:
#
# 중량,
#
# Caution : Do not use more than 1g total of sample and white oil or other fluorine-free combustible material.
#
# A3.7.2 AA FQ
# 시료컵을 제위치에 놓고 면 심지 또는 나일론 실
#
# A3.7.2 Addition of Oxygen
#
# Place the sample cup in position and arrange the nylon
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:15:22 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 2 ---
#
#
#
#
# MEN(202014 판)                                                                                                   MEN(2020 Ed.)
# [20224 4S]                                                                         [2022 Add.]
# 의 끝단이 시료 안에 담기도록 배치한다. 고압분해    thread, or wisp of cotton. so that the end dips into the
# 장치를 조립하고 덮개를 단단히 조인다. (경고 -       sample. Assemble the bomb and tighten the cover
# 고압분해장치가 충격을 받았거나, 떨어뜨렸거나 또      securely. Admit oxygen (see the Warning below) slowly
# 는 기울어졌을 경우 산소를 Fea  시료를 점    (to avoid blowing the sample from the cup) until a
# 화하지 않는다.) 표 43.1에 주어진 압력에 도달할     pressure is reached as indicated in Table A3.1.
# mA) AfeAL 7°] eA] SRS AbaA(oke 2
# 고 참조)를 천천히 주입한다.
# (경고 - 고압분해장치가 충격을 받았거나, 떨어뜨렸거나 또는         (Warning - It is recommended to not add oxygen or ignite the sample
# 기울어졌을 경우에 시료를 점화시키거나  a   를 주입         if the bomb has been jarred, dropped, or tilted.)
# 하지 않도록 권장된다.)
# 표 4 3.1 게이지 압력
# 게이지압력, 307 (44『8)
# 38(3.85)                      40(4.05)
# 35(3.55)                      37(3.75)
# 30(3.04)                      32(3.24)
# 27(2.74)                      29(2.94)
# 압력
# TABLE A3.1 GAGE PRESSURES
# Gage Pressure, atm (MPa)
# Capacity of Bomb, mL
# min”                       max
# 300 to 350                            38(3.85)                     40(4.05)
# 350 to 400                               35(3.55)                       37(3.75)
# 400 to 450                               30(3.04)                       32(3.24)
# 450 to 500                           27(2.74)                    29(2.94)
# NOTE <1> The minimum pressures are specified to provide sufficient oxygen for complete combustion and the
# maximum pressures present a safety requirement.
# A3.7.3 AA                                                        A3.7.3 Combustion
# 차가운 중류수조에 고압분해장치를 담근다. 개방       Immerse the bomb in a cold- water bath. Connect the
# 된 전기회로에 난자를 연결한다. 회로를 닫아 시료   terminals to the open electrical circuit. Close the circuit to
# 를 점화시킨다. 고압분해장치는 최소한 10분 동안     ignite the sample. Remove the bomb from the bath after
# 담근 후에 수조에서 꺼낸다. 조작이 최소한 1분 이      immersion for at least 10 min. Release the pressure at a
# 상이 되도록 일정한 낮은 속도로 압력을 천천히 해    slow, uniform rate such that the operation requires not less
# 제한다. 고압분해장치를 열고 내용물을 검사한다.      than 1 min. Open the bomb and examine the contents. If
# 연소되지 않은 미량의 기름 또는 그을린 A4e°l       traces of unburned oil or sooty deposits are found,
# 발견될 경우에는 측정을 취소하고 고압분해장치를       discard the determination, and thoroughly clean the
# 다시 사용하기 전에 완전히 세척한다.                       bomb before again putting it in use.
#
# Copyrighted mater ial
#
# 1538
#
# licensed to deepai0915 on 2025.6.16 15:15:23 for license's use only.
# Copyrighted and Authorized by Korea Electric Association.
#
# Copying and networking prohibited.
#
#
# --- Page 3 ---
# <
# m
# NE
# N
# ©
# MN
#
# 깨끗한 집게로 시료컵을 꺼내어 이온제거수로 시
# 료를 세척하고 이 세척액을 여과하여 100 ㅁ1 용량
# 의 플라스크에 담는다. 용기측면 벽을 세정액 병의
# 이온제거수로 조금씩 흘려 Hoc. 이 Ae AS
# 여과지를 통해 플라스크에 첨가한다. 그 다음 용기
# 9] Ast GAS AAA AAAS 여과하여 플
# 스크에 첨가한다. 마지막으로 플라스크의 내용물이
# 적정선까지 오도록 이온수를 첨가한다. 이온 크로
# 마토그라피 분석시 이 용액을 나뉘서 사용한다.
# A3.8 BA}
#
# A3.8.1 제조자의 설명에 따라 전극의 기울기(10배의
#
# 의
# 농도 변화 당 밀리볼트의 변화량)를 확인한다.
#
# 7
#
# A3.8.2 시료없이 절차를 수행하여 바탕값 용액을
#
# 얻는다
# 43.8.3 응액에 불소와 대비전극을 넣고 0.1 mv에
# 해당하는 평형값을 얻는다(이 전극의 조건에서 평
# 영에 도달하는데 필요한 시간을 결정한다. 이 시간
# 은 짧으면 5분에서 길면 20분이 걸릴 수 있다.)
# A3.8.4 100 pL2] BASSAS 첨가하고 43.8.3에서
# 필요로 하는 동일한 시간 경과 후에 판독값을 얻는
# 다.
# 43.9 계산
# A3.9.1 A529) 불소함유량은 다음과 같이 계산한다
# 2×10 ” 2×10”
# 10AE/S—-1 10AB/S—1
# = 2 (ppm) = LMARIST 1 MWABISTA] 0
# W
# (A3.1)
# 여기서
#
# 4467 : 시료용액에 불소용액을 100 1Ｌ 첨가했을
# E
#
# 442 : 시료가 없을 경우 불소용액을 100 11. 첨
# 가했을 때의 밀리볼트의 변화
# $: 46.3.8.1 에서 확정한 불화물 전극의 기울기
# W: ABS] SE, g
# ^3.10 정밀도와 편차
#
# 43.10.1 반복성
#
# 같은 시료로부터 얻은 두개의 결과는 그 차이가
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# A3.7.4 Collection of Fluorine Solution
#
# Remove the sample cup with clean forceps and rinse
# with wash solution into a 100-mL volumetric flask. Rinse
# the walls of the bomb shell with a fine stream of wash
# solution from a wash bottle, and add the washings to the
# flask.
# Next, rinse the bomb cover and terminals into the
# volumetric flask. Finally, add wash solution to bring the
#
# contents of the flask to the line.
#
# A3.8 Procedure
# A3.8.1
#
# change in concentration) of the electrode as described by
#
# Ascertain the slope (millivolts per ten-fold
#
# the manufacturer.
#
# A3.8.2 Obtain a blank solution by performing _ the
# procedure without a sample.
#
# A3.8.3 Immerse the fluoride and reference electrodes in
# solutions and obtain the equilibrium reading to 0.1
# mvV.(The condition of the electrode determines the length
# of time necessary to reach equilibrium. This may be as
# little as 5 min or as much as 20 min.)
#
# A3.8.4 Add 100 wL of stock fluoride solution and obtain
# the reading after the same length of time necessary for
# A3.8.3.
#
# A3.9 Calculation
#
# A3.9.1 Calculate the fluorine content of the sample as
# follows:
# 2×10 ， 2×10”
# .             10AB,/S—-1 10AB/S—1      6
# Fluorine, ppm =                                             < 10
# W
# (A3.1)
#
# where:
# E1 = millivolt change in sample solution on addition
# of 100 L of stock fluoride solution,
# E2 = millivolt change in blank solution on addition of
# 100 L of the stock fluoride solution,
# S = slope of fluoride electrode as determined in
# A3.8.1, and
# W = grams of sample.
# A3.10 Precision and Bias
# A3.10.1 Repeatability
#
# The results of two determinations by the same analyst
#
# 1539
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:21:46 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 4 ---
# MEN(202014 판)
#
# [2022년 추록]
# 1.1 ppm(0.00011 %) 또는 측정값의 8.0 %중 큰 것
# 이상의 차이가 없으면 의심할 필요가 없다
# 43.10.2 재현성
#
# 다른 실험실에서 얻은 두개의 결과는 그 차이가
# 6.7 200(0.00067 %) 또는 측정값의 129.0 %중 =
# 것 이상의 차이가 없으면 의심할 필요가 없다.
# A3.10.3 HA}
#
# 이 방법의 평균적인 재현성은 실제 지시값의 6
# 2~64 %이며 적절한 기법을 이용한다면 83-&5 %
#
# 의 재현성이 기대된다.
#
# 44. 전도도 측정을 이용한
# 크로마토그라피법에 의한 음이온
# 바번
# |
#
# A4.1 “eee
#
# A4.1.1 이 8
#
# 약하였으며
#
# 가장 적합호
#
# oO
#
# 정
#
# 적요
# ㄱㅎ
#
# 2 ASTM © APHA 429 내
# Jue] 유해
# 다. 브롬화
#
# 용을
# 물질을 분석하기
#
# Wa
# =
#
# ~
#
# 0]
#
# 06 (6 Mt 오 i
#
# oO
#
# —_
#
# u
#
# 이온
# 대한
#
# 1
#
# column) 4]
# 리된다.                         교환기
# (suppressor column)= 보내어지며, 여기에서 음ㅇ
# 온은 고 전도성의 산 형태(300 10070)로 변환된다.
# 산 형태로 분리된 음이온의 전도도를 측정한다. 음
#
# 양이온
#
# H
# VT
#
# —[— -_-ㅡ_
#
# Copyrighted mater ial
#
# 1540
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# should not be considered suspect unless they differ by
# more than 1.1 ppm (0.00011%) or 8.0% of the amount
# detected, whichever is greater.
# A3.10.2 Reproducibility
#
# The
# laboratories should not be considered suspect unless they
#
# differ by 6.7 ppm or 129.0% of the amount detected,
#
# results of two determinations by different
#
# whichever is greater.
# A3.10.3 Bias and Precision
#
# The average recovery of the method is 62 to 64% of the
# amount actually present although 83 to 85% recoveries
#
# can be expected with proper technique.
#
# A4. Determination of Anions by Ion
# Chromatography With Conductivity
# Measurement
#
# A4.1 Scope and Application
#
# A4.1.1   This method is condensed from ASTM
#
# procedures and APHA Method 429 and optimized for the
#
# analysis of detrimental substances in organic based
# materials.
#
# It provides a single instrumental technique for rapid,
#
# sequential measurement of common anions such as
#
# bromide, chloride, fluoride, nitrate, nitrite, phosphate, and
#
# sulfate.
# A4.2. Summary of Method
# A4.2.1 The material must be put in the form of an
#
# aqueous solution before analysis can be attempted. The
# sample is oxidized by combustion in a bomb containing
# oxygen under pressure. The products liberated are
# absorbed in the eluant present in the bomb at the time of
# ignition. This solution is washed from the bomb, filtered,
# and diluted to a known volume.
#
# A4.2.1.1
#
# stream of carbonate-bicarbonate eluant and passed
#
# A filtered aliquot of sample is injected into a
#
# through a series of ion exchangers. The anions of interest
# are separated on the basis of their relative affinities for a
# low capacity, strongly basic anion exchanger (guard and
# separator column). The separated anions are directed onto
# a strongly acidic cation exchanger (suppressor column)
# form and the carbonate-bicarbonate eluant is converted to
#
# weakly conductive carbonic acid. The separated anions in
#
# licensed to deepai0915 on 2025.6.16 15:21:47 for license's use only.
# Copyrighted and Authorized by Korea Electric Association.
#
# Copying and networking prohibited.
#
#
# --- Page 5 ---
# ‘BY to
#
# 대
# uu
#
# X
#
# 년
# ro
# 비오
# Ol
#
# 월
#
# Om
#
# et
#
# of a
# we, ”
# 니카 그
#
# 비이
#
# 나오
#
# 위
# jo 수
#
# 때
#
# ※
# rol fll pO 1% of 32 oY
#
# °    to ht
# ng,
#
# |
#
# ㅇ
# Om
#
# 1°,
#
# ea
#
# O
#
# 웨
# +
#
# 시료의 크기와 사용된
# 일반적으로 최소 검
# Ｌ 시   0000)을 사용하고 전도도
#
# 전측정범위가 10 17010일 때 는 0.05
# mg/L, Br, Cl, NO3, NO», PO.” 및 580 = 0.1
#
# 718/Ｌ이다. 눈금설정이 더 큰 전자 인테그레이터
# (1016813107)를 사용하여 근접한 값을 얻을 수 있다.
# 44.3 장치
# 44.3.1 고압분해장치
# 고압분해장치는 300 ㅁＬ이상의 용량을 가진 것으로
# 시험 중 누설이 발생하지 않고 고압분해장치에서
# 액체의 정량적인 회수가 용이하게 이루어지도록 제
# 작한다. 고압분해장치 내부 표면은 스테인리스 강
# 또는 연소과정이나 제품에 영향이 없는 기타의 다
# 른 재료로 만든다. 헤드 개스킷과 납선 절연제와
# 같이 고압분해장치 조립에 사용되는 재료는 화학적
# 반응과 열에 저항성을 가져야 하고 고압분해장치
# 내부 액체의 염소 함유량에 영향을 줄 수 있는 어
# 떠한 반응도 일어나서는 안 된다.
# 44.3.2 시료컵
#
# 시료컵은 하단 바깥지름 34 07, 상단 바깥지름
#
# Copyrighted mater ial
#
# 1541
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# their acid form are measured by conductivity. They are
# identified on the basis of retention time as peak height.
#
# Blanks are prepared and analyzed in a similar fashion.
#
# A4.2.2 Interferences
# Any substance that has a retention time coinciding with
#
# that of any anion to be determined will interfere. For
#
# example,   relatively   high   concentrations   of
# low-molecular-weight organic acids interfere with the
# determination of chloride and fluoride.  A high
#
# concentration of any one ion also interferes with the
# resolution of others. Sample dilution overcomes many
# interferences. To resolve uncertainties of identification or
# quantitation use the method of known additions. Spurious
# peaks may result from contaminants in reagent water,
# glass- ware, or sample processing apparatus. Because
# small sample volumes are used, scrupulously avoid
# contamination.
# A4.2.3 Minimum Detectable Concentration
#
# The minimum detectable concentration of an anion is a
# function of sample size and conductivity scale used.
# Generally, minimum detectable concentrations are in the
# range of 0.05 mg/L for F and 0.1 mg/L for Br, Cl, NOs,
# NO2z, PO«*, and SO4 with a 100- L sample loop and a
# 10-mho scale setting on the conductivity detector. Similar
# values may be achieved by using a higher scale setting
# and an electronic integrator.
# A4.3. Apparatus
# A4.3.1 Bomb
#
# Having a capacity of not less than 300 mL, so
# constructed that it will not leak during the test, and that
# quantitative recovery of the liquids from the bomb may
# be readily achieved. The inner surface of the bomb may be
# made of stainless steel or any other material that will not
# be affected by the combustion process or products.
# Materials used in the bomb assembly, such as the head
# gasket and leadwire insulation, shall be resistant to heat
# and chemical action, and shall not undergo any reaction
# that will affect the chlorine content of the liquid in the
# bomb.
# A4.3.2 Sample Cup
#
# Platinum, 24 mm in outside diameter at the bottom, 27
#
# licensed to deepai0915 on 2025.6.16 15:21:49 for license's use only.
#
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 6 ---
# MEN(202014 판)
# [2022년  수록]
#
# 27 20001, 높이 12 000이며 중량이 10~11 &인 백
# 으로 제작된 것이거나, 상단 바깥지름 29 200,
# 이 19 27001, 용량이 5 270Ｌ인 불투명     실리카(
#
# ©                    a
# AAIAA)= 제작된 대형         단 바깥
#
# mw ay
#
# Ee
# 투
# 4
#
# 점,
#
# [ 00
#
# °
# 유
# 또는 하
#
# ㄴ
#
# kK
#
# _—/
#
# 름 20 00, 상단 바깥지름 28 mm, =°] 15 mm,
#
# 용량이 5 mL?l UA(Kawin BS)Z2 제작된 것이
#
# 어야 한다.
#
# 비고 44.1: 용융 실리카 도가니는 백금보다 훨씬 경제적이고 오
# 래 사용한다. 사용 후에는 매번 가루가 곱고 젖어있
# 는 금강사(6067/)천으로 문지르고, 버너의 BES
# 어두운 적색 불꽃에서 가열한다. 그리고 나서 뜨거
# 운 물속에 1시간 동안 담가둔 다음 건조시키고 제사
# 용할 때까지 건조기에 보관한다.
#
# 44.3.3 착화선
# No. 26B & 을 게이지에 가까운
#
# A4.3.4 ete we A4.2)
# 착화선이 녹지않고 면 심지 또는 나일론 실을 점
# 화시키기에 충분한 전류를 공급할 수 있어야 한다.
# 비고 44.2 주의 - 점화 회로의 스위치는 작업자가 누르고 있는
# 동안만 회로가 닫히는 형태이어야 한다,
# 44.3.5 흰색의 나일론 실 또는 면 심지
# 4&4.3.6 이온 크로마토그라프
# 주입밸브,   A) SZ,   7+=(guard),    분리기
# (861081231017), 억제기(641001685801), 온도보정 저용량
# 전도도 셀(0601)(6 14Ｌ 이하), 그리고 2초 이하에 전
# 체 눈금의 응답을 기록할 + te SEY AE 기
# =7](strip chart recorder)= 구성된다. 정점 적분
# 기능은 선택사항이다. 이온 크로마토그라프는 140
# 0~6900 103압력에서 일루언트 2~5 701Ｌ/분을 이
# 송할 수 있어야 한다.
# 4&4.3.7 음이온 분리기(30101 500200『 <014170)
# 재질은 스티렌 디비닐 벤젠이며 저용량 박막 음
#
# 이온 교환수지이고 크기는 4 × 250 mme]4 Br
#
# ’
#
# Cl, F, NOs, NO: , PO”, SO” 를 분리시킨다.
# A4.3.8 7}&(guard column)
#
# 크기가 4 × 50 mmel AS A sabe Bel 7] gy}
# 동일하다. 미립자나 유기물에 의해 분리기가 막히
# 는 것을 방지한다.
#
# A4.3.9 AAl7|(suppressor column)
#
# 고용량 양이온 교환수지이며 분리되어 있는 음이
# 온과 일루언트를 산(300) 형태로 변환시킨다.
# A4.3.10 42 7| (syringe)
#
# 최소용량이 2 2ㅁ1.이고 압력용 숫이음쇠가 부착되
#
# Copyrighted mater ial
#
# Copyrighted and Authorized by Korea Electric Association.
#
# 1542
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# mm in outside diameter at the top, 12 mm in height
# outside, and weighing 10 to 11 g; opaque fused silica,
# wide-form with an outside diameterof 29 mm at the top, a
# height of 19 mm, and a 5mL capacity (Note A4.1), or
# nickel (Kawin capsule form), top diameter of 28 mm, 15
#
# mm in height, and 5mL capacity.
#
# NOTE A4.1: Fused silica crucibles are much more economical and
# longer lasting than platinum. After each use, they should
# be scrubbed out with fine, wet emery cloth, heated to dull
# red heat over a burner, soaked in hot water for 1 h then
#
# dried and stored in a desiccator before reuse.
#
# A4.3.3 Firing Wire
# Platinum, approximately No. 26 B and S gage.
# A4.3.4 Ignition Circuit (Note A4.2)
# Capable of supplying sufficient current to ignite the nylon
#
# thread or cotton wicking without melting the wire.
# NOTE A4.2 Caution : The switch in the ignition circuit shall be of a
#
# type that remains open, except when held in closed
#
# position by the operator.
#
# A4.3.5 Nylon Sewing Thread, or Cotton Wicking, white.
# A4.3.6 Ion Chromatograph
#
# Including an injection valve, a sample loop, guard,
# separator, and suppressor columns, a_ temperature-
# compensated small-volume conductivity cell (6 L or less),
# and a strip chart recorder capable of full-scale response of
# 2s or less. An electronic peak integrator is optional. The
# ion chromatograph shall be capable of delivering 2 to 5
#
# mL eluant/ min at a pressure of 1400 to 6900 kPa.
#
# A4.3.7 Anion Separator Column
# With
#
# pellicular anion-exchange resin capable of resolving Br,
#
# Cl, F, NO3, NO», PO. *, and SOq 2° ; 4x250 mm
#
# A4.3.8 Guard Column
#
# Identical to separator column except 4x50mm, to protect
#
# styrene divinyl-benzene-based low-capacity
#
# separator column from fouling by particulates or
# organics.
#
# A4.3.9 Suppressor Column
#
# of
# converting eluant and separated anions to their acid forms.
#
# A4.3.10 Syringe
#
# High-capacity cation-exchange resin capable
#
# licensed to deepai0915 on 2025.6.16 15:21:50 for license's use only.
#
# Copying and networking prohibited.
#
#
# --- Page 7 ---
# MEN(202014 판)
# [202244 A=]
#
# 어 있
#
# 4^4.4 시약
# 44.4.1 시약의 순도
#
# 모든 시험에는 시약등급의 화학약품을 사용하
# 야 한다. 별도의 언급이 없으면 모든 시
# 화학협회의          분석 시약위 21 3] (Committee         on
# Analytical Reagents of the America Chemical
# 80016600)요건(이 요건의 적용이 가능한 경우)에 따
#
# 라야 한다. 다른 등급의 시약은 시험법의 정확도와
# 편차가 감소되지 않고 사용이 가능한 충분한 고순
#
# oO
# 않고
# 도가 처음에 입증되면 사용할 수 있다,
#
# A4.4.2 0J2AAS 또
# 4a
#
# 각 성분의 최소 검출한계에도 방해가 없어야 하
# 며 0.2 의 박막필터로 여과하여 교환기의 막힘을
#
# 방지해야 한다.
# A4.4.3 일루언트(0201) 용액
#
# 중탄산나트륨-탄산소다 용액(0.00344 NaHCO; -
# 0.0024M NayCOs). 1.008 g2] NaHCO; $ 1.0176 g
# 의 제32005 를 물에 용해시키고 4 Ｌ로 희석시킨
# 것.
# 44.4.4 재생용액 1
#
# 1 지의 26504 이며 연속재생력을 갖지 않
# 제기에 사용한다.
# 44.4.5 재생용액 2
#
# 0.025 줘의 680, 이며 농축 11280, 2.8 ㅁ1.를 4
# Ｌ로 희석시키거나 100 2ㅁㅠＬ 의 재생용액 1을 4 Ｌ로
# 희석시킨 것이다. 이 재생용액은 연속재생용 섬유
# 질 억제시스템을 가진 억제기에 사용한다.
# 44.4.6 표준 음이온 용액
#
# oO)
# a
#
# (lo
#
# 아래에 표시된 양의 염기물을 용해시킨 물을
# 1000 27Ｌ.가 되도록 105 (의 온도에서 건조시켜 표
# 준 음이온 용액 100 78/Ｌ를 만든다. 이 용액은 플
#
# 스틱병에 담아 냉장고에 보관해야 하고 적어도 1
# 개월 동안은 보관하여 사용할 수 있다
#
# 1548
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# Minimum capacity of 2 mL and equipped with a male
# pressure fitting.
# A4.4 Reagents
# A4.4.1 Purity of Reagents
#
# Reagent grade chemicals shall be used in all tests.
# Unless otherwise indicated, it is intended that all reagents
# shall conform to the specifications of the Committee on
# Analytical Reagents of the American Chemical Society,
# where such specifications are available. Other grades may
# be used, provided it is first ascertained that the reagent
# 189 sufficiently high purity to permit its use without
# lessening the accuracy of the determination.
# A4.4.2 Deionized or Distilled Water
#
# Free from interferences at the minimum detection limit
# of each constituent and filtered through a 0.2 um
# membrane filter to avoid plugging columns.
# A4.4.3 Eluant Solution
#
# Sodium                                       0.003M
# NaHCO3-0.0024M Na2COs: dissolve 1.008 g NaHCOs
# and 1.0176 g Na2CO3 in water and dilute to 4 L.
#
# bicarbonate-sodium — carbonate,
#
# A4.4.4 Regenerant Solution 1
#
# H2S0O4,1 N, use this regenerant when suppressor is not a
# continuously regenerated one.
# A4.4.5 Regenerant Solution 2
#
# H2S04, 0.025 N, dilute 2.8 mL cone H2S04 to 4 L or
# 100 mL regenerant solution! to 4 L. Use this regenerant
#
# with continuous regeneration fiber suppressor system.
#
# A4.4.6 Standard Anion Solutions
#
# 100 mg/L, prepare a series of standard anion solutions
# by weighing the indicated amount of salt, dried to a
# constant weight at 105 °C, to 1000 mL. Store in plastic
# bottles in a refrigerator; these solutions are stable for at
#
# least one month.
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:21:51 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 8 ---
# MEN(202014 판)
# [2022년  수록]
#
# A4.4.7 혼합작업용 표준용액-고준우
#
# 10 mL2] Cl, F, NOs, NO. 및 202 표준
#
# NaCl
# NaF
# NaBr
# NaNO3
#
# NaNO,
#
# KH2P04
# K2S04
#
#
#
# oO
#
# —
#
# v
#
# o]< 2A | mL2} Br, Zz] 100 mL2} SO,”
#
# 준용액을 혼합하고 1000 ㅠㅁ[로 희석시킨 후 광선
# 자단이 되는 플라스틱병에 보관한다. 01, F, NOs,
#
# NO, 및 ㅁ20" 7k ZZ} 10 mg/L, Bre] 1 mg/L,
#
# 그리고 50” 를 100 208/Ｌ포함한 용액이다. 매일
# 새로운 용액을 준비해야 한다.
# 44.4.8 혼합작업용 표준용액-저준우
#
# 고준위 혼합작업용 표준용액 100 ㅁ1를 1000 ㅁＬ
# 로 희석시킨 것이며 광선차단이 되는 플라스틱병에
#
# 보관한다. 21, F, NOs, NO. © PO,’ 가 각각
#
# 10 mg/L, Bre) 0.1 1200/Ｌ 그리고 80
#
# 10
#
# 008/Ｌ, 포함한 용액이다. 매일 새로운 용액을 준비
#
# 해야 한다.
#
# 44.4.9 대체 혼합작업용 표준용액
#
# ^4.5 시료 준비
# &4.5.1 침두제, 현상제, 유화제, 마그네틱 오일
#
# A4.5.1.1 150 mm WEz 접시에 무게 508@의
#
# 시험
#
# 1544
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# A4.4.7 Combined Working Standard Solution, High Range
#
# Combine 10 mL of the Cl, F, NOs, NOx, and PO,”
# standard anion solutions, 1 mL of the Br, and 100 mL of
# the SO,” standard solutions, dilute to 1000 mL, and store
# in a plastic bottle protected from light; contains 10 mg/L
# each of Cl, F, NOs, NO,-, and PO,, 1 mg Br/L, and
# 100 mg SO,”/L. Prepare fresh daily.
#
# A4.4.8 Combined Working Standard Solution, Low Range
#
# Dilute 100 mL combined working standard solution,
# high range, to 1000 mL and store in a plastic bottle
# protected from light; contains 1.0 mg/L each CI, F, NO3,
# and PO,°, 0.1 mg Br/L, and 10 mg SO,”/L. Prepare fresh
# daily.
#
# A4.4.9 Altemative Combined Working Standard Solutions
# Prepare appropriate combinations according to anion
#
# concentration to be determined. If NO2 and PO,° are not
#
# included, the combined working standard is stable for one
#
# month.
#
# A4.5 Sample Preparation
#
# A4.5.1 Penetrants, Developers, Emulsifiers, Magnetic
#
# Oils:
#
# A4.5.1.1 Weigh 50 g of test material into a 150-mm
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:21:52 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 9 ---
# 재료를 투입한다.
#
# A4.5.1.2 150 7707 패트리 접시를 오븐에 90':(19
# A°F)~ 100°C (212°F)로 60분간 가열한다.
#
# 4&4.5.1.3 시험재료는 실온에서 식힌다.
#
# 44.5.2 용제 세척제
#
# A4.5.2.1 Se 8A12] FAS Ach.
#
# A4.5.2.2 24) 접시에 세척제 1006을 넣는
# &4.5.2.3 알루미늄 접시는 환기후드의 가열판에 놓
# 는다.
#
# &4.5.2.4 알루미늄 접시가 거의 건조될 때까지 시험
#
# ASS Se
# A4.5.2.5 2   AAS 90° (194°F)o]A7 100
# (212°F)Abo] 2] AS eo] lok Sek BWEr.
#
# A4.5.2.6 2Se ANS 오븐에서 꺼내고 식힌다.
#
# rT
# >»
# 며
#
# &4.5.2.7 알루미늄 접시의 무게를 다시 재고 무게를
# 기록한다.
#
# 비고 44.3: 세척제
#
# 잔여물이 50 000보다 작을 경우, 잔여물 무게를 기록한다. 잔여
# 물 무게가 50 00보다 클 경우, 고압분해장치의 검사절차를 진
# 행한다.
#
# 44.6 분해절차
#
# 4&4.6.1 고압분해장치와 시료의 준비
#
# 착화선을 약 100 1700길이로 자른다. 중앙부분(약
# 20 ㅁ001)를 감아서 양단을 단자에 연결한다. 코일이
# 시료컵의 상단 한쪽에 오도록 코일을 배열한다. 용
# 기에 5 700Ｌ의 페32008/띠30110()6를 넣고 고압분해장
# 치 뚜경을 덮는다. 그리고 고압분해장치 내의 용액
# 이 잘 섞이도록 15초 동안 흔들어 준다. 고압분해장
# 치를 열고 시료를 채운 시료 컵을 단자 물림부에
# 놓고 짧은 실로 시료와 착화선을 연결한다. 사용된
# 시료의 종량은 1 을 넘어서는 안 된다. 만약 시료
# 가 고체라면 시료의 점화를 확실히 하기 위해 이때
# H    별
#
# 1545
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# petri dish.
# A4.5.1.2 Place the 150-mm petri dish into a 90°C
# [194°F] to 100°C [212°F] oven for 60 minutes.
# A4.5.1.3. Allow the test material to cool to room
# temperature.
#
# A4.5.2 Solvent Cleaners:
#
# A4.5.2.1 Take the tare weight of an aluminum dish.
# A4.5.2.2 Weigh
#
# aluminum dish.
#
# 100 g of the cleaner into the
#
# A4.5.2.3 Place the aluminum dish on a hot plate in a
# fume hood.
#
# A4.5.2.4 Let the material evaporate until the dish is
# nearly dry.
#
# A4.5.2.5 Place the dish into a preheated oven from
# 90°C [194°F] to 100°C [212°F] for 10 minutes.
# A4.5.2.6 Take the dish out of the oven and allow to
# cool.
#
# A4.5.2.7 Reweigh the dish and record weight.
#
# NOTE A4.3 For Cleaners—If the residue is less than 50 ppm,
# report the residue weight. If the weight is greater than 50 ppm,
#
# proceed with the bomb procedure.
#
# A4.6 Decomposition Procedure
# A4.6.1 Preparation of Bomb and Sample
#
# Cut a piece of firing wire approximately 100 mm in
# length. Coil the middle section (about 20 mm) and attach
# the free ends to the terminals. Arrange the coil so that it
# will be above and to one side of the sample cup. Place 5
# mL of Na2CO3/ NaHCO; solution in the bomb, place the
# cover on the bomb, and vigorously shake for 15 s to
# distribute the solution over the inside of the bomb. Open
# the bomb, place the sample-filled sample cup in the
# terminal holder, and insert a short length of thread
# between the firing wire and the sample. The sample
# weight used should not exceed lg. If the sample is a
# solid, add a few drops of white oil at this time to ensure
#
# ignition of the sample.
#
# NOTE A4.4 Use of sample weights containing over 20 mg of chlorine
# may cause corrosion of the bomb. To avoid this it is recommended that
# for samples containing over 2% chlorine, the sample weight be based on
#
# the following:
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:21:53 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 10 ---
#
#
# MEN(20204 판)                                                                                                MEN(2020 Ed.)
# [20224 4S]                                                                                                      [2022 Add.]
# 시료 중량, 0
# 주의                                                                                        된다.
#
# Chlorine Content, %               Sample Weight, g                White Oil Weight, g
#
# 5 to 10
# 10 to 20
# 20 to 50
# CAUTION: Do not use more than 1| g total of sample and white oil or other fluorine-free combustible material.
# A4.6.2 AIX~ 주입                                          A4.6.2 Addition of Oxygen
# 시료컵을 제 위치에 놓고 면 심지 또는 나일론        Place the sample cup in position and arrange the nylon
# Alo) Bro] Als obo] G7)E= waa     고암부      thread, or wisp of cotton so that the end dips into the
# ca    Bu          Le    v      ㄱ       L   .    Hw                   p                            p
# 해장치를 조립하고 덮개를 단단히 조인다. (경고 -      sample. Assemble the bomb and tighten the cover
# 고압분해장치가 충격을 받았거나, 떨어뜨렸거나 =      securely. Admit oxygen (Note A4.5) slowly (to avoid
# 는 기울어졌을 경우 산소를 주입하거나 시료를 점      blowing the sample from the cup) until a pressure is
# 화하지 않는다.) FF Adio 주어진 압력에 도달할      reached as indicated in Table A4.1.
# 때까지 컵에서 기름이 날리지 않도록 산소(비고        NOTE A4-.5 -It is recommended to not add oxygen or ignite the sample
# ^45)를 천천히 주입한다                                        if the bomb has been jarred, dropped, or tilted.
# 비고 44.5 고압분해장치가 충격을 받았거나, 떨어졌거나 또는 기
# 울어졌을 경우에 시료를 점화시키거나 산소를 주입하지
# 않도록 권장된다
#
# H A411 게이지 압력
#
# 게이지압력 atm (MPa)
#
# 38(3.85)                                 40(4.05)
# 35(3.59)                                 37(3.75)
#
# 30(3.04)                                 32(3.24)
# 27(2.74)                                 29(2.94)
#
# 제공하기 위해 규정되고,
#
#
#
# 1546
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:21:54 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 11 ---
# MEN(202014 판)                                                           MEN(2020 Ed.)
# (202244 4S]                                                               [2022 Add.]
#
# TABLE A4.1 GAGE PRESSURE
#
# Gage Pressure, atm (MPa)
#
# max
#
# Capacity of Bom,(mL)
#
# 38(3.85)                               40(4.05)
#
# 35(3.55)                              37(3.75)
# 30(3.04)                              32(3.24)
# 27(2.74)                              29(2.94)
#
#
#
# NOTE <I> The minimum pressures are specified to provide sufficient oxygen for complete combustion and
# the maximum pressures present a safety requirement.
#
# A4.6.3 Aa                                                    A4.6.3 Combustion
#
# 차가운 중류수조에 고압분해장치를 담근다. 개방      Immerse the bomb in a cold-water bath. Connect the
# 된 전기회로에 단자를 연결한다. 회로를 닫아 시료       terminals to the open electrical circuit. Close the circuit to
# 를 점화시킨다. 고압분해장치는 최소한 10분 동안     ignite the sample. Remove the bomb from the bath after
# 담근 후에 수조에서 꺼낸다. 조작이 최소한 1분 이      immersion for at least 10 min. Release the pressure at a
# 상이 되도록 일정한 낮은 속도로 압력을 천천히 해       slow, uniform rate such that the operation requires not less
# 제한다. 고압분해장치를 열고 내용물을 검사한다.      than 1 min. Open the bomb and examine the contents. If
# 연소되지 않은 미량의 기름 또는 그을린 침전물이       traces of unburned oil or sooty deposits are found, discard
# 발견될 경우에는 측정을 취소하고 고압분해장치를      the determination, and thoroughly clean the bomb before
# 다시 사용하기 전에 완전히 세척한다                    again putting it in use.
# 4^4.6.4 용액의 채집                              A4.6.4 Collection of Solution
#
# 깨끗한 집게로 시료컵을 꺼내어 이온제거수로 시      Remove the sample cup with clean forceps and rinse
# 료를 세척하고 이 세척액을 여과하여 100 ㅁ1 용량      with deionized water and filter the washings into a
# 을 갖는 플라스크에 담는다. 용기측면 벽을 세정액     100-mL volumetric flask. Rinse the walls of the bomb
# 병의 이온 제거수를 조금씩 흘려 Wopdc. 이 4      shell with a fine stream of deionized water from a wash
# 2 AS Oo 까지 를 통해 플라스크에 첨가한다. 그       bottle, and add the washings through the filter paper to the
# 다음 용기의 뚜 BAS AAs AAAS 여과     flask. Next, rinse the bomb coverand terminals and add
# 하여 플라스크에 첨가한다. 마지막으로 플라스크의      the washings through the filter into the volumetric flask.
# 내용물이 적정한 선까지 오도록 LFS 첨가한      Finally, add deionized water to bring the contents of the
# 다. 이온 크로마토그라피 분석 시 이 용액을 나뉘    flask to the line. Use aliquots of this solution for the ion
# 서 사용한다.                                                              chromatography (IC) analysis.
# 44.7 절차                                    A4.7 Procedure
#
# A4.7.1 AAG 평형                        A4.7.1 System Equilibration
#
# 이온 크로마토그라프를 켜고 그럼 4ㅅ4.1에서의        Turn on ion chromatograph and adjust eluant flow rate
# 분리상태에 근접하도록 용리제 유량을 조절한다      to approximate the separation achieved in Fig. A4.1 (2 to
# (2~3 mL/min.). A27)S 원하는 값으로 조절하고       3 mL/min). Adjust detector to desired setting (usually 10 1
# (통상 10 12780) 시스템이 평형상태가 되도록 한다      mho) and let system come to equilibrium (15 to 20 min).
# (15~20분). 기준선의 안정은 시스템의 평형을 의미       A stable base line indicates equilibrium conditions.
# 한다. 용리제 전도도가 0이 되도록 검출기 오프셋       Adjust detector offset to zero-out eluant conductivity with
# (offset)을 조절하고 재생유량은 Sr 25~3     the fiber suppressor adjust the regeneration flow rate to
# mL/min2] Stags 유지하도록 섬유질 억제기를       maintain stability, usually 2.5 to 3 mL/min.
#
# 1547
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:21:55 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 12 ---
# MEN(2020°2° 판)                                                                                  MEN(2020 Ed.)
# (20220 +S]
#
#
#
# [2022 Add.]
# 조절한다.
# Minutes
# FIG. A4.1 TYPICAL ANION PROFILE
# &4.7.1.1 제조자의 지침에 따라 이온 크로마토그라    A4.7.1.1 Set up the ion chromatograph in accordance
# 프를 설정한다.                                                     with the manufacturer's instructions.
# A4.7.2 Wd                                   A4.7.2. Calibration
# 단일 음이온을 가진 표준용액이나 혼합용액을 주       Inject standards containing a single anion or a mixture
# 입하고 대략적인 유지시간을 결정한다. 관찰시간은    and determine approximate retention times. Observed
# 조건에 따라 변하지만 표준 용리제와 음이온 분리    times vary with conditions but if standard eluant and
# 기를 사용할 경우에는 F2lAZte a4 F, Cl,     anion separator column are used, retention always in the
# NOz, PO,?, Br, NO; & SO, 순서가 된다. =|     order F, Cl, NOx PO,*, Br, NO3, and SO,”. Inject at
# 정하고자 하는 각 음이온의 농도가 다른 3개 이상     least three different concentrations for each anion to be
# 1548
#
# Copyrighted mater ial
#
# licensed to deepai0915 on 2025.6.16 15:21:56 for license's use only.
#
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 13 ---
# MEN(202014
# [202244 A=]
#
# 그리고 1차선
# (peak) = ©] U4}
#
# 검출기의
#
# J
#
# * 겼
#
# Aza
#
# NOs
#
# m
# »
#
# 0
#
# 5
# oN
#
# oO
#
# Le
# no
# ro
# ox
#
# At nm 픈
# x (‘lo 1
#
# ro
#
# 프
# of     4S
#
# =
# +r
#
# 전도도
#
# 시료내의 물의     가 용리
# 다(용리제는 물로 희석한다.).
#
# 에 대해 직선성이 확립되
# 끄정이 허용된다. 교정계
#
# Ww   oO
# 또는 구역 및 유
#
# A4.7.2.1
# 면 단
#
# oO]
# 그
#
# 구
# > illo
#
# ~
# 7 fo w
#
# =f
#
# bx]
#
# Ja
#
# A
# 개 >
# »
#
# =
# Ertl
#
# cw
#
# x=
#
# 그
#
# ro,
#
# 4 0.1 mL 시
# . 이온 크로마토그라
# (1030)모드에서 주입(101600모드로 바꾸고
# 기록기에    높이와 유지시간을 기록한다.
# 정점(60《 )이 나타나고 전도
# 으로 복귀하면 다른 시
# 4&4.7.4 재생
# 섬유질 억제기가 없는 시스템은 억제기가
# 상태에서 전도도 기준선이 300 17130를 초과할
# 우 제조자의 권고에 따라 1 지의 11280/로 재
#
# 우
#
# LE 세 (일 세
# ,. 00
# 3 -N
#
# (그
#
# 트           정점
#
# Zz
#
# a:
# ㅇ
#
# a
#
# aLa
#
# 어느
#
# HA
# ~A
# Ww
#
# Copyrighted mater ial
#
# 1549
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# measured and construct a calibration curve by plotting
# peak height or area against concentration on linear graph
# paper. Recalibrate whenever the detector setting is
# changed. With a system requiring suppressor regeneration,
# NOz
#
# erroneous NO, results; make this determination only
#
# interaction with the suppressor may lead to
#
# when the suppressor is at the same stage of exhaustion as
# during standardization or recalibrate frequently. In this
# type of system the water dip (see Note A4.6) may shift
# slightly during suppressor exhaustion and with a fast run
# column this may lead to slight interference for F or CI.
# To eliminate this interference, analyze standards that
# bracket the expected result or eliminate the water dip by
# diluting the sample with eluant or by adding concentrated
# eluant to the sample to give the same HCO3/CO;”
# concentration as in the eluant. If sample adjustments are
#
# made, adjust standards and blanks identically. Both
#
# calibration and calculation of results may be performed
# either manually or via use of a computer and appropriate
# software.
#
# NOTE A4.6 Water dip occurs because water conductivity in sample is
#
# less than eluant conductivity (eluant is diluted by water).
#
# A4.7.2.1
#
# setting, it is acceptable to calibrate with a single standard.
#
# If linearity is established for a given detector
#
# Record the peak height or area and retention time to permit
# calculation of the calibration factor, F.
# A4.7.3 Sample Analysis
#
# Remove sample particuates, if necessary, by filtering
# through a prewashed 0.m-porediam membrane filter.
# Using a prewashed syringe of 1 to 10 mL capacity
# equipped with a male luer fitting inject sample or
# standard. Inject enough sample to flush sample loop
# several times: for 0.1 mL sample loop injetion. at least
# ImL. Switch ion chromatograph from inject mode and
# record peak heights and retention on strip chart recorder.
# After the last peak (SO,7) has appeared and the
# conductivity signal has returned to base line, another
# sample can be injected.
# A4.7.4 Regeneration
#
# For systems without fiber suppressor regenerate with 1
# 제 - 8290"
#
# instructions when the conductivity base line
#
# in accordance with the manufacturer's
#
# exceeds
#
# licensed to deepai0915 on 2025.6.16 15:21:56 for license's use only.
#
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 14 ---
# MEN(202014 판)
# [2022년  수록]
#
# 킨다.
#
# 44.8 계산
# &4.8.1 해당     Tl
# ES me/L dae A
# 선성(1차식)을 나타내면
#
# 차고
# 한다.
# 다음
#
# 교정곡선을
#
# Oo.
# 그
# 산
#
# A4.9 %
# A4.9.1
# 곳의 ^
#
# Copyrighted mater ial
#
# Copyrighted and Authorized by Korea Electric Association
#
# 의 식
#
# 하여 24
# 대안으로
#
# 1550
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# 300mho when the suppressor column is on line.
# A4.8 Calculation
#
# Calculate concentration of each anion, in mg/L, by
# the
#
# referring to
#
# appropriate calibration curve.
# Alternatively, when the response is shown to be linear,
#
# use the following equation:
#
# C=HxFxD
# where:
# C= mg anion/L,
# H = peak height or area,
# F = response factor-concentration of standard/height
# (or area) of standard, and
# D
#
# dilution factor for those samples requiring
# dilution.
#
# A4.9 Precision and Bias
#
# A4.9.1 Samples of reagent water to which were added the
#
# common anions were analyzed in 15 laboratories with the
#
# results shown in Table A4.2.
#
# licensed to deepai0915 on 2025.6.16 15:21:58 for license's use only.
#
# . Copying and networking prohibited.
#
#
# --- Page 15 ---
# MEN(202014 판)                                                           MEN(2020 Ed.)
# (202244 4S]                                                               [2022 Add.]
#
#
#
# TABLE A4.2 PRECISION AND ACCURACY OBSERVED FOR ANIONS
# AT VARIOUS CONCENTRATION LEVELS IN REAGENT WATER
#
# A       Amount Added, |} Amount Found,     Overall        Single-Operator     Signifiant Bias 95 %
# nion
# mg/L       mg/L    Precision, mg/L   Precision, mg/L        | ievel |
#
#
#
# 1501
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:21:58 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 16 ---
# MEN(20204 판)                                                             MEN(2020 Ed.)
# [20224 4S]                                                                   [2022 Add.]
#
# MEN B25          MEN B25
# 자분검사 채택표준      MAGNETIC
# PARTICLE
#
# EXAMINATION
#
# 1552
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:21:58 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 17 ---
# MEN(202014 판)
# [202244 A=]
#
# MEN B25 SD-1186
# 철강재료 모재에 적용된 비자성
#
# 코팅의 건식필름 두께에 대한
# 비파괴측정 표준시험법
#
# 1 이 시험법은 상업적으로 유용한 시험장치를 사
# 용하여 철강재료 모재에 적용된 비자성코팅의 건식
# 필름 두께에 대한 비파괴 측정에 적용한다. 이 시
# AW] BBS Aol] ERAS YA asap
# 지침을 보충하기 위한 것이며, 이를 대체하고자 ㅎ
# 는 것이 아니다. 이 시험법은 오직 자기 측정원
#
# 방법을 제공한다.
#
# 1.2 이 시험법은 기기 탐촉자를 측정하고자 하는
# 코팅 표면에 직접 놓아야 하기 때문에 측정기기의
# 하중에 의해 쉽게 변형되는 코팅에 적용하지 않는
# 다.
# 1.
#
# 1.4 이 규격은 이 규격의 사용에 수반되는 모든 안
# SL
#
# 전성 문제를 다루는 것을
#
# 2.1 ASTM Standards
# ASTM D 609
# Practice for Preparation of Cold-Rolled
# Steel Panels for Testing Paint, Varnish,
# Related
#
# Conversion Coatings, and
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# ARTICLE 25 SD-1186
# STANDARD TEST METHODS FOR
# NONDESTRUCTIVE
# MEASUREMENT OF DRY FILM
# THICKNESS OF NONMAGNETIC
# COATINGS APPLIED TO A
# FERROUS BASE
#
# 1. Scope
#
# 1.1 These test methods cover the nondestructive
# measurement of the dry film thickness of nonmagnetic
# coatings applied over a ferrous base material using
# commercially available test instruments. The test methods
# are intended to supplement manufacturers’ instructions for
# the manual operation of the gages and are not intended to
# replace them. They cover the use of instruments based on
# magnetic measuring principles only. Test Method A
# provides for the measurement of films using mechanical
# magnetic pull-off gages and Test Method B provides for
# the measurement of films using magnetic electronic gages.
# 1.2 These test methods are not applicable to coatings that
# will be readily deformable under the load of the measuring
# instruments, as the instrument probe must be placed
# directly on the coating surface to take a reading.
# 1.3 The values given in SI units of measurement are to be
# regarded as the standard. The values in parentheses are for
# information only.
# 1.4 This standard does not purport to address all of the
# safety concerns, if any, associated with its use. It is the
# responsibility of the user of this standard to establish
# appropriate safety and health practices and determine the
# applicability of regulatory limitations prior to use.
# 2. Referenced Documents
# 2.1 ASTM Standards
#
# D 609 Practice for Preparation of Cold-Rolled Steel
#
# Panels for Testing Paint, Varnish, Conversion
#
# Coatings, and Related Coating Products
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:21:59 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 18 ---
# 판
#
# MEN(202014
#
# )
# [202244 A=]
#
# Coating Products
#
#
#
# ASTM D 823
# Practices for Producing Films _ of
# Uniform Thickness of Paint, Varnish,
# and Related Products on Test Panels
# 2.2 Steel Structures Painting Council Standard
# SSPC-PA2 Measurement of Dry Paint
# Thickness with Magnetic Gages
# AS A - AE7| SA (pull-off) 71] A]
# 3. 시험법의 개요
# 3.1 이 시험을 충족하는 기기는 비자성필름이 코팅
# 된 철강 모재로부터 자석을 당기기 위해 요구되는
# 힘을 결정하도록 교정된 스프링을 사용하여 필름
# 두께를 측정한다. 기기는 필름두께를 측정하기 우
# 해 코팅표면에 직접 놓여야 한다.
# 3.2 기면(뚜00)에 대한 자석의 인력은 적용 필름
# 두께에 반비례한다. 기면(500)에 대한 자석의 인력
# 을 극복하는데 요구되는 스프링의 장력은 기기 눈
# 금상에 자석과 기면 사이의 Ae] (mils 또는
# 011060009)로서 나타내진다.
# 4. 취지 및 적용
# 4.1 부착, 부식, 방식, 유연성 2 gus ge aye
# 많은 특성은 현저하게 건식필름 두께의 영향을 받는
# 다. 다른 운전자가 얻은 결과를 비교할 수 있도록 하
# 기 위해서는 필름두께를 아는 것이 필수적이다.
# 4.2 대부분의 보호 및 고성능 코팅은 건식필름 두
# 께 또는 완전한 시스템 또는 이 두 가지에 대한 요
# 건 또는 사양을 만촉하도록 적용된다. 코팅은 코팅
# 의 기대 성등을 충족하기 위해 어떤 최소 및 최대
# 두께 Ue ASsok tu. HAA BWeay
# 에 추가하여, 넓은 PAS 코팅할 때 필요 이상의
# 재료를 더 많이 적용하는 것은 비경제적이다. 이
# 시험법은 철강금속에 코팅된 필름두께를 측정하기
# 위해 사용된다.
# 5. 장치
# 5.1 코일 스프링에 직접 부착되거나 또는 헬리컬
# 스프링에 부착되는 수평 지랫대에 부착된 작은 영
#
# Copyrighted mater ial
#
# 1554
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# D 823 Practices for Producing Films of Uniform
# Thickness of Paint, Varnish, and Related
#
# Products on Test Panels
#
# 2.2 Steel Structures Painting Council Standard
# SSPC-PA2 Measurement of Dry Paint Thickness with
# Magnetic Gages
#
# TEST METHOD A- MAGNETIC PULLOFF GAGES
#
# 3. Summary of Test Method
#
# 3.1 Instruments complying with this test method measure
# thickness by using a spring calibrated to determine the
# force required to pull a magnet from a ferrous base coated
# with a nonmagnetic film. The instrument must be placed
# directly on the coating surface to take a reading.
#
# 3.2 The attractive force of the magnet to the substrate
# varies inversely with the thickness of the applied film. The
# spring tension required to overcome the attraction of the
# magnet to the substrate is shown on the instrument scale
# as the distance (in mils or microns) between the magnet
# and the substrate.
#
# 4. Significance and Use
#
# 4.1 Many coating properties are markedly affected by the
# thickness of the dry film such as adhesion, corrosion
# protection, flexibility, and hardness. To be able to
# compare results obtained by different operators, it 18
# essential to know film thickness.
#
# 4.2 Most protective and high performance coatings are
# applied to meet a requirement or a specification for the
# dry-film thickness of each coat, or for the complete
# system, or both. Coatings must be applied within certain
# minimum and maximum thicknesses to fill their expected
# function. In addition to potential performance
# deficiencies, it is uneconomical to apply more material
# than necessary when coating large areas. This test method
# is used to measure film thickness of coatings on ferrous
# metals.
#
# 5. Apparatus
#
# 5.1 Permanent Magnet, small, either attached directly to a
# coil spring (“pencil” gage) or to a horizontal lever arm
#
# that is attached to a helical spring (“‘dial-type” gage).
#
# licensed to deepai0915 on 2025.6.16 15:22:0 for license's use only.
#
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 19 ---
# 판
#
# MEN(202014
# [20224 4S]
#
# Ts
#
# LAAT (“dial-type” Alo] 4}). 첫 번째
# 프링을 팽창시키거나 또는 두
# ㅣ 감겨 wre] WA
# 자석에 적용한다.
#
# ㄴ
#
# )
#
# ㅇ
# 길스
#
# kt 10, by
#
# N
# —+
#
# a
#
# ~
#
# 사용시, 두께를
#
# 유사한 거칠기,
#
# 적용 가능한 시현 판넬
#
# ASTM D-609¢]] 7]
#
# 에
#
# ^
# ee
#
# be
#
# —
#
# HN
#
# 당
#
# 사자 사이의
#
# “ON
# 에
#
# 비
#
# or 20,
#
# ilo
#
# ia 우
# ro, rfl
#
# EJ oh
#
# of 1
#
# ™N
# cH, [| -오 18
#
# NJ
# 구디
#
# Olt
# ou
# &
# E| do
# ox, tho
#
# 5,
#
# 형태가 최상 및 가장
# 기술되어야 한다. 즉,
# 및 계약요건. 시험편
#
# 부록 ※1에 제공되어 있
#
# 2
#
# oF
# 에
# ~
# 전
# N
#
# 부르
#
# 게이
#
# ^
#
# 것
# oft!
# 고
#
# ~
#
# 때
# 16
# Ek
# oft!
# ox
# Lr
# to
#
# A
# ‘|r
# o®,
# ㅁ
# N
# ~
# 2
#
# 다.
#
# :
#
# 그
#
# |
#
# 비
#
# 예
#
# :
#
# 에
# gy
# Sot
#
# =
#
# ㅁ
# mi
#
# IN
# ox,
# om
# x»
#
# 에
# —+
#
# oh   ey   sr
#
# a 4
# [원
# 4
#
# O
#
# —/
#
# OW
# Hm
# MY
# rea
# dt
#
# ch
#
# Copyrighted mater ial
#
# 1555
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# Increasing force is applied to the magnet by extending the
# coil spring in the first case or turning a graduated dial that
# coils the helical spring in the second. The readings
#
# obtained are shown directly on the instrument scale.
#
# 5.2 Coating Thickness Standards, with assigned values
# traceable to national standards are available from several
# sources, including most manufacturers of coating
# thickness gages.
#
# 6. Test Specimens
#
# 6.1 When this test method is used in the field, the
# specimen is the coated structure or article on which the
# thickness is to be evaluated.
#
# 6.2 For laboratory use, apply the material to be tested to
# panels of similar roughness, shape, thickness, composition
# and magnetic properties on which it is desired to
#
# determine the thickness.
#
# NOTE 1 - Applicable test panel description and surface preparation
# methods are given in Practice D 609.
#
# NOTE 2 - Coatings should be applied in accordance with Practices D
# 823 or as agreed upon between the contracting parties.
#
# 7. Verification of Calibration of Apparatus
#
# 7.1 Different gage manufacturers follow different methods
#
# of calibration adjustment. Verify calibration according to
#
# manufacturer’s instructions.
#
# 7.2 The section of the type of standards used to verify
#
# calibration should be predicated upon which type provides
#
# the best and most appropriate calibration considering: type
#
# of gage, sample surface geometry, and _ contract
#
# requirements. Appendix X1 provides information helpful
#
# to making an informed selection of standards.
#
# 7.3 Following the manufacturer’s operating instructions,
#
# measure the thickness of a series of calibration standards
#
# covering the expected range of coating thickness. To
#
# guard against measuring with an inaccurate gage, recheck
#
# the gage at regular intervals. That interval should be set by
#
# agreement between contracting parties and maintained
#
# throughout the control process.
#
# NOTE 3 - Generally “Dial-type” instruments can be used in any
# position, while “pencil-type” instruments may be used in
# the vertical position only unless they have separate
# indicators for the horizontal and vertical positions. Follow
#
# the manufacturer’s recommendations.
#
# licensed to deepai0915 on 2025.6.16 15:22:1 for l|icense's use only.
#
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 20 ---
# MEN(202014 판)
# [2022년  수록]
#
# 8. 절차
# 8.1 반드시 7항에 따라 기기의 교정을 확인한 후에
# 기기를 사용한다.
#
# Leu  ㆍ       H att          i
# 게이지 측정에 영향을 미친다.
# 84 전기 또는 자기장이 없는 장수에서 읽는다.
#
# l(pull-off) 기
# 없어야 한다.
#
# N
#
# s               |를 사용할 때,
# 패망 장소이는 긴동이 §
# 8.5 측정의 정확도는 측정이 시료의 모서리 25
# 00000 10.)이내 또는 직각방향에서 이루어질때 영
# HS We 수 Ql
#
# 8.6 제작사의 지침에 따라 코팅을 측정한다.
#
# 00
# N
# 그,
# 그,
# 1°,
#
# ox,
# ㅇ
#
# ro a div
# 0
#
# 에
#
# —+
# (tlo   4o
# >
#
# 060
# po (HUN
# Se
# i AMR Ie 개
# (Hod pO EO
# El
# ont
# me py
# m 2
# 0
#
# [원
# ix 꾸 00 」윈
# jm *
#
# nl
#
# 측정시, 크기가 75 × 150 mm (3 × 6
# 대해 권장되는 최소 횟수는 3회이
# ;    는 크기에 비례하여 중가한다.
#
# 8.8.2 현장 측정의 경우, 권장되는 최소 횟수는 매
# 표면적 10 ㅠ(100 [“")당 무작위로 5회 결정이다. 5
# 회 결정의 각각은 직경 4 0204 (15 10.) 원내에서 3
# 개의 분리된 게이지 읽음치의 평균값이다.
#
# ne
# x
#
# Ir re
#
# 8.9 시험편의 어떠한 모서리 또는 구석으로부터 최
# 4.13 mm (1/2 in.) U4 KYA Sastry}. Yet
# 13 mm (1/2 1.)보다 더 가까운 곳에서 SAC] 필
# 요할 경우, 측정이 모서리에서 이루어지는 영향을
#
# an                                          ㅇ
#
# 확인한다.
#
# 비고 (4) : 또는 큰 구조물과 부드럽지 않은 표면의 측정횟수에
# 대한 추가 정보는 661(@`; 12&-2.을 참조한다
#
# 9. 보고서
#
# 9.1 다음의 정보를 보고한다.
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# 8. Procedure
#
# 8.1 Use the instrument only after calibration has been
# verified in accordance with Section 7.
#
# 8.2 Ensure that the coating is dry prior to use of the
# instrument.
#
# 8.3 Inspect the probe tip and surface to be measured to
# ensure that they are clean. Adherent magnetic filings or
# other surface contaminants will affect gage readings.
#
# 8.4 Take readings in locations free of electrical or
# magnetic fields. The location should also be free of
# vibration when using mechanical magnetic pull-off
# instruments.
#
# 8.5 The accuracy of the measurement can be influenced
# when made within 25 mm (1 in.) of the edge or right angle
# in the sample.
#
# 8.6 Measure the coating, following the manufacturer’s
# instructions.
#
# 8.7 Verify calibration periodically to ensure that the
# instrument continues to read properly. If the instrument is
# found to be out of adjustment, remeasure the thicknesses
# taken since the last satisfactory calibration check was
# made.
#
# 8.8 Take a sufficient number of readings to characterize
# the surface.
#
# 8.8.1 For laboratory measurements, a recommended
# minimum is three for a 75 by 150- mm (3 by 6-in.) panel
# and more in proportion to size.
#
# 8.8.2 For field measurements, a recommended minimum
# is five determinations at random for every 10m’(100 ft’) of
# surface area. Each of the five determinations should be the
# mean of three separate gage readings within the area of a 4
# cm (1.5 in.) diameter circle.
#
# ...
#
# heating/cooling, EDM notches, artificial discontinuities
#
# per 14.2.2 or other means.
# Warning : Notches are to be filled flush to the surface with a
# nonconducting material, such as epoxy, to prevent the
#
# mechanical holding of the indicating medium.
#
# 1628
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:23:19 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 88 ---
# MEN(202014 판)                                                                                 MEN(2020 Ed.)
#
# 00000 조타                                                                                                                                                      [2022 400.
# ㅣ                         62RHR
# i
# 기
# 변 《.
# E zi                              254.0 mm(10 ") SE
# ~ 때
#
# ㅠㅠ    규정된 치수
#
# 254.0 0000(10 ") 또는
# 규정된 치수
#
#
#
# 그림 13 자분성능 확인판 견본. 확인판의 제작자 사양에 따라 결함을 만들어 위치시킨다.
#
# 254.0 mm(10 “) or
#
# |                                  as specified
#
# 2.54 mmf “) or
# as specified
#
# 254.0 mm(1L0 “) or
# as specified
#
#
#
# FIG. 13 SAMPLE OF A MAGNETIC PARTICLE PERFORMANCE VERIFICATION PLATE. DEFECTS ARE
# FORMED AND LOCATED IN ACCORDANCE WITH PLATE MANUFACTURERS’ SPECIFICATIONS
#
# 1624
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:23:20 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 89 ---
# 판
#
# MEN(202014 판)
# [202244 A=]
#
# =
#
# 20.8.4
#
# ts
#
# LL
#
# A| BH (test ring specimen)
#
# 인(ㄷ6608) 링시험편은 중심도체 자화법을
#
# 및    , 형광 및 비형광 자분기법의
# 도를 평가하기 위해 사용된다.
#
# xX
#
# 「
#
# =
#
# Al
#
# Le
# 스  2a
# ㄱ  =
#
# O
#
# 위
#
# Zz
#
# Le
#
# ——
#
# ㅇ
#
# 보
#
# oO         ㅁ20   1"
# ^
#
# Le
#
# »
#
# 3}
# 건
# ]
#
# ofp
#
# py
# NI
#
# q
#
# 3
# al  ㄴ
#
# —
#
# ㄴ
#
# yh pe
# 전
#
# 인
#
# ㄴㄴ
#
# 7
#
# }
#
# {fl
# ~]
#
# 4
#
# ㅇ
#
# 20.8.4.1 링시험편의 사용
# 추가적인 정보는 부록 ※7을
# 20.8.5 자장지시계
# 20.8.5.1 파이 자장지시계
# 그림 14의 자장지시게는 외부 자장의 존재 및 대
# 략적인 방향을 파이 형태의 조각사이에 있는 슬롯
# (81018)에 의해 나타낸다. 파이 자장지시계는 100%
# 관통벽      가진    투자율 재료로 만들어지
# 기 때   지시계에 나타나는 지시는 검사대
#
# 품에
#
# uM
#
# 조한다.
#
# LL
#
# ~
#
# lL
#
# 노으
#
# ye Le
#
# 그
#
# ~
#
# Le
# lL
#
# A}
#
# Copyrighted mater ial
#
# 1625
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# 20.8.4 Test Ring Specimen
#
# A verification (Ketos) ring specimen may also be used
# in evaluating and comparing the overall performance and
# sensitivity of both dry and wet, fluorescent and
# non-fluorescent magnetic particle techniques using a
# central conductor magnetization technique. Refer to
# Appendix X7 for further information.
# 20.8.4.1 Using the Test Ring
#
# See Appendix X7 for further information.
# 20.8.5 Magnetic Field Indicators
# 20.8.5.1 "Pie" Field Indicator
#
# The magnetic field indicator shown in Fig. 14 relies on
# the slots between the pie shaped segments to show the
# presence and the approximate direction of the external
#
# field
# constructed of highly permeable material with 100%
#
# magnetic field. Because “pie”      indicators are
# through wall flaws, indications do not mean that suitable
# field strength is present for the location of relevant
# indications in the part under examination. The “pie” field
# indicator is used with the magnetic particles applied
# across the copper face of the indicator (the slots are
# against the piece) simultaneously with the magnetizing
# force. Typical “pie” field indicators show a clear
# indication in a five gauss external field. These devices are
#
# generally used as instructional aids.
#
# licensed to deepai0915 on 2025.6.16 15:23:20 for license's use only.
#
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 90 ---
# MEN(202014_ 판)                                                             MEN(2020 Ed.)
# (202240 추록]                                                                   [2022 Add._]
#
# 8개 저탄소강파이 단편
# 노내 브레이징에 의해 듯편의 구리판과
#
# 228
#
#
#
#
#
#
#
#
#
#
# 대표석으로
# 0.079 cm
# (1/32 in.)
#
# 1,92~2.54 cm
# (4-1 in.)
#
# 그림 14 자장지시계
#
# Eight Low Carbon Steel Pie Sections
# Furnace Brazed Together with Copper Back Panel
#
#
#
#
#
# (1.91-2.54 cm)                                           Nonferrous Handle of
#
# Convenient Length and Shape
#
# Nonferrous Trunnions
#
# FIG. 14 MAGNETIC FIELD INDICATOR
#
# 1626
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:23:21 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 91 ---
# ee     판)
# [2022년 주록]
#
# 20.8.5.2 SE + (slotted shims)
#
# 여러 형태의 슬롯 심이 존재한다. 48 5371 및 부
# 록 ※2의 실 예를 참조한다.
#
# 21. 절차서
#
# 21.1 자분탐상
#
# ALA
# 해야 하며 최소한 다음 사항을 포함하여야 한다.
# 부품의 기하학적 모양, 자화방법, 부품검사 면적을
# 설명하기 위해 항상 스       ©
#
# AAAS AA SA 시험편의 위치와 불연속의 위
# 치를 기록하는 데
#
# 21.1.1 검사한 면적 (특수한 지역의 전체부품)
# 21.1.2 자분재료의 유형(건식 또는 습식, 가시성 또
# 는 형광)
#
# 21.1.3 자화장치
#
# 21.1.4 부품표면 처리요건
# 21.1.5 자화공정(연속법, 실제연속법, 잔류법)
#
# 21.1.6 자화전류(교류, 반파 정류교류, 전파 정류교
#
# 21.1.7 부품자화 설정방법 (직접 프로드, 헤드 접촉
# 또는 케이블 랩, 간접 코일/케이블 랩, 요크, 중심
#
# 21.1.9 시스템 성능/감도 점검
# 21.1.10 자장세기 (암페아 턴,
# 화전류의 적용시간과 횟수
#
# 자속밀도, 자화력, 자
#
# 2
#
# 21.1.11 검사액
# 21.1.12 지 ^
# 21.1.13 합격기준을 포함한 기록의 형태
# 21.1.14 탈자법
# 21.1.15 검사후
# 21.2 보고서
#
# 보고서는 검사기관과 구매자 사이의 협의에 따라
# 작성하여야 한다.
#
# 22. 합격기준
# 22.1 이 규격에 따라 검사한 검사품의 합격기
# 공급자와 구매자간의 합의 또는 적용 기술기
#
# 으
# ㄴ
#
# 어
#
# sz
# Ww
# Ss
# VW
#
# —
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# 20.8.5.2 Slotted Shims
#
# Several types of slotted shims exist. Refer to AS 5371
# and to illustrations in Appendix X2.
# 21. Procedures
# 21.1. When specified a procedure should be written for
# all magnetic particle examinations and should include as a
# minimum the following information. A sketch is usually
# used for illustrating part geometry, techniques, and areas
# for examination. This sketch may also be used for
# recording location of magnetic field indicators and for
# recording location of discontinuities.
# 21.1.1 Area to be examined (entire part or specific area),
# 21.1.2 Type of magnetic particle material (dry or wet,
# visible or fluorescent),
# 21.1.3 Magnetic particle equipment
# 21.1.4 Part surface preparation requirements,
# 21.1.5 Magnetizing process (continuous, true-continuous,
# residual),
# 21.1.6 Magnetizing current (alternating, half-wave
# rectified AC, full-wave rectified AC, direct),
# 21.1.7 Means
#
# (direct-prods,
#
# of establishing part magnetization
# head/tailstock contact or cable wrap,
# indirect- coil/cable wrap, yoke, central conductor, and so
# forth),
# 21.1.8 Direction of magnetic field (circular or
# longitudinal),
# 21.1.9 System performance/sensitivity checks,
# 21.1.10 Magnetic field strength (ampere turns, field
# density, magnetizing force, and number and duration of
# application of magnetizing current),
# 21.1.11 Application of examination media,
# 21.1.12 Interpretation and evaluation of indications,
# 21.1.13 Type of records including accept/reject criteria,
# 21.1.14 Demagnetizing techniques, if required, and
# 21.1.15 Post-examination cleaning, if required,
# 21.2 Written Reports
#
# Written reports shall be prepared as agreed upon
# between the testing agency/ department and _ the
# purchaser/user.
# 22. Acceptance Standards
# 22.1 The acceptability of parts examined by this method
#
# is not specified herein. Acceptance standards are a matter
#
# 1627
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:23:21 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 92 ---
# MEN(202014 판)
#
# [2022년 추록]
# 따른다.
# 23. 안전
# 23.1 수동 자분탐상검사는 다음의 위험이
# 23.1.1 전기감전과 화상
#
# 전기회로의 단락은 감전을 유발할 수 있고 상대
# 적으로 저전압이면서 고전류일 때 화상의 위험이
# 있다. 물 현탁액을 취급하는 장치는 접지가 잘
# 어    야 한다.
# 23.1.2 자분의 비산
#
# 자분(특히 건식자분), 먼지, 모래, 녹, 밀 스케일
# 이 눈이나 귀에 들어갈 수 있다. 부품을 불어낼 때,
# 수직 또는 위보기 표면에 적용할 때 또는 압축공기
# 로 검사표면을 세척할 때 그러하다. 건식자분은 들
# 이마시기 쉬우므로 마스크의 사용이 권고된다.
# 23.1.3 낙하
#
# 야외 또는 공장내의 대형 구조물 위에서 검사 시
# 발판이나 계단으로부터의 낙하.
# 23.1.4 화재
#
# 유 액조의 인화.
#
# 23.1.5 환경
#
# 석유화학공장이나 정유공장처럼 인화성 증기가
# 있는 곳에서의 자분탐상검사 수행. 수중작업은 그
# 자체가 위험이 있다.
# 23.1.6 젖은 바닥
#
# 자분현탁액으로 젖어있어 미끄러운 바닥
# 23.1.7 대형 기기의 이동 또는 낙하 위험
#
# 대형 기기, 특히 임시 지지물 위에 있는 기기는
# 검사 중에 이동시키거나 들어 올리는 동안에 낙하
# 의 위험이 있다. 또한 체인이나 물건들 사이에 Al
# 체 일부가 끼어 다치는 것을 주의해야 한다.
# 23.1.8 자외선 노출
#
# 자외선은 눈과 피부에 해로울 수도 있다. 고강도
# 자외선등을 사용할 경우 자외선을 흡수하도록 설계
# 된 보안경 착용이 권고된다.
#
# Copyrighted mater ial
#
# 1628
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# of agreement between the manufacturer and the purchaser
#
# and should be stated in a_ referenced contract,
# specification, or code.
# 23. Safety
#
# 23.1 Those involved with hands-on magnetic particle
# examination exposure to hazards include:
# 23.1.1 Electric Shock and Burns
#
# Electric short circuits can cause shock and particularly
# burns from the high amperages at relatively low voltages
# that are used. Equipment handling water suspensions
# should have good electrical grounds.
# 23.1.2 Flying Particles
#
# Magnetic particles, particularly the dry ones, dirt,
# foundry sand, rust, and mill scale can enter the eyes and
# ears when they are blown off the part when applying them
# to a vertical or overhead surface or when cleaning an
# examined surface with compressed air. Dry particles are
# easy to inhale and the use of a dust respirator is
# recommended.
# 23.1.3 Falls
#
# A fall from a scaffold or ladder if working on a large
# structure in the field or shop.
# 23.1.4 Fire
#
# Ignition of a petroleum distillate bath.
# 23.1.5 Environment
#
# Doing magnetic particle examination where flammable
# vapors are present as in a petrochemical plant or oil
# refinery. Underwater work has its own set of hazards.
# 23.1.6 Wet Floors
#
# Slipping on a floor wetted with a particle suspension.
# 23.1.7 Shifting or Dropping of Large Components
#
# Large components, especially those on temporary
# supports, can shift during examination or fall while being
# lifted. In addition, operators should be alert to the
# possibility of injury to body members being caught
# beneath a sling/chain or between head/tail stock and the
# piece.
# 23.1.8 Ultraviolet Light Exposure
#
# Ultraviolet light can adversely affect the eyes and skin.
# Safety goggles designed to absorb UV _ wavelength
# radiation are suggested where high intensity blacklight is
#
# used.
#
# licensed to deepai0915 on 2025.6.16 15:23:22 for license's use only.
# Copyrighted and Authorized by Korea Electric Association.
#
# Copying and networking prohibited.
#
#
# --- Page 93 ---
# 판
#
# MEN(202014
#
# )
# [202244 A=]
#
# 23.1.9 We 및 농축액
#
# 자분과 농축액의 안전한 취급은 공급자의 재료안
# 전성데이터시트)(548108)에 따라야 한다. 환경부의
# 유해화학물질관리법에 따르거나 또는 공급자가 동
# 등 재료안전성데이터시트를 사용자에게 제공해야
# 하며 관련 규정에 따라 작성되어야 한다.
# 24. 정밀도 및 편차
# 24.1 이 기술기준에 설명된 방법론은 검출하고자
# 하는 불연속에 대해 자장이 적절한 방향을 가질 경
# 우에 재현 가능한 결과를 얻을 수 있다
# 24.2 검사대상 재료의 표면상태, 재료의 자기특성,
# 모양 및 얻어지는 결과에 영향을 주는 20.1 4S
# 된 인자의 제어를 인식해야 한다.
#
# 25. 주요용어((6\000105)
# 25.1 염색(0576),                                    비파괴검사
# (examination), @&-(fluorescent), 74A}(inspection),
#
# 4] 3} +] (nondestructive),
#
# 34 7} (evaluation),
#
# z}+4 (magnetic particle),
#
# A] 4 (testing)
#
# Go}E|AIE : Material safety data sheet(MSDS)
#
# Copyrighted mater ial
#
# 1629
#
# MEN(2020 Ed.)
# [2022 Add.]
#
# 23.1.9 Materials and Concentrates
#
# The safe handling of magnetic particles and concentrates
# are governed by the supplier’s Material Safety Data
# Sheets (MSDS). The MSDS conforming to 29 CFR
# 1910.1200 or equivalent must be provided by the supplier
# to any user and must be prepared in accordance with
# FED-STD-313.
# 24. Precision and Bias
# 24.1 The methodology described in the practice will
# produce repeatable results provided the field has the
# proper orientation with respect to the discontinuities being
# sought.
# 24.1 It must be recognized that the surface condition of
# the material being examined, the material’s magnetic
# properties, its shape, and control of the factors listed in
# 20.1 influence the results obtained.
# 25. Keywords
# 25.1 dye; evaluation; examination; fluorescent; inspection;
#
# magnetic particle; nondestructive; testing
#
# licensed to deepai0915 on 2025.6.16 15:23:24 for license's use only.
#
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 94 ---
# MEN(202014 판)                                                                                 MEN(2020 Ed.)
#
# [2022 4S]                                                                   [2022 Add]
# 부록                                         ANNEX
# 의무요건                                      (Mandatory Information)
# Al, CHEMO! ARE ALA                  Al. TYPICAL MAGNETIC PARTICLE INDICATIONS
# A11 24 예외적인 경우를 제외하고는 표면 불연     A1.1 Surface discontinuities with few exceptions produce
# 속은 예리하고 명확한 자분지시를 나타낸다. 반면     sharp 800 distinct magnetic particle indications.
# 에 표면직하 불연속은 표면 불연속보다 명확하지    Near-surface discontinuities on the other hand produce
# 않고 모호한 자분지시를 나타내며, 이때의 자분지    less distinct or fuzzy magnetic particle indications in
# 지는 예리하기 보다는 광범위하고, 자분의 분포가     comparison to surface discontinuities; the magnetic
# SE SA) STH.                                    particle indications are broad rather than sharp and the
# particles are less tightly held.
# A1.2 e413                             A1.2_ Wet Method
# 41.2.1 형광법 : 표면균열의 지시, 표면 지시 그리       A1.2.1 Fluorescent : Indications of surface cracks, surface
# aL 34S SASS 2H All ~ Al6y 같다.      indications, and an indication of a 17687 surface
# discontinuity are shown in Figs. Al.1 - Al.6.
# 4&1.2.2 비형광법 : 표면균열의 지시는 그림 ㅅ1.7    A1.2.2 Nonfluorescent : Indications of surface cracks are
# ~ ㅅ1.16과 같다.                                     shown in Figs. Al.7- Al.16.
# 4&1.3 건식법 : 표면균열의 지시는 그림 41.17 ~    Al1.3. Dry Method : Indications of surface cracks are
# &1.23과 같다.                              shown in Figs. ㅅ1.17 - ㅅ1.23.
# A1.4 무관지시는 그림 41.24 ~ ㅅ1.26과 같다.        A1.4 Nonrelevant indications are shown in Figs. Al1.24 -
# Al.26.
# 1630
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:23:24 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 95 ---
# MEN(20204 판)                                                             MEN(2020 Ed.)
# [20224 4S]                                                                   [2022 Add.]
#
#
#
# 12 A1.1 SQ) 7H (Ghoulder)o] AHS PAS 7A WSS
#
#
#
# FIG. Al.l AXLE WITH CIRCUMFERENTIAL CRACK IN SHOULDER
#
# 1631
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:23:25 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 96 ---
# MEN(20204 판)                                                             MEN(2020 Ed.)
# [20224 4S]                                                                   [2022 Add.]
#
#
#
# FIG. Al.2 ARM WITH TWO LONGITUDINAL INDICATIONS
#
# 1632
#
#
# --- Page 97 ---
# MEN O02 도  판)                                                                                  MEN(2020 Ed.)
# (20220 4S]                                                                           [2022 Add.]
#
#
#
# Se 0
# Eee ai OSS ay
#
# 그림 41.3 방사 및 축방향 지시를 가진 허브01406)
#
#   —                    yet. fr  es  Ma tt = ‘ ‘  ;       By. ees
#
#
#
# FIG. Al.3 HUB WITH BOTH RADIAL AND LONGITUDINAL INDICATIONS
#
# 1638
#
# Copyrighted material licensed to deepai0915 on 2025.6.16 15:23:25 for license's use only.
# Copyrighted and Authorized by Korea Electric Association. Copying and networking prohibited.
#
#
# --- Page 98 ---
# MEN(202014_ 판)                                                             MEN(2020 Ed.)
# (202240 추록]                                                                   [2022 Add._]
#
#
#
# FIG. Al.4 CRANKSHAFT WITH VARIOUS LONGITUDINAL INDICATIONS
#
# 1634
#
#
# --- Page 99 ---
# MEN(20204 판)                                                             MEN(2020 Ed.)
# [20224 4S]                                                                   [2022 Add.]
#
#
#
# |r
#
# 그림 41.5 스템(6600)에 지시를 가진 2
#
# fl
#
#
#
# FIG. Al.5 VALVE WITH INDICATION ON THE STEM
#
# 1635
#
#
# --- Page 100 ---
# MEN(20204 판)                                                             MEN(2020 Ed.)
# [20224 4S]                                                                   [2022 Add.]
#
#
#
#
#
# FIG. Al.6 YOKE SHOWING BALANCED QQIs
#
# 1636
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
